# %%
#####################
## Litecoin (LTC)  ##
#####################

# %%
# !pip install pyts
# !pip install tensorflow
# !pip install numpy
# !pip install pandas

# %%
#################
### Libraries ###
#################

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from pyts.image import GramianAngularField, MarkovTransitionField
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, LSTM, Dense, Flatten, Concatenate
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam, RMSprop

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Set 3 seeds and record the model performance for each : 42, 45, 91
# Best seed 91
tf.random.set_seed(91)
np.random.seed(91)

# %%
#################
###   Data    ###
#################

litecoin = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LTC_noscale.csv')
litecoin.drop(columns=['Crypto', 'Open', 'High', 'Low'], inplace=True)
litecoin.head()
# Out:
#          Date   Close
# 0  2018-01-01  225.63
# 1  2018-01-02  254.60
# 2  2018-01-03  243.00
# 3  2018-01-04  240.00
# 4  2018-01-05  240.45

# %%
########################
#### Input GAF/MTF  ####
########################

ltc = litecoin.iloc[:]

# ------------
# Parameters
# ------------
window_size = 224     # timesteps per sample
image_size = 224      # size for GAF/MTF images
train_ratio = 0.65    # training ratio
val_ratio = 0.10      # validation ratio


# ----------------------
# Step 1 — Normalization
# ----------------------
scaler = MinMaxScaler(feature_range=(0, 1))
ltc['close_scaled'] = scaler.fit_transform(ltc[['Close']])

# ---------------------------------
# Step 2 — Generate sliding windows
# ---------------------------------
def create_sequences(series, window_size):
    X_seq = []
    y = []
    for i in range(len(series) - window_size):
        X_seq.append(series[i:i+window_size])
        y.append(series[i+window_size])  # predict next value
    return np.array(X_seq), np.array(y)

X_seq, y = create_sequences(ltc['close_scaled'].values, window_size)

# ---------------------------------
# Step 3 — GAF & MTF for CNN branch
# ---------------------------------
gasf = GramianAngularField(image_size=image_size, method='summation')
gadf = GramianAngularField(image_size=image_size, method='difference')
mtf = MarkovTransitionField(image_size=image_size)

# Apply transforms to each sequence
X_gasf = gasf.fit_transform(X_seq)
X_gadf = gadf.fit_transform(X_seq)
X_mtf = mtf.fit_transform(X_seq)

# Stack into channels: (samples, H, W, 3)
X_cnn = np.stack((X_gasf, X_gadf, X_mtf), axis=-1)

# --------------------------
# Step 4 — LSTM branch input
# --------------------------
# LSTM expects shape: (samples, timesteps, features)
X_lstm = X_seq.reshape((X_seq.shape[0], X_seq.shape[1], 1))

# %%
# -------------------------------
# Step 5 — Train/Test split
# -------------------------------
n_samples = len(X_seq)
train_end = int(n_samples * train_ratio)
val_end = train_end + int(n_samples * val_ratio)

X_cnn_train, X_cnn_val, X_cnn_test = X_cnn[:train_end], X_cnn[train_end:val_end], X_cnn[val_end:]
X_lstm_train, X_lstm_val, X_lstm_test = X_lstm[:train_end], X_lstm[train_end:val_end], X_lstm[val_end:]
y_train, y_val, y_test = y[:train_end], y[train_end:val_end], y[val_end:]

# -------------------
# Shapes check
# -------------------
print("CNN train shape:", X_cnn_train.shape)   # (samples, H, W, 3)
print("LSTM train shape:", X_lstm_train.shape) # (samples, timesteps, 1)
print("Targets train shape:", y_train.shape)
# Out:
# CNN train shape: (1139, 224, 224, 3)
# LSTM train shape: (1139, 224, 1)
# Targets train shape: (1139,)

# %%
################
##### CNN  #####
################

# ------------------------
# Step 1 — Build Input CNN
# ------------------------
cnn_input = Input(shape=(224, 224, 3))
dropout_rate = 0.29145153405423596
activation_func = 'relu'

# --------------------------------------------
# Step 2 — Build VGG16 Model (pre-trained CNN)
# --------------------------------------------

vgg = VGG16(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)

# ----------------------------------
# Step 3 — Convolution/Pooling/Dense
# ----------------------------------

# Conv2D 128-64, Flatten, Dense(128)
x = vgg(cnn_input)
x = layers.Conv2D(128, (2, 2), activation=activation_func)(x)
x = layers.Conv2D(64, (2, 2), activation=activation_func)(x)
x = layers.Flatten()(x)
x = layers.Dropout(dropout_rate)(x)
x = layers.Dense(128, activation=activation_func)(x)
cnn_out = x

# ---------------------------
# Step 4 — Input LSTM
# ---------------------------

# Parameters
act_func = 'tanh'
n_timesteps = X_lstm_train.shape[1]
n_features = X_lstm_train.shape[2]

# ---------------------------
# Step 5 — LSTM structure
# ---------------------------

lstm_input = Input(shape=(n_timesteps,n_features))
y = LSTM(64, return_sequences=True, activation='tanh')(lstm_input)
y = LSTM(16, return_sequences=True, activation='tanh')(y)
y = LSTM(2, return_sequences=False, activation='tanh')(y)
lstm_out = y


# ---------------------------
# Step 6 — Concated O/P
# ---------------------------
combined = Concatenate()([cnn_out, lstm_out])
output = Dense(1, activation='linear')(combined)


# ----------------------------------
# Step 7 — Compile Model/Regression
# ----------------------------------
optimizer_func = RMSprop(learning_rate=0.0004047368844376192)
model = Model(inputs=[cnn_input, lstm_input], outputs=output)
model.compile(loss='mean_squared_error', optimizer=optimizer_func, metrics=['mae', RootMeanSquaredError(), 'mape'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
# --------------------
# Step 8 — Training
# --------------------

history = model.fit([X_cnn_train, X_lstm_train], y_train,
                   epochs=150, batch_size=64,
                    validation_data=([X_cnn_val, X_lstm_val], y_val),
                   verbose=2)
# Out:
# Epoch 1/150
# 18/18 - 25s - 1s/step - loss: 8.1665 - mae: 1.1514 - mape: 277718.1562 - root_mean_squared_error: 2.8577 - val_loss: 0.0740 - val_mae: 0.2406 - val_mape: 58.5119 - val_root_mean_squared_error: 0.2721
# Epoch 2/150
# 18/18 - 2s - 137ms/step - loss: 0.0374 - mae: 0.1469 - mape: 52252.0312 - root_mean_squared_error: 0.1935 - val_loss: 0.0569 - val_mae: 0.2004 - val_mape: 46.8486 - val_root_mean_squared_error: 0.2385
# Epoch 3/150
# 18/18 - 2s - 136ms/step - loss: 0.0359 - mae: 0.1412 - mape: 103501.5938 - root_mean_squared_error: 0.1896 - val_loss: 0.0721 - val_mae: 0.2378 - val_mape: 58.1431 - val_root_mean_squared_error: 0.2684
# Epoch 4/150
# 18/18 - 2s - 136ms/step - loss: 0.0229 - mae: 0.1070 - mape: 51959.0352 - root_mean_squared_error: 0.1513 - val_loss: 0.0460 - val_mae: 0.1666 - val_mape: 37.0627 - val_root_mean_squared_error: 0.2144
# Epoch 5/150
# 18/18 - 2s - 135ms/step - loss: 0.0249 - mae: 0.1129 - mape: 140670.3906 - root_mean_squared_error: 0.1579 - val_loss: 0.0594 - val_mae: 0.2153 - val_mape: 52.4325 - val_root_mean_squared_error: 0.2438
# Epoch 6/150
# 18/18 - 2s - 136ms/step - loss: 0.0175 - mae: 0.0931 - mape: 73674.2734 - root_mean_squared_error: 0.1322 - val_loss: 0.0398 - val_mae: 0.1685 - val_mape: 39.7297 - val_root_mean_squared_error: 0.1995
# Epoch 7/150
# 18/18 - 2s - 136ms/step - loss: 0.0140 - mae: 0.0830 - mape: 35237.7852 - root_mean_squared_error: 0.1185 - val_loss: 0.0497 - val_mae: 0.1938 - val_mape: 46.7226 - val_root_mean_squared_error: 0.2230
# Epoch 8/150
# 18/18 - 2s - 136ms/step - loss: 0.0116 - mae: 0.0731 - mape: 38364.8008 - root_mean_squared_error: 0.1077 - val_loss: 0.0438 - val_mae: 0.1639 - val_mape: 36.6511 - val_root_mean_squared_error: 0.2093
# Epoch 9/150
# 18/18 - 2s - 136ms/step - loss: 0.0917 - mae: 0.2038 - mape: 119883.4922 - root_mean_squared_error: 0.3029 - val_loss: 0.0234 - val_mae: 0.1181 - val_mape: 26.4999 - val_root_mean_squared_error: 0.1528
# Epoch 10/150
# 18/18 - 2s - 136ms/step - loss: 0.0095 - mae: 0.0643 - mape: 24188.4551 - root_mean_squared_error: 0.0977 - val_loss: 0.0214 - val_mae: 0.1156 - val_mape: 26.3851 - val_root_mean_squared_error: 0.1464
# Epoch 11/150
# 18/18 - 2s - 136ms/step - loss: 0.0297 - mae: 0.1084 - mape: 333529.4062 - root_mean_squared_error: 0.1723 - val_loss: 0.0254 - val_mae: 0.1216 - val_mape: 27.0196 - val_root_mean_squared_error: 0.1592
# Epoch 12/150
# 18/18 - 2s - 136ms/step - loss: 0.0077 - mae: 0.0611 - mape: 26274.0781 - root_mean_squared_error: 0.0878 - val_loss: 0.0113 - val_mae: 0.0779 - val_mape: 18.4009 - val_root_mean_squared_error: 0.1063
# Epoch 13/150
# 18/18 - 2s - 136ms/step - loss: 0.0090 - mae: 0.0654 - mape: 40496.8867 - root_mean_squared_error: 0.0948 - val_loss: 0.0133 - val_mae: 0.0849 - val_mape: 19.0597 - val_root_mean_squared_error: 0.1153
# Epoch 14/150
# 18/18 - 2s - 136ms/step - loss: 0.0059 - mae: 0.0527 - mape: 18386.3027 - root_mean_squared_error: 0.0769 - val_loss: 0.0083 - val_mae: 0.0662 - val_mape: 15.3336 - val_root_mean_squared_error: 0.0910
# Epoch 15/150
# 18/18 - 2s - 135ms/step - loss: 0.0065 - mae: 0.0557 - mape: 28983.1523 - root_mean_squared_error: 0.0808 - val_loss: 0.0083 - val_mae: 0.0660 - val_mape: 15.3917 - val_root_mean_squared_error: 0.0910
# Epoch 16/150
# 18/18 - 2s - 135ms/step - loss: 0.0052 - mae: 0.0495 - mape: 42739.1758 - root_mean_squared_error: 0.0719 - val_loss: 0.0099 - val_mae: 0.0772 - val_mape: 18.9098 - val_root_mean_squared_error: 0.0996
# Epoch 17/150
# 18/18 - 2s - 136ms/step - loss: 0.0102 - mae: 0.0661 - mape: 59953.5234 - root_mean_squared_error: 0.1011 - val_loss: 0.0070 - val_mae: 0.0615 - val_mape: 16.0999 - val_root_mean_squared_error: 0.0838
# Epoch 18/150
# 18/18 - 2s - 136ms/step - loss: 0.0039 - mae: 0.0423 - mape: 27963.4844 - root_mean_squared_error: 0.0623 - val_loss: 0.0074 - val_mae: 0.0639 - val_mape: 15.8505 - val_root_mean_squared_error: 0.0860
# Epoch 19/150
# 18/18 - 2s - 136ms/step - loss: 0.0028 - mae: 0.0381 - mape: 2500.4148 - root_mean_squared_error: 0.0530 - val_loss: 0.0101 - val_mae: 0.0794 - val_mape: 20.5615 - val_root_mean_squared_error: 0.1004
# Epoch 20/150
# 18/18 - 2s - 136ms/step - loss: 0.0036 - mae: 0.0427 - mape: 41329.5039 - root_mean_squared_error: 0.0599 - val_loss: 0.0101 - val_mae: 0.0795 - val_mape: 20.8571 - val_root_mean_squared_error: 0.1004
# Epoch 21/150
# 18/18 - 2s - 136ms/step - loss: 0.0019 - mae: 0.0312 - mape: 16711.2070 - root_mean_squared_error: 0.0441 - val_loss: 0.0108 - val_mae: 0.0849 - val_mape: 23.3115 - val_root_mean_squared_error: 0.1037
# Epoch 22/150
# 18/18 - 2s - 136ms/step - loss: 0.0030 - mae: 0.0380 - mape: 38551.9727 - root_mean_squared_error: 0.0547 - val_loss: 0.0101 - val_mae: 0.0820 - val_mape: 22.9759 - val_root_mean_squared_error: 0.1007
# Epoch 23/150
# 18/18 - 2s - 136ms/step - loss: 0.0020 - mae: 0.0324 - mape: 22281.2734 - root_mean_squared_error: 0.0448 - val_loss: 0.0101 - val_mae: 0.0818 - val_mape: 21.5207 - val_root_mean_squared_error: 0.1006
# Epoch 24/150
# 18/18 - 2s - 136ms/step - loss: 0.0032 - mae: 0.0383 - mape: 22372.2676 - root_mean_squared_error: 0.0565 - val_loss: 0.0109 - val_mae: 0.0832 - val_mape: 22.3854 - val_root_mean_squared_error: 0.1046
# Epoch 25/150
# 18/18 - 2s - 135ms/step - loss: 0.0034 - mae: 0.0381 - mape: 32863.3086 - root_mean_squared_error: 0.0580 - val_loss: 0.0099 - val_mae: 0.0791 - val_mape: 21.6625 - val_root_mean_squared_error: 0.0996
# Epoch 26/150
# 18/18 - 2s - 136ms/step - loss: 0.0017 - mae: 0.0283 - mape: 16386.0605 - root_mean_squared_error: 0.0408 - val_loss: 0.0098 - val_mae: 0.0781 - val_mape: 20.8276 - val_root_mean_squared_error: 0.0991
# Epoch 27/150
# 18/18 - 2s - 135ms/step - loss: 0.0017 - mae: 0.0288 - mape: 31797.2891 - root_mean_squared_error: 0.0409 - val_loss: 0.0100 - val_mae: 0.0795 - val_mape: 21.6896 - val_root_mean_squared_error: 0.1001
# Epoch 28/150
# 18/18 - 2s - 136ms/step - loss: 0.0012 - mae: 0.0248 - mape: 18595.5234 - root_mean_squared_error: 0.0345 - val_loss: 0.0111 - val_mae: 0.0820 - val_mape: 20.2604 - val_root_mean_squared_error: 0.1056
# Epoch 29/150
# 18/18 - 2s - 135ms/step - loss: 0.0014 - mae: 0.0269 - mape: 17752.8301 - root_mean_squared_error: 0.0373 - val_loss: 0.0099 - val_mae: 0.0783 - val_mape: 20.6217 - val_root_mean_squared_error: 0.0996
# Epoch 30/150
# 18/18 - 2s - 136ms/step - loss: 0.0012 - mae: 0.0238 - mape: 19880.1895 - root_mean_squared_error: 0.0340 - val_loss: 0.0107 - val_mae: 0.0809 - val_mape: 20.9503 - val_root_mean_squared_error: 0.1035
# Epoch 31/150
# 18/18 - 2s - 136ms/step - loss: 0.0014 - mae: 0.0260 - mape: 19469.8105 - root_mean_squared_error: 0.0368 - val_loss: 0.0100 - val_mae: 0.0795 - val_mape: 21.0094 - val_root_mean_squared_error: 0.1000
# Epoch 32/150
# 18/18 - 2s - 136ms/step - loss: 0.0011 - mae: 0.0235 - mape: 14161.4922 - root_mean_squared_error: 0.0332 - val_loss: 0.0100 - val_mae: 0.0779 - val_mape: 20.4413 - val_root_mean_squared_error: 0.0998
# Epoch 33/150
# 18/18 - 2s - 136ms/step - loss: 0.0012 - mae: 0.0249 - mape: 16600.2441 - root_mean_squared_error: 0.0352 - val_loss: 0.0098 - val_mae: 0.0779 - val_mape: 20.5438 - val_root_mean_squared_error: 0.0990
# Epoch 34/150
# 18/18 - 2s - 136ms/step - loss: 9.8085e-04 - mae: 0.0227 - mape: 8114.3862 - root_mean_squared_error: 0.0313 - val_loss: 0.0105 - val_mae: 0.0782 - val_mape: 19.5180 - val_root_mean_squared_error: 0.1023
# Epoch 35/150
# 18/18 - 2s - 136ms/step - loss: 0.0011 - mae: 0.0235 - mape: 11396.9541 - root_mean_squared_error: 0.0332 - val_loss: 0.0092 - val_mae: 0.0759 - val_mape: 20.3579 - val_root_mean_squared_error: 0.0957
# Epoch 36/150
# 18/18 - 2s - 136ms/step - loss: 7.9615e-04 - mae: 0.0194 - mape: 9351.6602 - root_mean_squared_error: 0.0282 - val_loss: 0.0087 - val_mae: 0.0736 - val_mape: 20.0840 - val_root_mean_squared_error: 0.0932
# Epoch 37/150
# 18/18 - 2s - 136ms/step - loss: 0.0010 - mae: 0.0226 - mape: 840.4659 - root_mean_squared_error: 0.0321 - val_loss: 0.0092 - val_mae: 0.0751 - val_mape: 20.0884 - val_root_mean_squared_error: 0.0958
# Epoch 38/150
# 18/18 - 2s - 136ms/step - loss: 8.8039e-04 - mae: 0.0210 - mape: 5461.1074 - root_mean_squared_error: 0.0297 - val_loss: 0.0090 - val_mae: 0.0739 - val_mape: 19.6070 - val_root_mean_squared_error: 0.0951
# Epoch 39/150
# 18/18 - 2s - 136ms/step - loss: 9.1298e-04 - mae: 0.0206 - mape: 8617.6631 - root_mean_squared_error: 0.0302 - val_loss: 0.0092 - val_mae: 0.0734 - val_mape: 19.0818 - val_root_mean_squared_error: 0.0959
# Epoch 40/150
# 18/18 - 2s - 136ms/step - loss: 7.6503e-04 - mae: 0.0199 - mape: 4151.7344 - root_mean_squared_error: 0.0277 - val_loss: 0.0095 - val_mae: 0.0753 - val_mape: 19.6300 - val_root_mean_squared_error: 0.0973
# Epoch 41/150
# 18/18 - 2s - 136ms/step - loss: 7.2628e-04 - mae: 0.0192 - mape: 22368.8418 - root_mean_squared_error: 0.0269 - val_loss: 0.0088 - val_mae: 0.0709 - val_mape: 18.0206 - val_root_mean_squared_error: 0.0936
# Epoch 42/150
# 18/18 - 2s - 136ms/step - loss: 6.3087e-04 - mae: 0.0172 - mape: 7791.5620 - root_mean_squared_error: 0.0251 - val_loss: 0.0086 - val_mae: 0.0721 - val_mape: 19.3716 - val_root_mean_squared_error: 0.0925
# Epoch 43/150
# 18/18 - 2s - 136ms/step - loss: 8.0643e-04 - mae: 0.0197 - mape: 968.5144 - root_mean_squared_error: 0.0284 - val_loss: 0.0091 - val_mae: 0.0754 - val_mape: 20.3690 - val_root_mean_squared_error: 0.0953
# Epoch 44/150
# 18/18 - 2s - 136ms/step - loss: 6.7988e-04 - mae: 0.0179 - mape: 6369.3169 - root_mean_squared_error: 0.0261 - val_loss: 0.0091 - val_mae: 0.0735 - val_mape: 19.3784 - val_root_mean_squared_error: 0.0953
# Epoch 45/150
# 18/18 - 2s - 136ms/step - loss: 7.7414e-04 - mae: 0.0197 - mape: 15486.4023 - root_mean_squared_error: 0.0278 - val_loss: 0.0095 - val_mae: 0.0759 - val_mape: 20.2386 - val_root_mean_squared_error: 0.0974
# Epoch 46/150
# 18/18 - 2s - 136ms/step - loss: 7.2128e-04 - mae: 0.0182 - mape: 3664.1316 - root_mean_squared_error: 0.0269 - val_loss: 0.0093 - val_mae: 0.0750 - val_mape: 19.7733 - val_root_mean_squared_error: 0.0964
# Epoch 47/150
# 18/18 - 2s - 137ms/step - loss: 6.0963e-04 - mae: 0.0174 - mape: 3829.8806 - root_mean_squared_error: 0.0247 - val_loss: 0.0084 - val_mae: 0.0719 - val_mape: 19.4061 - val_root_mean_squared_error: 0.0919
# Epoch 48/150
# 18/18 - 2s - 137ms/step - loss: 6.0075e-04 - mae: 0.0169 - mape: 1700.1293 - root_mean_squared_error: 0.0245 - val_loss: 0.0092 - val_mae: 0.0732 - val_mape: 18.8796 - val_root_mean_squared_error: 0.0958
# Epoch 49/150
# 18/18 - 2s - 136ms/step - loss: 6.1510e-04 - mae: 0.0174 - mape: 10118.8467 - root_mean_squared_error: 0.0248 - val_loss: 0.0089 - val_mae: 0.0722 - val_mape: 18.8021 - val_root_mean_squared_error: 0.0944
# Epoch 50/150
# 18/18 - 2s - 135ms/step - loss: 7.8733e-04 - mae: 0.0193 - mape: 19757.8672 - root_mean_squared_error: 0.0281 - val_loss: 0.0088 - val_mae: 0.0728 - val_mape: 19.2799 - val_root_mean_squared_error: 0.0940
# Epoch 51/150
# 18/18 - 2s - 136ms/step - loss: 5.5751e-04 - mae: 0.0166 - mape: 11410.6104 - root_mean_squared_error: 0.0236 - val_loss: 0.0089 - val_mae: 0.0736 - val_mape: 19.6394 - val_root_mean_squared_error: 0.0944
# Epoch 52/150
# 18/18 - 2s - 136ms/step - loss: 4.8144e-04 - mae: 0.0153 - mape: 6851.8599 - root_mean_squared_error: 0.0219 - val_loss: 0.0088 - val_mae: 0.0726 - val_mape: 19.2156 - val_root_mean_squared_error: 0.0939
# Epoch 53/150
# 18/18 - 2s - 136ms/step - loss: 5.4148e-04 - mae: 0.0160 - mape: 1984.1409 - root_mean_squared_error: 0.0233 - val_loss: 0.0093 - val_mae: 0.0728 - val_mape: 18.5861 - val_root_mean_squared_error: 0.0966
# Epoch 54/150
# 18/18 - 2s - 135ms/step - loss: 5.4375e-04 - mae: 0.0163 - mape: 585.6351 - root_mean_squared_error: 0.0233 - val_loss: 0.0096 - val_mae: 0.0759 - val_mape: 19.9577 - val_root_mean_squared_error: 0.0980
# Epoch 55/150
# 18/18 - 2s - 136ms/step - loss: 4.9158e-04 - mae: 0.0153 - mape: 3672.4319 - root_mean_squared_error: 0.0222 - val_loss: 0.0087 - val_mae: 0.0744 - val_mape: 20.3039 - val_root_mean_squared_error: 0.0935
# Epoch 56/150
# 18/18 - 2s - 136ms/step - loss: 6.2167e-04 - mae: 0.0175 - mape: 2088.8813 - root_mean_squared_error: 0.0249 - val_loss: 0.0086 - val_mae: 0.0723 - val_mape: 19.2400 - val_root_mean_squared_error: 0.0928
# Epoch 57/150
# 18/18 - 2s - 136ms/step - loss: 4.5019e-04 - mae: 0.0145 - mape: 11967.9844 - root_mean_squared_error: 0.0212 - val_loss: 0.0093 - val_mae: 0.0744 - val_mape: 19.4163 - val_root_mean_squared_error: 0.0967
# Epoch 58/150
# 18/18 - 2s - 136ms/step - loss: 4.9278e-04 - mae: 0.0154 - mape: 6307.2739 - root_mean_squared_error: 0.0222 - val_loss: 0.0089 - val_mae: 0.0733 - val_mape: 19.3608 - val_root_mean_squared_error: 0.0944
# Epoch 59/150
# 18/18 - 2s - 136ms/step - loss: 5.9468e-04 - mae: 0.0172 - mape: 11287.8525 - root_mean_squared_error: 0.0244 - val_loss: 0.0091 - val_mae: 0.0756 - val_mape: 20.3126 - val_root_mean_squared_error: 0.0955
# Epoch 60/150
# 18/18 - 2s - 136ms/step - loss: 5.2449e-04 - mae: 0.0154 - mape: 5733.9355 - root_mean_squared_error: 0.0229 - val_loss: 0.0090 - val_mae: 0.0730 - val_mape: 19.2609 - val_root_mean_squared_error: 0.0947
# Epoch 61/150
# 18/18 - 2s - 135ms/step - loss: 4.9075e-04 - mae: 0.0149 - mape: 6351.6377 - root_mean_squared_error: 0.0222 - val_loss: 0.0092 - val_mae: 0.0747 - val_mape: 19.7926 - val_root_mean_squared_error: 0.0961
# Epoch 62/150
# 18/18 - 2s - 136ms/step - loss: 4.8680e-04 - mae: 0.0152 - mape: 7120.6006 - root_mean_squared_error: 0.0221 - val_loss: 0.0089 - val_mae: 0.0738 - val_mape: 19.6619 - val_root_mean_squared_error: 0.0943
# Epoch 63/150
# 18/18 - 2s - 136ms/step - loss: 4.2539e-04 - mae: 0.0144 - mape: 5865.0483 - root_mean_squared_error: 0.0206 - val_loss: 0.0086 - val_mae: 0.0724 - val_mape: 19.2973 - val_root_mean_squared_error: 0.0928
# Epoch 64/150
# 18/18 - 2s - 135ms/step - loss: 4.5040e-04 - mae: 0.0148 - mape: 559.6110 - root_mean_squared_error: 0.0212 - val_loss: 0.0089 - val_mae: 0.0737 - val_mape: 19.5684 - val_root_mean_squared_error: 0.0944
# Epoch 65/150
# 18/18 - 2s - 136ms/step - loss: 5.6664e-04 - mae: 0.0156 - mape: 4111.2197 - root_mean_squared_error: 0.0238 - val_loss: 0.0086 - val_mae: 0.0730 - val_mape: 19.5521 - val_root_mean_squared_error: 0.0928
# Epoch 66/150
# 18/18 - 2s - 136ms/step - loss: 4.7754e-04 - mae: 0.0154 - mape: 1911.2974 - root_mean_squared_error: 0.0219 - val_loss: 0.0086 - val_mae: 0.0712 - val_mape: 18.6426 - val_root_mean_squared_error: 0.0925
# Epoch 67/150
# 18/18 - 2s - 136ms/step - loss: 3.8129e-04 - mae: 0.0136 - mape: 2917.8293 - root_mean_squared_error: 0.0195 - val_loss: 0.0089 - val_mae: 0.0744 - val_mape: 20.0668 - val_root_mean_squared_error: 0.0941
# Epoch 68/150
# 18/18 - 2s - 136ms/step - loss: 4.7047e-04 - mae: 0.0147 - mape: 14439.9043 - root_mean_squared_error: 0.0217 - val_loss: 0.0092 - val_mae: 0.0746 - val_mape: 19.6287 - val_root_mean_squared_error: 0.0961
# Epoch 69/150
# 18/18 - 2s - 136ms/step - loss: 4.1102e-04 - mae: 0.0141 - mape: 2919.7122 - root_mean_squared_error: 0.0203 - val_loss: 0.0088 - val_mae: 0.0727 - val_mape: 19.1747 - val_root_mean_squared_error: 0.0937
# Epoch 70/150
# 18/18 - 2s - 136ms/step - loss: 3.6128e-04 - mae: 0.0132 - mape: 9308.0918 - root_mean_squared_error: 0.0190 - val_loss: 0.0087 - val_mae: 0.0723 - val_mape: 19.0354 - val_root_mean_squared_error: 0.0935
# Epoch 71/150
# 18/18 - 2s - 135ms/step - loss: 4.5738e-04 - mae: 0.0148 - mape: 8418.6855 - root_mean_squared_error: 0.0214 - val_loss: 0.0087 - val_mae: 0.0729 - val_mape: 19.3871 - val_root_mean_squared_error: 0.0932
# Epoch 72/150
# 18/18 - 2s - 137ms/step - loss: 3.5964e-04 - mae: 0.0132 - mape: 2055.3538 - root_mean_squared_error: 0.0190 - val_loss: 0.0082 - val_mae: 0.0704 - val_mape: 18.5665 - val_root_mean_squared_error: 0.0908
# Epoch 73/150
# 18/18 - 2s - 135ms/step - loss: 3.9778e-04 - mae: 0.0143 - mape: 5329.2520 - root_mean_squared_error: 0.0199 - val_loss: 0.0083 - val_mae: 0.0714 - val_mape: 18.9457 - val_root_mean_squared_error: 0.0912
# Epoch 74/150
# 18/18 - 2s - 135ms/step - loss: 3.6253e-04 - mae: 0.0137 - mape: 4992.3901 - root_mean_squared_error: 0.0190 - val_loss: 0.0090 - val_mae: 0.0727 - val_mape: 18.8527 - val_root_mean_squared_error: 0.0950
# Epoch 75/150
# 18/18 - 2s - 136ms/step - loss: 3.4559e-04 - mae: 0.0129 - mape: 18069.4297 - root_mean_squared_error: 0.0186 - val_loss: 0.0088 - val_mae: 0.0725 - val_mape: 19.0917 - val_root_mean_squared_error: 0.0936
# Epoch 76/150
# 18/18 - 2s - 136ms/step - loss: 4.3987e-04 - mae: 0.0147 - mape: 2445.5229 - root_mean_squared_error: 0.0210 - val_loss: 0.0086 - val_mae: 0.0723 - val_mape: 19.0779 - val_root_mean_squared_error: 0.0929
# Epoch 77/150
# 18/18 - 2s - 136ms/step - loss: 4.0947e-04 - mae: 0.0136 - mape: 3330.2778 - root_mean_squared_error: 0.0202 - val_loss: 0.0087 - val_mae: 0.0717 - val_mape: 18.7331 - val_root_mean_squared_error: 0.0934
# Epoch 78/150
# 18/18 - 2s - 136ms/step - loss: 3.6658e-04 - mae: 0.0134 - mape: 1868.5093 - root_mean_squared_error: 0.0191 - val_loss: 0.0085 - val_mae: 0.0714 - val_mape: 18.8440 - val_root_mean_squared_error: 0.0920
# Epoch 79/150
# 18/18 - 2s - 136ms/step - loss: 3.7995e-04 - mae: 0.0134 - mape: 4473.4565 - root_mean_squared_error: 0.0195 - val_loss: 0.0090 - val_mae: 0.0739 - val_mape: 19.4847 - val_root_mean_squared_error: 0.0949
# Epoch 80/150
# 18/18 - 2s - 136ms/step - loss: 4.0243e-04 - mae: 0.0137 - mape: 6802.2559 - root_mean_squared_error: 0.0201 - val_loss: 0.0082 - val_mae: 0.0709 - val_mape: 18.9009 - val_root_mean_squared_error: 0.0908
# Epoch 81/150
# 18/18 - 2s - 135ms/step - loss: 3.5956e-04 - mae: 0.0134 - mape: 3276.3638 - root_mean_squared_error: 0.0190 - val_loss: 0.0085 - val_mae: 0.0717 - val_mape: 18.8916 - val_root_mean_squared_error: 0.0923
# Epoch 82/150
# 18/18 - 2s - 137ms/step - loss: 3.5807e-04 - mae: 0.0133 - mape: 7021.1089 - root_mean_squared_error: 0.0189 - val_loss: 0.0088 - val_mae: 0.0743 - val_mape: 19.8305 - val_root_mean_squared_error: 0.0940
# Epoch 83/150
# 18/18 - 2s - 135ms/step - loss: 3.8519e-04 - mae: 0.0137 - mape: 1660.3939 - root_mean_squared_error: 0.0196 - val_loss: 0.0086 - val_mae: 0.0729 - val_mape: 19.3765 - val_root_mean_squared_error: 0.0925
# Epoch 84/150
# 18/18 - 2s - 136ms/step - loss: 3.6223e-04 - mae: 0.0130 - mape: 1360.0559 - root_mean_squared_error: 0.0190 - val_loss: 0.0081 - val_mae: 0.0687 - val_mape: 17.8161 - val_root_mean_squared_error: 0.0900
# Epoch 85/150
# 18/18 - 2s - 136ms/step - loss: 3.7463e-04 - mae: 0.0133 - mape: 11151.6582 - root_mean_squared_error: 0.0194 - val_loss: 0.0078 - val_mae: 0.0698 - val_mape: 18.6779 - val_root_mean_squared_error: 0.0886
# Epoch 86/150
# 18/18 - 2s - 136ms/step - loss: 3.4878e-04 - mae: 0.0134 - mape: 7196.4907 - root_mean_squared_error: 0.0187 - val_loss: 0.0088 - val_mae: 0.0744 - val_mape: 19.9841 - val_root_mean_squared_error: 0.0939
# Epoch 87/150
# 18/18 - 2s - 136ms/step - loss: 3.7281e-04 - mae: 0.0133 - mape: 16607.9746 - root_mean_squared_error: 0.0193 - val_loss: 0.0080 - val_mae: 0.0699 - val_mape: 18.6020 - val_root_mean_squared_error: 0.0893
# Epoch 88/150
# 18/18 - 2s - 136ms/step - loss: 3.0398e-04 - mae: 0.0121 - mape: 288.8065 - root_mean_squared_error: 0.0174 - val_loss: 0.0080 - val_mae: 0.0686 - val_mape: 17.9308 - val_root_mean_squared_error: 0.0894
# Epoch 89/150
# 18/18 - 2s - 136ms/step - loss: 3.3912e-04 - mae: 0.0127 - mape: 12175.1514 - root_mean_squared_error: 0.0184 - val_loss: 0.0083 - val_mae: 0.0709 - val_mape: 18.7504 - val_root_mean_squared_error: 0.0911
# Epoch 90/150
# 18/18 - 2s - 136ms/step - loss: 2.8113e-04 - mae: 0.0120 - mape: 10202.3457 - root_mean_squared_error: 0.0168 - val_loss: 0.0080 - val_mae: 0.0707 - val_mape: 18.9328 - val_root_mean_squared_error: 0.0896
# Epoch 91/150
# 18/18 - 2s - 136ms/step - loss: 4.0824e-04 - mae: 0.0139 - mape: 4491.2954 - root_mean_squared_error: 0.0202 - val_loss: 0.0084 - val_mae: 0.0697 - val_mape: 17.9449 - val_root_mean_squared_error: 0.0918
# Epoch 92/150
# 18/18 - 2s - 136ms/step - loss: 3.1264e-04 - mae: 0.0125 - mape: 11663.1113 - root_mean_squared_error: 0.0177 - val_loss: 0.0081 - val_mae: 0.0717 - val_mape: 19.3447 - val_root_mean_squared_error: 0.0898
# Epoch 93/150
# 18/18 - 2s - 136ms/step - loss: 3.0709e-04 - mae: 0.0123 - mape: 5545.2710 - root_mean_squared_error: 0.0175 - val_loss: 0.0081 - val_mae: 0.0711 - val_mape: 18.9319 - val_root_mean_squared_error: 0.0902
# Epoch 94/150
# 18/18 - 2s - 135ms/step - loss: 2.5870e-04 - mae: 0.0115 - mape: 3885.0447 - root_mean_squared_error: 0.0161 - val_loss: 0.0079 - val_mae: 0.0706 - val_mape: 19.0326 - val_root_mean_squared_error: 0.0888
# Epoch 95/150
# 18/18 - 2s - 135ms/step - loss: 2.6443e-04 - mae: 0.0116 - mape: 6461.4717 - root_mean_squared_error: 0.0163 - val_loss: 0.0084 - val_mae: 0.0687 - val_mape: 17.4866 - val_root_mean_squared_error: 0.0916
# Epoch 96/150
# 18/18 - 2s - 136ms/step - loss: 3.5391e-04 - mae: 0.0131 - mape: 6868.6899 - root_mean_squared_error: 0.0188 - val_loss: 0.0085 - val_mae: 0.0733 - val_mape: 19.6265 - val_root_mean_squared_error: 0.0924
# Epoch 97/150
# 18/18 - 2s - 136ms/step - loss: 2.5051e-04 - mae: 0.0112 - mape: 7852.1938 - root_mean_squared_error: 0.0158 - val_loss: 0.0082 - val_mae: 0.0704 - val_mape: 18.4845 - val_root_mean_squared_error: 0.0905
# Epoch 98/150
# 18/18 - 2s - 136ms/step - loss: 3.7186e-04 - mae: 0.0133 - mape: 4239.9370 - root_mean_squared_error: 0.0193 - val_loss: 0.0083 - val_mae: 0.0715 - val_mape: 18.9849 - val_root_mean_squared_error: 0.0910
# Epoch 99/150
# 18/18 - 2s - 136ms/step - loss: 2.6734e-04 - mae: 0.0115 - mape: 388.2597 - root_mean_squared_error: 0.0164 - val_loss: 0.0082 - val_mae: 0.0718 - val_mape: 19.2946 - val_root_mean_squared_error: 0.0905
# Epoch 100/150
# 18/18 - 2s - 136ms/step - loss: 2.4284e-04 - mae: 0.0112 - mape: 213.5717 - root_mean_squared_error: 0.0156 - val_loss: 0.0080 - val_mae: 0.0720 - val_mape: 19.4243 - val_root_mean_squared_error: 0.0895
# Epoch 101/150
# 18/18 - 2s - 136ms/step - loss: 3.2054e-04 - mae: 0.0124 - mape: 8918.9141 - root_mean_squared_error: 0.0179 - val_loss: 0.0084 - val_mae: 0.0734 - val_mape: 19.7342 - val_root_mean_squared_error: 0.0918
# Epoch 102/150
# 18/18 - 2s - 137ms/step - loss: 3.5927e-04 - mae: 0.0126 - mape: 2539.4292 - root_mean_squared_error: 0.0190 - val_loss: 0.0081 - val_mae: 0.0711 - val_mape: 18.9057 - val_root_mean_squared_error: 0.0899
# Epoch 103/150
# 18/18 - 2s - 136ms/step - loss: 3.1310e-04 - mae: 0.0118 - mape: 10962.2461 - root_mean_squared_error: 0.0177 - val_loss: 0.0080 - val_mae: 0.0709 - val_mape: 18.9278 - val_root_mean_squared_error: 0.0895
# Epoch 104/150
# 18/18 - 2s - 136ms/step - loss: 2.4303e-04 - mae: 0.0108 - mape: 2249.3921 - root_mean_squared_error: 0.0156 - val_loss: 0.0083 - val_mae: 0.0714 - val_mape: 18.9248 - val_root_mean_squared_error: 0.0909
# Epoch 105/150
# 18/18 - 2s - 137ms/step - loss: 2.7766e-04 - mae: 0.0118 - mape: 5631.2310 - root_mean_squared_error: 0.0167 - val_loss: 0.0081 - val_mae: 0.0709 - val_mape: 19.0312 - val_root_mean_squared_error: 0.0897
# Epoch 106/150
# 18/18 - 2s - 136ms/step - loss: 2.4728e-04 - mae: 0.0113 - mape: 5572.1309 - root_mean_squared_error: 0.0157 - val_loss: 0.0080 - val_mae: 0.0702 - val_mape: 18.7098 - val_root_mean_squared_error: 0.0893
# Epoch 107/150
# 18/18 - 2s - 136ms/step - loss: 2.6577e-04 - mae: 0.0115 - mape: 2531.6038 - root_mean_squared_error: 0.0163 - val_loss: 0.0080 - val_mae: 0.0696 - val_mape: 18.2280 - val_root_mean_squared_error: 0.0896
# Epoch 108/150
# 18/18 - 2s - 136ms/step - loss: 3.0937e-04 - mae: 0.0121 - mape: 13470.1680 - root_mean_squared_error: 0.0176 - val_loss: 0.0083 - val_mae: 0.0714 - val_mape: 18.8691 - val_root_mean_squared_error: 0.0911
# Epoch 109/150
# 18/18 - 2s - 136ms/step - loss: 2.9695e-04 - mae: 0.0119 - mape: 3137.2737 - root_mean_squared_error: 0.0172 - val_loss: 0.0080 - val_mae: 0.0704 - val_mape: 18.7394 - val_root_mean_squared_error: 0.0896
# Epoch 110/150
# 18/18 - 2s - 135ms/step - loss: 2.6125e-04 - mae: 0.0114 - mape: 2109.1646 - root_mean_squared_error: 0.0162 - val_loss: 0.0081 - val_mae: 0.0712 - val_mape: 19.0609 - val_root_mean_squared_error: 0.0898
# Epoch 111/150
# 18/18 - 2s - 136ms/step - loss: 2.6373e-04 - mae: 0.0111 - mape: 7178.1187 - root_mean_squared_error: 0.0162 - val_loss: 0.0077 - val_mae: 0.0692 - val_mape: 18.3537 - val_root_mean_squared_error: 0.0879
# Epoch 112/150
# 18/18 - 2s - 136ms/step - loss: 3.2619e-04 - mae: 0.0124 - mape: 3756.3989 - root_mean_squared_error: 0.0181 - val_loss: 0.0083 - val_mae: 0.0723 - val_mape: 19.3835 - val_root_mean_squared_error: 0.0910
# Epoch 113/150
# 18/18 - 2s - 136ms/step - loss: 2.3581e-04 - mae: 0.0108 - mape: 4488.0479 - root_mean_squared_error: 0.0154 - val_loss: 0.0081 - val_mae: 0.0686 - val_mape: 17.5654 - val_root_mean_squared_error: 0.0902
# Epoch 114/150
# 18/18 - 2s - 136ms/step - loss: 2.7984e-04 - mae: 0.0116 - mape: 3767.8884 - root_mean_squared_error: 0.0167 - val_loss: 0.0077 - val_mae: 0.0689 - val_mape: 18.2707 - val_root_mean_squared_error: 0.0877
# Epoch 115/150
# 18/18 - 2s - 135ms/step - loss: 2.3635e-04 - mae: 0.0106 - mape: 4313.1494 - root_mean_squared_error: 0.0154 - val_loss: 0.0081 - val_mae: 0.0710 - val_mape: 18.7649 - val_root_mean_squared_error: 0.0902
# Epoch 116/150
# 18/18 - 2s - 136ms/step - loss: 2.5105e-04 - mae: 0.0110 - mape: 83.7085 - root_mean_squared_error: 0.0158 - val_loss: 0.0079 - val_mae: 0.0692 - val_mape: 18.1898 - val_root_mean_squared_error: 0.0891
# Epoch 117/150
# 18/18 - 2s - 136ms/step - loss: 2.5084e-04 - mae: 0.0113 - mape: 9060.2734 - root_mean_squared_error: 0.0158 - val_loss: 0.0075 - val_mae: 0.0672 - val_mape: 17.6514 - val_root_mean_squared_error: 0.0865
# Epoch 118/150
# 18/18 - 2s - 136ms/step - loss: 2.8549e-04 - mae: 0.0115 - mape: 405.3974 - root_mean_squared_error: 0.0169 - val_loss: 0.0080 - val_mae: 0.0702 - val_mape: 18.4801 - val_root_mean_squared_error: 0.0897
# Epoch 119/150
# 18/18 - 2s - 136ms/step - loss: 2.2650e-04 - mae: 0.0108 - mape: 356.6714 - root_mean_squared_error: 0.0151 - val_loss: 0.0078 - val_mae: 0.0668 - val_mape: 17.1148 - val_root_mean_squared_error: 0.0883
# Epoch 120/150
# 18/18 - 2s - 136ms/step - loss: 2.3583e-04 - mae: 0.0111 - mape: 1294.2228 - root_mean_squared_error: 0.0154 - val_loss: 0.0077 - val_mae: 0.0692 - val_mape: 18.4546 - val_root_mean_squared_error: 0.0875
# Epoch 121/150
# 18/18 - 2s - 136ms/step - loss: 2.3236e-04 - mae: 0.0106 - mape: 1823.2366 - root_mean_squared_error: 0.0152 - val_loss: 0.0076 - val_mae: 0.0668 - val_mape: 17.3210 - val_root_mean_squared_error: 0.0872
# Epoch 122/150
# 18/18 - 2s - 136ms/step - loss: 1.9036e-04 - mae: 0.0100 - mape: 4031.8542 - root_mean_squared_error: 0.0138 - val_loss: 0.0079 - val_mae: 0.0709 - val_mape: 19.1347 - val_root_mean_squared_error: 0.0889
# Epoch 123/150
# 18/18 - 2s - 136ms/step - loss: 3.4229e-04 - mae: 0.0123 - mape: 6797.1787 - root_mean_squared_error: 0.0185 - val_loss: 0.0079 - val_mae: 0.0684 - val_mape: 17.7675 - val_root_mean_squared_error: 0.0889
# Epoch 124/150
# 18/18 - 2s - 136ms/step - loss: 2.0476e-04 - mae: 0.0102 - mape: 1695.2592 - root_mean_squared_error: 0.0143 - val_loss: 0.0079 - val_mae: 0.0688 - val_mape: 18.0028 - val_root_mean_squared_error: 0.0886
# Epoch 125/150
# 18/18 - 2s - 136ms/step - loss: 2.9993e-04 - mae: 0.0118 - mape: 17213.6328 - root_mean_squared_error: 0.0173 - val_loss: 0.0078 - val_mae: 0.0691 - val_mape: 18.1283 - val_root_mean_squared_error: 0.0884
# Epoch 126/150
# 18/18 - 2s - 136ms/step - loss: 2.5707e-04 - mae: 0.0112 - mape: 426.4248 - root_mean_squared_error: 0.0160 - val_loss: 0.0078 - val_mae: 0.0684 - val_mape: 17.8761 - val_root_mean_squared_error: 0.0881
# Epoch 127/150
# 18/18 - 2s - 136ms/step - loss: 2.5322e-04 - mae: 0.0112 - mape: 9062.0303 - root_mean_squared_error: 0.0159 - val_loss: 0.0075 - val_mae: 0.0687 - val_mape: 18.4580 - val_root_mean_squared_error: 0.0868
# Epoch 128/150
# 18/18 - 2s - 135ms/step - loss: 1.6896e-04 - mae: 0.0095 - mape: 2025.8549 - root_mean_squared_error: 0.0130 - val_loss: 0.0080 - val_mae: 0.0692 - val_mape: 18.0853 - val_root_mean_squared_error: 0.0892
# Epoch 129/150
# 18/18 - 2s - 136ms/step - loss: 2.3657e-04 - mae: 0.0111 - mape: 729.9864 - root_mean_squared_error: 0.0154 - val_loss: 0.0079 - val_mae: 0.0691 - val_mape: 18.1867 - val_root_mean_squared_error: 0.0889
# Epoch 130/150
# 18/18 - 2s - 136ms/step - loss: 2.1300e-04 - mae: 0.0101 - mape: 160.2843 - root_mean_squared_error: 0.0146 - val_loss: 0.0077 - val_mae: 0.0693 - val_mape: 18.4877 - val_root_mean_squared_error: 0.0875
# Epoch 131/150
# 18/18 - 2s - 137ms/step - loss: 2.3417e-04 - mae: 0.0108 - mape: 275.4361 - root_mean_squared_error: 0.0153 - val_loss: 0.0075 - val_mae: 0.0678 - val_mape: 17.8972 - val_root_mean_squared_error: 0.0864
# Epoch 132/150
# 18/18 - 2s - 136ms/step - loss: 3.3951e-04 - mae: 0.0125 - mape: 12367.8330 - root_mean_squared_error: 0.0184 - val_loss: 0.0079 - val_mae: 0.0692 - val_mape: 18.1959 - val_root_mean_squared_error: 0.0889
# Epoch 133/150
# 18/18 - 2s - 135ms/step - loss: 1.8532e-04 - mae: 0.0098 - mape: 196.0337 - root_mean_squared_error: 0.0136 - val_loss: 0.0076 - val_mae: 0.0674 - val_mape: 17.5285 - val_root_mean_squared_error: 0.0874
# Epoch 134/150
# 18/18 - 2s - 136ms/step - loss: 2.4417e-04 - mae: 0.0107 - mape: 5730.6963 - root_mean_squared_error: 0.0156 - val_loss: 0.0075 - val_mae: 0.0684 - val_mape: 18.2883 - val_root_mean_squared_error: 0.0865
# Epoch 135/150
# 18/18 - 2s - 135ms/step - loss: 2.2183e-04 - mae: 0.0103 - mape: 1536.5897 - root_mean_squared_error: 0.0149 - val_loss: 0.0077 - val_mae: 0.0692 - val_mape: 18.3294 - val_root_mean_squared_error: 0.0880
# Epoch 136/150
# 18/18 - 2s - 136ms/step - loss: 2.0103e-04 - mae: 0.0101 - mape: 3087.0735 - root_mean_squared_error: 0.0142 - val_loss: 0.0078 - val_mae: 0.0679 - val_mape: 17.6514 - val_root_mean_squared_error: 0.0882
# Epoch 137/150
# 18/18 - 2s - 136ms/step - loss: 2.1030e-04 - mae: 0.0104 - mape: 3067.7056 - root_mean_squared_error: 0.0145 - val_loss: 0.0074 - val_mae: 0.0649 - val_mape: 16.6501 - val_root_mean_squared_error: 0.0861
# Epoch 138/150
# 18/18 - 2s - 136ms/step - loss: 1.8922e-04 - mae: 0.0100 - mape: 1110.5868 - root_mean_squared_error: 0.0138 - val_loss: 0.0075 - val_mae: 0.0688 - val_mape: 18.4047 - val_root_mean_squared_error: 0.0867
# Epoch 139/150
# 18/18 - 2s - 136ms/step - loss: 2.0838e-04 - mae: 0.0104 - mape: 2927.4141 - root_mean_squared_error: 0.0144 - val_loss: 0.0074 - val_mae: 0.0670 - val_mape: 17.5650 - val_root_mean_squared_error: 0.0863
# Epoch 140/150
# 18/18 - 2s - 136ms/step - loss: 1.6919e-04 - mae: 0.0093 - mape: 11505.4170 - root_mean_squared_error: 0.0130 - val_loss: 0.0073 - val_mae: 0.0664 - val_mape: 17.3917 - val_root_mean_squared_error: 0.0852
# Epoch 141/150
# 18/18 - 2s - 136ms/step - loss: 1.9496e-04 - mae: 0.0099 - mape: 6740.9458 - root_mean_squared_error: 0.0140 - val_loss: 0.0076 - val_mae: 0.0693 - val_mape: 18.4008 - val_root_mean_squared_error: 0.0873
# Epoch 142/150
# 18/18 - 2s - 136ms/step - loss: 2.0655e-04 - mae: 0.0102 - mape: 421.3801 - root_mean_squared_error: 0.0144 - val_loss: 0.0076 - val_mae: 0.0685 - val_mape: 18.0775 - val_root_mean_squared_error: 0.0870
# Epoch 143/150
# 18/18 - 2s - 136ms/step - loss: 1.8880e-04 - mae: 0.0098 - mape: 2778.8516 - root_mean_squared_error: 0.0137 - val_loss: 0.0077 - val_mae: 0.0678 - val_mape: 17.5814 - val_root_mean_squared_error: 0.0880
# Epoch 144/150
# 18/18 - 2s - 136ms/step - loss: 2.4939e-04 - mae: 0.0109 - mape: 3362.2830 - root_mean_squared_error: 0.0158 - val_loss: 0.0076 - val_mae: 0.0692 - val_mape: 18.4571 - val_root_mean_squared_error: 0.0873
# Epoch 145/150
# 18/18 - 2s - 136ms/step - loss: 1.9014e-04 - mae: 0.0097 - mape: 6110.3750 - root_mean_squared_error: 0.0138 - val_loss: 0.0073 - val_mae: 0.0674 - val_mape: 17.8544 - val_root_mean_squared_error: 0.0854
# Epoch 146/150
# 18/18 - 2s - 136ms/step - loss: 1.9503e-04 - mae: 0.0099 - mape: 245.3168 - root_mean_squared_error: 0.0140 - val_loss: 0.0076 - val_mae: 0.0686 - val_mape: 18.1879 - val_root_mean_squared_error: 0.0869
# Epoch 147/150
# 18/18 - 2s - 136ms/step - loss: 2.2050e-04 - mae: 0.0107 - mape: 4705.7305 - root_mean_squared_error: 0.0148 - val_loss: 0.0075 - val_mae: 0.0679 - val_mape: 17.8159 - val_root_mean_squared_error: 0.0867
# Epoch 148/150
# 18/18 - 2s - 136ms/step - loss: 1.7485e-04 - mae: 0.0096 - mape: 1266.0657 - root_mean_squared_error: 0.0132 - val_loss: 0.0074 - val_mae: 0.0666 - val_mape: 17.3399 - val_root_mean_squared_error: 0.0861
# Epoch 149/150
# 18/18 - 2s - 136ms/step - loss: 1.6485e-04 - mae: 0.0092 - mape: 3552.0068 - root_mean_squared_error: 0.0128 - val_loss: 0.0079 - val_mae: 0.0679 - val_mape: 17.4415 - val_root_mean_squared_error: 0.0887
# Epoch 150/150
# 18/18 - 2s - 135ms/step - loss: 2.6156e-04 - mae: 0.0112 - mape: 1717.0430 - root_mean_squared_error: 0.0162 - val_loss: 0.0074 - val_mae: 0.0682 - val_mape: 18.1049 - val_root_mean_squared_error: 0.0862

# %%
####################
### Plot Results ###
####################

# Training MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['loss'][1:], label='MSE')
ax[0, 0].set_title('Training Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Training MAE
ax[0, 1].plot(history.history['mae'][1:], label='MAE', color='black')
ax[0, 1].set_title('Training MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Training RMSE
ax[1, 0].plot(history.history['root_mean_squared_error'][1:], label='RMSE', color='green')
ax[1, 0].set_title('Training RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Training MAPE
ax[1, 1].plot(history.history['mape'][1:], label='MAPE', color='red')
ax[1, 1].set_title('Training MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Validation MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['val_loss'][1:], label='Val MSE')
ax[0, 0].set_title('Validation Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Validation MAE
ax[0, 1].plot(history.history['val_mae'][1:], label='Val MAE')
ax[0, 1].set_title('Validation MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Validation RMSE
ax[1, 0].plot(history.history['val_root_mean_squared_error'][1:], label='Val RMSE')
ax[1, 0].set_title('Validation RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Validation MAPE
ax[1, 1].plot(history.history['val_mape'][1:], label='Val MAPE')
ax[1, 1].set_title('Validation MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Store best training/validation metrics
# Training
train_mse = history.history['loss']
best_epoch = np.argmin(train_mse)
best_train_mse = train_mse[best_epoch]
best_train_rmse = history.history['root_mean_squared_error'][best_epoch]
best_train_mae  = history.history['mae'][best_epoch]
best_train_mape = history.history['mape'][best_epoch]

# Validation: record epoch at which validation loss is the lowest for each seed
val_mse = history.history['val_loss']
best_epoch = np.argmin(val_mse)
best_val_mse = val_mse[best_epoch]
best_val_rmse = history.history['val_root_mean_squared_error'][best_epoch]
best_val_mae  = history.history['val_mae'][best_epoch]
best_val_mape = history.history['val_mape'][best_epoch]

# %%
# -------------------------
# Step 9 — Predict/Testing
# -------------------------

y_predict= model.predict([X_cnn_test, X_lstm_test])
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
# -----------------------------------
# Step 10 — Test MSE/RMSE/MAE/MAPE/R2
# -----------------------------------

# Compute the loss metrics
test_mse = mean_squared_error(y_test, y_predict)
test_rmse = root_mean_squared_error(y_test, y_predict)
test_mae = mean_absolute_error(y_test, y_predict)
test_mape = mean_absolute_percentage_error(y_test, y_predict)
test_r2_score = r2_score(y_test, y_predict)

print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Mean Absolute Error:", test_mae)
print("Mean Absolute Percentage Error:", test_mape)
print("R2 Score:", test_r2_score)
# Out:
# Mean Squared Error: 0.0007532248240021903
# Root Mean Squared Error: 0.02744494168334468
# Mean Absolute Error: 0.023634297035058923
# Mean Absolute Percentage Error: 0.17757722752235702
# R2 Score: 0.7714441001227702

# %%
#-------------------------------------------------
# Step 11 - Inverse scaling: original price scale
#-------------------------------------------------

y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))
y_predict_orig = scaler.inverse_transform(y_predict)

# %%
#----------------------------------------------
# Step 12 - Plot prediction vs. actuals prices
#----------------------------------------------

# Add window size
start_index = len(y_train)+len(y_val)+ 224

# Test set dates + convert to datetime
dates = ltc['Date'].iloc[start_index:start_index + len(y_test_orig)].reset_index(drop=True)
dates = pd.to_datetime(dates)

# Plot the actual vs predicted prices
plt.figure(figsize=(10, 5))
plt.plot(dates, y_test_orig, label='Actual', linewidth=2)
plt.plot(dates, y_predict_orig, label='Predicted', color='red')
plt.title('Actual vs Predicted Litecoin Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Store metrics in dataframe along with best training/validation loss (record epoch)
results = {
    "seed": 91,
    "best_epoch": best_epoch + 1,    # best validation epoch
    "train_mse": best_train_mse,
    "train_rmse": best_train_rmse,
    "train_mae": best_train_mae,
    "train_mape": best_train_mape,
    "val_mse": best_val_mse,
    "val_rmse": best_val_rmse,
    "val_mae": best_val_mae,
    "val_mape": best_val_mape,
    "test_mse": test_mse,
    "test_rmse": test_rmse,
    "test_mae": test_mae,
    "test_mape": test_mape,
    "test_r2_score": test_r2_score
}

ltc_results = pd.DataFrame([results])
ltc_results.to_csv('ltc_results.csv')

from google.colab import files
files.download('ltc_results.csv')

# %%
# Export results

loss_results = pd.DataFrame(history.history)
loss_results.to_csv('ltc_loss_results.csv')

files.download('ltc_loss_results.csv')

# %% [markdown]
# # **Regime Classification**

# %%
# ------------------------------------------
# Step 1 — Compute Log returns & Volatility
# ------------------------------------------

original = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.ravel()
})

predicted = pd.DataFrame({
    'Date': dates,
    'Predicted': y_predict_orig.ravel()
})

# Compute returns from actual and predicted prices
returns_orig = original['Actual'].pct_change()
returns_pred = predicted['Predicted'].pct_change()
# Drop NaN values from returns
returns_orig = returns_orig.fillna(0)
returns_pred = returns_pred.fillna(0)

# Compute 10-day rolling volatility
volatility_orig = returns_orig.rolling(window=10).std()
volatility_pred = returns_pred.rolling(window=10).std()
volatility_orig = volatility_orig.fillna(0)
volatility_pred = volatility_pred.fillna(0)

# Update dataframes with returns and volatility
original['Returns'] = returns_orig
predicted['Returns'] = returns_pred
original['Volatility'] = volatility_orig
predicted['Volatility'] = volatility_pred

# %%
# --------------------------------
# Step 2 — Label Volatility L-M-H
# --------------------------------

# Compute quantiles as thresholds for low/med/high volatility
low_threshold = volatility_orig.quantile(0.33)   # lower 33%
high_threshold = volatility_orig.quantile(0.67)  # upper 33%

# Label volatility
def label_volatility(vol):
    if vol <= low_threshold:
        return 'low'
    elif vol >= high_threshold:
        return 'high'
    else:
        return 'medium'

# Apply volatility low/medium/high to original and prediction dataset
original['Volatility_level'] = original['Volatility'].apply(label_volatility)
predicted['Volatility_level'] = predicted['Volatility'].apply(label_volatility)

# %%
# -------------------------------
# Step 3 — Regime Classification
# -------------------------------

# Classify regime based on volatility + average sign of the returns
def classify_regime(pred_labels, vol_value, vol_threshold=(low_threshold, high_threshold), window=3):
    regimes = []
    low_threshold, high_threshold = vol_threshold

    for i in range(len(pred_labels) - window):
        window_preds = pred_labels[i:i+window]
        window_vol = vol_value[i+window]
        sign_pred = np.sign(window_preds.mean())

        if window_vol <= low_threshold:
            regimes.append("Neutral")

        else:
            if sign_pred > 0:
                regimes.append("Bull")
            elif sign_pred < 0:
                regimes.append("Bear")
            else:
                regimes.append("Uncertain")

    return regimes

vol_value = original['Volatility']
regimes = classify_regime(original['Returns'], vol_value)

# %%
####################
######  Plots ######
####################

# Plot price vs. date regime shifts in
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Actual'][3:])
plt.plot(original['Date'][3:], predicted['Predicted'][3:], color='black', alpha=0.65)
# plt.fill_between(original['Date'][3:],original['Actual'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4);
# plt.fill_between(original['Date'][3:], original['Actual'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4);
# plt.fill_between(original['Date'][3:], original['Actual'][3:], where=[r == 'Neutral' for r in regimes], color='purple', alpha=0.1);

plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Neutral' for r in regimes], color='grey', alpha=0.3);

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2029653710.py:20: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot regime shift for log returns vs. date
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Returns'][3:])
plt.plot(original['Date'][3:], predicted['Returns'][3:], color='red', alpha=0.6)
# plt.fill_between(original['Date'][3:],original['Returns'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4);
# plt.fill_between(original['Date'][3:], original['Returns'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4);
# plt.fill_between(original['Date'][3:], original['Returns'][3:], where=[r == 'Neutral' for r in regimes], color='black', alpha=0.1);

# plt.fill_between(original['Date'][3:], predicted['Returns'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4);
# plt.fill_between(original['Date'][3:], predicted['Returns'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4);
# plt.fill_between(original['Date'][3:], predicted['Returns'][3:], where=[r == 'Neutral' for r in regimes], color='black', alpha=0.1);

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-302823133.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = original['Actual'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(13, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = predicted['Predicted'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(13, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()
