# %%
#####################
## Ethereum (ETH)  ##
#####################

# %%
# !pip install pyts
# !pip install tensorflow
# !pip install numpy
# !pip install pandas
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from pyts) (2.0.2)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from pyts) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyts) (1.6.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from pyts) (1.5.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.12/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 66.8 MB/s eta 0:00:00
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#################
### Libraries ###
#################

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from pyts.image import GramianAngularField, MarkovTransitionField
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, LSTM, Dense, Flatten, Concatenate
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam, RMSprop

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Set 3 seeds and record the model performance for each : 42, 45, 91
# Best seed 45
tf.random.set_seed(45)
np.random.seed(45)

# %%
#################
###   Data    ###
#################

ethereum = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ETH_noscale.csv')
ethereum.drop(columns=['Crypto', 'Open', 'High', 'Low'], inplace=True)
ethereum.head()
# Out:
#          Date   Close
# 0  2018-01-01  757.01
# 1  2018-01-02  864.00
# 2  2018-01-03  938.00
# 3  2018-01-04  942.04
# 4  2018-01-05  958.00

# %%
########################
#### Input GAF/MTF  ####
########################

eth = ethereum.iloc[:]

# ------------
# Parameters
# ------------
window_size = 224     # timesteps per sample
image_size = 224      # size for GAF/MTF images
train_ratio = 0.65    # training ratio
val_ratio = 0.10      # validation ratio


# ----------------------
# Step 1 — Normalization
# ----------------------
scaler = MinMaxScaler(feature_range=(0, 1))
eth['close_scaled'] = scaler.fit_transform(eth[['Close']])

# ---------------------------------
# Step 2 — Generate sliding windows
# ---------------------------------
def create_sequences(series, window_size):
    X_seq = []
    y = []
    for i in range(len(series) - window_size):
        X_seq.append(series[i:i+window_size])
        y.append(series[i+window_size])  # predict next value
    return np.array(X_seq), np.array(y)

X_seq, y = create_sequences(eth['close_scaled'].values, window_size)

# ---------------------------------
# Step 3 — GAF & MTF for CNN branch
# ---------------------------------
gasf = GramianAngularField(image_size=image_size, method='summation')
gadf = GramianAngularField(image_size=image_size, method='difference')
mtf = MarkovTransitionField(image_size=image_size)

# Apply transforms to each sequence
X_gasf = gasf.fit_transform(X_seq)
X_gadf = gadf.fit_transform(X_seq)
X_mtf = mtf.fit_transform(X_seq)

# Stack into channels: (samples, H, W, 3)
X_cnn = np.stack((X_gasf, X_gadf, X_mtf), axis=-1)

# --------------------------
# Step 4 — LSTM branch input
# --------------------------
# LSTM expects shape: (samples, timesteps, features)
X_lstm = X_seq.reshape((X_seq.shape[0], X_seq.shape[1], 1))

# %%
# -------------------------------
# Step 5 — Train/Test split
# -------------------------------
n_samples = len(X_seq)
train_end = int(n_samples * train_ratio)
val_end = train_end + int(n_samples * val_ratio)

X_cnn_train, X_cnn_val, X_cnn_test = X_cnn[:train_end], X_cnn[train_end:val_end], X_cnn[val_end:]
X_lstm_train, X_lstm_val, X_lstm_test = X_lstm[:train_end], X_lstm[train_end:val_end], X_lstm[val_end:]
y_train, y_val, y_test = y[:train_end], y[train_end:val_end], y[val_end:]

# -------------------
# Shapes check
# -------------------
print("CNN train shape:", X_cnn_train.shape)   # (samples, H, W, 3)
print("LSTM train shape:", X_lstm_train.shape) # (samples, timesteps, 1)
print("Targets train shape:", y_train.shape)
# Out:
# CNN train shape: (1139, 224, 224, 3)
# LSTM train shape: (1139, 224, 1)
# Targets train shape: (1139,)

# %%
################
##### CNN  #####
################

# ------------------------
# Step 1 — Build Input CNN
# ------------------------
cnn_input = Input(shape=(224, 224, 3))
dropout_rate = 0.29145153405423596
activation_func = 'relu'

# --------------------------------------------
# Step 2 — Build VGG16 Model (pre-trained CNN)
# --------------------------------------------

vgg = VGG16(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)

# ----------------------------------
# Step 3 — Convolution/Pooling/Dense
# ----------------------------------

# Conv2D 64-10, Flatten, Dense(200)
x = vgg(cnn_input)
x = layers.Conv2D(128, (2, 2), activation=activation_func)(x)
x = layers.Conv2D(64, (2, 2), activation=activation_func)(x)
x = layers.Flatten()(x)
x = layers.Dropout(dropout_rate)(x)
x = layers.Dense(128, activation=activation_func)(x)
cnn_out = x

# ---------------------------
# Step 4 — Input LSTM
# ---------------------------

# Parameters
act_func = 'tanh'
n_timesteps = X_lstm_train.shape[1]
n_features = X_lstm_train.shape[2]

# ---------------------------
# Step 5 — LSTM structure
# ---------------------------

lstm_input = Input(shape=(n_timesteps,n_features))
y = LSTM(64, return_sequences=True, activation='tanh')(lstm_input)
y = LSTM(16, return_sequences=True, activation='tanh')(y)
y = LSTM(2, return_sequences=False, activation='tanh')(y)
lstm_out = y


# ---------------------------
# Step 6 — Concated O/P
# ---------------------------
combined = Concatenate()([cnn_out, lstm_out])
output = Dense(1, activation='linear')(combined)


# ----------------------------------
# Step 7 — Compile Model/Regression
# ----------------------------------
optimizer_func = RMSprop(learning_rate=0.0004047368844376192)
model = Model(inputs=[cnn_input, lstm_input], outputs=output)
model.compile(loss='mean_squared_error', optimizer=optimizer_func, metrics=['mae', RootMeanSquaredError(), 'mape'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
# --------------------
# Step 8 — Training
# --------------------

history = model.fit([X_cnn_train, X_lstm_train], y_train,
                   epochs=150, batch_size=64,
                    validation_data=([X_cnn_val, X_lstm_val], y_val),
                   verbose=2)
# Out:
# Epoch 1/150
# 19/19 - 25s - 1s/step - loss: 161.9794 - mae: 3.2445 - mape: 43240.9180 - root_mean_squared_error: 12.7271 - val_loss: 0.2625 - val_mae: 0.5005 - val_mape: 75.4796 - val_root_mean_squared_error: 0.5123
# Epoch 2/150
# 19/19 - 3s - 133ms/step - loss: 0.0663 - mae: 0.1976 - mape: 195535.0469 - root_mean_squared_error: 0.2576 - val_loss: 0.0705 - val_mae: 0.2396 - val_mape: 34.4095 - val_root_mean_squared_error: 0.2655
# Epoch 3/150
# 19/19 - 3s - 134ms/step - loss: 0.0670 - mae: 0.1985 - mape: 160089.3906 - root_mean_squared_error: 0.2589 - val_loss: 0.2093 - val_mae: 0.4491 - val_mape: 68.0493 - val_root_mean_squared_error: 0.4575
# Epoch 4/150
# 19/19 - 3s - 134ms/step - loss: 0.0588 - mae: 0.1823 - mape: 104707.1875 - root_mean_squared_error: 0.2425 - val_loss: 0.1825 - val_mae: 0.4193 - val_mape: 63.8949 - val_root_mean_squared_error: 0.4272
# Epoch 5/150
# 19/19 - 3s - 133ms/step - loss: 0.0477 - mae: 0.1573 - mape: 19788.6641 - root_mean_squared_error: 0.2184 - val_loss: 0.1282 - val_mae: 0.3455 - val_mape: 51.8948 - val_root_mean_squared_error: 0.3581
# Epoch 6/150
# 19/19 - 3s - 134ms/step - loss: 0.0433 - mae: 0.1459 - mape: 129597.9219 - root_mean_squared_error: 0.2080 - val_loss: 0.0922 - val_mae: 0.2906 - val_mape: 43.7054 - val_root_mean_squared_error: 0.3037
# Epoch 7/150
# 19/19 - 3s - 133ms/step - loss: 0.0300 - mae: 0.1213 - mape: 1514.9028 - root_mean_squared_error: 0.1733 - val_loss: 0.0799 - val_mae: 0.2601 - val_mape: 37.8362 - val_root_mean_squared_error: 0.2827
# Epoch 8/150
# 19/19 - 3s - 133ms/step - loss: 0.0352 - mae: 0.1315 - mape: 9762.8262 - root_mean_squared_error: 0.1875 - val_loss: 0.0780 - val_mae: 0.2653 - val_mape: 39.2499 - val_root_mean_squared_error: 0.2793
# Epoch 9/150
# 19/19 - 3s - 133ms/step - loss: 0.0218 - mae: 0.0976 - mape: 20140.8496 - root_mean_squared_error: 0.1477 - val_loss: 0.0536 - val_mae: 0.2153 - val_mape: 31.4442 - val_root_mean_squared_error: 0.2316
# Epoch 10/150
# 19/19 - 3s - 133ms/step - loss: 0.0276 - mae: 0.1132 - mape: 90747.7578 - root_mean_squared_error: 0.1662 - val_loss: 0.0502 - val_mae: 0.2030 - val_mape: 29.2500 - val_root_mean_squared_error: 0.2241
# Epoch 11/150
# 19/19 - 3s - 134ms/step - loss: 0.0169 - mae: 0.0883 - mape: 25443.6309 - root_mean_squared_error: 0.1300 - val_loss: 0.1113 - val_mae: 0.3145 - val_mape: 46.2173 - val_root_mean_squared_error: 0.3336
# Epoch 12/150
# 19/19 - 3s - 133ms/step - loss: 0.0151 - mae: 0.0803 - mape: 27214.4590 - root_mean_squared_error: 0.1227 - val_loss: 0.0639 - val_mae: 0.2286 - val_mape: 32.8532 - val_root_mean_squared_error: 0.2527
# Epoch 13/150
# 19/19 - 3s - 133ms/step - loss: 0.0280 - mae: 0.1152 - mape: 20595.1367 - root_mean_squared_error: 0.1673 - val_loss: 0.0207 - val_mae: 0.1240 - val_mape: 21.3054 - val_root_mean_squared_error: 0.1437
# Epoch 14/150
# 19/19 - 3s - 134ms/step - loss: 0.0142 - mae: 0.0775 - mape: 1604.8997 - root_mean_squared_error: 0.1191 - val_loss: 0.0344 - val_mae: 0.1697 - val_mape: 24.7207 - val_root_mean_squared_error: 0.1855
# Epoch 15/150
# 19/19 - 3s - 133ms/step - loss: 0.0092 - mae: 0.0622 - mape: 31470.2930 - root_mean_squared_error: 0.0962 - val_loss: 0.0738 - val_mae: 0.2542 - val_mape: 37.2011 - val_root_mean_squared_error: 0.2717
# Epoch 16/150
# 19/19 - 3s - 134ms/step - loss: 0.0073 - mae: 0.0563 - mape: 5265.3496 - root_mean_squared_error: 0.0854 - val_loss: 0.0373 - val_mae: 0.1743 - val_mape: 25.0946 - val_root_mean_squared_error: 0.1931
# Epoch 17/150
# 19/19 - 3s - 134ms/step - loss: 0.0078 - mae: 0.0565 - mape: 30277.5117 - root_mean_squared_error: 0.0886 - val_loss: 0.0637 - val_mae: 0.2293 - val_mape: 33.0559 - val_root_mean_squared_error: 0.2525
# Epoch 18/150
# 19/19 - 3s - 133ms/step - loss: 0.0049 - mae: 0.0469 - mape: 20210.9434 - root_mean_squared_error: 0.0701 - val_loss: 0.0389 - val_mae: 0.1788 - val_mape: 25.9667 - val_root_mean_squared_error: 0.1973
# Epoch 19/150
# 19/19 - 3s - 133ms/step - loss: 0.0023 - mae: 0.0329 - mape: 9802.8945 - root_mean_squared_error: 0.0476 - val_loss: 0.0506 - val_mae: 0.2073 - val_mape: 30.2090 - val_root_mean_squared_error: 0.2249
# Epoch 20/150
# 19/19 - 3s - 134ms/step - loss: 0.0106 - mae: 0.0602 - mape: 16268.7412 - root_mean_squared_error: 0.1030 - val_loss: 0.0266 - val_mae: 0.1301 - val_mape: 17.8262 - val_root_mean_squared_error: 0.1631
# Epoch 21/150
# 19/19 - 3s - 133ms/step - loss: 0.0081 - mae: 0.0546 - mape: 7231.6201 - root_mean_squared_error: 0.0897 - val_loss: 0.0219 - val_mae: 0.1219 - val_mape: 16.9333 - val_root_mean_squared_error: 0.1479
# Epoch 22/150
# 19/19 - 3s - 134ms/step - loss: 0.0064 - mae: 0.0489 - mape: 1478.7919 - root_mean_squared_error: 0.0797 - val_loss: 0.0188 - val_mae: 0.1089 - val_mape: 14.9466 - val_root_mean_squared_error: 0.1372
# Epoch 23/150
# 19/19 - 3s - 133ms/step - loss: 0.0054 - mae: 0.0454 - mape: 8731.3428 - root_mean_squared_error: 0.0733 - val_loss: 0.0112 - val_mae: 0.0890 - val_mape: 12.7123 - val_root_mean_squared_error: 0.1057
# Epoch 24/150
# 19/19 - 3s - 134ms/step - loss: 0.0032 - mae: 0.0352 - mape: 5921.8193 - root_mean_squared_error: 0.0567 - val_loss: 0.0251 - val_mae: 0.1221 - val_mape: 16.4303 - val_root_mean_squared_error: 0.1584
# Epoch 25/150
# 19/19 - 3s - 134ms/step - loss: 0.0043 - mae: 0.0407 - mape: 28654.5898 - root_mean_squared_error: 0.0656 - val_loss: 0.0191 - val_mae: 0.1052 - val_mape: 14.3253 - val_root_mean_squared_error: 0.1382
# Epoch 26/150
# 19/19 - 3s - 133ms/step - loss: 0.0062 - mae: 0.0478 - mape: 28679.2559 - root_mean_squared_error: 0.0785 - val_loss: 0.0158 - val_mae: 0.0988 - val_mape: 13.8031 - val_root_mean_squared_error: 0.1256
# Epoch 27/150
# 19/19 - 3s - 133ms/step - loss: 0.0038 - mae: 0.0395 - mape: 24348.0742 - root_mean_squared_error: 0.0619 - val_loss: 0.0077 - val_mae: 0.0722 - val_mape: 10.4139 - val_root_mean_squared_error: 0.0877
# Epoch 28/150
# 19/19 - 3s - 133ms/step - loss: 0.0018 - mae: 0.0273 - mape: 13835.1758 - root_mean_squared_error: 0.0428 - val_loss: 0.0085 - val_mae: 0.0762 - val_mape: 10.9490 - val_root_mean_squared_error: 0.0923
# Epoch 29/150
# 19/19 - 3s - 133ms/step - loss: 0.0015 - mae: 0.0252 - mape: 8407.8594 - root_mean_squared_error: 0.0386 - val_loss: 0.0137 - val_mae: 0.0938 - val_mape: 13.1240 - val_root_mean_squared_error: 0.1172
# Epoch 30/150
# 19/19 - 3s - 133ms/step - loss: 0.0015 - mae: 0.0249 - mape: 11504.3721 - root_mean_squared_error: 0.0386 - val_loss: 0.0074 - val_mae: 0.0709 - val_mape: 10.4207 - val_root_mean_squared_error: 0.0861
# Epoch 31/150
# 19/19 - 3s - 134ms/step - loss: 0.0012 - mae: 0.0223 - mape: 23000.1348 - root_mean_squared_error: 0.0341 - val_loss: 0.0157 - val_mae: 0.0991 - val_mape: 13.6414 - val_root_mean_squared_error: 0.1254
# Epoch 32/150
# 19/19 - 3s - 133ms/step - loss: 0.0014 - mae: 0.0244 - mape: 12616.6582 - root_mean_squared_error: 0.0372 - val_loss: 0.0170 - val_mae: 0.1022 - val_mape: 13.9922 - val_root_mean_squared_error: 0.1306
# Epoch 33/150
# 19/19 - 3s - 133ms/step - loss: 0.0012 - mae: 0.0221 - mape: 9344.5098 - root_mean_squared_error: 0.0351 - val_loss: 0.0116 - val_mae: 0.0861 - val_mape: 12.1479 - val_root_mean_squared_error: 0.1077
# Epoch 34/150
# 19/19 - 3s - 135ms/step - loss: 0.0012 - mae: 0.0231 - mape: 12951.5635 - root_mean_squared_error: 0.0348 - val_loss: 0.0125 - val_mae: 0.0890 - val_mape: 12.4888 - val_root_mean_squared_error: 0.1117
# Epoch 35/150
# 19/19 - 3s - 134ms/step - loss: 9.4344e-04 - mae: 0.0204 - mape: 13895.7803 - root_mean_squared_error: 0.0307 - val_loss: 0.0119 - val_mae: 0.0884 - val_mape: 12.4977 - val_root_mean_squared_error: 0.1091
# Epoch 36/150
# 19/19 - 3s - 133ms/step - loss: 0.0010 - mae: 0.0205 - mape: 7679.7378 - root_mean_squared_error: 0.0316 - val_loss: 0.0124 - val_mae: 0.0904 - val_mape: 12.7654 - val_root_mean_squared_error: 0.1115
# Epoch 37/150
# 19/19 - 3s - 133ms/step - loss: 9.8897e-04 - mae: 0.0209 - mape: 4961.3647 - root_mean_squared_error: 0.0314 - val_loss: 0.0125 - val_mae: 0.0897 - val_mape: 12.5739 - val_root_mean_squared_error: 0.1119
# Epoch 38/150
# 19/19 - 3s - 134ms/step - loss: 8.5375e-04 - mae: 0.0194 - mape: 16976.0781 - root_mean_squared_error: 0.0292 - val_loss: 0.0091 - val_mae: 0.0770 - val_mape: 11.1546 - val_root_mean_squared_error: 0.0953
# Epoch 39/150
# 19/19 - 3s - 134ms/step - loss: 9.7190e-04 - mae: 0.0205 - mape: 2484.3027 - root_mean_squared_error: 0.0312 - val_loss: 0.0098 - val_mae: 0.0802 - val_mape: 11.5369 - val_root_mean_squared_error: 0.0992
# Epoch 40/150
# 19/19 - 3s - 133ms/step - loss: 8.6557e-04 - mae: 0.0196 - mape: 28170.3418 - root_mean_squared_error: 0.0294 - val_loss: 0.0121 - val_mae: 0.0878 - val_mape: 12.3016 - val_root_mean_squared_error: 0.1100
# Epoch 41/150
# 19/19 - 3s - 134ms/step - loss: 8.6532e-04 - mae: 0.0192 - mape: 9697.9600 - root_mean_squared_error: 0.0294 - val_loss: 0.0114 - val_mae: 0.0850 - val_mape: 11.9380 - val_root_mean_squared_error: 0.1068
# Epoch 42/150
# 19/19 - 3s - 134ms/step - loss: 8.2867e-04 - mae: 0.0191 - mape: 17770.2852 - root_mean_squared_error: 0.0288 - val_loss: 0.0106 - val_mae: 0.0826 - val_mape: 11.7422 - val_root_mean_squared_error: 0.1029
# Epoch 43/150
# 19/19 - 3s - 133ms/step - loss: 8.8617e-04 - mae: 0.0197 - mape: 12730.2471 - root_mean_squared_error: 0.0298 - val_loss: 0.0084 - val_mae: 0.0736 - val_mape: 10.6793 - val_root_mean_squared_error: 0.0918
# Epoch 44/150
# 19/19 - 3s - 134ms/step - loss: 8.0207e-04 - mae: 0.0188 - mape: 11344.1768 - root_mean_squared_error: 0.0283 - val_loss: 0.0089 - val_mae: 0.0759 - val_mape: 10.9518 - val_root_mean_squared_error: 0.0946
# Epoch 45/150
# 19/19 - 3s - 133ms/step - loss: 6.7139e-04 - mae: 0.0175 - mape: 9203.5400 - root_mean_squared_error: 0.0259 - val_loss: 0.0089 - val_mae: 0.0771 - val_mape: 11.1036 - val_root_mean_squared_error: 0.0942
# Epoch 46/150
# 19/19 - 3s - 133ms/step - loss: 6.7677e-04 - mae: 0.0175 - mape: 12207.0674 - root_mean_squared_error: 0.0260 - val_loss: 0.0097 - val_mae: 0.0789 - val_mape: 11.2255 - val_root_mean_squared_error: 0.0985
# Epoch 47/150
# 19/19 - 3s - 132ms/step - loss: 7.2826e-04 - mae: 0.0181 - mape: 18713.6328 - root_mean_squared_error: 0.0270 - val_loss: 0.0112 - val_mae: 0.0850 - val_mape: 11.9662 - val_root_mean_squared_error: 0.1061
# Epoch 48/150
# 19/19 - 3s - 133ms/step - loss: 7.2119e-04 - mae: 0.0176 - mape: 13351.9111 - root_mean_squared_error: 0.0269 - val_loss: 0.0107 - val_mae: 0.0830 - val_mape: 11.7299 - val_root_mean_squared_error: 0.1033
# Epoch 49/150
# 19/19 - 3s - 134ms/step - loss: 6.9869e-04 - mae: 0.0175 - mape: 23940.7266 - root_mean_squared_error: 0.0264 - val_loss: 0.0095 - val_mae: 0.0780 - val_mape: 11.1718 - val_root_mean_squared_error: 0.0975
# Epoch 50/150
# 19/19 - 3s - 133ms/step - loss: 5.9760e-04 - mae: 0.0163 - mape: 12286.2891 - root_mean_squared_error: 0.0244 - val_loss: 0.0088 - val_mae: 0.0756 - val_mape: 10.9063 - val_root_mean_squared_error: 0.0939
# Epoch 51/150
# 19/19 - 3s - 134ms/step - loss: 7.0822e-04 - mae: 0.0179 - mape: 15986.5645 - root_mean_squared_error: 0.0266 - val_loss: 0.0098 - val_mae: 0.0799 - val_mape: 11.3816 - val_root_mean_squared_error: 0.0990
# Epoch 52/150
# 19/19 - 3s - 133ms/step - loss: 6.1871e-04 - mae: 0.0164 - mape: 11641.8809 - root_mean_squared_error: 0.0249 - val_loss: 0.0095 - val_mae: 0.0782 - val_mape: 11.2070 - val_root_mean_squared_error: 0.0973
# Epoch 53/150
# 19/19 - 3s - 133ms/step - loss: 6.5332e-04 - mae: 0.0167 - mape: 18265.4688 - root_mean_squared_error: 0.0256 - val_loss: 0.0092 - val_mae: 0.0772 - val_mape: 11.0636 - val_root_mean_squared_error: 0.0958
# Epoch 54/150
# 19/19 - 3s - 134ms/step - loss: 6.2647e-04 - mae: 0.0170 - mape: 15645.8115 - root_mean_squared_error: 0.0250 - val_loss: 0.0083 - val_mae: 0.0734 - val_mape: 10.6521 - val_root_mean_squared_error: 0.0913
# Epoch 55/150
# 19/19 - 3s - 133ms/step - loss: 5.9084e-04 - mae: 0.0161 - mape: 8870.6777 - root_mean_squared_error: 0.0243 - val_loss: 0.0100 - val_mae: 0.0814 - val_mape: 11.7775 - val_root_mean_squared_error: 0.1000
# Epoch 56/150
# 19/19 - 3s - 133ms/step - loss: 5.9710e-04 - mae: 0.0158 - mape: 11762.8311 - root_mean_squared_error: 0.0244 - val_loss: 0.0091 - val_mae: 0.0774 - val_mape: 11.1049 - val_root_mean_squared_error: 0.0956
# Epoch 57/150
# 19/19 - 3s - 134ms/step - loss: 8.6084e-04 - mae: 0.0187 - mape: 5252.6572 - root_mean_squared_error: 0.0293 - val_loss: 0.0092 - val_mae: 0.0777 - val_mape: 11.1563 - val_root_mean_squared_error: 0.0962
# Epoch 58/150
# 19/19 - 3s - 133ms/step - loss: 5.3603e-04 - mae: 0.0153 - mape: 13695.2373 - root_mean_squared_error: 0.0232 - val_loss: 0.0118 - val_mae: 0.0869 - val_mape: 12.1813 - val_root_mean_squared_error: 0.1085
# Epoch 59/150
# 19/19 - 3s - 133ms/step - loss: 7.0653e-04 - mae: 0.0170 - mape: 18981.9297 - root_mean_squared_error: 0.0266 - val_loss: 0.0093 - val_mae: 0.0780 - val_mape: 11.2070 - val_root_mean_squared_error: 0.0967
# Epoch 60/150
# 19/19 - 3s - 134ms/step - loss: 5.0113e-04 - mae: 0.0146 - mape: 15993.4785 - root_mean_squared_error: 0.0224 - val_loss: 0.0094 - val_mae: 0.0774 - val_mape: 11.0795 - val_root_mean_squared_error: 0.0967
# Epoch 61/150
# 19/19 - 3s - 132ms/step - loss: 6.2616e-04 - mae: 0.0163 - mape: 17879.6094 - root_mean_squared_error: 0.0250 - val_loss: 0.0095 - val_mae: 0.0779 - val_mape: 11.1255 - val_root_mean_squared_error: 0.0973
# Epoch 62/150
# 19/19 - 3s - 133ms/step - loss: 5.2756e-04 - mae: 0.0153 - mape: 10662.2461 - root_mean_squared_error: 0.0230 - val_loss: 0.0100 - val_mae: 0.0805 - val_mape: 11.5065 - val_root_mean_squared_error: 0.0999
# Epoch 63/150
# 19/19 - 3s - 134ms/step - loss: 5.0346e-04 - mae: 0.0148 - mape: 9957.8086 - root_mean_squared_error: 0.0224 - val_loss: 0.0087 - val_mae: 0.0748 - val_mape: 10.8016 - val_root_mean_squared_error: 0.0933
# Epoch 64/150
# 19/19 - 3s - 133ms/step - loss: 5.1626e-04 - mae: 0.0150 - mape: 8479.4229 - root_mean_squared_error: 0.0227 - val_loss: 0.0097 - val_mae: 0.0790 - val_mape: 11.2767 - val_root_mean_squared_error: 0.0986
# Epoch 65/150
# 19/19 - 3s - 133ms/step - loss: 5.5432e-04 - mae: 0.0155 - mape: 16195.3018 - root_mean_squared_error: 0.0235 - val_loss: 0.0096 - val_mae: 0.0792 - val_mape: 11.4270 - val_root_mean_squared_error: 0.0979
# Epoch 66/150
# 19/19 - 3s - 132ms/step - loss: 5.2225e-04 - mae: 0.0151 - mape: 12776.2705 - root_mean_squared_error: 0.0229 - val_loss: 0.0101 - val_mae: 0.0809 - val_mape: 11.5400 - val_root_mean_squared_error: 0.1006
# Epoch 67/150
# 19/19 - 3s - 134ms/step - loss: 4.6728e-04 - mae: 0.0144 - mape: 10317.1104 - root_mean_squared_error: 0.0216 - val_loss: 0.0088 - val_mae: 0.0760 - val_mape: 10.9857 - val_root_mean_squared_error: 0.0940
# Epoch 68/150
# 19/19 - 3s - 133ms/step - loss: 4.9518e-04 - mae: 0.0144 - mape: 11951.7881 - root_mean_squared_error: 0.0223 - val_loss: 0.0076 - val_mae: 0.0688 - val_mape: 10.0973 - val_root_mean_squared_error: 0.0870
# Epoch 69/150
# 19/19 - 3s - 133ms/step - loss: 4.3483e-04 - mae: 0.0138 - mape: 12187.3164 - root_mean_squared_error: 0.0209 - val_loss: 0.0096 - val_mae: 0.0789 - val_mape: 11.3179 - val_root_mean_squared_error: 0.0982
# Epoch 70/150
# 19/19 - 3s - 132ms/step - loss: 5.0817e-04 - mae: 0.0146 - mape: 6478.6831 - root_mean_squared_error: 0.0225 - val_loss: 0.0090 - val_mae: 0.0767 - val_mape: 11.0805 - val_root_mean_squared_error: 0.0948
# Epoch 71/150
# 19/19 - 3s - 132ms/step - loss: 4.4269e-04 - mae: 0.0140 - mape: 14278.5908 - root_mean_squared_error: 0.0210 - val_loss: 0.0094 - val_mae: 0.0779 - val_mape: 11.1681 - val_root_mean_squared_error: 0.0969
# Epoch 72/150
# 19/19 - 3s - 133ms/step - loss: 5.2408e-04 - mae: 0.0144 - mape: 13445.5107 - root_mean_squared_error: 0.0229 - val_loss: 0.0081 - val_mae: 0.0719 - val_mape: 10.4600 - val_root_mean_squared_error: 0.0899
# Epoch 73/150
# 19/19 - 3s - 134ms/step - loss: 4.2909e-04 - mae: 0.0135 - mape: 11738.6621 - root_mean_squared_error: 0.0207 - val_loss: 0.0086 - val_mae: 0.0750 - val_mape: 10.9426 - val_root_mean_squared_error: 0.0930
# Epoch 74/150
# 19/19 - 3s - 133ms/step - loss: 5.0914e-04 - mae: 0.0146 - mape: 9531.4160 - root_mean_squared_error: 0.0226 - val_loss: 0.0117 - val_mae: 0.0866 - val_mape: 12.1675 - val_root_mean_squared_error: 0.1081
# Epoch 75/150
# 19/19 - 3s - 133ms/step - loss: 4.9856e-04 - mae: 0.0138 - mape: 13194.0518 - root_mean_squared_error: 0.0223 - val_loss: 0.0082 - val_mae: 0.0723 - val_mape: 10.5554 - val_root_mean_squared_error: 0.0905
# Epoch 76/150
# 19/19 - 3s - 133ms/step - loss: 4.6629e-04 - mae: 0.0140 - mape: 12319.2188 - root_mean_squared_error: 0.0216 - val_loss: 0.0087 - val_mae: 0.0748 - val_mape: 10.8649 - val_root_mean_squared_error: 0.0930
# Epoch 77/150
# 19/19 - 3s - 133ms/step - loss: 4.3613e-04 - mae: 0.0136 - mape: 12158.8271 - root_mean_squared_error: 0.0209 - val_loss: 0.0097 - val_mae: 0.0798 - val_mape: 11.4903 - val_root_mean_squared_error: 0.0985
# Epoch 78/150
# 19/19 - 3s - 134ms/step - loss: 3.5101e-04 - mae: 0.0126 - mape: 11084.4297 - root_mean_squared_error: 0.0187 - val_loss: 0.0094 - val_mae: 0.0782 - val_mape: 11.2292 - val_root_mean_squared_error: 0.0971
# Epoch 79/150
# 19/19 - 3s - 133ms/step - loss: 4.4641e-04 - mae: 0.0138 - mape: 14577.7109 - root_mean_squared_error: 0.0211 - val_loss: 0.0090 - val_mae: 0.0763 - val_mape: 11.0106 - val_root_mean_squared_error: 0.0950
# Epoch 80/150
# 19/19 - 3s - 133ms/step - loss: 3.8917e-04 - mae: 0.0130 - mape: 15031.5020 - root_mean_squared_error: 0.0197 - val_loss: 0.0102 - val_mae: 0.0808 - val_mape: 11.5296 - val_root_mean_squared_error: 0.1008
# Epoch 81/150
# 19/19 - 3s - 133ms/step - loss: 4.2623e-04 - mae: 0.0133 - mape: 10899.0518 - root_mean_squared_error: 0.0206 - val_loss: 0.0089 - val_mae: 0.0756 - val_mape: 10.9748 - val_root_mean_squared_error: 0.0941
# Epoch 82/150
# 19/19 - 3s - 133ms/step - loss: 4.2772e-04 - mae: 0.0138 - mape: 13350.6025 - root_mean_squared_error: 0.0207 - val_loss: 0.0094 - val_mae: 0.0778 - val_mape: 11.1698 - val_root_mean_squared_error: 0.0970
# Epoch 83/150
# 19/19 - 3s - 133ms/step - loss: 3.4809e-04 - mae: 0.0125 - mape: 12736.8408 - root_mean_squared_error: 0.0187 - val_loss: 0.0089 - val_mae: 0.0757 - val_mape: 10.9258 - val_root_mean_squared_error: 0.0945
# Epoch 84/150
# 19/19 - 3s - 133ms/step - loss: 4.3359e-04 - mae: 0.0137 - mape: 10796.2334 - root_mean_squared_error: 0.0208 - val_loss: 0.0098 - val_mae: 0.0792 - val_mape: 11.3165 - val_root_mean_squared_error: 0.0988
# Epoch 85/150
# 19/19 - 3s - 133ms/step - loss: 4.2476e-04 - mae: 0.0135 - mape: 12669.8086 - root_mean_squared_error: 0.0206 - val_loss: 0.0097 - val_mae: 0.0788 - val_mape: 11.2860 - val_root_mean_squared_error: 0.0983
# Epoch 86/150
# 19/19 - 3s - 133ms/step - loss: 3.9251e-04 - mae: 0.0130 - mape: 13987.3037 - root_mean_squared_error: 0.0198 - val_loss: 0.0083 - val_mae: 0.0735 - val_mape: 10.7509 - val_root_mean_squared_error: 0.0910
# Epoch 87/150
# 19/19 - 3s - 133ms/step - loss: 4.5019e-04 - mae: 0.0136 - mape: 8351.3486 - root_mean_squared_error: 0.0212 - val_loss: 0.0090 - val_mae: 0.0768 - val_mape: 11.2019 - val_root_mean_squared_error: 0.0949
# Epoch 88/150
# 19/19 - 3s - 132ms/step - loss: 3.7779e-04 - mae: 0.0129 - mape: 12811.1377 - root_mean_squared_error: 0.0194 - val_loss: 0.0090 - val_mae: 0.0757 - val_mape: 10.9142 - val_root_mean_squared_error: 0.0947
# Epoch 89/150
# 19/19 - 3s - 133ms/step - loss: 3.4080e-04 - mae: 0.0120 - mape: 9929.8594 - root_mean_squared_error: 0.0185 - val_loss: 0.0088 - val_mae: 0.0757 - val_mape: 11.0244 - val_root_mean_squared_error: 0.0938
# Epoch 90/150
# 19/19 - 3s - 132ms/step - loss: 4.0339e-04 - mae: 0.0132 - mape: 15627.1230 - root_mean_squared_error: 0.0201 - val_loss: 0.0087 - val_mae: 0.0751 - val_mape: 10.9372 - val_root_mean_squared_error: 0.0932
# Epoch 91/150
# 19/19 - 3s - 133ms/step - loss: 3.6772e-04 - mae: 0.0124 - mape: 14070.1143 - root_mean_squared_error: 0.0192 - val_loss: 0.0104 - val_mae: 0.0814 - val_mape: 11.5910 - val_root_mean_squared_error: 0.1018
# Epoch 92/150
# 19/19 - 3s - 133ms/step - loss: 3.7457e-04 - mae: 0.0126 - mape: 13558.2178 - root_mean_squared_error: 0.0194 - val_loss: 0.0077 - val_mae: 0.0703 - val_mape: 10.3456 - val_root_mean_squared_error: 0.0878
# Epoch 93/150
# 19/19 - 3s - 133ms/step - loss: 3.3666e-04 - mae: 0.0121 - mape: 12995.4717 - root_mean_squared_error: 0.0183 - val_loss: 0.0087 - val_mae: 0.0741 - val_mape: 10.7500 - val_root_mean_squared_error: 0.0932
# Epoch 94/150
# 19/19 - 3s - 133ms/step - loss: 3.9683e-04 - mae: 0.0128 - mape: 13094.8662 - root_mean_squared_error: 0.0199 - val_loss: 0.0076 - val_mae: 0.0692 - val_mape: 10.3110 - val_root_mean_squared_error: 0.0870
# Epoch 95/150
# 19/19 - 3s - 132ms/step - loss: 3.5653e-04 - mae: 0.0124 - mape: 13218.7500 - root_mean_squared_error: 0.0189 - val_loss: 0.0085 - val_mae: 0.0745 - val_mape: 10.9009 - val_root_mean_squared_error: 0.0924
# Epoch 96/150
# 19/19 - 3s - 133ms/step - loss: 3.3929e-04 - mae: 0.0120 - mape: 12178.4307 - root_mean_squared_error: 0.0184 - val_loss: 0.0087 - val_mae: 0.0755 - val_mape: 11.0979 - val_root_mean_squared_error: 0.0933
# Epoch 97/150
# 19/19 - 3s - 132ms/step - loss: 3.7701e-04 - mae: 0.0130 - mape: 7160.5366 - root_mean_squared_error: 0.0194 - val_loss: 0.0080 - val_mae: 0.0721 - val_mape: 10.6260 - val_root_mean_squared_error: 0.0895
# Epoch 98/150
# 19/19 - 3s - 132ms/step - loss: 2.7837e-04 - mae: 0.0110 - mape: 9531.9385 - root_mean_squared_error: 0.0167 - val_loss: 0.0074 - val_mae: 0.0686 - val_mape: 10.1734 - val_root_mean_squared_error: 0.0858
# Epoch 99/150
# 19/19 - 3s - 132ms/step - loss: 3.2893e-04 - mae: 0.0119 - mape: 9084.3105 - root_mean_squared_error: 0.0181 - val_loss: 0.0084 - val_mae: 0.0732 - val_mape: 10.7101 - val_root_mean_squared_error: 0.0916
# Epoch 100/150
# 19/19 - 3s - 133ms/step - loss: 3.2993e-04 - mae: 0.0120 - mape: 9965.8779 - root_mean_squared_error: 0.0182 - val_loss: 0.0086 - val_mae: 0.0748 - val_mape: 10.9552 - val_root_mean_squared_error: 0.0928
# Epoch 101/150
# 19/19 - 3s - 133ms/step - loss: 3.0181e-04 - mae: 0.0116 - mape: 9661.6680 - root_mean_squared_error: 0.0174 - val_loss: 0.0092 - val_mae: 0.0763 - val_mape: 10.9729 - val_root_mean_squared_error: 0.0959
# Epoch 102/150
# 19/19 - 3s - 132ms/step - loss: 3.3331e-04 - mae: 0.0117 - mape: 11047.7422 - root_mean_squared_error: 0.0183 - val_loss: 0.0091 - val_mae: 0.0766 - val_mape: 11.0844 - val_root_mean_squared_error: 0.0953
# Epoch 103/150
# 19/19 - 3s - 132ms/step - loss: 3.7239e-04 - mae: 0.0126 - mape: 13842.9082 - root_mean_squared_error: 0.0193 - val_loss: 0.0089 - val_mae: 0.0757 - val_mape: 11.0077 - val_root_mean_squared_error: 0.0941
# Epoch 104/150
# 19/19 - 3s - 132ms/step - loss: 2.8712e-04 - mae: 0.0113 - mape: 8825.1025 - root_mean_squared_error: 0.0169 - val_loss: 0.0078 - val_mae: 0.0712 - val_mape: 10.6214 - val_root_mean_squared_error: 0.0882
# Epoch 105/150
# 19/19 - 3s - 132ms/step - loss: 2.8999e-04 - mae: 0.0112 - mape: 7564.7202 - root_mean_squared_error: 0.0170 - val_loss: 0.0084 - val_mae: 0.0745 - val_mape: 10.9792 - val_root_mean_squared_error: 0.0919
# Epoch 106/150
# 19/19 - 3s - 132ms/step - loss: 2.6831e-04 - mae: 0.0111 - mape: 10715.6348 - root_mean_squared_error: 0.0164 - val_loss: 0.0087 - val_mae: 0.0747 - val_mape: 10.8342 - val_root_mean_squared_error: 0.0935
# Epoch 107/150
# 19/19 - 3s - 132ms/step - loss: 3.2710e-04 - mae: 0.0118 - mape: 11259.4463 - root_mean_squared_error: 0.0181 - val_loss: 0.0085 - val_mae: 0.0737 - val_mape: 10.8723 - val_root_mean_squared_error: 0.0920
# Epoch 108/150
# 19/19 - 3s - 132ms/step - loss: 3.1415e-04 - mae: 0.0115 - mape: 12352.7900 - root_mean_squared_error: 0.0177 - val_loss: 0.0091 - val_mae: 0.0768 - val_mape: 11.2487 - val_root_mean_squared_error: 0.0955
# Epoch 109/150
# 19/19 - 3s - 132ms/step - loss: 2.3139e-04 - mae: 0.0101 - mape: 11127.4980 - root_mean_squared_error: 0.0152 - val_loss: 0.0084 - val_mae: 0.0737 - val_mape: 10.7574 - val_root_mean_squared_error: 0.0915
# Epoch 110/150
# 19/19 - 3s - 132ms/step - loss: 2.7071e-04 - mae: 0.0114 - mape: 10031.1299 - root_mean_squared_error: 0.0165 - val_loss: 0.0083 - val_mae: 0.0736 - val_mape: 10.8434 - val_root_mean_squared_error: 0.0910
# Epoch 111/150
# 19/19 - 3s - 133ms/step - loss: 2.5861e-04 - mae: 0.0108 - mape: 7188.7686 - root_mean_squared_error: 0.0161 - val_loss: 0.0080 - val_mae: 0.0720 - val_mape: 10.6285 - val_root_mean_squared_error: 0.0895
# Epoch 112/150
# 19/19 - 3s - 132ms/step - loss: 2.8017e-04 - mae: 0.0111 - mape: 4844.4863 - root_mean_squared_error: 0.0167 - val_loss: 0.0082 - val_mae: 0.0727 - val_mape: 10.7212 - val_root_mean_squared_error: 0.0905
# Epoch 113/150
# 19/19 - 3s - 133ms/step - loss: 3.1548e-04 - mae: 0.0115 - mape: 9207.6133 - root_mean_squared_error: 0.0178 - val_loss: 0.0070 - val_mae: 0.0660 - val_mape: 9.9574 - val_root_mean_squared_error: 0.0837
# Epoch 114/150
# 19/19 - 3s - 132ms/step - loss: 3.1473e-04 - mae: 0.0111 - mape: 9783.2959 - root_mean_squared_error: 0.0177 - val_loss: 0.0081 - val_mae: 0.0717 - val_mape: 10.5155 - val_root_mean_squared_error: 0.0899
# Epoch 115/150
# 19/19 - 3s - 132ms/step - loss: 2.8715e-04 - mae: 0.0109 - mape: 13703.7793 - root_mean_squared_error: 0.0169 - val_loss: 0.0086 - val_mae: 0.0742 - val_mape: 10.8263 - val_root_mean_squared_error: 0.0927
# Epoch 116/150
# 19/19 - 3s - 134ms/step - loss: 2.8217e-04 - mae: 0.0110 - mape: 8867.7891 - root_mean_squared_error: 0.0168 - val_loss: 0.0079 - val_mae: 0.0706 - val_mape: 10.3878 - val_root_mean_squared_error: 0.0890
# Epoch 117/150
# 19/19 - 3s - 132ms/step - loss: 2.7490e-04 - mae: 0.0106 - mape: 8414.2207 - root_mean_squared_error: 0.0166 - val_loss: 0.0080 - val_mae: 0.0710 - val_mape: 10.3926 - val_root_mean_squared_error: 0.0896
# Epoch 118/150
# 19/19 - 3s - 132ms/step - loss: 2.8129e-04 - mae: 0.0112 - mape: 11210.6982 - root_mean_squared_error: 0.0168 - val_loss: 0.0083 - val_mae: 0.0734 - val_mape: 11.0627 - val_root_mean_squared_error: 0.0911
# Epoch 119/150
# 19/19 - 3s - 132ms/step - loss: 3.2715e-04 - mae: 0.0118 - mape: 4448.9507 - root_mean_squared_error: 0.0181 - val_loss: 0.0082 - val_mae: 0.0732 - val_mape: 10.7677 - val_root_mean_squared_error: 0.0907
# Epoch 120/150
# 19/19 - 3s - 132ms/step - loss: 2.6312e-04 - mae: 0.0107 - mape: 11210.1738 - root_mean_squared_error: 0.0162 - val_loss: 0.0081 - val_mae: 0.0726 - val_mape: 10.8104 - val_root_mean_squared_error: 0.0898
# Epoch 121/150
# 19/19 - 3s - 133ms/step - loss: 2.6737e-04 - mae: 0.0107 - mape: 3343.5518 - root_mean_squared_error: 0.0164 - val_loss: 0.0084 - val_mae: 0.0743 - val_mape: 10.9699 - val_root_mean_squared_error: 0.0917
# Epoch 122/150
# 19/19 - 3s - 132ms/step - loss: 2.6891e-04 - mae: 0.0106 - mape: 3159.1213 - root_mean_squared_error: 0.0164 - val_loss: 0.0083 - val_mae: 0.0727 - val_mape: 10.6496 - val_root_mean_squared_error: 0.0909
# Epoch 123/150
# 19/19 - 3s - 132ms/step - loss: 2.9295e-04 - mae: 0.0112 - mape: 2870.5696 - root_mean_squared_error: 0.0171 - val_loss: 0.0086 - val_mae: 0.0750 - val_mape: 10.9956 - val_root_mean_squared_error: 0.0927
# Epoch 124/150
# 19/19 - 3s - 132ms/step - loss: 2.7470e-04 - mae: 0.0109 - mape: 13947.7002 - root_mean_squared_error: 0.0166 - val_loss: 0.0080 - val_mae: 0.0719 - val_mape: 10.6238 - val_root_mean_squared_error: 0.0893
# Epoch 125/150
# 19/19 - 3s - 133ms/step - loss: 2.6912e-04 - mae: 0.0106 - mape: 8968.6973 - root_mean_squared_error: 0.0164 - val_loss: 0.0078 - val_mae: 0.0716 - val_mape: 10.6610 - val_root_mean_squared_error: 0.0885
# Epoch 126/150
# 19/19 - 3s - 133ms/step - loss: 2.6280e-04 - mae: 0.0107 - mape: 6018.2856 - root_mean_squared_error: 0.0162 - val_loss: 0.0083 - val_mae: 0.0736 - val_mape: 10.9563 - val_root_mean_squared_error: 0.0911
# Epoch 127/150
# 19/19 - 3s - 132ms/step - loss: 2.5344e-04 - mae: 0.0104 - mape: 1373.4847 - root_mean_squared_error: 0.0159 - val_loss: 0.0083 - val_mae: 0.0733 - val_mape: 10.8275 - val_root_mean_squared_error: 0.0908
# Epoch 128/150
# 19/19 - 3s - 133ms/step - loss: 3.0800e-04 - mae: 0.0114 - mape: 6813.0581 - root_mean_squared_error: 0.0175 - val_loss: 0.0081 - val_mae: 0.0726 - val_mape: 10.7531 - val_root_mean_squared_error: 0.0897
# Epoch 129/150
# 19/19 - 3s - 132ms/step - loss: 2.2585e-04 - mae: 0.0102 - mape: 3780.3398 - root_mean_squared_error: 0.0150 - val_loss: 0.0080 - val_mae: 0.0715 - val_mape: 10.4995 - val_root_mean_squared_error: 0.0895
# Epoch 130/150
# 19/19 - 3s - 132ms/step - loss: 2.4086e-04 - mae: 0.0102 - mape: 9573.9473 - root_mean_squared_error: 0.0155 - val_loss: 0.0083 - val_mae: 0.0726 - val_mape: 10.6590 - val_root_mean_squared_error: 0.0909
# Epoch 131/150
# 19/19 - 3s - 132ms/step - loss: 2.4035e-04 - mae: 0.0101 - mape: 10407.9922 - root_mean_squared_error: 0.0155 - val_loss: 0.0080 - val_mae: 0.0721 - val_mape: 10.7943 - val_root_mean_squared_error: 0.0893
# Epoch 132/150
# 19/19 - 3s - 132ms/step - loss: 2.4523e-04 - mae: 0.0103 - mape: 738.9796 - root_mean_squared_error: 0.0157 - val_loss: 0.0078 - val_mae: 0.0706 - val_mape: 10.4348 - val_root_mean_squared_error: 0.0881
# Epoch 133/150
# 19/19 - 3s - 132ms/step - loss: 2.1913e-04 - mae: 0.0099 - mape: 536.4329 - root_mean_squared_error: 0.0148 - val_loss: 0.0078 - val_mae: 0.0711 - val_mape: 10.7267 - val_root_mean_squared_error: 0.0883
# Epoch 134/150
# 19/19 - 3s - 132ms/step - loss: 2.3153e-04 - mae: 0.0100 - mape: 11755.3828 - root_mean_squared_error: 0.0152 - val_loss: 0.0078 - val_mae: 0.0711 - val_mape: 10.7079 - val_root_mean_squared_error: 0.0880
# Epoch 135/150
# 19/19 - 3s - 133ms/step - loss: 2.5794e-04 - mae: 0.0107 - mape: 9476.9551 - root_mean_squared_error: 0.0161 - val_loss: 0.0072 - val_mae: 0.0677 - val_mape: 10.1680 - val_root_mean_squared_error: 0.0849
# Epoch 136/150
# 19/19 - 3s - 132ms/step - loss: 2.5748e-04 - mae: 0.0106 - mape: 4630.9302 - root_mean_squared_error: 0.0160 - val_loss: 0.0079 - val_mae: 0.0708 - val_mape: 10.4077 - val_root_mean_squared_error: 0.0888
# Epoch 137/150
# 19/19 - 3s - 132ms/step - loss: 2.7827e-04 - mae: 0.0109 - mape: 6370.5986 - root_mean_squared_error: 0.0167 - val_loss: 0.0081 - val_mae: 0.0724 - val_mape: 10.6871 - val_root_mean_squared_error: 0.0900
# Epoch 138/150
# 19/19 - 3s - 133ms/step - loss: 1.8318e-04 - mae: 0.0092 - mape: 8027.9927 - root_mean_squared_error: 0.0135 - val_loss: 0.0076 - val_mae: 0.0704 - val_mape: 10.6947 - val_root_mean_squared_error: 0.0873
# Epoch 139/150
# 19/19 - 3s - 132ms/step - loss: 2.2770e-04 - mae: 0.0102 - mape: 3810.2241 - root_mean_squared_error: 0.0151 - val_loss: 0.0080 - val_mae: 0.0715 - val_mape: 10.5760 - val_root_mean_squared_error: 0.0893
# Epoch 140/150
# 19/19 - 3s - 133ms/step - loss: 2.3975e-04 - mae: 0.0103 - mape: 9463.8350 - root_mean_squared_error: 0.0155 - val_loss: 0.0079 - val_mae: 0.0708 - val_mape: 10.4172 - val_root_mean_squared_error: 0.0889
# Epoch 141/150
# 19/19 - 3s - 132ms/step - loss: 2.3379e-04 - mae: 0.0102 - mape: 12070.9443 - root_mean_squared_error: 0.0153 - val_loss: 0.0080 - val_mae: 0.0715 - val_mape: 10.5837 - val_root_mean_squared_error: 0.0896
# Epoch 142/150
# 19/19 - 3s - 133ms/step - loss: 2.4011e-04 - mae: 0.0099 - mape: 4083.0750 - root_mean_squared_error: 0.0155 - val_loss: 0.0085 - val_mae: 0.0748 - val_mape: 11.2022 - val_root_mean_squared_error: 0.0924
# Epoch 143/150
# 19/19 - 3s - 132ms/step - loss: 2.3742e-04 - mae: 0.0101 - mape: 1444.8813 - root_mean_squared_error: 0.0154 - val_loss: 0.0074 - val_mae: 0.0695 - val_mape: 10.5175 - val_root_mean_squared_error: 0.0857
# Epoch 144/150
# 19/19 - 3s - 132ms/step - loss: 2.2627e-04 - mae: 0.0101 - mape: 9440.9844 - root_mean_squared_error: 0.0150 - val_loss: 0.0079 - val_mae: 0.0716 - val_mape: 10.7031 - val_root_mean_squared_error: 0.0888
# Epoch 145/150
# 19/19 - 3s - 133ms/step - loss: 2.4235e-04 - mae: 0.0101 - mape: 11938.4941 - root_mean_squared_error: 0.0156 - val_loss: 0.0075 - val_mae: 0.0695 - val_mape: 10.3440 - val_root_mean_squared_error: 0.0867
# Epoch 146/150
# 19/19 - 3s - 133ms/step - loss: 2.0813e-04 - mae: 0.0097 - mape: 4783.1997 - root_mean_squared_error: 0.0144 - val_loss: 0.0086 - val_mae: 0.0746 - val_mape: 10.8526 - val_root_mean_squared_error: 0.0927
# Epoch 147/150
# 19/19 - 3s - 133ms/step - loss: 2.5742e-04 - mae: 0.0104 - mape: 3638.5513 - root_mean_squared_error: 0.0160 - val_loss: 0.0080 - val_mae: 0.0716 - val_mape: 10.5553 - val_root_mean_squared_error: 0.0895
# Epoch 148/150
# 19/19 - 3s - 132ms/step - loss: 2.2937e-04 - mae: 0.0096 - mape: 7626.4634 - root_mean_squared_error: 0.0151 - val_loss: 0.0073 - val_mae: 0.0686 - val_mape: 10.3582 - val_root_mean_squared_error: 0.0857
# Epoch 149/150
# 19/19 - 3s - 134ms/step - loss: 2.2220e-04 - mae: 0.0096 - mape: 6131.5181 - root_mean_squared_error: 0.0149 - val_loss: 0.0075 - val_mae: 0.0695 - val_mape: 10.7029 - val_root_mean_squared_error: 0.0865
# Epoch 150/150
# 19/19 - 3s - 134ms/step - loss: 1.6595e-04 - mae: 0.0087 - mape: 5675.5000 - root_mean_squared_error: 0.0129 - val_loss: 0.0075 - val_mae: 0.0702 - val_mape: 10.7291 - val_root_mean_squared_error: 0.0869

# %%
####################
### Plot Results ###
####################

# Training MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['loss'][1:], label='MSE')
ax[0, 0].set_title('Training Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Training MAE
ax[0, 1].plot(history.history['mae'][1:], label='MAE', color='black')
ax[0, 1].set_title('Training MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Training RMSE
ax[1, 0].plot(history.history['root_mean_squared_error'][1:], label='RMSE', color='green')
ax[1, 0].set_title('Training RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Training MAPE
ax[1, 1].plot(history.history['mape'][1:], label='MAPE', color='red')
ax[1, 1].set_title('Training MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Validation MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['val_loss'][1:], label='Val MSE')
ax[0, 0].set_title('Validation Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Validation MAE
ax[0, 1].plot(history.history['val_mae'][1:], label='Val MAE')
ax[0, 1].set_title('Validation MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Validation RMSE
ax[1, 0].plot(history.history['val_root_mean_squared_error'][1:], label='Val RMSE')
ax[1, 0].set_title('Validation RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Validation MAPE
ax[1, 1].plot(history.history['val_mape'][1:], label='Val MAPE')
ax[1, 1].set_title('Validation MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Store best training/validation metrics
# Training
train_mse = history.history['loss']
best_epoch = np.argmin(train_mse)
best_train_mse = train_mse[best_epoch]
best_train_rmse = history.history['root_mean_squared_error'][best_epoch]
best_train_mae  = history.history['mae'][best_epoch]
best_train_mape = history.history['mape'][best_epoch]

# Validation: record epoch at which validation loss is the lowest for each seed
val_mse = history.history['val_loss']
best_epoch = np.argmin(val_mse)
best_val_mse = val_mse[best_epoch]
best_val_rmse = history.history['val_root_mean_squared_error'][best_epoch]
best_val_mae  = history.history['val_mae'][best_epoch]
best_val_mape = history.history['val_mape'][best_epoch]

# %%
# -------------------------
# Step 9 — Predict/Testing
# -------------------------

y_predict= model.predict([X_cnn_test, X_lstm_test])
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
# -----------------------------------
# Step 10 — Test MSE/RMSE/MAE/MAPE/R2
# -----------------------------------

# Compute the loss metrics
test_mse = mean_squared_error(y_test, y_predict)
test_rmse = root_mean_squared_error(y_test, y_predict)
test_mae = mean_absolute_error(y_test, y_predict)
test_mape = mean_absolute_percentage_error(y_test, y_predict)
test_r2_score = r2_score(y_test, y_predict)

print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Mean Absolute Error:", test_mae)
print("Mean Absolute Percentage Error:", test_mape)
print("R2 Score:", test_r2_score)
# Out:
# Mean Squared Error: 0.004841378886426337
# Root Mean Squared Error: 0.06958001786739018
# Mean Absolute Error: 0.05854740305209549
# Mean Absolute Percentage Error: 0.18770697160234723
# R2 Score: 0.647936825572587

# %%
#-------------------------------------------------
# Step 11 - Inverse scaling: original price scale
#-------------------------------------------------

y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))
y_predict_orig = scaler.inverse_transform(y_predict)

# %%
#----------------------------------------------
# Step 12 - Plot prediction vs. actuals prices
#----------------------------------------------

# Add window size
start_index = len(y_train)+len(y_val)+ 224

# Test set dates + convert to datetime
dates = eth['Date'].iloc[start_index:start_index + len(y_test_orig)].reset_index(drop=True)
dates = pd.to_datetime(dates)

# Plot the actual vs predicted prices
plt.figure(figsize=(10, 5))
plt.plot(dates, y_test_orig, label='Actual', linewidth=2)
plt.plot(dates, y_predict_orig, label='Predicted', color='red')
plt.title('Actual vs Predicted Ethereum Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#--------------------------
# Step 13 - Export results
#--------------------------

# Export prediction dataset
predictions_df = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.flatten(),
    'Predicted': y_predict_orig.flatten()
})

predictions_df.to_csv('ETH_predictions.csv', index=False)

from google.colab import files
files.download('ETH_predictions.csv')

# %%
# Store metrics in dataframe along with best training/validation loss (record epoch)
results = {
    "seed": 45,
    "best_epoch": best_epoch + 1,    # best validation epoch
    "train_mse": best_train_mse,
    "train_rmse": best_train_rmse,
    "train_mae": best_train_mae,
    "train_mape": best_train_mape,
    "val_mse": best_val_mse,
    "val_rmse": best_val_rmse,
    "val_mae": best_val_mae,
    "val_mape": best_val_mape,
    "test_mse": test_mse,
    "test_rmse": test_rmse,
    "test_mae": test_mae,
    "test_mape": test_mape,
    "test_r2_score": test_r2_score
}

eth_results = pd.DataFrame([results])
eth_results.to_csv('eth_results.csv')

from google.colab import files
files.download('eth_results.csv')

# %%
# Export results

loss_results = pd.DataFrame(history.history)
loss_results.to_csv('eth_loss_results.csv')

files.download('eth_loss_results.csv')

# %% [markdown]
# # **Regime Classification**

# %%
# ------------------------------------------
# Step 1 — Compute Log returns & Volatility
# ------------------------------------------

original = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.ravel()
})

predicted = pd.DataFrame({
    'Date': dates,
    'Predicted': y_predict_orig.ravel()
})

# Compute returns from actual and predicted prices
returns_orig = original['Actual'].pct_change()
returns_pred = predicted['Predicted'].pct_change()
# Drop NaN values from returns
returns_orig = returns_orig.fillna(0)
returns_pred = returns_pred.fillna(0)

# Compute 10-day rolling volatility
volatility_orig = returns_orig.rolling(window=10).std()
volatility_pred = returns_pred.rolling(window=10).std()
volatility_orig = volatility_orig.fillna(0)
volatility_pred = volatility_pred.fillna(0)

# Update dataframes with returns and volatility
original['Returns'] = returns_orig
predicted['Returns'] = returns_pred
original['Volatility'] = volatility_orig
predicted['Volatility'] = volatility_pred

# %%
# --------------------------------
# Step 2 — Label Volatility L-M-H
# --------------------------------

# Compute quantiles as thresholds for low/med/high volatility
low_threshold = volatility_orig.quantile(0.33)   # lower 33%
high_threshold = volatility_orig.quantile(0.67)  # upper 33%

# Label volatility
def label_volatility(vol):
    if vol <= low_threshold:
        return 'low'
    elif vol >= high_threshold:
        return 'high'
    else:
        return 'medium'

# Apply volatility low/medium/high to original and prediction dataset
original['Volatility_level'] = original['Volatility'].apply(label_volatility)
predicted['Volatility_level'] = predicted['Volatility'].apply(label_volatility)

# %%
# -------------------------------
# Step 3 — Regime Classification
# -------------------------------

# Classify regime based on volatility + average sign of the returns
def classify_regime(pred_labels, vol_value, vol_threshold=(low_threshold, high_threshold), window=3):
    regimes = []
    low_threshold, high_threshold = vol_threshold

    for i in range(len(pred_labels) - window):
        window_preds = pred_labels[i:i+window]
        window_vol = vol_value[i+window]
        sign_pred = np.sign(window_preds.mean())

        if window_vol <= low_threshold:
            regimes.append("Neutral")

        else:
            if sign_pred > 0:
                regimes.append("Bull")
            elif sign_pred < 0:
                regimes.append("Bear")
            else:
                regimes.append("Uncertain")

    return regimes

vol_value = original['Volatility']
regimes = classify_regime(original['Returns'], vol_value)

# %%
####################
######  Plots ######
####################

# Plot price vs. date regime shifts in
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Actual'][3:])
plt.plot(original['Date'][3:], predicted['Predicted'][3:], color='black', alpha=0.75)

plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Neutral' for r in regimes], color='grey', alpha=0.3);

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2928619468.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot regime shift for log returns vs. date
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Returns'][3:])
plt.plot(original['Date'][3:], predicted['Returns'][3:], color='red', alpha=0.6)

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2006677897.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = original['Actual'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(13, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Actual")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = predicted['Predicted'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(13, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Prediction")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()
