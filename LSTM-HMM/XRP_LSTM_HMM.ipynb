# %%
################
####  XRP   ####
################

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install pandas
# !pip install hmmlearn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting hmmlearn
#   Downloading hmmlearn-0.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (2.0.2)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (1.6.1)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.6.0)
# Downloading hmmlearn-0.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.3.3

# %%
#######################
###### Libraries ######
#######################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import tensorflow as tf

from hmmlearn.hmm import GaussianHMM
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.utils import to_categorical

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Set 3 seeds and record the model performance for each : 42, 45, 91
# Best seed 42
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Load dataset without scaling

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/XRP_noscale.csv')
data.drop(columns=['Crypto', 'Open', 'High', 'Low'], inplace=True)
data.head()
# Out:
#          Date  Close
# 0  2018-01-01   2.10
# 1  2018-01-02   2.21
# 2  2018-01-03   2.78
# 3  2018-01-04   2.60
# 4  2018-01-05   2.65

# %%
# -------------------------
# Step 1 - Normalisation
# -------------------------
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['Close']].values.reshape(-1, 1))
input_data = scaled_data.reshape(-1)

# ---------------------------------
# Step 2 - Generate sliding windows
# ---------------------------------
train_end = int(0.65 * len(scaled_data)            ) # training ratio
val_end   = train_end + int(0.10 * len(scaled_data)) # validation ratio
window = 120                                         # window size - days of price input

train_slice = input_data[:train_end]
val_slice   = input_data[train_end:val_end]
test_slice  = input_data[val_end:]

def sequence(data, window_size):
    data = np.asarray(data).reshape(-1, 1)
    x, y = [], []
    for i in range(window_size, len(data)):
        x.append(data[i-window_size:i])
        y.append(data[i])
    return np.array(x), np.array(y)

x_train, y_train = sequence(train_slice, window)
x_val,   y_val   = sequence(val_slice,   window)
x_test,  y_test  = sequence(test_slice,  window)

# %%
# ---------------------------------
# Step 3 - Build Gaussian HMM
# ---------------------------------

# Fit Gaussian HMM with 3 states on the training input data
hmm = GaussianHMM(n_components=3, n_iter=200, random_state=42)
hmm.fit(train_slice.reshape(-1,1))

# Build train, val, test arrays with the last indices in each LSTM sequence (above)
# The aim is to align the HMM input data to the LSTM sequences of 120-day input
# To avoid data leakage (into the future)
window = 120
train_last_idx = np.arange(window-1, train_end-1)
val_last_idx   = np.arange(train_end + window-1, val_end-1)
test_last_idx  = np.arange(val_end   + window-1, len(input_data)-1)


# -----------------------------------------
# Step 5 — Compute posterior probabilities
# -----------------------------------------

# Build the Causal HMM with the input data and train/val/test indices from above
# The probability of the next point is only based on the past datapoints
# Compute the posterior probability for each price at time t+1 for input 0...t (t=window-1)
# The post_probability of each of the 3 states is returned for all 3 sets and ready for use in training the model
def causal_hmm(price_series, hmm, index):
    post_probabilities = np.zeros((len(index), hmm.n_components))
    for i, t in enumerate(index):
        post_probabilities[i] = hmm.predict_proba(price_series[:t+1].reshape(-1,1))[-1]  # last row = uses data ≤ t
    return post_probabilities

H_train = causal_hmm(input_data, hmm, train_last_idx)
H_val   = causal_hmm(input_data, hmm, val_last_idx)
H_test  = causal_hmm(input_data, hmm, test_last_idx)

# HMM output with 'relu' activation function
# Input = one probability for each of 3 states
hmm_input = Input(shape=(3,))
hmm_out   = Dense(64, activation='relu')(hmm_input)

# %%
# ------------
# Parameters
# ------------
n_timesteps = x_train.shape[1]
n_features  = x_train.shape[2]
dropout_rate = 0.33454307320167703


# --------------------------
# Step 5 — LSTM branch input
# --------------------------
# LSTM branch
lstm_input = Input(shape=(n_timesteps, n_features))
y = LSTM(64, return_sequences=True, activation='tanh')(lstm_input)
y = Dropout(dropout_rate)(y)
y = LSTM(8, return_sequences=True, activation='tanh')(y)
lstm_out = LSTM(4, return_sequences=False, activation='tanh')(y)


# -----------------------------
# Step 6 — Concatenate HMM/LSTM
# -----------------------------
combined = Concatenate()([lstm_out, hmm_out])
combined = Dense(64, activation='tanh')(combined)
output = Dense(1, activation='linear')(combined)


# ---------------------------------
# Step 7 — Compile Model/Regression
# ---------------------------------
model = Model(inputs=[lstm_input, hmm_input], outputs=output)
model.compile(loss='mean_squared_error',
              optimizer=RMSprop(learning_rate=0.0009717787126451334),
              metrics=['mae', RootMeanSquaredError(), 'mape'])

# %%
# ---------------------------------
# Step 8 — Model Training
# ---------------------------------
history = model.fit([x_train, H_train], y_train,
                    epochs=150, batch_size=16,
                    shuffle=False,
                    validation_data=([x_val, H_val], y_val),
                    verbose=2)
# Out:
# Epoch 1/150
# 73/73 - 6s - 79ms/step - loss: 0.0050 - mae: 0.0464 - mape: 36723.1094 - root_mean_squared_error: 0.0707 - val_loss: 0.0062 - val_mae: 0.0707 - val_mape: 26.7177 - val_root_mean_squared_error: 0.0785
# Epoch 2/150
# 73/73 - 1s - 16ms/step - loss: 0.0033 - mae: 0.0391 - mape: 25433.9375 - root_mean_squared_error: 0.0575 - val_loss: 0.0086 - val_mae: 0.0862 - val_mape: 31.8634 - val_root_mean_squared_error: 0.0926
# Epoch 3/150
# 73/73 - 1s - 18ms/step - loss: 0.0029 - mae: 0.0365 - mape: 25786.5605 - root_mean_squared_error: 0.0540 - val_loss: 0.0063 - val_mae: 0.0734 - val_mape: 27.0288 - val_root_mean_squared_error: 0.0797
# Epoch 4/150
# 73/73 - 1s - 17ms/step - loss: 0.0026 - mae: 0.0345 - mape: 25101.3984 - root_mean_squared_error: 0.0507 - val_loss: 0.0047 - val_mae: 0.0626 - val_mape: 22.9695 - val_root_mean_squared_error: 0.0686
# Epoch 5/150
# 73/73 - 1s - 17ms/step - loss: 0.0024 - mae: 0.0332 - mape: 25485.6816 - root_mean_squared_error: 0.0486 - val_loss: 0.0037 - val_mae: 0.0552 - val_mape: 20.1440 - val_root_mean_squared_error: 0.0608
# Epoch 6/150
# 73/73 - 1s - 16ms/step - loss: 0.0022 - mae: 0.0316 - mape: 21967.2832 - root_mean_squared_error: 0.0472 - val_loss: 0.0045 - val_mae: 0.0611 - val_mape: 22.2180 - val_root_mean_squared_error: 0.0668
# Epoch 7/150
# 73/73 - 1s - 16ms/step - loss: 0.0021 - mae: 0.0303 - mape: 20986.6543 - root_mean_squared_error: 0.0457 - val_loss: 0.0012 - val_mae: 0.0306 - val_mape: 10.8780 - val_root_mean_squared_error: 0.0347
# Epoch 8/150
# 73/73 - 1s - 17ms/step - loss: 0.0020 - mae: 0.0293 - mape: 23174.8770 - root_mean_squared_error: 0.0445 - val_loss: 0.0013 - val_mae: 0.0314 - val_mape: 11.2121 - val_root_mean_squared_error: 0.0357
# Epoch 9/150
# 73/73 - 1s - 17ms/step - loss: 0.0019 - mae: 0.0283 - mape: 20401.9199 - root_mean_squared_error: 0.0433 - val_loss: 0.0017 - val_mae: 0.0366 - val_mape: 13.1786 - val_root_mean_squared_error: 0.0414
# Epoch 10/150
# 73/73 - 1s - 16ms/step - loss: 0.0018 - mae: 0.0277 - mape: 23126.4492 - root_mean_squared_error: 0.0424 - val_loss: 0.0017 - val_mae: 0.0366 - val_mape: 13.1520 - val_root_mean_squared_error: 0.0415
# Epoch 11/150
# 73/73 - 1s - 16ms/step - loss: 0.0017 - mae: 0.0270 - mape: 18479.6035 - root_mean_squared_error: 0.0417 - val_loss: 0.0013 - val_mae: 0.0317 - val_mape: 11.3100 - val_root_mean_squared_error: 0.0363
# Epoch 12/150
# 73/73 - 1s - 16ms/step - loss: 0.0017 - mae: 0.0260 - mape: 20730.7109 - root_mean_squared_error: 0.0409 - val_loss: 0.0012 - val_mae: 0.0303 - val_mape: 10.7783 - val_root_mean_squared_error: 0.0351
# Epoch 13/150
# 73/73 - 1s - 16ms/step - loss: 0.0016 - mae: 0.0254 - mape: 25888.5156 - root_mean_squared_error: 0.0397 - val_loss: 0.0013 - val_mae: 0.0306 - val_mape: 10.8620 - val_root_mean_squared_error: 0.0356
# Epoch 14/150
# 73/73 - 1s - 16ms/step - loss: 0.0015 - mae: 0.0248 - mape: 19441.8164 - root_mean_squared_error: 0.0393 - val_loss: 0.0013 - val_mae: 0.0308 - val_mape: 10.9469 - val_root_mean_squared_error: 0.0358
# Epoch 15/150
# 73/73 - 1s - 16ms/step - loss: 0.0015 - mae: 0.0243 - mape: 16034.4346 - root_mean_squared_error: 0.0382 - val_loss: 8.7212e-04 - val_mae: 0.0240 - val_mape: 8.4229 - val_root_mean_squared_error: 0.0295
# Epoch 16/150
# 73/73 - 1s - 16ms/step - loss: 0.0014 - mae: 0.0238 - mape: 17877.9180 - root_mean_squared_error: 0.0381 - val_loss: 7.3995e-04 - val_mae: 0.0216 - val_mape: 7.4876 - val_root_mean_squared_error: 0.0272
# Epoch 17/150
# 73/73 - 1s - 16ms/step - loss: 0.0014 - mae: 0.0232 - mape: 22279.7070 - root_mean_squared_error: 0.0375 - val_loss: 8.5698e-04 - val_mae: 0.0237 - val_mape: 8.2744 - val_root_mean_squared_error: 0.0293
# Epoch 18/150
# 73/73 - 1s - 17ms/step - loss: 0.0013 - mae: 0.0222 - mape: 16052.4668 - root_mean_squared_error: 0.0363 - val_loss: 6.8967e-04 - val_mae: 0.0206 - val_mape: 7.1350 - val_root_mean_squared_error: 0.0263
# Epoch 19/150
# 73/73 - 1s - 17ms/step - loss: 0.0013 - mae: 0.0223 - mape: 16393.9570 - root_mean_squared_error: 0.0361 - val_loss: 6.1530e-04 - val_mae: 0.0192 - val_mape: 6.5676 - val_root_mean_squared_error: 0.0248
# Epoch 20/150
# 73/73 - 1s - 16ms/step - loss: 0.0013 - mae: 0.0218 - mape: 18419.4375 - root_mean_squared_error: 0.0357 - val_loss: 6.0095e-04 - val_mae: 0.0189 - val_mape: 6.4743 - val_root_mean_squared_error: 0.0245
# Epoch 21/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0213 - mape: 17001.8281 - root_mean_squared_error: 0.0349 - val_loss: 6.5993e-04 - val_mae: 0.0200 - val_mape: 6.9532 - val_root_mean_squared_error: 0.0257
# Epoch 22/150
# 73/73 - 1s - 17ms/step - loss: 0.0012 - mae: 0.0206 - mape: 15332.1631 - root_mean_squared_error: 0.0340 - val_loss: 7.2261e-04 - val_mae: 0.0210 - val_mape: 7.3517 - val_root_mean_squared_error: 0.0269
# Epoch 23/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0208 - mape: 15940.3105 - root_mean_squared_error: 0.0340 - val_loss: 7.2736e-04 - val_mae: 0.0211 - val_mape: 7.3659 - val_root_mean_squared_error: 0.0270
# Epoch 24/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0206 - mape: 16425.5957 - root_mean_squared_error: 0.0338 - val_loss: 7.8337e-04 - val_mae: 0.0222 - val_mape: 7.7643 - val_root_mean_squared_error: 0.0280
# Epoch 25/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0199 - mape: 18014.5137 - root_mean_squared_error: 0.0335 - val_loss: 7.2558e-04 - val_mae: 0.0210 - val_mape: 7.4006 - val_root_mean_squared_error: 0.0269
# Epoch 26/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0197 - mape: 14255.2676 - root_mean_squared_error: 0.0327 - val_loss: 5.5567e-04 - val_mae: 0.0179 - val_mape: 6.2026 - val_root_mean_squared_error: 0.0236
# Epoch 27/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0194 - mape: 4409.7485 - root_mean_squared_error: 0.0324 - val_loss: 5.5166e-04 - val_mae: 0.0178 - val_mape: 6.1757 - val_root_mean_squared_error: 0.0235
# Epoch 28/150
# 73/73 - 1s - 16ms/step - loss: 0.0010 - mae: 0.0192 - mape: 11973.7441 - root_mean_squared_error: 0.0322 - val_loss: 7.6141e-04 - val_mae: 0.0217 - val_mape: 7.5748 - val_root_mean_squared_error: 0.0276
# Epoch 29/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0195 - mape: 9716.6650 - root_mean_squared_error: 0.0327 - val_loss: 6.2051e-04 - val_mae: 0.0190 - val_mape: 6.6526 - val_root_mean_squared_error: 0.0249
# Epoch 30/150
# 73/73 - 1s - 16ms/step - loss: 9.5580e-04 - mae: 0.0186 - mape: 19643.4766 - root_mean_squared_error: 0.0309 - val_loss: 0.0010 - val_mae: 0.0272 - val_mape: 9.5826 - val_root_mean_squared_error: 0.0323
# Epoch 31/150
# 73/73 - 1s - 16ms/step - loss: 9.9370e-04 - mae: 0.0186 - mape: 13418.1426 - root_mean_squared_error: 0.0315 - val_loss: 6.7387e-04 - val_mae: 0.0200 - val_mape: 7.0190 - val_root_mean_squared_error: 0.0260
# Epoch 32/150
# 73/73 - 1s - 16ms/step - loss: 9.2973e-04 - mae: 0.0182 - mape: 11981.6729 - root_mean_squared_error: 0.0305 - val_loss: 6.3405e-04 - val_mae: 0.0192 - val_mape: 6.7506 - val_root_mean_squared_error: 0.0252
# Epoch 33/150
# 73/73 - 1s - 16ms/step - loss: 9.4378e-04 - mae: 0.0184 - mape: 18389.6543 - root_mean_squared_error: 0.0307 - val_loss: 5.5396e-04 - val_mae: 0.0177 - val_mape: 6.2165 - val_root_mean_squared_error: 0.0235
# Epoch 34/150
# 73/73 - 1s - 16ms/step - loss: 8.9279e-04 - mae: 0.0178 - mape: 15495.1484 - root_mean_squared_error: 0.0299 - val_loss: 8.4259e-04 - val_mae: 0.0234 - val_mape: 8.1883 - val_root_mean_squared_error: 0.0290
# Epoch 35/150
# 73/73 - 1s - 15ms/step - loss: 9.2397e-04 - mae: 0.0180 - mape: 10914.0830 - root_mean_squared_error: 0.0304 - val_loss: 7.5850e-04 - val_mae: 0.0218 - val_mape: 7.6090 - val_root_mean_squared_error: 0.0275
# Epoch 36/150
# 73/73 - 1s - 16ms/step - loss: 9.0563e-04 - mae: 0.0177 - mape: 9047.7666 - root_mean_squared_error: 0.0301 - val_loss: 9.7341e-04 - val_mae: 0.0260 - val_mape: 9.1149 - val_root_mean_squared_error: 0.0312
# Epoch 37/150
# 73/73 - 1s - 16ms/step - loss: 8.5050e-04 - mae: 0.0173 - mape: 13254.2168 - root_mean_squared_error: 0.0292 - val_loss: 6.2866e-04 - val_mae: 0.0192 - val_mape: 6.7177 - val_root_mean_squared_error: 0.0251
# Epoch 38/150
# 73/73 - 1s - 16ms/step - loss: 8.3486e-04 - mae: 0.0174 - mape: 10615.4229 - root_mean_squared_error: 0.0289 - val_loss: 0.0010 - val_mae: 0.0266 - val_mape: 9.3429 - val_root_mean_squared_error: 0.0319
# Epoch 39/150
# 73/73 - 1s - 16ms/step - loss: 8.7286e-04 - mae: 0.0173 - mape: 15336.4619 - root_mean_squared_error: 0.0295 - val_loss: 9.0874e-04 - val_mae: 0.0247 - val_mape: 8.6150 - val_root_mean_squared_error: 0.0301
# Epoch 40/150
# 73/73 - 1s - 16ms/step - loss: 8.0829e-04 - mae: 0.0169 - mape: 12916.1484 - root_mean_squared_error: 0.0284 - val_loss: 8.9109e-04 - val_mae: 0.0245 - val_mape: 8.6060 - val_root_mean_squared_error: 0.0299
# Epoch 41/150
# 73/73 - 1s - 16ms/step - loss: 8.3071e-04 - mae: 0.0167 - mape: 11877.7627 - root_mean_squared_error: 0.0288 - val_loss: 5.8310e-04 - val_mae: 0.0184 - val_mape: 6.4205 - val_root_mean_squared_error: 0.0241
# Epoch 42/150
# 73/73 - 1s - 16ms/step - loss: 7.9485e-04 - mae: 0.0168 - mape: 14132.4268 - root_mean_squared_error: 0.0282 - val_loss: 7.0958e-04 - val_mae: 0.0209 - val_mape: 7.3042 - val_root_mean_squared_error: 0.0266
# Epoch 43/150
# 73/73 - 1s - 16ms/step - loss: 7.2974e-04 - mae: 0.0164 - mape: 12802.6172 - root_mean_squared_error: 0.0270 - val_loss: 0.0016 - val_mae: 0.0350 - val_mape: 12.2695 - val_root_mean_squared_error: 0.0399
# Epoch 44/150
# 73/73 - 1s - 15ms/step - loss: 7.5807e-04 - mae: 0.0166 - mape: 14925.4854 - root_mean_squared_error: 0.0275 - val_loss: 8.4059e-04 - val_mae: 0.0232 - val_mape: 8.0317 - val_root_mean_squared_error: 0.0290
# Epoch 45/150
# 73/73 - 1s - 16ms/step - loss: 7.6105e-04 - mae: 0.0164 - mape: 8586.9639 - root_mean_squared_error: 0.0276 - val_loss: 0.0012 - val_mae: 0.0290 - val_mape: 10.1838 - val_root_mean_squared_error: 0.0342
# Epoch 46/150
# 73/73 - 1s - 16ms/step - loss: 7.4982e-04 - mae: 0.0160 - mape: 7587.6704 - root_mean_squared_error: 0.0274 - val_loss: 5.9436e-04 - val_mae: 0.0186 - val_mape: 6.5289 - val_root_mean_squared_error: 0.0244
# Epoch 47/150
# 73/73 - 1s - 16ms/step - loss: 7.6137e-04 - mae: 0.0162 - mape: 2422.0447 - root_mean_squared_error: 0.0276 - val_loss: 8.7145e-04 - val_mae: 0.0238 - val_mape: 8.2541 - val_root_mean_squared_error: 0.0295
# Epoch 48/150
# 73/73 - 1s - 16ms/step - loss: 7.2413e-04 - mae: 0.0161 - mape: 9191.7471 - root_mean_squared_error: 0.0269 - val_loss: 5.6991e-04 - val_mae: 0.0182 - val_mape: 6.3674 - val_root_mean_squared_error: 0.0239
# Epoch 49/150
# 73/73 - 1s - 16ms/step - loss: 7.1166e-04 - mae: 0.0157 - mape: 7230.6602 - root_mean_squared_error: 0.0267 - val_loss: 0.0014 - val_mae: 0.0329 - val_mape: 11.5117 - val_root_mean_squared_error: 0.0379
# Epoch 50/150
# 73/73 - 1s - 16ms/step - loss: 7.0228e-04 - mae: 0.0158 - mape: 10512.9180 - root_mean_squared_error: 0.0265 - val_loss: 7.3096e-04 - val_mae: 0.0213 - val_mape: 7.4436 - val_root_mean_squared_error: 0.0270
# Epoch 51/150
# 73/73 - 1s - 16ms/step - loss: 7.4685e-04 - mae: 0.0159 - mape: 12269.0693 - root_mean_squared_error: 0.0273 - val_loss: 8.9198e-04 - val_mae: 0.0244 - val_mape: 8.5499 - val_root_mean_squared_error: 0.0299
# Epoch 52/150
# 73/73 - 1s - 15ms/step - loss: 6.9912e-04 - mae: 0.0155 - mape: 8997.6348 - root_mean_squared_error: 0.0264 - val_loss: 0.0018 - val_mae: 0.0377 - val_mape: 13.1355 - val_root_mean_squared_error: 0.0425
# Epoch 53/150
# 73/73 - 1s - 15ms/step - loss: 6.8129e-04 - mae: 0.0157 - mape: 10601.8809 - root_mean_squared_error: 0.0261 - val_loss: 9.4252e-04 - val_mae: 0.0251 - val_mape: 8.7333 - val_root_mean_squared_error: 0.0307
# Epoch 54/150
# 73/73 - 1s - 16ms/step - loss: 6.5884e-04 - mae: 0.0155 - mape: 12851.9961 - root_mean_squared_error: 0.0257 - val_loss: 0.0015 - val_mae: 0.0336 - val_mape: 11.7347 - val_root_mean_squared_error: 0.0386
# Epoch 55/150
# 73/73 - 1s - 16ms/step - loss: 6.9042e-04 - mae: 0.0155 - mape: 9655.6035 - root_mean_squared_error: 0.0263 - val_loss: 0.0011 - val_mae: 0.0280 - val_mape: 9.7585 - val_root_mean_squared_error: 0.0331
# Epoch 56/150
# 73/73 - 1s - 16ms/step - loss: 6.2484e-04 - mae: 0.0152 - mape: 5590.7358 - root_mean_squared_error: 0.0250 - val_loss: 0.0014 - val_mae: 0.0327 - val_mape: 11.3804 - val_root_mean_squared_error: 0.0377
# Epoch 57/150
# 73/73 - 1s - 16ms/step - loss: 6.4104e-04 - mae: 0.0153 - mape: 19975.3613 - root_mean_squared_error: 0.0253 - val_loss: 0.0010 - val_mae: 0.0267 - val_mape: 9.2863 - val_root_mean_squared_error: 0.0321
# Epoch 58/150
# 73/73 - 1s - 16ms/step - loss: 6.7713e-04 - mae: 0.0152 - mape: 11761.2490 - root_mean_squared_error: 0.0260 - val_loss: 0.0013 - val_mae: 0.0312 - val_mape: 10.8635 - val_root_mean_squared_error: 0.0362
# Epoch 59/150
# 73/73 - 1s - 16ms/step - loss: 6.1197e-04 - mae: 0.0147 - mape: 14824.2559 - root_mean_squared_error: 0.0247 - val_loss: 0.0014 - val_mae: 0.0332 - val_mape: 11.5581 - val_root_mean_squared_error: 0.0381
# Epoch 60/150
# 73/73 - 1s - 16ms/step - loss: 6.0366e-04 - mae: 0.0148 - mape: 18553.2773 - root_mean_squared_error: 0.0246 - val_loss: 0.0016 - val_mae: 0.0347 - val_mape: 12.0508 - val_root_mean_squared_error: 0.0396
# Epoch 61/150
# 73/73 - 1s - 16ms/step - loss: 6.1255e-04 - mae: 0.0149 - mape: 12432.6279 - root_mean_squared_error: 0.0247 - val_loss: 0.0011 - val_mae: 0.0278 - val_mape: 9.6470 - val_root_mean_squared_error: 0.0330
# Epoch 62/150
# 73/73 - 1s - 16ms/step - loss: 6.2983e-04 - mae: 0.0146 - mape: 24704.4609 - root_mean_squared_error: 0.0251 - val_loss: 9.3328e-04 - val_mae: 0.0253 - val_mape: 8.8259 - val_root_mean_squared_error: 0.0305
# Epoch 63/150
# 73/73 - 1s - 16ms/step - loss: 6.1233e-04 - mae: 0.0145 - mape: 11261.0000 - root_mean_squared_error: 0.0247 - val_loss: 9.3170e-04 - val_mae: 0.0248 - val_mape: 8.5254 - val_root_mean_squared_error: 0.0305
# Epoch 64/150
# 73/73 - 1s - 16ms/step - loss: 5.7513e-04 - mae: 0.0145 - mape: 14039.5186 - root_mean_squared_error: 0.0240 - val_loss: 0.0011 - val_mae: 0.0284 - val_mape: 9.8195 - val_root_mean_squared_error: 0.0337
# Epoch 65/150
# 73/73 - 1s - 16ms/step - loss: 5.6648e-04 - mae: 0.0143 - mape: 12106.9893 - root_mean_squared_error: 0.0238 - val_loss: 0.0016 - val_mae: 0.0351 - val_mape: 12.1242 - val_root_mean_squared_error: 0.0402
# Epoch 66/150
# 73/73 - 1s - 16ms/step - loss: 5.6621e-04 - mae: 0.0144 - mape: 10221.7324 - root_mean_squared_error: 0.0238 - val_loss: 0.0014 - val_mae: 0.0325 - val_mape: 11.2278 - val_root_mean_squared_error: 0.0376
# Epoch 67/150
# 73/73 - 1s - 16ms/step - loss: 5.4825e-04 - mae: 0.0143 - mape: 26208.7930 - root_mean_squared_error: 0.0234 - val_loss: 0.0015 - val_mae: 0.0338 - val_mape: 11.7219 - val_root_mean_squared_error: 0.0387
# Epoch 68/150
# 73/73 - 1s - 16ms/step - loss: 5.7169e-04 - mae: 0.0143 - mape: 386.9143 - root_mean_squared_error: 0.0239 - val_loss: 8.4916e-04 - val_mae: 0.0235 - val_mape: 8.0761 - val_root_mean_squared_error: 0.0291
# Epoch 69/150
# 73/73 - 1s - 16ms/step - loss: 5.3912e-04 - mae: 0.0138 - mape: 6973.2744 - root_mean_squared_error: 0.0232 - val_loss: 0.0013 - val_mae: 0.0313 - val_mape: 10.8063 - val_root_mean_squared_error: 0.0366
# Epoch 70/150
# 73/73 - 1s - 16ms/step - loss: 5.5959e-04 - mae: 0.0142 - mape: 13452.7012 - root_mean_squared_error: 0.0237 - val_loss: 5.9127e-04 - val_mae: 0.0189 - val_mape: 6.4930 - val_root_mean_squared_error: 0.0243
# Epoch 71/150
# 73/73 - 1s - 16ms/step - loss: 5.3474e-04 - mae: 0.0139 - mape: 4506.7300 - root_mean_squared_error: 0.0231 - val_loss: 0.0011 - val_mae: 0.0276 - val_mape: 9.4820 - val_root_mean_squared_error: 0.0330
# Epoch 72/150
# 73/73 - 1s - 16ms/step - loss: 5.4660e-04 - mae: 0.0141 - mape: 14670.3125 - root_mean_squared_error: 0.0234 - val_loss: 8.5283e-04 - val_mae: 0.0235 - val_mape: 8.0496 - val_root_mean_squared_error: 0.0292
# Epoch 73/150
# 73/73 - 1s - 16ms/step - loss: 5.6328e-04 - mae: 0.0138 - mape: 5629.3770 - root_mean_squared_error: 0.0237 - val_loss: 0.0012 - val_mae: 0.0288 - val_mape: 9.8399 - val_root_mean_squared_error: 0.0344
# Epoch 74/150
# 73/73 - 1s - 16ms/step - loss: 5.2809e-04 - mae: 0.0139 - mape: 19063.1328 - root_mean_squared_error: 0.0230 - val_loss: 8.6843e-04 - val_mae: 0.0239 - val_mape: 8.2353 - val_root_mean_squared_error: 0.0295
# Epoch 75/150
# 73/73 - 1s - 16ms/step - loss: 5.0243e-04 - mae: 0.0138 - mape: 14112.6787 - root_mean_squared_error: 0.0224 - val_loss: 8.1811e-04 - val_mae: 0.0229 - val_mape: 7.8052 - val_root_mean_squared_error: 0.0286
# Epoch 76/150
# 73/73 - 1s - 16ms/step - loss: 4.7746e-04 - mae: 0.0134 - mape: 15072.0977 - root_mean_squared_error: 0.0219 - val_loss: 0.0015 - val_mae: 0.0330 - val_mape: 11.2806 - val_root_mean_squared_error: 0.0385
# Epoch 77/150
# 73/73 - 1s - 15ms/step - loss: 5.2997e-04 - mae: 0.0135 - mape: 11487.0605 - root_mean_squared_error: 0.0230 - val_loss: 5.9381e-04 - val_mae: 0.0190 - val_mape: 6.5352 - val_root_mean_squared_error: 0.0244
# Epoch 78/150
# 73/73 - 1s - 16ms/step - loss: 5.0805e-04 - mae: 0.0135 - mape: 8584.0234 - root_mean_squared_error: 0.0225 - val_loss: 9.7275e-04 - val_mae: 0.0257 - val_mape: 8.7878 - val_root_mean_squared_error: 0.0312
# Epoch 79/150
# 73/73 - 1s - 16ms/step - loss: 5.1555e-04 - mae: 0.0135 - mape: 13059.4883 - root_mean_squared_error: 0.0227 - val_loss: 6.3430e-04 - val_mae: 0.0197 - val_mape: 6.7380 - val_root_mean_squared_error: 0.0252
# Epoch 80/150
# 73/73 - 1s - 16ms/step - loss: 5.2781e-04 - mae: 0.0138 - mape: 15636.7539 - root_mean_squared_error: 0.0230 - val_loss: 0.0016 - val_mae: 0.0343 - val_mape: 11.7709 - val_root_mean_squared_error: 0.0395
# Epoch 81/150
# 73/73 - 1s - 17ms/step - loss: 5.2657e-04 - mae: 0.0135 - mape: 8986.6885 - root_mean_squared_error: 0.0229 - val_loss: 6.4146e-04 - val_mae: 0.0198 - val_mape: 6.8313 - val_root_mean_squared_error: 0.0253
# Epoch 82/150
# 73/73 - 1s - 16ms/step - loss: 4.9097e-04 - mae: 0.0135 - mape: 9280.5107 - root_mean_squared_error: 0.0222 - val_loss: 0.0011 - val_mae: 0.0271 - val_mape: 9.1640 - val_root_mean_squared_error: 0.0329
# Epoch 83/150
# 73/73 - 1s - 16ms/step - loss: 5.1221e-04 - mae: 0.0134 - mape: 8497.8291 - root_mean_squared_error: 0.0226 - val_loss: 0.0011 - val_mae: 0.0268 - val_mape: 9.1025 - val_root_mean_squared_error: 0.0326
# Epoch 84/150
# 73/73 - 1s - 16ms/step - loss: 4.8729e-04 - mae: 0.0132 - mape: 6403.3735 - root_mean_squared_error: 0.0221 - val_loss: 0.0011 - val_mae: 0.0278 - val_mape: 9.4044 - val_root_mean_squared_error: 0.0337
# Epoch 85/150
# 73/73 - 1s - 16ms/step - loss: 4.6552e-04 - mae: 0.0131 - mape: 4772.8369 - root_mean_squared_error: 0.0216 - val_loss: 8.8395e-04 - val_mae: 0.0237 - val_mape: 7.9686 - val_root_mean_squared_error: 0.0297
# Epoch 86/150
# 73/73 - 1s - 16ms/step - loss: 5.0349e-04 - mae: 0.0133 - mape: 15886.7549 - root_mean_squared_error: 0.0224 - val_loss: 0.0016 - val_mae: 0.0344 - val_mape: 11.6816 - val_root_mean_squared_error: 0.0400
# Epoch 87/150
# 73/73 - 1s - 16ms/step - loss: 5.0357e-04 - mae: 0.0134 - mape: 14289.3564 - root_mean_squared_error: 0.0224 - val_loss: 0.0011 - val_mae: 0.0278 - val_mape: 9.3259 - val_root_mean_squared_error: 0.0339
# Epoch 88/150
# 73/73 - 1s - 16ms/step - loss: 4.7600e-04 - mae: 0.0130 - mape: 1566.2451 - root_mean_squared_error: 0.0218 - val_loss: 0.0015 - val_mae: 0.0328 - val_mape: 11.0651 - val_root_mean_squared_error: 0.0387
# Epoch 89/150
# 73/73 - 1s - 16ms/step - loss: 4.7854e-04 - mae: 0.0131 - mape: 11625.5557 - root_mean_squared_error: 0.0219 - val_loss: 0.0011 - val_mae: 0.0275 - val_mape: 9.2645 - val_root_mean_squared_error: 0.0334
# Epoch 90/150
# 73/73 - 1s - 15ms/step - loss: 4.8031e-04 - mae: 0.0131 - mape: 391.0076 - root_mean_squared_error: 0.0219 - val_loss: 8.2436e-04 - val_mae: 0.0228 - val_mape: 7.6459 - val_root_mean_squared_error: 0.0287
# Epoch 91/150
# 73/73 - 1s - 16ms/step - loss: 4.5080e-04 - mae: 0.0130 - mape: 17560.2949 - root_mean_squared_error: 0.0212 - val_loss: 7.1651e-04 - val_mae: 0.0211 - val_mape: 7.1304 - val_root_mean_squared_error: 0.0268
# Epoch 92/150
# 73/73 - 1s - 16ms/step - loss: 4.5451e-04 - mae: 0.0127 - mape: 14786.7266 - root_mean_squared_error: 0.0213 - val_loss: 8.4990e-04 - val_mae: 0.0231 - val_mape: 7.7307 - val_root_mean_squared_error: 0.0292
# Epoch 93/150
# 73/73 - 1s - 16ms/step - loss: 4.7630e-04 - mae: 0.0129 - mape: 18602.9395 - root_mean_squared_error: 0.0218 - val_loss: 0.0012 - val_mae: 0.0287 - val_mape: 9.6539 - val_root_mean_squared_error: 0.0347
# Epoch 94/150
# 73/73 - 1s - 15ms/step - loss: 4.7012e-04 - mae: 0.0128 - mape: 10127.9043 - root_mean_squared_error: 0.0217 - val_loss: 0.0010 - val_mae: 0.0255 - val_mape: 8.5605 - val_root_mean_squared_error: 0.0317
# Epoch 95/150
# 73/73 - 1s - 16ms/step - loss: 4.6997e-04 - mae: 0.0131 - mape: 3387.6394 - root_mean_squared_error: 0.0217 - val_loss: 8.3464e-04 - val_mae: 0.0228 - val_mape: 7.5900 - val_root_mean_squared_error: 0.0289
# Epoch 96/150
# 73/73 - 1s - 15ms/step - loss: 4.5143e-04 - mae: 0.0126 - mape: 541.9422 - root_mean_squared_error: 0.0212 - val_loss: 6.8690e-04 - val_mae: 0.0206 - val_mape: 6.8891 - val_root_mean_squared_error: 0.0262
# Epoch 97/150
# 73/73 - 1s - 15ms/step - loss: 4.5167e-04 - mae: 0.0126 - mape: 9660.0527 - root_mean_squared_error: 0.0213 - val_loss: 0.0012 - val_mae: 0.0288 - val_mape: 9.5948 - val_root_mean_squared_error: 0.0353
# Epoch 98/150
# 73/73 - 1s - 15ms/step - loss: 4.8764e-04 - mae: 0.0128 - mape: 11722.9326 - root_mean_squared_error: 0.0221 - val_loss: 6.7354e-04 - val_mae: 0.0203 - val_mape: 6.7697 - val_root_mean_squared_error: 0.0260
# Epoch 99/150
# 73/73 - 1s - 16ms/step - loss: 4.4653e-04 - mae: 0.0125 - mape: 21165.1777 - root_mean_squared_error: 0.0211 - val_loss: 5.4668e-04 - val_mae: 0.0185 - val_mape: 6.2327 - val_root_mean_squared_error: 0.0234
# Epoch 100/150
# 73/73 - 1s - 16ms/step - loss: 4.7750e-04 - mae: 0.0129 - mape: 6586.9297 - root_mean_squared_error: 0.0219 - val_loss: 0.0015 - val_mae: 0.0325 - val_mape: 10.8552 - val_root_mean_squared_error: 0.0387
# Epoch 101/150
# 73/73 - 1s - 15ms/step - loss: 4.3193e-04 - mae: 0.0127 - mape: 12687.9824 - root_mean_squared_error: 0.0208 - val_loss: 8.7686e-04 - val_mae: 0.0235 - val_mape: 7.8321 - val_root_mean_squared_error: 0.0296
# Epoch 102/150
# 73/73 - 1s - 16ms/step - loss: 4.2560e-04 - mae: 0.0125 - mape: 12751.0537 - root_mean_squared_error: 0.0206 - val_loss: 0.0011 - val_mae: 0.0264 - val_mape: 8.7641 - val_root_mean_squared_error: 0.0330
# Epoch 103/150
# 73/73 - 1s - 16ms/step - loss: 4.2745e-04 - mae: 0.0124 - mape: 13136.9561 - root_mean_squared_error: 0.0207 - val_loss: 8.1358e-04 - val_mae: 0.0222 - val_mape: 7.3388 - val_root_mean_squared_error: 0.0285
# Epoch 104/150
# 73/73 - 1s - 15ms/step - loss: 4.4561e-04 - mae: 0.0126 - mape: 12367.1758 - root_mean_squared_error: 0.0211 - val_loss: 0.0011 - val_mae: 0.0272 - val_mape: 9.0030 - val_root_mean_squared_error: 0.0336
# Epoch 105/150
# 73/73 - 1s - 15ms/step - loss: 4.3015e-04 - mae: 0.0124 - mape: 8047.0762 - root_mean_squared_error: 0.0207 - val_loss: 6.1517e-04 - val_mae: 0.0193 - val_mape: 6.4367 - val_root_mean_squared_error: 0.0248
# Epoch 106/150
# 73/73 - 1s - 15ms/step - loss: 4.3252e-04 - mae: 0.0123 - mape: 8926.4834 - root_mean_squared_error: 0.0208 - val_loss: 0.0011 - val_mae: 0.0260 - val_mape: 8.5784 - val_root_mean_squared_error: 0.0327
# Epoch 107/150
# 73/73 - 1s - 15ms/step - loss: 4.4047e-04 - mae: 0.0125 - mape: 8961.1113 - root_mean_squared_error: 0.0210 - val_loss: 0.0011 - val_mae: 0.0269 - val_mape: 8.9505 - val_root_mean_squared_error: 0.0333
# Epoch 108/150
# 73/73 - 1s - 15ms/step - loss: 4.4150e-04 - mae: 0.0123 - mape: 13102.4756 - root_mean_squared_error: 0.0210 - val_loss: 7.3587e-04 - val_mae: 0.0210 - val_mape: 6.9309 - val_root_mean_squared_error: 0.0271
# Epoch 109/150
# 73/73 - 1s - 15ms/step - loss: 4.0810e-04 - mae: 0.0122 - mape: 13186.1436 - root_mean_squared_error: 0.0202 - val_loss: 0.0010 - val_mae: 0.0255 - val_mape: 8.3750 - val_root_mean_squared_error: 0.0321
# Epoch 110/150
# 73/73 - 1s - 15ms/step - loss: 4.3693e-04 - mae: 0.0125 - mape: 1583.7389 - root_mean_squared_error: 0.0209 - val_loss: 0.0010 - val_mae: 0.0250 - val_mape: 8.1948 - val_root_mean_squared_error: 0.0319
# Epoch 111/150
# 73/73 - 1s - 15ms/step - loss: 4.3505e-04 - mae: 0.0121 - mape: 11073.6934 - root_mean_squared_error: 0.0209 - val_loss: 0.0010 - val_mae: 0.0253 - val_mape: 8.2685 - val_root_mean_squared_error: 0.0321
# Epoch 112/150
# 73/73 - 1s - 16ms/step - loss: 4.4230e-04 - mae: 0.0122 - mape: 12194.4111 - root_mean_squared_error: 0.0210 - val_loss: 7.9745e-04 - val_mae: 0.0219 - val_mape: 7.1930 - val_root_mean_squared_error: 0.0282
# Epoch 113/150
# 73/73 - 1s - 16ms/step - loss: 4.0384e-04 - mae: 0.0120 - mape: 10691.6514 - root_mean_squared_error: 0.0201 - val_loss: 8.5266e-04 - val_mae: 0.0227 - val_mape: 7.4335 - val_root_mean_squared_error: 0.0292
# Epoch 114/150
# 73/73 - 1s - 16ms/step - loss: 4.0442e-04 - mae: 0.0121 - mape: 11844.8359 - root_mean_squared_error: 0.0201 - val_loss: 0.0011 - val_mae: 0.0260 - val_mape: 8.4823 - val_root_mean_squared_error: 0.0331
# Epoch 115/150
# 73/73 - 1s - 16ms/step - loss: 4.0049e-04 - mae: 0.0121 - mape: 15644.4170 - root_mean_squared_error: 0.0200 - val_loss: 9.8389e-04 - val_mae: 0.0248 - val_mape: 8.1500 - val_root_mean_squared_error: 0.0314
# Epoch 116/150
# 73/73 - 1s - 15ms/step - loss: 3.8657e-04 - mae: 0.0118 - mape: 19449.4414 - root_mean_squared_error: 0.0197 - val_loss: 8.9920e-04 - val_mae: 0.0233 - val_mape: 7.6362 - val_root_mean_squared_error: 0.0300
# Epoch 117/150
# 73/73 - 1s - 15ms/step - loss: 4.0747e-04 - mae: 0.0121 - mape: 16465.8789 - root_mean_squared_error: 0.0202 - val_loss: 0.0012 - val_mae: 0.0268 - val_mape: 8.6541 - val_root_mean_squared_error: 0.0342
# Epoch 118/150
# 73/73 - 1s - 16ms/step - loss: 4.3592e-04 - mae: 0.0120 - mape: 21740.3809 - root_mean_squared_error: 0.0209 - val_loss: 0.0013 - val_mae: 0.0288 - val_mape: 9.3208 - val_root_mean_squared_error: 0.0364
# Epoch 119/150
# 73/73 - 1s - 15ms/step - loss: 4.2492e-04 - mae: 0.0121 - mape: 11505.4355 - root_mean_squared_error: 0.0206 - val_loss: 8.7690e-04 - val_mae: 0.0228 - val_mape: 7.4264 - val_root_mean_squared_error: 0.0296
# Epoch 120/150
# 73/73 - 1s - 15ms/step - loss: 4.6105e-04 - mae: 0.0123 - mape: 21151.7227 - root_mean_squared_error: 0.0215 - val_loss: 0.0018 - val_mae: 0.0345 - val_mape: 11.3168 - val_root_mean_squared_error: 0.0418
# Epoch 121/150
# 73/73 - 1s - 16ms/step - loss: 4.1938e-04 - mae: 0.0120 - mape: 14631.9189 - root_mean_squared_error: 0.0205 - val_loss: 8.1674e-04 - val_mae: 0.0221 - val_mape: 7.2174 - val_root_mean_squared_error: 0.0286
# Epoch 122/150
# 73/73 - 1s - 15ms/step - loss: 4.0882e-04 - mae: 0.0118 - mape: 10201.5078 - root_mean_squared_error: 0.0202 - val_loss: 0.0012 - val_mae: 0.0270 - val_mape: 8.8020 - val_root_mean_squared_error: 0.0341
# Epoch 123/150
# 73/73 - 1s - 16ms/step - loss: 4.4998e-04 - mae: 0.0124 - mape: 7471.2959 - root_mean_squared_error: 0.0212 - val_loss: 0.0013 - val_mae: 0.0289 - val_mape: 9.3519 - val_root_mean_squared_error: 0.0366
# Epoch 124/150
# 73/73 - 1s - 16ms/step - loss: 4.0540e-04 - mae: 0.0118 - mape: 12712.2979 - root_mean_squared_error: 0.0201 - val_loss: 6.2959e-04 - val_mae: 0.0200 - val_mape: 6.6477 - val_root_mean_squared_error: 0.0251
# Epoch 125/150
# 73/73 - 1s - 16ms/step - loss: 4.0609e-04 - mae: 0.0117 - mape: 19152.7285 - root_mean_squared_error: 0.0202 - val_loss: 9.5433e-04 - val_mae: 0.0240 - val_mape: 7.8280 - val_root_mean_squared_error: 0.0309
# Epoch 126/150
# 73/73 - 1s - 15ms/step - loss: 3.8523e-04 - mae: 0.0117 - mape: 12426.1445 - root_mean_squared_error: 0.0196 - val_loss: 8.5795e-04 - val_mae: 0.0226 - val_mape: 7.3437 - val_root_mean_squared_error: 0.0293
# Epoch 127/150
# 73/73 - 1s - 15ms/step - loss: 4.1592e-04 - mae: 0.0119 - mape: 13778.7109 - root_mean_squared_error: 0.0204 - val_loss: 0.0010 - val_mae: 0.0244 - val_mape: 7.8852 - val_root_mean_squared_error: 0.0317
# Epoch 128/150
# 73/73 - 1s - 16ms/step - loss: 4.0847e-04 - mae: 0.0117 - mape: 14678.6680 - root_mean_squared_error: 0.0202 - val_loss: 0.0012 - val_mae: 0.0279 - val_mape: 9.0460 - val_root_mean_squared_error: 0.0353
# Epoch 129/150
# 73/73 - 1s - 16ms/step - loss: 3.6805e-04 - mae: 0.0117 - mape: 10634.5293 - root_mean_squared_error: 0.0192 - val_loss: 7.2451e-04 - val_mae: 0.0214 - val_mape: 7.0647 - val_root_mean_squared_error: 0.0269
# Epoch 130/150
# 73/73 - 1s - 15ms/step - loss: 3.9444e-04 - mae: 0.0117 - mape: 14113.5479 - root_mean_squared_error: 0.0199 - val_loss: 9.1384e-04 - val_mae: 0.0233 - val_mape: 7.5859 - val_root_mean_squared_error: 0.0302
# Epoch 131/150
# 73/73 - 1s - 15ms/step - loss: 3.9649e-04 - mae: 0.0117 - mape: 21010.9805 - root_mean_squared_error: 0.0199 - val_loss: 6.9539e-04 - val_mae: 0.0209 - val_mape: 6.9148 - val_root_mean_squared_error: 0.0264
# Epoch 132/150
# 73/73 - 1s - 15ms/step - loss: 4.2996e-04 - mae: 0.0120 - mape: 17995.6738 - root_mean_squared_error: 0.0207 - val_loss: 7.9584e-04 - val_mae: 0.0217 - val_mape: 7.0884 - val_root_mean_squared_error: 0.0282
# Epoch 133/150
# 73/73 - 1s - 15ms/step - loss: 3.9419e-04 - mae: 0.0118 - mape: 12573.7227 - root_mean_squared_error: 0.0199 - val_loss: 9.3279e-04 - val_mae: 0.0236 - val_mape: 7.6695 - val_root_mean_squared_error: 0.0305
# Epoch 134/150
# 73/73 - 1s - 16ms/step - loss: 4.0343e-04 - mae: 0.0117 - mape: 12845.0049 - root_mean_squared_error: 0.0201 - val_loss: 8.3346e-04 - val_mae: 0.0222 - val_mape: 7.2465 - val_root_mean_squared_error: 0.0289
# Epoch 135/150
# 73/73 - 1s - 16ms/step - loss: 3.8261e-04 - mae: 0.0116 - mape: 12598.4932 - root_mean_squared_error: 0.0196 - val_loss: 7.7271e-04 - val_mae: 0.0215 - val_mape: 7.0266 - val_root_mean_squared_error: 0.0278
# Epoch 136/150
# 73/73 - 1s - 15ms/step - loss: 4.1527e-04 - mae: 0.0122 - mape: 7022.4639 - root_mean_squared_error: 0.0204 - val_loss: 0.0012 - val_mae: 0.0273 - val_mape: 8.8308 - val_root_mean_squared_error: 0.0347
# Epoch 137/150
# 73/73 - 1s - 15ms/step - loss: 3.8343e-04 - mae: 0.0116 - mape: 6916.6851 - root_mean_squared_error: 0.0196 - val_loss: 8.9249e-04 - val_mae: 0.0230 - val_mape: 7.4491 - val_root_mean_squared_error: 0.0299
# Epoch 138/150
# 73/73 - 1s - 15ms/step - loss: 3.7612e-04 - mae: 0.0114 - mape: 10342.7412 - root_mean_squared_error: 0.0194 - val_loss: 0.0012 - val_mae: 0.0265 - val_mape: 8.5585 - val_root_mean_squared_error: 0.0339
# Epoch 139/150
# 73/73 - 1s - 16ms/step - loss: 4.0130e-04 - mae: 0.0116 - mape: 14685.9912 - root_mean_squared_error: 0.0200 - val_loss: 7.9744e-04 - val_mae: 0.0222 - val_mape: 7.2698 - val_root_mean_squared_error: 0.0282
# Epoch 140/150
# 73/73 - 1s - 15ms/step - loss: 3.7012e-04 - mae: 0.0115 - mape: 17624.7285 - root_mean_squared_error: 0.0192 - val_loss: 0.0010 - val_mae: 0.0251 - val_mape: 8.1211 - val_root_mean_squared_error: 0.0323
# Epoch 141/150
# 73/73 - 1s - 15ms/step - loss: 3.7449e-04 - mae: 0.0115 - mape: 12958.4541 - root_mean_squared_error: 0.0194 - val_loss: 6.3086e-04 - val_mae: 0.0199 - val_mape: 6.5962 - val_root_mean_squared_error: 0.0251
# Epoch 142/150
# 73/73 - 1s - 15ms/step - loss: 4.1076e-04 - mae: 0.0116 - mape: 16540.3770 - root_mean_squared_error: 0.0203 - val_loss: 8.5161e-04 - val_mae: 0.0225 - val_mape: 7.2993 - val_root_mean_squared_error: 0.0292
# Epoch 143/150
# 73/73 - 1s - 16ms/step - loss: 3.9583e-04 - mae: 0.0117 - mape: 12991.1074 - root_mean_squared_error: 0.0199 - val_loss: 8.0836e-04 - val_mae: 0.0220 - val_mape: 7.1720 - val_root_mean_squared_error: 0.0284
# Epoch 144/150
# 73/73 - 1s - 16ms/step - loss: 3.7348e-04 - mae: 0.0116 - mape: 15749.3682 - root_mean_squared_error: 0.0193 - val_loss: 0.0010 - val_mae: 0.0250 - val_mape: 8.0870 - val_root_mean_squared_error: 0.0322
# Epoch 145/150
# 73/73 - 1s - 16ms/step - loss: 3.7739e-04 - mae: 0.0118 - mape: 12791.3633 - root_mean_squared_error: 0.0194 - val_loss: 0.0014 - val_mae: 0.0287 - val_mape: 9.2094 - val_root_mean_squared_error: 0.0368
# Epoch 146/150
# 73/73 - 1s - 16ms/step - loss: 3.9798e-04 - mae: 0.0116 - mape: 7758.3691 - root_mean_squared_error: 0.0199 - val_loss: 8.0399e-04 - val_mae: 0.0220 - val_mape: 7.1773 - val_root_mean_squared_error: 0.0284
# Epoch 147/150
# 73/73 - 1s - 15ms/step - loss: 3.9868e-04 - mae: 0.0116 - mape: 13712.4570 - root_mean_squared_error: 0.0200 - val_loss: 0.0010 - val_mae: 0.0248 - val_mape: 7.9666 - val_root_mean_squared_error: 0.0320
# Epoch 148/150
# 73/73 - 1s - 15ms/step - loss: 3.7298e-04 - mae: 0.0114 - mape: 9007.2773 - root_mean_squared_error: 0.0193 - val_loss: 0.0015 - val_mae: 0.0295 - val_mape: 9.4065 - val_root_mean_squared_error: 0.0381
# Epoch 149/150
# 73/73 - 1s - 15ms/step - loss: 3.9748e-04 - mae: 0.0116 - mape: 12234.4619 - root_mean_squared_error: 0.0199 - val_loss: 8.8202e-04 - val_mae: 0.0228 - val_mape: 7.3889 - val_root_mean_squared_error: 0.0297
# Epoch 150/150
# 73/73 - 1s - 15ms/step - loss: 3.8794e-04 - mae: 0.0115 - mape: 9137.5107 - root_mean_squared_error: 0.0197 - val_loss: 6.3860e-04 - val_mae: 0.0206 - val_mape: 6.8946 - val_root_mean_squared_error: 0.0253

# %%
####################
### Plot Results ###
####################

# Training MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['loss'][1:], label='MSE')
ax[0, 0].set_title('Training Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Training MAE
ax[0, 1].plot(history.history['mae'][1:], label='MAE', color='black')
ax[0, 1].set_title('Training MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Training RMSE
ax[1, 0].plot(history.history['root_mean_squared_error'][1:], label='RMSE', color='green')
ax[1, 0].set_title('Training RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)

# Training MAPE
ax[1, 1].plot(history.history['mape'][1:], label='MAPE', color='red')
ax[1, 1].set_title('Training MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Validation MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['val_loss'][1:], label='Val MSE')
ax[0, 0].set_title('Validation Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Validation MAE
ax[0, 1].plot(history.history['val_mae'][1:], label='Val MAE')
ax[0, 1].set_title('Validation MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Validation RMSE
ax[1, 0].plot(history.history['val_root_mean_squared_error'][1:], label='Val RMSE')
ax[1, 0].set_title('Validation RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Validation MAPE
ax[1, 1].plot(history.history['val_mape'][1:], label='Val MAPE')
ax[1, 1].set_title('Validation MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Store best training/validation metrics
# Training
train_mse = history.history['loss']
best_epoch = np.argmin(train_mse)
best_train_mse = train_mse[best_epoch]
best_train_rmse = history.history['root_mean_squared_error'][best_epoch]
best_train_mae  = history.history['mae'][best_epoch]
best_train_mape = history.history['mape'][best_epoch]

# Validation: record epoch at which validation loss is the lowest for each seed
val_mse = history.history['val_loss']
best_epoch = np.argmin(val_mse)
best_val_mse = val_mse[best_epoch]
best_val_rmse = history.history['val_root_mean_squared_error'][best_epoch]
best_val_mae  = history.history['val_mae'][best_epoch]
best_val_mape = history.history['val_mape'][best_epoch]

# %%
# -------------------------
# Step 9 — Predict/Testing
# -------------------------
y_predict= model.predict([x_test, test_states[window:]])
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step

# %%
# -----------------------------------
# Step 10 — Test MSE/RMSE/MAE/MAPE/R2
# -----------------------------------

# Compute the loss metrics
test_mse = mean_squared_error(y_test, y_predict)
test_rmse = root_mean_squared_error(y_test, y_predict)
test_mae = mean_absolute_error(y_test, y_predict)
test_mape = mean_absolute_percentage_error(y_test, y_predict)
test_r2_score = r2_score(y_test, y_predict)

print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Mean Absolute Error:", test_mae)
print("Mean Absolute Percentage Error:", test_mape)
print("R2 Score:", test_r2_score)
# Out:
# Mean Squared Error: 0.00010451035901420247
# Root Mean Squared Error: 0.010223030813521128
# Mean Absolute Error: 0.008239468457120841
# Mean Absolute Percentage Error: 0.08835208198330662
# R2 Score: 0.7786966646116815

# %%
#-------------------------------------------------
# Step 11 - Inverse scaling: original price scale
#-------------------------------------------------

y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))
y_predict_orig = scaler.inverse_transform(y_predict)

# %%
#----------------------------------------------
# Step 12 - Plot prediction vs. actuals prices
#----------------------------------------------

# Add window size to test idx
start_index = 1482 + 120
# Test set dates range + convert to datetime
dates = data['Date'].iloc[start_index:start_index + len(y_test_orig)].reset_index(drop=True)
dates = pd.to_datetime(dates)

# Plot the actual vs predicted prices
plt.figure(figsize=(10, 5))
plt.plot(dates, y_test_orig, label='Actual', linewidth=2)
plt.plot(dates, y_predict_orig, label='Predicted', color='red')
plt.title('Actual vs Predicted XRP Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#--------------------------
# Step 13 - Export results
#--------------------------

# Export prediction dataset
predictions_df = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.flatten(),
    'Predicted': y_predict_orig.flatten()
})

predictions_df.to_csv('XRP_lstm_hmm_predictions.csv', index=False)

from google.colab import files
files.download('XRP_lstm_hmm_predictions.csv')

# %%
# Store metrics in dataframe along with best training/validation loss (record epoch)
results = {
    "seed": 42,
    "best_epoch": best_epoch + 1,    # best validation epoch
    "train_mse": best_train_mse,
    "train_rmse": best_train_rmse,
    "train_mae": best_train_mae,
    "train_mape": best_train_mape,
    "val_mse": best_val_mse,
    "val_rmse": best_val_rmse,
    "val_mae": best_val_mae,
    "val_mape": best_val_mape,
    "test_mse": test_mse,
    "test_rmse": test_rmse,
    "test_mae": test_mae,
    "test_mape": test_mape,
    "test_r2_score": test_r2_score
}

xrp_results = pd.DataFrame([results])
xrp_results.to_csv('xrp_lstm_hmm_results.csv')

files.download('xrp_lstm_hmm_results.csv')

# %%
# Export results

loss_results = pd.DataFrame(history.history)
loss_results.to_csv('xrp_lstm_hmm_loss_results.csv')

files.download('xrp_lstm_hmm_loss_results.csv')

# %% [markdown]
# # **Regime Classification**

# %%
# ------------------------------------------
# Step 1 — Compute Log returns & Volatility
# ------------------------------------------

original = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.ravel()
})

predicted = pd.DataFrame({
    'Date': dates,
    'Predicted': y_predict_orig.ravel()
})

# Compute returns from actual and predicted prices
returns_orig = original['Actual'].pct_change()
returns_pred = predicted['Predicted'].pct_change()
# Drop NaN values from returns
returns_orig = returns_orig.fillna(0)
returns_pred = returns_pred.fillna(0)

# Compute 10-day rolling volatility
volatility_orig = returns_orig.rolling(window=10).std()
volatility_pred = returns_pred.rolling(window=10).std()
volatility_orig = volatility_orig.fillna(0)
volatility_pred = volatility_pred.fillna(0)

# Update dataframes with returns and volatility
original['Returns'] = returns_orig
predicted['Returns'] = returns_pred
original['Volatility'] = volatility_orig
predicted['Volatility'] = volatility_pred

# %%
# --------------------------------
# Step 2 — Label Volatility L-M-H
# --------------------------------

# Compute quantiles as thresholds for low/med/high volatility
low_threshold = volatility_orig.quantile(0.33)   # lower 33%
high_threshold = volatility_orig.quantile(0.67)  # upper 33%

# Label volatility
def label_volatility(vol):
    if vol <= low_threshold:
        return 'low'
    elif vol >= high_threshold:
        return 'high'
    else:
        return 'medium'

# Apply volatility low/medium/high to original and prediction dataset
original['Volatility_level'] = original['Volatility'].apply(label_volatility)
predicted['Volatility_level'] = predicted['Volatility'].apply(label_volatility)

# %%
# -------------------------------
# Step 3 — Regime Classification
# -------------------------------

# Classify regime based on volatility + average sign of the returns
def classify_regime(pred_labels, vol_value, vol_threshold=(low_threshold, high_threshold), window=3):
    regimes = []
    low_threshold, high_threshold = vol_threshold

    for i in range(len(pred_labels) - window):
        window_preds = pred_labels[i:i+window]
        window_vol = vol_value[i+window]
        sign_pred = np.sign(window_preds.mean())

        if window_vol <= low_threshold:
            regimes.append("Neutral")

        else:
            if sign_pred > 0:
                regimes.append("Bull")
            elif sign_pred < 0:
                regimes.append("Bear")
            else:
                regimes.append("Uncertain")

    return regimes

vol_value = original['Volatility']
regimes = classify_regime(original['Returns'], vol_value)

# %%
####################
######  Plots ######
####################

# Plot price vs. date regime shifts in
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Actual'][3:]);
plt.plot(original['Date'][3:], predicted['Predicted'][3:], color='black', alpha=0.65);

plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4, label='Bull');
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4, label='Bear');
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Neutral' for r in regimes], color='grey', alpha=0.3, label='Neutral');

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);
plt.legend();
plt.title('Regime Shift XRP Predicted')
plt.grid(True);
plt.tight_layout();
plt.show();

# %%
# Plot regime shift for log returns vs. date
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Returns'][3:], label='Actual')
plt.plot(original['Date'][3:], predicted['Returns'][3:], color='red', alpha=0.6, label='Predicted')

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);

plt.legend()
plt.title('Regime Shift XRP Returns')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift
# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = original['Actual'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift XRP Actual")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = predicted['Predicted'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift XRP Prediction")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()
