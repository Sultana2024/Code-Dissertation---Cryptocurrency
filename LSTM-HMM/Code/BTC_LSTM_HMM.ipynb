# %%
#####################
## Bitcoin (BTC)   ##
#####################

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install pandas
# !pip install hmmlearn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting hmmlearn
#   Downloading hmmlearn-0.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (2.0.2)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (1.6.1)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.6.0)
# Downloading hmmlearn-0.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 kB 13.9 MB/s eta 0:00:00
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.3.3

# %%
#######################
###### Libraries ######
#######################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import tensorflow as tf

from hmmlearn.hmm import GaussianHMM
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.utils import to_categorical

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Best Optuna trial:
#   Loss: 0.001459612394683063
#   Params:
#     lstm_units1: 64
#     lstm_units2: 8
#     lstm_units3: 4
#     dense_units: 64
#     dense_units2: 64
#     dropout_rate: 0.33454307320167703
#     activation: tanh
#     optimizer: rmsprop
#     learning_rate: 0.0009717787126451334
#     batch_size: 16
#     epochs: 130

# 1st best model setting (optuna) - no seed
# Mean Squared Error: 0.0002804228438039534
# Root Mean Squared Error: 0.0167458306394145
# Mean Absolute Error: 0.011813302290956064
# Mean Absolute Percentage Error: 0.039248074052865435
# R2 Score: 0.9335748445514824

# Best trial:
#   Loss: 0.0008035983191803098
#   Params:
#     lstm_units1: 128
#     lstm_units2: 8
#     lstm_units3: 8
#     dense_units: 4
#     dense_units2: 64
#     dropout_rate: 0.09246768282596343
#     activation: tanh
#     optimizer: adam
#     learning_rate: 0.0027441467785781193
#     batch_size: 16
#     epochs: 140

# 2nd best model setting (optuna) - no seed
# Mean Squared Error: 0.00035627191913944605
# Root Mean Squared Error: 0.01887516673143435
# Mean Absolute Error: 0.015145563049009455
# Mean Absolute Percentage Error: 0.05077025790281554
# R2 Score: 0.9156080963670559

# 1st model hyperparameters are selected

# %%
# Set 3 seeds and record the model performance for each : 42, 45, 91
# Best seed 91
np.random.seed(91)
tf.random.set_seed(91)

# %%
# Load dataset without scaling
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BTC_noscale.csv')
data.drop(columns=['Crypto', 'Open', 'High', 'Low'], inplace=True)
data.head()
# Out:
#          Date    Close
# 0  2018-01-01  13535.0
# 1  2018-01-02  14770.0
# 2  2018-01-03  15057.0
# 3  2018-01-04  14921.0
# 4  2018-01-05  16828.0

# %%
# -------------------------
# Step 1 - Normalisation
# -------------------------
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['Close']].values.reshape(-1, 1))
input_data = scaled_data.reshape(-1)

# ---------------------------------
# Step 2 - Generate sliding windows
# ---------------------------------
train_end = int(0.65 * len(scaled_data)            ) # training ratio
val_end   = train_end + int(0.10 * len(scaled_data)) # validation ratio
window = 120                                         # window size - days of price input

train_slice = input_data[:train_end]
val_slice   = input_data[train_end:val_end]
test_slice  = input_data[val_end:]

def sequence(data, window_size):
    data = np.asarray(data).reshape(-1, 1)
    x, y = [], []
    for i in range(window_size, len(data)):
        x.append(data[i-window_size:i])
        y.append(data[i])
    return np.array(x), np.array(y)

x_train, y_train = sequence(train_slice, window)
x_val,   y_val   = sequence(val_slice,   window)
x_test,  y_test  = sequence(test_slice,  window)

# %%
# ---------------------------------
# Step 3 - Build Gaussian HMM
# ---------------------------------

# Fit Gaussian HMM with 3 states on the training input data
hmm = GaussianHMM(n_components=3, n_iter=200, random_state=42)
hmm.fit(train_slice.reshape(-1,1))

# Build train, val, test arrays with the last indices in each LSTM sequence (above)
# The aim is to align the HMM input data to the LSTM sequences of 120-day input
# To avoid data leakage (into the future)
window = 120
train_last_idx = np.arange(window-1, train_end-1)
val_last_idx   = np.arange(train_end + window-1, val_end-1)
test_last_idx  = np.arange(val_end   + window-1, len(input_data)-1)


# -----------------------------------------
# Step 5 — Compute posterior probabilities
# -----------------------------------------

# Build the Causal HMM with the input data and train/val/test indices from above
# The probability of the next point is only based on the past datapoints
# Compute the posterior probability for each price at time t+1 for input 0...t (t=window-1)
# The post_probability of each of the 3 states is returned for all 3 sets and ready for use in training the model
def causal_hmm(price_series, hmm, index):
    post_probabilities = np.zeros((len(index), hmm.n_components))
    for i, t in enumerate(index):
        post_probabilities[i] = hmm.predict_proba(price_series[:t+1].reshape(-1,1))[-1]  # last row = uses data ≤ t
    return post_probabilities

H_train = causal_hmm(input_data, hmm, train_last_idx)
H_val   = causal_hmm(input_data, hmm, val_last_idx)
H_test  = causal_hmm(input_data, hmm, test_last_idx)

# HMM output with 'relu' activation function
# Input = one probability for each of 3 states
hmm_input = Input(shape=(3,))
hmm_out   = Dense(64, activation='relu')(hmm_input)

# %%
# ------------
# Parameters
# ------------
n_timesteps = x_train.shape[1]
n_features  = x_train.shape[2]
dropout_rate = 0.33454307320167703


# --------------------------
# Step 5 — LSTM branch input
# --------------------------
# LSTM branch
lstm_input = Input(shape=(n_timesteps, n_features))
y = LSTM(64, return_sequences=True, activation='tanh')(lstm_input)
y = Dropout(dropout_rate)(y)
y = LSTM(8, return_sequences=True, activation='tanh')(y)
lstm_out = LSTM(4, return_sequences=False, activation='tanh')(y)


# -----------------------------
# Step 6 — Concatenate HMM/LSTM
# -----------------------------
combined = Concatenate()([lstm_out, hmm_out])
combined = Dense(64, activation='tanh')(combined)
output = Dense(1, activation='linear')(combined)


# ---------------------------------
# Step 7 — Compile Model/Regression
# ---------------------------------
model = Model(inputs=[lstm_input, hmm_input], outputs=output)
model.compile(loss='mean_squared_error',
              optimizer=RMSprop(learning_rate=0.0009717787126451334),
              metrics=['mae', RootMeanSquaredError(), 'mape'])

# %%
# ---------------------------------
# Step 8 — Model Training
# ---------------------------------
history = model.fit([x_train, H_train], y_train,
                    epochs=150, batch_size=16,
                    shuffle=False,
                    validation_data=([x_val, H_val], y_val),
                    verbose=2)
# Out:
# Epoch 1/150
# 73/73 - 6s - 80ms/step - loss: 0.0139 - mae: 0.0686 - mape: 70457.2812 - root_mean_squared_error: 0.1178 - val_loss: 0.0096 - val_mae: 0.0739 - val_mape: 9.3134 - val_root_mean_squared_error: 0.0981
# Epoch 2/150
# 73/73 - 1s - 17ms/step - loss: 0.0046 - mae: 0.0498 - mape: 71040.4844 - root_mean_squared_error: 0.0676 - val_loss: 0.0079 - val_mae: 0.0656 - val_mape: 8.1811 - val_root_mean_squared_error: 0.0888
# Epoch 3/150
# 73/73 - 1s - 17ms/step - loss: 0.0039 - mae: 0.0457 - mape: 79158.6016 - root_mean_squared_error: 0.0621 - val_loss: 0.0069 - val_mae: 0.0591 - val_mape: 7.2428 - val_root_mean_squared_error: 0.0830
# Epoch 4/150
# 73/73 - 1s - 16ms/step - loss: 0.0035 - mae: 0.0428 - mape: 71338.7109 - root_mean_squared_error: 0.0590 - val_loss: 0.0065 - val_mae: 0.0570 - val_mape: 6.9476 - val_root_mean_squared_error: 0.0806
# Epoch 5/150
# 73/73 - 1s - 16ms/step - loss: 0.0031 - mae: 0.0402 - mape: 68281.7344 - root_mean_squared_error: 0.0557 - val_loss: 0.0059 - val_mae: 0.0546 - val_mape: 6.6743 - val_root_mean_squared_error: 0.0766
# Epoch 6/150
# 73/73 - 1s - 16ms/step - loss: 0.0029 - mae: 0.0389 - mape: 55771.0195 - root_mean_squared_error: 0.0541 - val_loss: 0.0063 - val_mae: 0.0586 - val_mape: 7.2066 - val_root_mean_squared_error: 0.0792
# Epoch 7/150
# 73/73 - 1s - 16ms/step - loss: 0.0027 - mae: 0.0365 - mape: 54358.2656 - root_mean_squared_error: 0.0520 - val_loss: 0.0058 - val_mae: 0.0564 - val_mape: 6.9569 - val_root_mean_squared_error: 0.0763
# Epoch 8/150
# 73/73 - 1s - 16ms/step - loss: 0.0025 - mae: 0.0351 - mape: 43205.3164 - root_mean_squared_error: 0.0496 - val_loss: 0.0067 - val_mae: 0.0628 - val_mape: 7.7941 - val_root_mean_squared_error: 0.0819
# Epoch 9/150
# 73/73 - 1s - 16ms/step - loss: 0.0024 - mae: 0.0349 - mape: 49455.9766 - root_mean_squared_error: 0.0490 - val_loss: 0.0062 - val_mae: 0.0602 - val_mape: 7.4814 - val_root_mean_squared_error: 0.0786
# Epoch 10/150
# 73/73 - 1s - 16ms/step - loss: 0.0022 - mae: 0.0326 - mape: 56386.7930 - root_mean_squared_error: 0.0470 - val_loss: 0.0057 - val_mae: 0.0574 - val_mape: 7.1491 - val_root_mean_squared_error: 0.0752
# Epoch 11/150
# 73/73 - 1s - 17ms/step - loss: 0.0021 - mae: 0.0320 - mape: 48015.1289 - root_mean_squared_error: 0.0455 - val_loss: 0.0068 - val_mae: 0.0651 - val_mape: 8.1515 - val_root_mean_squared_error: 0.0826
# Epoch 12/150
# 73/73 - 1s - 16ms/step - loss: 0.0020 - mae: 0.0307 - mape: 54689.5195 - root_mean_squared_error: 0.0446 - val_loss: 0.0078 - val_mae: 0.0716 - val_mape: 9.0251 - val_root_mean_squared_error: 0.0881
# Epoch 13/150
# 73/73 - 1s - 16ms/step - loss: 0.0020 - mae: 0.0306 - mape: 49850.3125 - root_mean_squared_error: 0.0443 - val_loss: 0.0065 - val_mae: 0.0637 - val_mape: 7.9982 - val_root_mean_squared_error: 0.0804
# Epoch 14/150
# 73/73 - 1s - 16ms/step - loss: 0.0018 - mae: 0.0292 - mape: 49731.4844 - root_mean_squared_error: 0.0426 - val_loss: 0.0061 - val_mae: 0.0619 - val_mape: 7.7757 - val_root_mean_squared_error: 0.0782
# Epoch 15/150
# 73/73 - 1s - 16ms/step - loss: 0.0016 - mae: 0.0279 - mape: 52739.7422 - root_mean_squared_error: 0.0401 - val_loss: 0.0060 - val_mae: 0.0618 - val_mape: 7.7853 - val_root_mean_squared_error: 0.0778
# Epoch 16/150
# 73/73 - 1s - 15ms/step - loss: 0.0016 - mae: 0.0276 - mape: 46813.8398 - root_mean_squared_error: 0.0403 - val_loss: 0.0073 - val_mae: 0.0704 - val_mape: 8.9396 - val_root_mean_squared_error: 0.0855
# Epoch 17/150
# 73/73 - 1s - 16ms/step - loss: 0.0016 - mae: 0.0273 - mape: 41133.1094 - root_mean_squared_error: 0.0399 - val_loss: 0.0051 - val_mae: 0.0560 - val_mape: 7.0614 - val_root_mean_squared_error: 0.0713
# Epoch 18/150
# 73/73 - 1s - 16ms/step - loss: 0.0015 - mae: 0.0264 - mape: 32546.0977 - root_mean_squared_error: 0.0388 - val_loss: 0.0049 - val_mae: 0.0545 - val_mape: 6.8668 - val_root_mean_squared_error: 0.0697
# Epoch 19/150
# 73/73 - 1s - 16ms/step - loss: 0.0014 - mae: 0.0250 - mape: 34639.1055 - root_mean_squared_error: 0.0374 - val_loss: 0.0053 - val_mae: 0.0578 - val_mape: 7.2959 - val_root_mean_squared_error: 0.0728
# Epoch 20/150
# 73/73 - 1s - 16ms/step - loss: 0.0015 - mae: 0.0252 - mape: 37082.8516 - root_mean_squared_error: 0.0383 - val_loss: 0.0053 - val_mae: 0.0579 - val_mape: 7.3148 - val_root_mean_squared_error: 0.0726
# Epoch 21/150
# 73/73 - 1s - 16ms/step - loss: 0.0014 - mae: 0.0247 - mape: 44776.7578 - root_mean_squared_error: 0.0371 - val_loss: 0.0075 - val_mae: 0.0736 - val_mape: 9.4365 - val_root_mean_squared_error: 0.0867
# Epoch 22/150
# 73/73 - 1s - 16ms/step - loss: 0.0013 - mae: 0.0240 - mape: 27093.5527 - root_mean_squared_error: 0.0359 - val_loss: 0.0066 - val_mae: 0.0679 - val_mape: 8.6716 - val_root_mean_squared_error: 0.0811
# Epoch 23/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0229 - mape: 27479.3340 - root_mean_squared_error: 0.0350 - val_loss: 0.0061 - val_mae: 0.0646 - val_mape: 8.2355 - val_root_mean_squared_error: 0.0780
# Epoch 24/150
# 73/73 - 1s - 16ms/step - loss: 0.0013 - mae: 0.0225 - mape: 37180.9570 - root_mean_squared_error: 0.0355 - val_loss: 0.0049 - val_mae: 0.0563 - val_mape: 7.1229 - val_root_mean_squared_error: 0.0703
# Epoch 25/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0221 - mape: 26857.2070 - root_mean_squared_error: 0.0347 - val_loss: 0.0059 - val_mae: 0.0639 - val_mape: 8.1423 - val_root_mean_squared_error: 0.0771
# Epoch 26/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0222 - mape: 45425.3008 - root_mean_squared_error: 0.0346 - val_loss: 0.0058 - val_mae: 0.0631 - val_mape: 8.0483 - val_root_mean_squared_error: 0.0761
# Epoch 27/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0219 - mape: 32499.5059 - root_mean_squared_error: 0.0337 - val_loss: 0.0046 - val_mae: 0.0547 - val_mape: 6.9365 - val_root_mean_squared_error: 0.0681
# Epoch 28/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0215 - mape: 39116.0156 - root_mean_squared_error: 0.0337 - val_loss: 0.0040 - val_mae: 0.0502 - val_mape: 6.3570 - val_root_mean_squared_error: 0.0634
# Epoch 29/150
# 73/73 - 1s - 16ms/step - loss: 0.0010 - mae: 0.0204 - mape: 29978.1289 - root_mean_squared_error: 0.0319 - val_loss: 0.0071 - val_mae: 0.0729 - val_mape: 9.3968 - val_root_mean_squared_error: 0.0840
# Epoch 30/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0205 - mape: 38524.2969 - root_mean_squared_error: 0.0326 - val_loss: 0.0047 - val_mae: 0.0556 - val_mape: 7.0789 - val_root_mean_squared_error: 0.0682
# Epoch 31/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0206 - mape: 15202.5371 - root_mean_squared_error: 0.0330 - val_loss: 0.0045 - val_mae: 0.0540 - val_mape: 6.8592 - val_root_mean_squared_error: 0.0669
# Epoch 32/150
# 73/73 - 1s - 16ms/step - loss: 0.0010 - mae: 0.0203 - mape: 30966.2051 - root_mean_squared_error: 0.0320 - val_loss: 0.0024 - val_mae: 0.0372 - val_mape: 4.7318 - val_root_mean_squared_error: 0.0493
# Epoch 33/150
# 73/73 - 1s - 16ms/step - loss: 0.0010 - mae: 0.0201 - mape: 40136.2695 - root_mean_squared_error: 0.0317 - val_loss: 0.0033 - val_mae: 0.0448 - val_mape: 5.6733 - val_root_mean_squared_error: 0.0575
# Epoch 34/150
# 73/73 - 1s - 16ms/step - loss: 9.8159e-04 - mae: 0.0194 - mape: 34422.9648 - root_mean_squared_error: 0.0313 - val_loss: 0.0036 - val_mae: 0.0478 - val_mape: 6.0763 - val_root_mean_squared_error: 0.0602
# Epoch 35/150
# 73/73 - 1s - 16ms/step - loss: 9.1718e-04 - mae: 0.0193 - mape: 23255.0723 - root_mean_squared_error: 0.0303 - val_loss: 0.0040 - val_mae: 0.0510 - val_mape: 6.5028 - val_root_mean_squared_error: 0.0629
# Epoch 36/150
# 73/73 - 1s - 16ms/step - loss: 8.7789e-04 - mae: 0.0192 - mape: 28889.1641 - root_mean_squared_error: 0.0296 - val_loss: 0.0035 - val_mae: 0.0470 - val_mape: 5.9915 - val_root_mean_squared_error: 0.0589
# Epoch 37/150
# 73/73 - 1s - 16ms/step - loss: 9.0462e-04 - mae: 0.0194 - mape: 18511.3359 - root_mean_squared_error: 0.0301 - val_loss: 0.0030 - val_mae: 0.0428 - val_mape: 5.4347 - val_root_mean_squared_error: 0.0549
# Epoch 38/150
# 73/73 - 1s - 16ms/step - loss: 9.1506e-04 - mae: 0.0190 - mape: 33031.9883 - root_mean_squared_error: 0.0302 - val_loss: 0.0064 - val_mae: 0.0700 - val_mape: 9.0549 - val_root_mean_squared_error: 0.0799
# Epoch 39/150
# 73/73 - 1s - 16ms/step - loss: 9.0835e-04 - mae: 0.0186 - mape: 18237.7168 - root_mean_squared_error: 0.0301 - val_loss: 0.0034 - val_mae: 0.0469 - val_mape: 5.9686 - val_root_mean_squared_error: 0.0585
# Epoch 40/150
# 73/73 - 1s - 16ms/step - loss: 9.3950e-04 - mae: 0.0192 - mape: 16949.0312 - root_mean_squared_error: 0.0307 - val_loss: 0.0038 - val_mae: 0.0498 - val_mape: 6.3542 - val_root_mean_squared_error: 0.0614
# Epoch 41/150
# 73/73 - 1s - 16ms/step - loss: 9.0897e-04 - mae: 0.0188 - mape: 25508.6543 - root_mean_squared_error: 0.0301 - val_loss: 0.0042 - val_mae: 0.0533 - val_mape: 6.7929 - val_root_mean_squared_error: 0.0650
# Epoch 42/150
# 73/73 - 1s - 16ms/step - loss: 8.3529e-04 - mae: 0.0182 - mape: 14085.8164 - root_mean_squared_error: 0.0289 - val_loss: 0.0032 - val_mae: 0.0449 - val_mape: 5.7036 - val_root_mean_squared_error: 0.0568
# Epoch 43/150
# 73/73 - 1s - 17ms/step - loss: 8.6608e-04 - mae: 0.0182 - mape: 15038.4961 - root_mean_squared_error: 0.0294 - val_loss: 0.0029 - val_mae: 0.0419 - val_mape: 5.3186 - val_root_mean_squared_error: 0.0535
# Epoch 44/150
# 73/73 - 1s - 16ms/step - loss: 8.1887e-04 - mae: 0.0179 - mape: 21122.8203 - root_mean_squared_error: 0.0286 - val_loss: 0.0030 - val_mae: 0.0430 - val_mape: 5.4644 - val_root_mean_squared_error: 0.0546
# Epoch 45/150
# 73/73 - 1s - 16ms/step - loss: 8.2681e-04 - mae: 0.0179 - mape: 23648.0859 - root_mean_squared_error: 0.0288 - val_loss: 0.0023 - val_mae: 0.0369 - val_mape: 4.7026 - val_root_mean_squared_error: 0.0481
# Epoch 46/150
# 73/73 - 1s - 16ms/step - loss: 7.7482e-04 - mae: 0.0174 - mape: 15365.0576 - root_mean_squared_error: 0.0278 - val_loss: 0.0028 - val_mae: 0.0420 - val_mape: 5.3448 - val_root_mean_squared_error: 0.0533
# Epoch 47/150
# 73/73 - 1s - 16ms/step - loss: 7.6162e-04 - mae: 0.0172 - mape: 17149.0508 - root_mean_squared_error: 0.0276 - val_loss: 0.0032 - val_mae: 0.0456 - val_mape: 5.8250 - val_root_mean_squared_error: 0.0568
# Epoch 48/150
# 73/73 - 1s - 16ms/step - loss: 7.9207e-04 - mae: 0.0176 - mape: 23337.3984 - root_mean_squared_error: 0.0281 - val_loss: 0.0043 - val_mae: 0.0550 - val_mape: 7.0583 - val_root_mean_squared_error: 0.0657
# Epoch 49/150
# 73/73 - 1s - 16ms/step - loss: 7.8704e-04 - mae: 0.0171 - mape: 11536.0078 - root_mean_squared_error: 0.0281 - val_loss: 0.0035 - val_mae: 0.0477 - val_mape: 6.0870 - val_root_mean_squared_error: 0.0590
# Epoch 50/150
# 73/73 - 1s - 16ms/step - loss: 8.1720e-04 - mae: 0.0178 - mape: 28636.4336 - root_mean_squared_error: 0.0286 - val_loss: 0.0026 - val_mae: 0.0399 - val_mape: 5.0683 - val_root_mean_squared_error: 0.0514
# Epoch 51/150
# 73/73 - 1s - 16ms/step - loss: 7.5697e-04 - mae: 0.0171 - mape: 16032.6201 - root_mean_squared_error: 0.0275 - val_loss: 0.0023 - val_mae: 0.0370 - val_mape: 4.7142 - val_root_mean_squared_error: 0.0481
# Epoch 52/150
# 73/73 - 1s - 16ms/step - loss: 7.4347e-04 - mae: 0.0171 - mape: 13803.0225 - root_mean_squared_error: 0.0273 - val_loss: 0.0037 - val_mae: 0.0505 - val_mape: 6.4797 - val_root_mean_squared_error: 0.0612
# Epoch 53/150
# 73/73 - 1s - 16ms/step - loss: 7.6680e-04 - mae: 0.0174 - mape: 26826.2031 - root_mean_squared_error: 0.0277 - val_loss: 0.0032 - val_mae: 0.0455 - val_mape: 5.7976 - val_root_mean_squared_error: 0.0566
# Epoch 54/150
# 73/73 - 1s - 16ms/step - loss: 7.2735e-04 - mae: 0.0168 - mape: 23746.5684 - root_mean_squared_error: 0.0270 - val_loss: 0.0023 - val_mae: 0.0374 - val_mape: 4.7771 - val_root_mean_squared_error: 0.0482
# Epoch 55/150
# 73/73 - 1s - 16ms/step - loss: 7.4736e-04 - mae: 0.0165 - mape: 24243.7617 - root_mean_squared_error: 0.0273 - val_loss: 0.0023 - val_mae: 0.0375 - val_mape: 4.7844 - val_root_mean_squared_error: 0.0484
# Epoch 56/150
# 73/73 - 1s - 16ms/step - loss: 7.2206e-04 - mae: 0.0167 - mape: 19016.2148 - root_mean_squared_error: 0.0269 - val_loss: 0.0040 - val_mae: 0.0530 - val_mape: 6.8042 - val_root_mean_squared_error: 0.0633
# Epoch 57/150
# 73/73 - 1s - 16ms/step - loss: 7.5558e-04 - mae: 0.0172 - mape: 22624.1543 - root_mean_squared_error: 0.0275 - val_loss: 0.0026 - val_mae: 0.0397 - val_mape: 5.0643 - val_root_mean_squared_error: 0.0509
# Epoch 58/150
# 73/73 - 1s - 15ms/step - loss: 6.4468e-04 - mae: 0.0160 - mape: 16837.5352 - root_mean_squared_error: 0.0254 - val_loss: 0.0034 - val_mae: 0.0481 - val_mape: 6.1679 - val_root_mean_squared_error: 0.0587
# Epoch 59/150
# 73/73 - 1s - 15ms/step - loss: 6.9201e-04 - mae: 0.0165 - mape: 22233.0566 - root_mean_squared_error: 0.0263 - val_loss: 0.0017 - val_mae: 0.0321 - val_mape: 4.1695 - val_root_mean_squared_error: 0.0414
# Epoch 60/150
# 73/73 - 1s - 15ms/step - loss: 6.9643e-04 - mae: 0.0164 - mape: 24085.7891 - root_mean_squared_error: 0.0264 - val_loss: 0.0022 - val_mae: 0.0362 - val_mape: 4.6263 - val_root_mean_squared_error: 0.0467
# Epoch 61/150
# 73/73 - 1s - 16ms/step - loss: 7.1646e-04 - mae: 0.0164 - mape: 26433.9883 - root_mean_squared_error: 0.0268 - val_loss: 0.0035 - val_mae: 0.0488 - val_mape: 6.2636 - val_root_mean_squared_error: 0.0591
# Epoch 62/150
# 73/73 - 1s - 16ms/step - loss: 7.0034e-04 - mae: 0.0162 - mape: 20135.5352 - root_mean_squared_error: 0.0265 - val_loss: 0.0022 - val_mae: 0.0363 - val_mape: 4.6553 - val_root_mean_squared_error: 0.0468
# Epoch 63/150
# 73/73 - 1s - 16ms/step - loss: 6.8890e-04 - mae: 0.0162 - mape: 9328.7861 - root_mean_squared_error: 0.0262 - val_loss: 0.0021 - val_mae: 0.0359 - val_mape: 4.5958 - val_root_mean_squared_error: 0.0464
# Epoch 64/150
# 73/73 - 1s - 16ms/step - loss: 6.7538e-04 - mae: 0.0162 - mape: 10745.7051 - root_mean_squared_error: 0.0260 - val_loss: 0.0017 - val_mae: 0.0319 - val_mape: 4.1482 - val_root_mean_squared_error: 0.0411
# Epoch 65/150
# 73/73 - 1s - 16ms/step - loss: 6.0449e-04 - mae: 0.0154 - mape: 20303.6816 - root_mean_squared_error: 0.0246 - val_loss: 0.0024 - val_mae: 0.0383 - val_mape: 4.8890 - val_root_mean_squared_error: 0.0490
# Epoch 66/150
# 73/73 - 1s - 16ms/step - loss: 6.6806e-04 - mae: 0.0161 - mape: 3396.4636 - root_mean_squared_error: 0.0258 - val_loss: 0.0015 - val_mae: 0.0302 - val_mape: 3.9642 - val_root_mean_squared_error: 0.0388
# Epoch 67/150
# 73/73 - 1s - 16ms/step - loss: 6.2220e-04 - mae: 0.0156 - mape: 15530.6523 - root_mean_squared_error: 0.0249 - val_loss: 0.0020 - val_mae: 0.0345 - val_mape: 4.4369 - val_root_mean_squared_error: 0.0446
# Epoch 68/150
# 73/73 - 1s - 16ms/step - loss: 7.1168e-04 - mae: 0.0163 - mape: 7837.8315 - root_mean_squared_error: 0.0267 - val_loss: 0.0032 - val_mae: 0.0463 - val_mape: 5.9197 - val_root_mean_squared_error: 0.0568
# Epoch 69/150
# 73/73 - 1s - 16ms/step - loss: 6.2747e-04 - mae: 0.0156 - mape: 10823.5273 - root_mean_squared_error: 0.0250 - val_loss: 0.0018 - val_mae: 0.0333 - val_mape: 4.2924 - val_root_mean_squared_error: 0.0429
# Epoch 70/150
# 73/73 - 1s - 16ms/step - loss: 6.5286e-04 - mae: 0.0158 - mape: 19411.2344 - root_mean_squared_error: 0.0256 - val_loss: 0.0031 - val_mae: 0.0451 - val_mape: 5.7777 - val_root_mean_squared_error: 0.0554
# Epoch 71/150
# 73/73 - 1s - 16ms/step - loss: 6.3445e-04 - mae: 0.0161 - mape: 11069.8311 - root_mean_squared_error: 0.0252 - val_loss: 0.0027 - val_mae: 0.0408 - val_mape: 5.2161 - val_root_mean_squared_error: 0.0515
# Epoch 72/150
# 73/73 - 1s - 16ms/step - loss: 6.7516e-04 - mae: 0.0161 - mape: 16737.2988 - root_mean_squared_error: 0.0260 - val_loss: 0.0015 - val_mae: 0.0298 - val_mape: 3.9248 - val_root_mean_squared_error: 0.0384
# Epoch 73/150
# 73/73 - 1s - 16ms/step - loss: 6.6661e-04 - mae: 0.0157 - mape: 21296.6738 - root_mean_squared_error: 0.0258 - val_loss: 0.0024 - val_mae: 0.0387 - val_mape: 4.9557 - val_root_mean_squared_error: 0.0492
# Epoch 74/150
# 73/73 - 1s - 17ms/step - loss: 6.3758e-04 - mae: 0.0156 - mape: 6006.0366 - root_mean_squared_error: 0.0253 - val_loss: 0.0021 - val_mae: 0.0355 - val_mape: 4.5561 - val_root_mean_squared_error: 0.0456
# Epoch 75/150
# 73/73 - 1s - 16ms/step - loss: 6.3953e-04 - mae: 0.0157 - mape: 17286.8906 - root_mean_squared_error: 0.0253 - val_loss: 0.0018 - val_mae: 0.0331 - val_mape: 4.2721 - val_root_mean_squared_error: 0.0427
# Epoch 76/150
# 73/73 - 1s - 16ms/step - loss: 6.4064e-04 - mae: 0.0155 - mape: 18325.7578 - root_mean_squared_error: 0.0253 - val_loss: 0.0017 - val_mae: 0.0321 - val_mape: 4.1522 - val_root_mean_squared_error: 0.0414
# Epoch 77/150
# 73/73 - 1s - 16ms/step - loss: 6.2157e-04 - mae: 0.0150 - mape: 5792.3477 - root_mean_squared_error: 0.0249 - val_loss: 0.0029 - val_mae: 0.0432 - val_mape: 5.5376 - val_root_mean_squared_error: 0.0534
# Epoch 78/150
# 73/73 - 1s - 16ms/step - loss: 6.6182e-04 - mae: 0.0154 - mape: 16373.4951 - root_mean_squared_error: 0.0257 - val_loss: 0.0019 - val_mae: 0.0341 - val_mape: 4.3929 - val_root_mean_squared_error: 0.0439
# Epoch 79/150
# 73/73 - 1s - 16ms/step - loss: 5.9893e-04 - mae: 0.0150 - mape: 28956.4629 - root_mean_squared_error: 0.0245 - val_loss: 0.0014 - val_mae: 0.0290 - val_mape: 3.8290 - val_root_mean_squared_error: 0.0375
# Epoch 80/150
# 73/73 - 1s - 16ms/step - loss: 6.6170e-04 - mae: 0.0157 - mape: 5332.0767 - root_mean_squared_error: 0.0257 - val_loss: 0.0033 - val_mae: 0.0477 - val_mape: 6.1442 - val_root_mean_squared_error: 0.0574
# Epoch 81/150
# 73/73 - 1s - 16ms/step - loss: 5.8346e-04 - mae: 0.0147 - mape: 16230.3467 - root_mean_squared_error: 0.0242 - val_loss: 0.0013 - val_mae: 0.0278 - val_mape: 3.7972 - val_root_mean_squared_error: 0.0361
# Epoch 82/150
# 73/73 - 1s - 15ms/step - loss: 6.3308e-04 - mae: 0.0154 - mape: 15973.4922 - root_mean_squared_error: 0.0252 - val_loss: 0.0025 - val_mae: 0.0397 - val_mape: 5.1024 - val_root_mean_squared_error: 0.0498
# Epoch 83/150
# 73/73 - 1s - 16ms/step - loss: 6.5183e-04 - mae: 0.0154 - mape: 14525.3203 - root_mean_squared_error: 0.0255 - val_loss: 0.0021 - val_mae: 0.0358 - val_mape: 4.5921 - val_root_mean_squared_error: 0.0460
# Epoch 84/150
# 73/73 - 1s - 16ms/step - loss: 6.1484e-04 - mae: 0.0150 - mape: 16499.4453 - root_mean_squared_error: 0.0248 - val_loss: 0.0025 - val_mae: 0.0393 - val_mape: 5.0302 - val_root_mean_squared_error: 0.0495
# Epoch 85/150
# 73/73 - 1s - 16ms/step - loss: 6.1950e-04 - mae: 0.0149 - mape: 24230.4160 - root_mean_squared_error: 0.0249 - val_loss: 0.0014 - val_mae: 0.0286 - val_mape: 3.7850 - val_root_mean_squared_error: 0.0372
# Epoch 86/150
# 73/73 - 1s - 16ms/step - loss: 5.9152e-04 - mae: 0.0152 - mape: 16040.1426 - root_mean_squared_error: 0.0243 - val_loss: 0.0023 - val_mae: 0.0373 - val_mape: 4.7739 - val_root_mean_squared_error: 0.0474
# Epoch 87/150
# 73/73 - 1s - 16ms/step - loss: 6.1681e-04 - mae: 0.0154 - mape: 17258.0215 - root_mean_squared_error: 0.0248 - val_loss: 0.0017 - val_mae: 0.0315 - val_mape: 4.0813 - val_root_mean_squared_error: 0.0407
# Epoch 88/150
# 73/73 - 1s - 16ms/step - loss: 5.9484e-04 - mae: 0.0149 - mape: 12725.6689 - root_mean_squared_error: 0.0244 - val_loss: 0.0028 - val_mae: 0.0433 - val_mape: 5.5533 - val_root_mean_squared_error: 0.0533
# Epoch 89/150
# 73/73 - 1s - 15ms/step - loss: 6.2472e-04 - mae: 0.0154 - mape: 14840.5234 - root_mean_squared_error: 0.0250 - val_loss: 0.0017 - val_mae: 0.0316 - val_mape: 4.0898 - val_root_mean_squared_error: 0.0408
# Epoch 90/150
# 73/73 - 1s - 15ms/step - loss: 6.1614e-04 - mae: 0.0153 - mape: 18672.5703 - root_mean_squared_error: 0.0248 - val_loss: 0.0020 - val_mae: 0.0346 - val_mape: 4.4491 - val_root_mean_squared_error: 0.0444
# Epoch 91/150
# 73/73 - 1s - 16ms/step - loss: 6.0166e-04 - mae: 0.0149 - mape: 16421.1367 - root_mean_squared_error: 0.0245 - val_loss: 0.0018 - val_mae: 0.0328 - val_mape: 4.2345 - val_root_mean_squared_error: 0.0423
# Epoch 92/150
# 73/73 - 1s - 16ms/step - loss: 6.1622e-04 - mae: 0.0150 - mape: 22032.6621 - root_mean_squared_error: 0.0248 - val_loss: 0.0020 - val_mae: 0.0346 - val_mape: 4.4454 - val_root_mean_squared_error: 0.0444
# Epoch 93/150
# 73/73 - 1s - 16ms/step - loss: 5.8544e-04 - mae: 0.0149 - mape: 21155.3281 - root_mean_squared_error: 0.0242 - val_loss: 0.0016 - val_mae: 0.0305 - val_mape: 3.9694 - val_root_mean_squared_error: 0.0395
# Epoch 94/150
# 73/73 - 1s - 16ms/step - loss: 5.8792e-04 - mae: 0.0150 - mape: 14768.5029 - root_mean_squared_error: 0.0242 - val_loss: 0.0017 - val_mae: 0.0320 - val_mape: 4.1443 - val_root_mean_squared_error: 0.0413
# Epoch 95/150
# 73/73 - 1s - 16ms/step - loss: 6.0343e-04 - mae: 0.0149 - mape: 17031.2109 - root_mean_squared_error: 0.0246 - val_loss: 0.0017 - val_mae: 0.0317 - val_mape: 4.1063 - val_root_mean_squared_error: 0.0409
# Epoch 96/150
# 73/73 - 1s - 16ms/step - loss: 5.9230e-04 - mae: 0.0149 - mape: 16828.6094 - root_mean_squared_error: 0.0243 - val_loss: 0.0016 - val_mae: 0.0306 - val_mape: 3.9732 - val_root_mean_squared_error: 0.0396
# Epoch 97/150
# 73/73 - 1s - 16ms/step - loss: 6.3128e-04 - mae: 0.0153 - mape: 10685.2090 - root_mean_squared_error: 0.0251 - val_loss: 0.0013 - val_mae: 0.0280 - val_mape: 3.7015 - val_root_mean_squared_error: 0.0367
# Epoch 98/150
# 73/73 - 1s - 16ms/step - loss: 5.4768e-04 - mae: 0.0144 - mape: 7132.4736 - root_mean_squared_error: 0.0234 - val_loss: 0.0019 - val_mae: 0.0345 - val_mape: 4.4417 - val_root_mean_squared_error: 0.0441
# Epoch 99/150
# 73/73 - 1s - 16ms/step - loss: 5.9407e-04 - mae: 0.0149 - mape: 13558.4922 - root_mean_squared_error: 0.0244 - val_loss: 0.0015 - val_mae: 0.0294 - val_mape: 3.8357 - val_root_mean_squared_error: 0.0384
# Epoch 100/150
# 73/73 - 1s - 16ms/step - loss: 5.8861e-04 - mae: 0.0151 - mape: 10342.0889 - root_mean_squared_error: 0.0243 - val_loss: 0.0030 - val_mae: 0.0447 - val_mape: 5.7447 - val_root_mean_squared_error: 0.0543
# Epoch 101/150
# 73/73 - 1s - 16ms/step - loss: 5.6909e-04 - mae: 0.0149 - mape: 20683.5449 - root_mean_squared_error: 0.0239 - val_loss: 0.0014 - val_mae: 0.0290 - val_mape: 3.7831 - val_root_mean_squared_error: 0.0380
# Epoch 102/150
# 73/73 - 1s - 16ms/step - loss: 5.9359e-04 - mae: 0.0149 - mape: 8133.2583 - root_mean_squared_error: 0.0244 - val_loss: 0.0018 - val_mae: 0.0327 - val_mape: 4.2073 - val_root_mean_squared_error: 0.0423
# Epoch 103/150
# 73/73 - 1s - 16ms/step - loss: 5.9850e-04 - mae: 0.0147 - mape: 13769.8574 - root_mean_squared_error: 0.0245 - val_loss: 0.0023 - val_mae: 0.0382 - val_mape: 4.9161 - val_root_mean_squared_error: 0.0478
# Epoch 104/150
# 73/73 - 1s - 16ms/step - loss: 5.7212e-04 - mae: 0.0149 - mape: 229.7938 - root_mean_squared_error: 0.0239 - val_loss: 0.0015 - val_mae: 0.0298 - val_mape: 3.8777 - val_root_mean_squared_error: 0.0389
# Epoch 105/150
# 73/73 - 1s - 16ms/step - loss: 6.1568e-04 - mae: 0.0148 - mape: 11889.2979 - root_mean_squared_error: 0.0248 - val_loss: 0.0019 - val_mae: 0.0335 - val_mape: 4.3066 - val_root_mean_squared_error: 0.0433
# Epoch 106/150
# 73/73 - 1s - 16ms/step - loss: 5.8628e-04 - mae: 0.0147 - mape: 6274.4297 - root_mean_squared_error: 0.0242 - val_loss: 0.0020 - val_mae: 0.0348 - val_mape: 4.4620 - val_root_mean_squared_error: 0.0446
# Epoch 107/150
# 73/73 - 1s - 15ms/step - loss: 5.8066e-04 - mae: 0.0148 - mape: 3192.2207 - root_mean_squared_error: 0.0241 - val_loss: 0.0015 - val_mae: 0.0301 - val_mape: 3.9016 - val_root_mean_squared_error: 0.0393
# Epoch 108/150
# 73/73 - 1s - 16ms/step - loss: 5.1627e-04 - mae: 0.0142 - mape: 3874.1553 - root_mean_squared_error: 0.0227 - val_loss: 0.0013 - val_mae: 0.0267 - val_mape: 3.5513 - val_root_mean_squared_error: 0.0354
# Epoch 109/150
# 73/73 - 1s - 16ms/step - loss: 5.3844e-04 - mae: 0.0146 - mape: 10125.3145 - root_mean_squared_error: 0.0232 - val_loss: 0.0022 - val_mae: 0.0377 - val_mape: 4.8547 - val_root_mean_squared_error: 0.0471
# Epoch 110/150
# 73/73 - 1s - 15ms/step - loss: 5.6992e-04 - mae: 0.0145 - mape: 24839.2129 - root_mean_squared_error: 0.0239 - val_loss: 0.0020 - val_mae: 0.0351 - val_mape: 4.5100 - val_root_mean_squared_error: 0.0446
# Epoch 111/150
# 73/73 - 1s - 15ms/step - loss: 5.5761e-04 - mae: 0.0146 - mape: 19963.6816 - root_mean_squared_error: 0.0236 - val_loss: 0.0017 - val_mae: 0.0313 - val_mape: 4.0350 - val_root_mean_squared_error: 0.0407
# Epoch 112/150
# 73/73 - 1s - 15ms/step - loss: 5.4730e-04 - mae: 0.0147 - mape: 19197.4902 - root_mean_squared_error: 0.0234 - val_loss: 0.0025 - val_mae: 0.0410 - val_mape: 5.2620 - val_root_mean_squared_error: 0.0504
# Epoch 113/150
# 73/73 - 1s - 16ms/step - loss: 5.6947e-04 - mae: 0.0145 - mape: 10458.8027 - root_mean_squared_error: 0.0239 - val_loss: 0.0018 - val_mae: 0.0325 - val_mape: 4.1901 - val_root_mean_squared_error: 0.0419
# Epoch 114/150
# 73/73 - 1s - 15ms/step - loss: 5.5297e-04 - mae: 0.0145 - mape: 18462.0703 - root_mean_squared_error: 0.0235 - val_loss: 0.0014 - val_mae: 0.0288 - val_mape: 3.7423 - val_root_mean_squared_error: 0.0380
# Epoch 115/150
# 73/73 - 1s - 16ms/step - loss: 5.2619e-04 - mae: 0.0140 - mape: 23011.4141 - root_mean_squared_error: 0.0229 - val_loss: 0.0016 - val_mae: 0.0304 - val_mape: 3.9304 - val_root_mean_squared_error: 0.0397
# Epoch 116/150
# 73/73 - 1s - 16ms/step - loss: 5.6927e-04 - mae: 0.0144 - mape: 18770.6367 - root_mean_squared_error: 0.0239 - val_loss: 0.0021 - val_mae: 0.0364 - val_mape: 4.6803 - val_root_mean_squared_error: 0.0455
# Epoch 117/150
# 73/73 - 1s - 16ms/step - loss: 4.9890e-04 - mae: 0.0139 - mape: 11226.9766 - root_mean_squared_error: 0.0223 - val_loss: 0.0018 - val_mae: 0.0325 - val_mape: 4.1878 - val_root_mean_squared_error: 0.0419
# Epoch 118/150
# 73/73 - 1s - 16ms/step - loss: 5.3183e-04 - mae: 0.0143 - mape: 17572.2480 - root_mean_squared_error: 0.0231 - val_loss: 0.0015 - val_mae: 0.0301 - val_mape: 3.8945 - val_root_mean_squared_error: 0.0392
# Epoch 119/150
# 73/73 - 1s - 16ms/step - loss: 4.8592e-04 - mae: 0.0139 - mape: 11528.2236 - root_mean_squared_error: 0.0220 - val_loss: 0.0015 - val_mae: 0.0293 - val_mape: 3.8064 - val_root_mean_squared_error: 0.0384
# Epoch 120/150
# 73/73 - 1s - 16ms/step - loss: 5.5458e-04 - mae: 0.0146 - mape: 14454.5713 - root_mean_squared_error: 0.0235 - val_loss: 0.0027 - val_mae: 0.0428 - val_mape: 5.5244 - val_root_mean_squared_error: 0.0520
# Epoch 121/150
# 73/73 - 1s - 16ms/step - loss: 5.2140e-04 - mae: 0.0140 - mape: 9162.2939 - root_mean_squared_error: 0.0228 - val_loss: 0.0013 - val_mae: 0.0274 - val_mape: 3.5928 - val_root_mean_squared_error: 0.0366
# Epoch 122/150
# 73/73 - 1s - 16ms/step - loss: 5.3438e-04 - mae: 0.0142 - mape: 12601.0400 - root_mean_squared_error: 0.0231 - val_loss: 0.0018 - val_mae: 0.0333 - val_mape: 4.3012 - val_root_mean_squared_error: 0.0425
# Epoch 123/150
# 73/73 - 1s - 16ms/step - loss: 5.4305e-04 - mae: 0.0144 - mape: 10281.5615 - root_mean_squared_error: 0.0233 - val_loss: 0.0012 - val_mae: 0.0263 - val_mape: 3.4673 - val_root_mean_squared_error: 0.0352
# Epoch 124/150
# 73/73 - 1s - 16ms/step - loss: 5.4273e-04 - mae: 0.0144 - mape: 20637.1562 - root_mean_squared_error: 0.0233 - val_loss: 0.0013 - val_mae: 0.0274 - val_mape: 3.5898 - val_root_mean_squared_error: 0.0364
# Epoch 125/150
# 73/73 - 1s - 15ms/step - loss: 5.5141e-04 - mae: 0.0141 - mape: 10031.6846 - root_mean_squared_error: 0.0235 - val_loss: 0.0014 - val_mae: 0.0289 - val_mape: 3.7557 - val_root_mean_squared_error: 0.0380
# Epoch 126/150
# 73/73 - 1s - 16ms/step - loss: 5.4954e-04 - mae: 0.0143 - mape: 17047.5078 - root_mean_squared_error: 0.0234 - val_loss: 0.0012 - val_mae: 0.0257 - val_mape: 3.4024 - val_root_mean_squared_error: 0.0345
# Epoch 127/150
# 73/73 - 1s - 16ms/step - loss: 5.2777e-04 - mae: 0.0141 - mape: 18898.5273 - root_mean_squared_error: 0.0230 - val_loss: 0.0012 - val_mae: 0.0258 - val_mape: 3.4149 - val_root_mean_squared_error: 0.0347
# Epoch 128/150
# 73/73 - 1s - 15ms/step - loss: 4.9907e-04 - mae: 0.0137 - mape: 10745.3496 - root_mean_squared_error: 0.0223 - val_loss: 0.0026 - val_mae: 0.0421 - val_mape: 5.4246 - val_root_mean_squared_error: 0.0511
# Epoch 129/150
# 73/73 - 1s - 16ms/step - loss: 5.6234e-04 - mae: 0.0144 - mape: 9860.7305 - root_mean_squared_error: 0.0237 - val_loss: 0.0015 - val_mae: 0.0302 - val_mape: 3.9081 - val_root_mean_squared_error: 0.0393
# Epoch 130/150
# 73/73 - 1s - 16ms/step - loss: 5.1620e-04 - mae: 0.0139 - mape: 13334.8203 - root_mean_squared_error: 0.0227 - val_loss: 0.0018 - val_mae: 0.0332 - val_mape: 4.3087 - val_root_mean_squared_error: 0.0420
# Epoch 131/150
# 73/73 - 1s - 16ms/step - loss: 4.8054e-04 - mae: 0.0139 - mape: 10197.1016 - root_mean_squared_error: 0.0219 - val_loss: 0.0020 - val_mae: 0.0354 - val_mape: 4.5577 - val_root_mean_squared_error: 0.0444
# Epoch 132/150
# 73/73 - 1s - 16ms/step - loss: 5.3903e-04 - mae: 0.0140 - mape: 24762.7520 - root_mean_squared_error: 0.0232 - val_loss: 0.0013 - val_mae: 0.0273 - val_mape: 3.5711 - val_root_mean_squared_error: 0.0364
# Epoch 133/150
# 73/73 - 1s - 15ms/step - loss: 5.4524e-04 - mae: 0.0142 - mape: 11863.8301 - root_mean_squared_error: 0.0234 - val_loss: 0.0015 - val_mae: 0.0297 - val_mape: 3.8484 - val_root_mean_squared_error: 0.0389
# Epoch 134/150
# 73/73 - 1s - 15ms/step - loss: 5.3387e-04 - mae: 0.0144 - mape: 15963.8320 - root_mean_squared_error: 0.0231 - val_loss: 0.0015 - val_mae: 0.0297 - val_mape: 3.8426 - val_root_mean_squared_error: 0.0390
# Epoch 135/150
# 73/73 - 1s - 15ms/step - loss: 4.9970e-04 - mae: 0.0140 - mape: 19646.2969 - root_mean_squared_error: 0.0224 - val_loss: 0.0018 - val_mae: 0.0326 - val_mape: 4.1966 - val_root_mean_squared_error: 0.0419
# Epoch 136/150
# 73/73 - 1s - 16ms/step - loss: 5.2139e-04 - mae: 0.0142 - mape: 17902.9434 - root_mean_squared_error: 0.0228 - val_loss: 0.0013 - val_mae: 0.0264 - val_mape: 3.4668 - val_root_mean_squared_error: 0.0354
# Epoch 137/150
# 73/73 - 1s - 16ms/step - loss: 5.5028e-04 - mae: 0.0144 - mape: 17834.4082 - root_mean_squared_error: 0.0235 - val_loss: 0.0015 - val_mae: 0.0292 - val_mape: 3.7859 - val_root_mean_squared_error: 0.0384
# Epoch 138/150
# 73/73 - 1s - 16ms/step - loss: 4.8422e-04 - mae: 0.0138 - mape: 8063.3706 - root_mean_squared_error: 0.0220 - val_loss: 0.0015 - val_mae: 0.0296 - val_mape: 3.8151 - val_root_mean_squared_error: 0.0391
# Epoch 139/150
# 73/73 - 1s - 16ms/step - loss: 4.9322e-04 - mae: 0.0141 - mape: 14071.1670 - root_mean_squared_error: 0.0222 - val_loss: 0.0014 - val_mae: 0.0283 - val_mape: 3.6687 - val_root_mean_squared_error: 0.0375
# Epoch 140/150
# 73/73 - 1s - 16ms/step - loss: 4.9546e-04 - mae: 0.0138 - mape: 13486.8613 - root_mean_squared_error: 0.0223 - val_loss: 0.0016 - val_mae: 0.0313 - val_mape: 4.0330 - val_root_mean_squared_error: 0.0406
# Epoch 141/150
# 73/73 - 1s - 15ms/step - loss: 5.1308e-04 - mae: 0.0138 - mape: 32898.5273 - root_mean_squared_error: 0.0227 - val_loss: 0.0015 - val_mae: 0.0291 - val_mape: 3.7574 - val_root_mean_squared_error: 0.0384
# Epoch 142/150
# 73/73 - 1s - 16ms/step - loss: 5.1866e-04 - mae: 0.0141 - mape: 19528.2852 - root_mean_squared_error: 0.0228 - val_loss: 0.0014 - val_mae: 0.0277 - val_mape: 3.6033 - val_root_mean_squared_error: 0.0369
# Epoch 143/150
# 73/73 - 1s - 16ms/step - loss: 4.8109e-04 - mae: 0.0139 - mape: 17576.0957 - root_mean_squared_error: 0.0219 - val_loss: 0.0016 - val_mae: 0.0311 - val_mape: 4.0243 - val_root_mean_squared_error: 0.0402
# Epoch 144/150
# 73/73 - 1s - 16ms/step - loss: 5.2053e-04 - mae: 0.0139 - mape: 12299.8955 - root_mean_squared_error: 0.0228 - val_loss: 0.0017 - val_mae: 0.0320 - val_mape: 4.1422 - val_root_mean_squared_error: 0.0408
# Epoch 145/150
# 73/73 - 1s - 15ms/step - loss: 5.6110e-04 - mae: 0.0142 - mape: 13548.8711 - root_mean_squared_error: 0.0237 - val_loss: 0.0017 - val_mae: 0.0329 - val_mape: 4.2509 - val_root_mean_squared_error: 0.0417
# Epoch 146/150
# 73/73 - 1s - 15ms/step - loss: 4.8066e-04 - mae: 0.0138 - mape: 8781.8008 - root_mean_squared_error: 0.0219 - val_loss: 0.0022 - val_mae: 0.0381 - val_mape: 4.9140 - val_root_mean_squared_error: 0.0467
# Epoch 147/150
# 73/73 - 1s - 16ms/step - loss: 5.0618e-04 - mae: 0.0139 - mape: 10097.4590 - root_mean_squared_error: 0.0225 - val_loss: 0.0016 - val_mae: 0.0302 - val_mape: 3.8961 - val_root_mean_squared_error: 0.0394
# Epoch 148/150
# 73/73 - 1s - 16ms/step - loss: 5.1650e-04 - mae: 0.0139 - mape: 18210.6445 - root_mean_squared_error: 0.0227 - val_loss: 0.0014 - val_mae: 0.0276 - val_mape: 3.5896 - val_root_mean_squared_error: 0.0368
# Epoch 149/150
# 73/73 - 1s - 16ms/step - loss: 4.8794e-04 - mae: 0.0138 - mape: 14206.4053 - root_mean_squared_error: 0.0221 - val_loss: 0.0025 - val_mae: 0.0414 - val_mape: 5.3441 - val_root_mean_squared_error: 0.0504
# Epoch 150/150
# 73/73 - 1s - 16ms/step - loss: 5.2165e-04 - mae: 0.0139 - mape: 19212.7207 - root_mean_squared_error: 0.0228 - val_loss: 0.0021 - val_mae: 0.0363 - val_mape: 4.6642 - val_root_mean_squared_error: 0.0454

# %%
####################
### Plot Results ###
####################

# Training MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['loss'][1:], label='MSE')
ax[0, 0].set_title('Training Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Training MAE
ax[0, 1].plot(history.history['mae'][1:], label='MAE', color='black')
ax[0, 1].set_title('Training MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Training RMSE
ax[1, 0].plot(history.history['root_mean_squared_error'][1:], label='RMSE', color='green')
ax[1, 0].set_title('Training RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)

# Training MAPE
ax[1, 1].plot(history.history['mape'][1:], label='MAPE', color='red')
ax[1, 1].set_title('Training MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Validation MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['val_loss'][1:], label='Val MSE')
ax[0, 0].set_title('Validation Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Validation MAE
ax[0, 1].plot(history.history['val_mae'][1:], label='Val MAE')
ax[0, 1].set_title('Validation MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Validation RMSE
ax[1, 0].plot(history.history['val_root_mean_squared_error'][1:], label='Val RMSE')
ax[1, 0].set_title('Validation RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Validation MAPE
ax[1, 1].plot(history.history['val_mape'][1:], label='Val MAPE')
ax[1, 1].set_title('Validation MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Store best training/validation metrics
# Training
train_mse = history.history['loss']
best_epoch = np.argmin(train_mse)
best_train_mse = train_mse[best_epoch]
best_train_rmse = history.history['root_mean_squared_error'][best_epoch]
best_train_mae  = history.history['mae'][best_epoch]
best_train_mape = history.history['mape'][best_epoch]

# Validation: record epoch at which validation loss is the lowest for each seed
val_mse = history.history['val_loss']
best_epoch = np.argmin(val_mse)
best_val_mse = val_mse[best_epoch]
best_val_rmse = history.history['val_root_mean_squared_error'][best_epoch]
best_val_mae  = history.history['val_mae'][best_epoch]
best_val_mape = history.history['val_mape'][best_epoch]

# %%
# -------------------------
# Step 9 — Predict/Testing
# -------------------------
y_predict= model.predict([x_test, test_states[window:]])
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step

# %%
# -----------------------------------
# Step 10 — Test MSE/RMSE/MAE/MAPE/R2
# -----------------------------------

# Compute the loss metrics
test_mse = mean_squared_error(y_test, y_predict)
test_rmse = root_mean_squared_error(y_test, y_predict)
test_mae = mean_absolute_error(y_test, y_predict)
test_mape = mean_absolute_percentage_error(y_test, y_predict)
test_r2_score = r2_score(y_test, y_predict)

print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Mean Absolute Error:", test_mae)
print("Mean Absolute Percentage Error:", test_mape)
print("R2 Score:", test_r2_score)
# Out:
# Mean Squared Error: 0.00029892661653741626
# Root Mean Squared Error: 0.017289494397969427
# Mean Absolute Error: 0.012990890369855021
# Mean Absolute Percentage Error: 0.044072192423921144
# R2 Score: 0.9291917637598777

# %%
#-------------------------------------------------
# Step 11 - Inverse scaling: original price scale
#-------------------------------------------------

y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))
y_predict_orig = scaler.inverse_transform(y_predict)

# %%
#----------------------------------------------
# Step 12 - Plot prediction vs. actuals prices
#----------------------------------------------

# Add window size to test idx
start_index = 1482 + 120
# Test set dates range + convert to datetime
dates = data['Date'].iloc[start_index:start_index + len(y_test_orig)].reset_index(drop=True)
dates = pd.to_datetime(dates)

# Plot the actual vs predicted prices
plt.figure(figsize=(10, 5))
plt.plot(dates, y_test_orig, label='Actual', linewidth=2)
plt.plot(dates, y_predict_orig, label='Predicted', color='red')
plt.title('Actual vs Predicted Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#--------------------------
# Step 13 - Export results
#--------------------------

# Export prediction dataset
predictions_df = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.flatten(),
    'Predicted': y_predict_orig.flatten()
})

predictions_df.to_csv('BTC_lstm_hmm_predictions.csv', index=False)

from google.colab import files
files.download('BTC_lstm_hmm_predictions.csv')

# %%
# Store metrics in dataframe along with best training/validation loss (record epoch)
results = {
    "seed": 91,
    "best_epoch": best_epoch + 1,    # best validation epoch
    "train_mse": best_train_mse,
    "train_rmse": best_train_rmse,
    "train_mae": best_train_mae,
    "train_mape": best_train_mape,
    "val_mse": best_val_mse,
    "val_rmse": best_val_rmse,
    "val_mae": best_val_mae,
    "val_mape": best_val_mape,
    "test_mse": test_mse,
    "test_rmse": test_rmse,
    "test_mae": test_mae,
    "test_mape": test_mape,
    "test_r2_score": test_r2_score
}

btc_results = pd.DataFrame([results])
btc_results.to_csv('btc_lstm_hmm_results.csv')

files.download('btc_lstm_hmm_results.csv')

# %%
# Export results

loss_results = pd.DataFrame(history.history)
loss_results.to_csv('btc_lstm_hmm_loss_results.csv')

files.download('btc_lstm_hmm_loss_results.csv')

# %% [markdown]
# # **Regime Classification**

# %%
# ------------------------------------------
# Step 1 — Compute Log returns & Volatility
# ------------------------------------------

original = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.ravel()
})

predicted = pd.DataFrame({
    'Date': dates,
    'Predicted': y_predict_orig.ravel()
})

# Compute returns from actual and predicted prices
returns_orig = original['Actual'].pct_change()
returns_pred = predicted['Predicted'].pct_change()
# Drop NaN values from returns
returns_orig = returns_orig.fillna(0)
returns_pred = returns_pred.fillna(0)

# Compute 10-day rolling volatility
volatility_orig = returns_orig.rolling(window=10).std()
volatility_pred = returns_pred.rolling(window=10).std()
volatility_orig = volatility_orig.fillna(0)
volatility_pred = volatility_pred.fillna(0)

# Update dataframes with returns and volatility
original['Returns'] = returns_orig
predicted['Returns'] = returns_pred
original['Volatility'] = volatility_orig
predicted['Volatility'] = volatility_pred

# %%
# --------------------------------
# Step 2 — Label Volatility L-M-H
# --------------------------------

# Compute quantiles as thresholds for low/med/high volatility
low_threshold = volatility_orig.quantile(0.33)   # lower 33%
high_threshold = volatility_orig.quantile(0.67)  # upper 33%

# Label volatility
def label_volatility(vol):
    if vol <= low_threshold:
        return 'low'
    elif vol >= high_threshold:
        return 'high'
    else:
        return 'medium'

# Apply volatility low/medium/high to original and prediction dataset
original['Volatility_level'] = original['Volatility'].apply(label_volatility)
predicted['Volatility_level'] = predicted['Volatility'].apply(label_volatility)

# %%
# -------------------------------
# Step 3 — Regime Classification
# -------------------------------

# Classify regime based on volatility + average sign of the returns
def classify_regime(pred_labels, vol_value, vol_threshold=(low_threshold, high_threshold), window=3):
    regimes = []
    low_threshold, high_threshold = vol_threshold

    for i in range(len(pred_labels) - window):
        window_preds = pred_labels[i:i+window]
        window_vol = vol_value[i+window]
        sign_pred = np.sign(window_preds.mean())

        if window_vol <= low_threshold:
            regimes.append("Neutral")

        else:
            if sign_pred > 0:
                regimes.append("Bull")
            elif sign_pred < 0:
                regimes.append("Bear")
            else:
                regimes.append("Uncertain")

    return regimes

vol_value = original['Volatility']
regimes = classify_regime(original['Returns'], vol_value)

# %%
####################
######  Plots ######
####################

# Plot price vs. date regime shifts in
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Actual'][3:]);
plt.plot(original['Date'][3:], predicted['Predicted'][3:], color='black', alpha=0.65);

plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4, label='Bull');
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4, label='Bear');
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Neutral' for r in regimes], color='grey', alpha=0.3, label='Neutral');

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);
plt.legend();
plt.title('Regime Shift Bitcoin Predicted')
plt.grid(True);
plt.tight_layout();
plt.show();

# %%
# Plot regime shift for log returns vs. date
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Returns'][3:], label='Actual')
plt.plot(original['Date'][3:], predicted['Returns'][3:], color='red', alpha=0.6, label='Predicted')

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);

plt.legend()
plt.title('Regime Shift Bitcoin Returns')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift
# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = original['Actual'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Bitcoin Actual")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = predicted['Predicted'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Bitcoin Prediction")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()
