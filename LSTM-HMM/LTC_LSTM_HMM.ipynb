# %%
#####################
## Litecoin (LTC)   ##
#####################

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install pandas
# !pip install hmmlearn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting hmmlearn
#   Downloading hmmlearn-0.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (2.0.2)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (1.6.1)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.12/dist-packages (from hmmlearn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.6.0)
# Downloading hmmlearn-0.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 kB 14.7 MB/s eta 0:00:00
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.3.3

# %%
#######################
###### Libraries ######
#######################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import tensorflow as tf

from hmmlearn.hmm import GaussianHMM
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.utils import to_categorical

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Set 3 seeds and record the model performance for each : 42, 45, 91
# Best seed 45
np.random.seed(45)
tf.random.set_seed(45)

# %%
# Load dataset without scaling
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LTC_noscale.csv')
data.drop(columns=['Crypto', 'Open', 'High', 'Low'], inplace=True)
data.head()
# Out:
#          Date   Close
# 0  2018-01-01  225.63
# 1  2018-01-02  254.60
# 2  2018-01-03  243.00
# 3  2018-01-04  240.00
# 4  2018-01-05  240.45

# %%
# -------------------------
# Step 1 - Normalisation
# -------------------------
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['Close']].values.reshape(-1, 1))
input_data = scaled_data.reshape(-1)

# ---------------------------------
# Step 2 - Generate sliding windows
# ---------------------------------
train_end = int(0.65 * len(scaled_data)            ) # training ratio
val_end   = train_end + int(0.10 * len(scaled_data)) # validation ratio
window = 120                                         # window size - days of price input

train_slice = input_data[:train_end]
val_slice   = input_data[train_end:val_end]
test_slice  = input_data[val_end:]

def sequence(data, window_size):
    data = np.asarray(data).reshape(-1, 1)
    x, y = [], []
    for i in range(window_size, len(data)):
        x.append(data[i-window_size:i])
        y.append(data[i])
    return np.array(x), np.array(y)

x_train, y_train = sequence(train_slice, window)
x_val,   y_val   = sequence(val_slice,   window)
x_test,  y_test  = sequence(test_slice,  window)

# %%
# ---------------------------------
# Step 3 - Build Gaussian HMM
# ---------------------------------

# Fit Gaussian HMM with 3 states on the training input data
hmm = GaussianHMM(n_components=3, n_iter=200, random_state=42)
hmm.fit(train_slice.reshape(-1,1))

# Build train, val, test arrays with the last indices in each LSTM sequence (above)
# The aim is to align the HMM input data to the LSTM sequences of 120-day input
# To avoid data leakage (into the future)
window = 120
train_last_idx = np.arange(window-1, train_end-1)
val_last_idx   = np.arange(train_end + window-1, val_end-1)
test_last_idx  = np.arange(val_end   + window-1, len(input_data)-1)


# -----------------------------------------
# Step 5 — Compute posterior probabilities
# -----------------------------------------

# Build the Causal HMM with the input data and train/val/test indices from above
# The probability of the next point is only based on the past datapoints
# Compute the posterior probability for each price at time t+1 for input 0...t (t=window-1)
# The post_probability of each of the 3 states is returned for all 3 sets and ready for use in training the model
def causal_hmm(price_series, hmm, index):
    post_probabilities = np.zeros((len(index), hmm.n_components))
    for i, t in enumerate(index):
        post_probabilities[i] = hmm.predict_proba(price_series[:t+1].reshape(-1,1))[-1]  # last row = uses data ≤ t
    return post_probabilities

H_train = causal_hmm(input_data, hmm, train_last_idx)
H_val   = causal_hmm(input_data, hmm, val_last_idx)
H_test  = causal_hmm(input_data, hmm, test_last_idx)

# HMM output with 'relu' activation function
# Input = one probability for each of 3 states
hmm_input = Input(shape=(3,))
hmm_out   = Dense(64, activation='relu')(hmm_input)

# %%
# ------------
# Parameters
# ------------
n_timesteps = x_train.shape[1]
n_features  = x_train.shape[2]
dropout_rate = 0.33454307320167703


# --------------------------
# Step 5 — LSTM branch input
# --------------------------
# LSTM branch
lstm_input = Input(shape=(n_timesteps, n_features))
y = LSTM(64, return_sequences=True, activation='tanh')(lstm_input)
y = Dropout(dropout_rate)(y)
y = LSTM(8, return_sequences=True, activation='tanh')(y)
lstm_out = LSTM(4, return_sequences=False, activation='tanh')(y)


# -----------------------------
# Step 6 — Concatenate HMM/LSTM
# -----------------------------
combined = Concatenate()([lstm_out, hmm_out])
combined = Dense(64, activation='tanh')(combined)
output = Dense(1, activation='linear')(combined)


# ---------------------------------
# Step 7 — Compile Model/Regression
# ---------------------------------
model = Model(inputs=[lstm_input, hmm_input], outputs=output)
model.compile(loss='mean_squared_error',
              optimizer=RMSprop(learning_rate=0.0009717787126451334),
              metrics=['mae', RootMeanSquaredError(), 'mape'])

# %%
# ---------------------------------
# Step 8 — Model Training
# ---------------------------------
history = model.fit([x_train, H_train], y_train,
                    epochs=150, batch_size=16,
                    shuffle=False,
                    validation_data=([x_val, H_val], y_val),
                    verbose=2)
# Out:
# Epoch 1/150
# 73/73 - 6s - 79ms/step - loss: 0.0086 - mae: 0.0616 - mape: 57410.3398 - root_mean_squared_error: 0.0927 - val_loss: 0.0344 - val_mae: 0.1739 - val_mape: 45.4996 - val_root_mean_squared_error: 0.1854
# Epoch 2/150
# 73/73 - 1s - 17ms/step - loss: 0.0055 - mae: 0.0517 - mape: 42537.2617 - root_mean_squared_error: 0.0742 - val_loss: 0.0167 - val_mae: 0.1212 - val_mape: 30.7356 - val_root_mean_squared_error: 0.1292
# Epoch 3/150
# 73/73 - 1s - 16ms/step - loss: 0.0046 - mae: 0.0470 - mape: 29391.3105 - root_mean_squared_error: 0.0679 - val_loss: 0.0145 - val_mae: 0.1123 - val_mape: 28.0979 - val_root_mean_squared_error: 0.1203
# Epoch 4/150
# 73/73 - 1s - 16ms/step - loss: 0.0042 - mae: 0.0440 - mape: 22764.8086 - root_mean_squared_error: 0.0650 - val_loss: 0.0107 - val_mae: 0.0951 - val_mape: 23.3642 - val_root_mean_squared_error: 0.1034
# Epoch 5/150
# 73/73 - 1s - 16ms/step - loss: 0.0039 - mae: 0.0429 - mape: 20254.5488 - root_mean_squared_error: 0.0627 - val_loss: 0.0146 - val_mae: 0.1123 - val_mape: 27.9156 - val_root_mean_squared_error: 0.1209
# Epoch 6/150
# 73/73 - 1s - 16ms/step - loss: 0.0035 - mae: 0.0404 - mape: 18075.7754 - root_mean_squared_error: 0.0594 - val_loss: 0.0089 - val_mae: 0.0860 - val_mape: 20.9425 - val_root_mean_squared_error: 0.0946
# Epoch 7/150
# 73/73 - 1s - 16ms/step - loss: 0.0034 - mae: 0.0386 - mape: 31758.9805 - root_mean_squared_error: 0.0581 - val_loss: 0.0042 - val_mae: 0.0477 - val_mape: 10.5735 - val_root_mean_squared_error: 0.0644
# Epoch 8/150
# 73/73 - 1s - 16ms/step - loss: 0.0030 - mae: 0.0376 - mape: 20225.0059 - root_mean_squared_error: 0.0546 - val_loss: 0.0066 - val_mae: 0.0708 - val_mape: 16.9102 - val_root_mean_squared_error: 0.0812
# Epoch 9/150
# 73/73 - 1s - 16ms/step - loss: 0.0029 - mae: 0.0354 - mape: 20859.0801 - root_mean_squared_error: 0.0539 - val_loss: 0.0040 - val_mae: 0.0480 - val_mape: 10.7865 - val_root_mean_squared_error: 0.0629
# Epoch 10/150
# 73/73 - 1s - 16ms/step - loss: 0.0027 - mae: 0.0354 - mape: 24482.5664 - root_mean_squared_error: 0.0522 - val_loss: 0.0069 - val_mae: 0.0734 - val_mape: 17.6830 - val_root_mean_squared_error: 0.0832
# Epoch 11/150
# 73/73 - 1s - 16ms/step - loss: 0.0026 - mae: 0.0346 - mape: 25183.6133 - root_mean_squared_error: 0.0508 - val_loss: 0.0061 - val_mae: 0.0671 - val_mape: 16.0109 - val_root_mean_squared_error: 0.0781
# Epoch 12/150
# 73/73 - 1s - 17ms/step - loss: 0.0024 - mae: 0.0337 - mape: 14295.5928 - root_mean_squared_error: 0.0492 - val_loss: 0.0039 - val_mae: 0.0490 - val_mape: 11.3985 - val_root_mean_squared_error: 0.0628
# Epoch 13/150
# 73/73 - 1s - 16ms/step - loss: 0.0022 - mae: 0.0319 - mape: 5578.1611 - root_mean_squared_error: 0.0474 - val_loss: 0.0035 - val_mae: 0.0453 - val_mape: 10.4523 - val_root_mean_squared_error: 0.0595
# Epoch 14/150
# 73/73 - 1s - 16ms/step - loss: 0.0021 - mae: 0.0314 - mape: 4014.0034 - root_mean_squared_error: 0.0459 - val_loss: 0.0046 - val_mae: 0.0560 - val_mape: 13.4533 - val_root_mean_squared_error: 0.0680
# Epoch 15/150
# 73/73 - 1s - 16ms/step - loss: 0.0020 - mae: 0.0297 - mape: 4474.1343 - root_mean_squared_error: 0.0442 - val_loss: 0.0035 - val_mae: 0.0413 - val_mape: 8.7848 - val_root_mean_squared_error: 0.0592
# Epoch 16/150
# 73/73 - 1s - 16ms/step - loss: 0.0019 - mae: 0.0299 - mape: 6997.3535 - root_mean_squared_error: 0.0435 - val_loss: 0.0035 - val_mae: 0.0416 - val_mape: 8.8413 - val_root_mean_squared_error: 0.0593
# Epoch 17/150
# 73/73 - 1s - 16ms/step - loss: 0.0018 - mae: 0.0294 - mape: 9325.6562 - root_mean_squared_error: 0.0426 - val_loss: 0.0028 - val_mae: 0.0362 - val_mape: 7.9870 - val_root_mean_squared_error: 0.0527
# Epoch 18/150
# 73/73 - 1s - 16ms/step - loss: 0.0017 - mae: 0.0287 - mape: 1543.6105 - root_mean_squared_error: 0.0416 - val_loss: 0.0027 - val_mae: 0.0356 - val_mape: 7.7824 - val_root_mean_squared_error: 0.0522
# Epoch 19/150
# 73/73 - 1s - 16ms/step - loss: 0.0016 - mae: 0.0279 - mape: 19674.9355 - root_mean_squared_error: 0.0401 - val_loss: 0.0027 - val_mae: 0.0356 - val_mape: 7.7290 - val_root_mean_squared_error: 0.0523
# Epoch 20/150
# 73/73 - 1s - 16ms/step - loss: 0.0016 - mae: 0.0273 - mape: 1580.2567 - root_mean_squared_error: 0.0397 - val_loss: 0.0027 - val_mae: 0.0350 - val_mape: 7.6493 - val_root_mean_squared_error: 0.0515
# Epoch 21/150
# 73/73 - 1s - 16ms/step - loss: 0.0015 - mae: 0.0270 - mape: 8350.3594 - root_mean_squared_error: 0.0388 - val_loss: 0.0028 - val_mae: 0.0364 - val_mape: 7.8079 - val_root_mean_squared_error: 0.0524
# Epoch 22/150
# 73/73 - 1s - 16ms/step - loss: 0.0015 - mae: 0.0266 - mape: 8130.3604 - root_mean_squared_error: 0.0382 - val_loss: 0.0032 - val_mae: 0.0416 - val_mape: 9.9499 - val_root_mean_squared_error: 0.0565
# Epoch 23/150
# 73/73 - 1s - 16ms/step - loss: 0.0014 - mae: 0.0257 - mape: 14522.5889 - root_mean_squared_error: 0.0375 - val_loss: 0.0027 - val_mae: 0.0356 - val_mape: 7.6667 - val_root_mean_squared_error: 0.0515
# Epoch 24/150
# 73/73 - 1s - 16ms/step - loss: 0.0014 - mae: 0.0258 - mape: 21443.9238 - root_mean_squared_error: 0.0379 - val_loss: 0.0032 - val_mae: 0.0411 - val_mape: 8.7435 - val_root_mean_squared_error: 0.0569
# Epoch 25/150
# 73/73 - 1s - 16ms/step - loss: 0.0013 - mae: 0.0248 - mape: 10210.2324 - root_mean_squared_error: 0.0362 - val_loss: 0.0025 - val_mae: 0.0345 - val_mape: 7.8846 - val_root_mean_squared_error: 0.0503
# Epoch 26/150
# 73/73 - 1s - 15ms/step - loss: 0.0014 - mae: 0.0247 - mape: 15074.6865 - root_mean_squared_error: 0.0369 - val_loss: 0.0028 - val_mae: 0.0370 - val_mape: 7.9036 - val_root_mean_squared_error: 0.0527
# Epoch 27/150
# 73/73 - 1s - 16ms/step - loss: 0.0013 - mae: 0.0246 - mape: 6741.5410 - root_mean_squared_error: 0.0365 - val_loss: 0.0030 - val_mae: 0.0405 - val_mape: 9.6583 - val_root_mean_squared_error: 0.0551
# Epoch 28/150
# 73/73 - 1s - 15ms/step - loss: 0.0013 - mae: 0.0243 - mape: 9996.7480 - root_mean_squared_error: 0.0364 - val_loss: 0.0027 - val_mae: 0.0366 - val_mape: 7.8626 - val_root_mean_squared_error: 0.0517
# Epoch 29/150
# 73/73 - 1s - 15ms/step - loss: 0.0012 - mae: 0.0237 - mape: 16999.3398 - root_mean_squared_error: 0.0350 - val_loss: 0.0026 - val_mae: 0.0359 - val_mape: 7.7571 - val_root_mean_squared_error: 0.0508
# Epoch 30/150
# 73/73 - 1s - 15ms/step - loss: 0.0013 - mae: 0.0239 - mape: 3213.5347 - root_mean_squared_error: 0.0354 - val_loss: 0.0027 - val_mae: 0.0368 - val_mape: 7.9403 - val_root_mean_squared_error: 0.0517
# Epoch 31/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0240 - mape: 6168.7778 - root_mean_squared_error: 0.0350 - val_loss: 0.0028 - val_mae: 0.0375 - val_mape: 8.0483 - val_root_mean_squared_error: 0.0527
# Epoch 32/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0231 - mape: 9358.1094 - root_mean_squared_error: 0.0341 - val_loss: 0.0027 - val_mae: 0.0368 - val_mape: 7.9273 - val_root_mean_squared_error: 0.0517
# Epoch 33/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0225 - mape: 8547.9043 - root_mean_squared_error: 0.0328 - val_loss: 0.0030 - val_mae: 0.0398 - val_mape: 8.5542 - val_root_mean_squared_error: 0.0547
# Epoch 34/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0227 - mape: 14377.9824 - root_mean_squared_error: 0.0340 - val_loss: 0.0035 - val_mae: 0.0443 - val_mape: 9.5162 - val_root_mean_squared_error: 0.0592
# Epoch 35/150
# 73/73 - 1s - 16ms/step - loss: 0.0012 - mae: 0.0227 - mape: 3920.8931 - root_mean_squared_error: 0.0339 - val_loss: 0.0023 - val_mae: 0.0329 - val_mape: 7.5221 - val_root_mean_squared_error: 0.0479
# Epoch 36/150
# 73/73 - 1s - 15ms/step - loss: 0.0011 - mae: 0.0223 - mape: 16667.2324 - root_mean_squared_error: 0.0339 - val_loss: 0.0025 - val_mae: 0.0352 - val_mape: 7.6476 - val_root_mean_squared_error: 0.0495
# Epoch 37/150
# 73/73 - 1s - 15ms/step - loss: 0.0011 - mae: 0.0222 - mape: 12370.6025 - root_mean_squared_error: 0.0328 - val_loss: 0.0023 - val_mae: 0.0334 - val_mape: 7.3735 - val_root_mean_squared_error: 0.0476
# Epoch 38/150
# 73/73 - 1s - 15ms/step - loss: 0.0011 - mae: 0.0220 - mape: 8392.8730 - root_mean_squared_error: 0.0326 - val_loss: 0.0031 - val_mae: 0.0410 - val_mape: 8.8417 - val_root_mean_squared_error: 0.0555
# Epoch 39/150
# 73/73 - 1s - 15ms/step - loss: 0.0010 - mae: 0.0216 - mape: 8438.3848 - root_mean_squared_error: 0.0324 - val_loss: 0.0025 - val_mae: 0.0353 - val_mape: 7.6408 - val_root_mean_squared_error: 0.0496
# Epoch 40/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0219 - mape: 843.4519 - root_mean_squared_error: 0.0335 - val_loss: 0.0028 - val_mae: 0.0388 - val_mape: 8.3431 - val_root_mean_squared_error: 0.0533
# Epoch 41/150
# 73/73 - 1s - 15ms/step - loss: 0.0010 - mae: 0.0216 - mape: 9096.3486 - root_mean_squared_error: 0.0322 - val_loss: 0.0023 - val_mae: 0.0343 - val_mape: 7.4600 - val_root_mean_squared_error: 0.0483
# Epoch 42/150
# 73/73 - 1s - 16ms/step - loss: 0.0010 - mae: 0.0209 - mape: 6695.4380 - root_mean_squared_error: 0.0318 - val_loss: 0.0022 - val_mae: 0.0330 - val_mape: 7.2889 - val_root_mean_squared_error: 0.0470
# Epoch 43/150
# 73/73 - 1s - 16ms/step - loss: 0.0010 - mae: 0.0211 - mape: 9689.1650 - root_mean_squared_error: 0.0323 - val_loss: 0.0022 - val_mae: 0.0325 - val_mape: 7.2255 - val_root_mean_squared_error: 0.0465
# Epoch 44/150
# 73/73 - 1s - 16ms/step - loss: 0.0011 - mae: 0.0214 - mape: 3260.3181 - root_mean_squared_error: 0.0331 - val_loss: 0.0027 - val_mae: 0.0377 - val_mape: 8.1433 - val_root_mean_squared_error: 0.0519
# Epoch 45/150
# 73/73 - 1s - 16ms/step - loss: 9.6811e-04 - mae: 0.0209 - mape: 14777.7510 - root_mean_squared_error: 0.0311 - val_loss: 0.0022 - val_mae: 0.0328 - val_mape: 7.2345 - val_root_mean_squared_error: 0.0467
# Epoch 46/150
# 73/73 - 1s - 16ms/step - loss: 9.9363e-04 - mae: 0.0206 - mape: 14044.8975 - root_mean_squared_error: 0.0315 - val_loss: 0.0026 - val_mae: 0.0369 - val_mape: 7.9577 - val_root_mean_squared_error: 0.0508
# Epoch 47/150
# 73/73 - 1s - 16ms/step - loss: 9.5891e-04 - mae: 0.0203 - mape: 23167.3066 - root_mean_squared_error: 0.0310 - val_loss: 0.0021 - val_mae: 0.0311 - val_mape: 7.1417 - val_root_mean_squared_error: 0.0459
# Epoch 48/150
# 73/73 - 1s - 16ms/step - loss: 9.9456e-04 - mae: 0.0203 - mape: 8018.5693 - root_mean_squared_error: 0.0315 - val_loss: 0.0020 - val_mae: 0.0313 - val_mape: 7.0140 - val_root_mean_squared_error: 0.0452
# Epoch 49/150
# 73/73 - 1s - 16ms/step - loss: 9.6107e-04 - mae: 0.0205 - mape: 5009.7632 - root_mean_squared_error: 0.0310 - val_loss: 0.0024 - val_mae: 0.0359 - val_mape: 7.8392 - val_root_mean_squared_error: 0.0492
# Epoch 50/150
# 73/73 - 1s - 16ms/step - loss: 9.4641e-04 - mae: 0.0198 - mape: 7033.2007 - root_mean_squared_error: 0.0308 - val_loss: 0.0020 - val_mae: 0.0310 - val_mape: 7.0029 - val_root_mean_squared_error: 0.0450
# Epoch 51/150
# 73/73 - 1s - 16ms/step - loss: 9.3049e-04 - mae: 0.0200 - mape: 7456.8525 - root_mean_squared_error: 0.0305 - val_loss: 0.0020 - val_mae: 0.0310 - val_mape: 6.9673 - val_root_mean_squared_error: 0.0449
# Epoch 52/150
# 73/73 - 1s - 16ms/step - loss: 9.9194e-04 - mae: 0.0199 - mape: 25367.1992 - root_mean_squared_error: 0.0315 - val_loss: 0.0021 - val_mae: 0.0319 - val_mape: 7.0313 - val_root_mean_squared_error: 0.0456
# Epoch 53/150
# 73/73 - 1s - 17ms/step - loss: 9.0793e-04 - mae: 0.0197 - mape: 1614.6481 - root_mean_squared_error: 0.0301 - val_loss: 0.0020 - val_mae: 0.0307 - val_mape: 6.9642 - val_root_mean_squared_error: 0.0450
# Epoch 54/150
# 73/73 - 1s - 16ms/step - loss: 9.1936e-04 - mae: 0.0199 - mape: 15214.7695 - root_mean_squared_error: 0.0303 - val_loss: 0.0020 - val_mae: 0.0310 - val_mape: 6.9496 - val_root_mean_squared_error: 0.0448
# Epoch 55/150
# 73/73 - 1s - 16ms/step - loss: 8.4951e-04 - mae: 0.0191 - mape: 17843.4004 - root_mean_squared_error: 0.0291 - val_loss: 0.0020 - val_mae: 0.0312 - val_mape: 6.9464 - val_root_mean_squared_error: 0.0449
# Epoch 56/150
# 73/73 - 1s - 16ms/step - loss: 8.9638e-04 - mae: 0.0199 - mape: 7596.7046 - root_mean_squared_error: 0.0299 - val_loss: 0.0020 - val_mae: 0.0306 - val_mape: 6.8903 - val_root_mean_squared_error: 0.0445
# Epoch 57/150
# 73/73 - 1s - 16ms/step - loss: 9.3743e-04 - mae: 0.0196 - mape: 3959.7141 - root_mean_squared_error: 0.0306 - val_loss: 0.0020 - val_mae: 0.0312 - val_mape: 6.9240 - val_root_mean_squared_error: 0.0448
# Epoch 58/150
# 73/73 - 1s - 15ms/step - loss: 8.8758e-04 - mae: 0.0191 - mape: 3110.9824 - root_mean_squared_error: 0.0298 - val_loss: 0.0021 - val_mae: 0.0322 - val_mape: 7.0659 - val_root_mean_squared_error: 0.0458
# Epoch 59/150
# 73/73 - 1s - 16ms/step - loss: 8.6034e-04 - mae: 0.0193 - mape: 12160.3789 - root_mean_squared_error: 0.0293 - val_loss: 0.0026 - val_mae: 0.0375 - val_mape: 8.0714 - val_root_mean_squared_error: 0.0515
# Epoch 60/150
# 73/73 - 1s - 16ms/step - loss: 8.2051e-04 - mae: 0.0190 - mape: 8799.2939 - root_mean_squared_error: 0.0286 - val_loss: 0.0020 - val_mae: 0.0300 - val_mape: 6.8229 - val_root_mean_squared_error: 0.0442
# Epoch 61/150
# 73/73 - 1s - 15ms/step - loss: 8.5148e-04 - mae: 0.0190 - mape: 3111.7664 - root_mean_squared_error: 0.0292 - val_loss: 0.0019 - val_mae: 0.0298 - val_mape: 6.7553 - val_root_mean_squared_error: 0.0439
# Epoch 62/150
# 73/73 - 1s - 15ms/step - loss: 8.9345e-04 - mae: 0.0188 - mape: 1390.5569 - root_mean_squared_error: 0.0299 - val_loss: 0.0019 - val_mae: 0.0305 - val_mape: 6.7688 - val_root_mean_squared_error: 0.0441
# Epoch 63/150
# 73/73 - 1s - 16ms/step - loss: 8.3825e-04 - mae: 0.0187 - mape: 14668.1494 - root_mean_squared_error: 0.0290 - val_loss: 0.0024 - val_mae: 0.0353 - val_mape: 7.6849 - val_root_mean_squared_error: 0.0486
# Epoch 64/150
# 73/73 - 1s - 16ms/step - loss: 8.7718e-04 - mae: 0.0192 - mape: 8484.6758 - root_mean_squared_error: 0.0296 - val_loss: 0.0019 - val_mae: 0.0305 - val_mape: 6.7396 - val_root_mean_squared_error: 0.0440
# Epoch 65/150
# 73/73 - 1s - 16ms/step - loss: 8.7387e-04 - mae: 0.0189 - mape: 5918.8062 - root_mean_squared_error: 0.0296 - val_loss: 0.0019 - val_mae: 0.0307 - val_mape: 6.7608 - val_root_mean_squared_error: 0.0441
# Epoch 66/150
# 73/73 - 1s - 15ms/step - loss: 8.3194e-04 - mae: 0.0184 - mape: 2436.8403 - root_mean_squared_error: 0.0288 - val_loss: 0.0019 - val_mae: 0.0294 - val_mape: 6.5966 - val_root_mean_squared_error: 0.0431
# Epoch 67/150
# 73/73 - 1s - 15ms/step - loss: 7.8113e-04 - mae: 0.0179 - mape: 3985.1575 - root_mean_squared_error: 0.0279 - val_loss: 0.0019 - val_mae: 0.0295 - val_mape: 6.6753 - val_root_mean_squared_error: 0.0436
# Epoch 68/150
# 73/73 - 1s - 15ms/step - loss: 8.6045e-04 - mae: 0.0188 - mape: 6401.2236 - root_mean_squared_error: 0.0293 - val_loss: 0.0025 - val_mae: 0.0366 - val_mape: 7.9090 - val_root_mean_squared_error: 0.0502
# Epoch 69/150
# 73/73 - 1s - 16ms/step - loss: 8.1246e-04 - mae: 0.0182 - mape: 5196.5586 - root_mean_squared_error: 0.0285 - val_loss: 0.0018 - val_mae: 0.0289 - val_mape: 6.5161 - val_root_mean_squared_error: 0.0428
# Epoch 70/150
# 73/73 - 1s - 16ms/step - loss: 8.1049e-04 - mae: 0.0184 - mape: 474.0564 - root_mean_squared_error: 0.0285 - val_loss: 0.0021 - val_mae: 0.0329 - val_mape: 7.1805 - val_root_mean_squared_error: 0.0460
# Epoch 71/150
# 73/73 - 1s - 15ms/step - loss: 8.4692e-04 - mae: 0.0182 - mape: 13203.6631 - root_mean_squared_error: 0.0291 - val_loss: 0.0019 - val_mae: 0.0292 - val_mape: 6.6441 - val_root_mean_squared_error: 0.0433
# Epoch 72/150
# 73/73 - 1s - 15ms/step - loss: 7.9308e-04 - mae: 0.0183 - mape: 16563.1230 - root_mean_squared_error: 0.0282 - val_loss: 0.0018 - val_mae: 0.0288 - val_mape: 6.4843 - val_root_mean_squared_error: 0.0427
# Epoch 73/150
# 73/73 - 1s - 15ms/step - loss: 7.7033e-04 - mae: 0.0181 - mape: 2538.2991 - root_mean_squared_error: 0.0278 - val_loss: 0.0018 - val_mae: 0.0300 - val_mape: 6.5999 - val_root_mean_squared_error: 0.0430
# Epoch 74/150
# 73/73 - 1s - 16ms/step - loss: 7.9194e-04 - mae: 0.0179 - mape: 748.4301 - root_mean_squared_error: 0.0281 - val_loss: 0.0025 - val_mae: 0.0367 - val_mape: 8.0318 - val_root_mean_squared_error: 0.0496
# Epoch 75/150
# 73/73 - 1s - 16ms/step - loss: 7.6594e-04 - mae: 0.0182 - mape: 7909.3208 - root_mean_squared_error: 0.0277 - val_loss: 0.0018 - val_mae: 0.0287 - val_mape: 6.3910 - val_root_mean_squared_error: 0.0420
# Epoch 76/150
# 73/73 - 1s - 16ms/step - loss: 8.4950e-04 - mae: 0.0182 - mape: 328.6501 - root_mean_squared_error: 0.0291 - val_loss: 0.0023 - val_mae: 0.0346 - val_mape: 7.5441 - val_root_mean_squared_error: 0.0475
# Epoch 77/150
# 73/73 - 1s - 16ms/step - loss: 7.0707e-04 - mae: 0.0174 - mape: 9680.0566 - root_mean_squared_error: 0.0266 - val_loss: 0.0019 - val_mae: 0.0303 - val_mape: 6.6374 - val_root_mean_squared_error: 0.0434
# Epoch 78/150
# 73/73 - 1s - 15ms/step - loss: 7.4786e-04 - mae: 0.0180 - mape: 11199.4688 - root_mean_squared_error: 0.0273 - val_loss: 0.0021 - val_mae: 0.0320 - val_mape: 7.3995 - val_root_mean_squared_error: 0.0455
# Epoch 79/150
# 73/73 - 1s - 15ms/step - loss: 7.5640e-04 - mae: 0.0175 - mape: 12301.9033 - root_mean_squared_error: 0.0275 - val_loss: 0.0018 - val_mae: 0.0295 - val_mape: 6.5041 - val_root_mean_squared_error: 0.0422
# Epoch 80/150
# 73/73 - 1s - 16ms/step - loss: 7.7429e-04 - mae: 0.0175 - mape: 14938.8564 - root_mean_squared_error: 0.0278 - val_loss: 0.0019 - val_mae: 0.0305 - val_mape: 6.6731 - val_root_mean_squared_error: 0.0434
# Epoch 81/150
# 73/73 - 1s - 15ms/step - loss: 7.7434e-04 - mae: 0.0179 - mape: 336.3764 - root_mean_squared_error: 0.0278 - val_loss: 0.0017 - val_mae: 0.0280 - val_mape: 6.2747 - val_root_mean_squared_error: 0.0416
# Epoch 82/150
# 73/73 - 1s - 15ms/step - loss: 8.0723e-04 - mae: 0.0176 - mape: 3398.5044 - root_mean_squared_error: 0.0284 - val_loss: 0.0020 - val_mae: 0.0314 - val_mape: 7.2875 - val_root_mean_squared_error: 0.0446
# Epoch 83/150
# 73/73 - 1s - 15ms/step - loss: 8.0912e-04 - mae: 0.0179 - mape: 3274.3733 - root_mean_squared_error: 0.0284 - val_loss: 0.0023 - val_mae: 0.0352 - val_mape: 7.6703 - val_root_mean_squared_error: 0.0480
# Epoch 84/150
# 73/73 - 1s - 15ms/step - loss: 7.5886e-04 - mae: 0.0177 - mape: 13618.7188 - root_mean_squared_error: 0.0275 - val_loss: 0.0017 - val_mae: 0.0283 - val_mape: 6.2462 - val_root_mean_squared_error: 0.0413
# Epoch 85/150
# 73/73 - 1s - 16ms/step - loss: 7.4674e-04 - mae: 0.0171 - mape: 18374.3965 - root_mean_squared_error: 0.0273 - val_loss: 0.0017 - val_mae: 0.0278 - val_mape: 6.2294 - val_root_mean_squared_error: 0.0412
# Epoch 86/150
# 73/73 - 1s - 16ms/step - loss: 7.7242e-04 - mae: 0.0174 - mape: 12253.8174 - root_mean_squared_error: 0.0278 - val_loss: 0.0017 - val_mae: 0.0291 - val_mape: 6.3851 - val_root_mean_squared_error: 0.0417
# Epoch 87/150
# 73/73 - 1s - 15ms/step - loss: 8.1868e-04 - mae: 0.0181 - mape: 796.5956 - root_mean_squared_error: 0.0286 - val_loss: 0.0019 - val_mae: 0.0311 - val_mape: 6.8018 - val_root_mean_squared_error: 0.0437
# Epoch 88/150
# 73/73 - 1s - 15ms/step - loss: 7.8355e-04 - mae: 0.0174 - mape: 10145.6602 - root_mean_squared_error: 0.0280 - val_loss: 0.0017 - val_mae: 0.0278 - val_mape: 6.1360 - val_root_mean_squared_error: 0.0407
# Epoch 89/150
# 73/73 - 1s - 15ms/step - loss: 7.3538e-04 - mae: 0.0174 - mape: 2775.9783 - root_mean_squared_error: 0.0271 - val_loss: 0.0018 - val_mae: 0.0291 - val_mape: 6.6497 - val_root_mean_squared_error: 0.0423
# Epoch 90/150
# 73/73 - 1s - 16ms/step - loss: 7.7698e-04 - mae: 0.0174 - mape: 5372.9448 - root_mean_squared_error: 0.0279 - val_loss: 0.0017 - val_mae: 0.0277 - val_mape: 6.2409 - val_root_mean_squared_error: 0.0411
# Epoch 91/150
# 73/73 - 1s - 15ms/step - loss: 7.0935e-04 - mae: 0.0171 - mape: 2365.4512 - root_mean_squared_error: 0.0266 - val_loss: 0.0018 - val_mae: 0.0289 - val_mape: 6.6184 - val_root_mean_squared_error: 0.0420
# Epoch 92/150
# 73/73 - 1s - 15ms/step - loss: 7.7826e-04 - mae: 0.0175 - mape: 15566.5166 - root_mean_squared_error: 0.0279 - val_loss: 0.0016 - val_mae: 0.0271 - val_mape: 6.0173 - val_root_mean_squared_error: 0.0402
# Epoch 93/150
# 73/73 - 1s - 15ms/step - loss: 7.3214e-04 - mae: 0.0175 - mape: 12476.5342 - root_mean_squared_error: 0.0271 - val_loss: 0.0016 - val_mae: 0.0273 - val_mape: 6.0328 - val_root_mean_squared_error: 0.0403
# Epoch 94/150
# 73/73 - 1s - 15ms/step - loss: 7.4769e-04 - mae: 0.0171 - mape: 308.7175 - root_mean_squared_error: 0.0273 - val_loss: 0.0017 - val_mae: 0.0278 - val_mape: 6.2897 - val_root_mean_squared_error: 0.0410
# Epoch 95/150
# 73/73 - 1s - 16ms/step - loss: 7.0933e-04 - mae: 0.0172 - mape: 18854.8867 - root_mean_squared_error: 0.0266 - val_loss: 0.0019 - val_mae: 0.0302 - val_mape: 6.9479 - val_root_mean_squared_error: 0.0433
# Epoch 96/150
# 73/73 - 1s - 16ms/step - loss: 7.3815e-04 - mae: 0.0172 - mape: 3327.3931 - root_mean_squared_error: 0.0272 - val_loss: 0.0016 - val_mae: 0.0270 - val_mape: 5.9789 - val_root_mean_squared_error: 0.0400
# Epoch 97/150
# 73/73 - 1s - 16ms/step - loss: 7.8073e-04 - mae: 0.0173 - mape: 70.2711 - root_mean_squared_error: 0.0279 - val_loss: 0.0016 - val_mae: 0.0270 - val_mape: 6.0111 - val_root_mean_squared_error: 0.0400
# Epoch 98/150
# 73/73 - 1s - 15ms/step - loss: 7.3473e-04 - mae: 0.0171 - mape: 9937.0928 - root_mean_squared_error: 0.0271 - val_loss: 0.0017 - val_mae: 0.0290 - val_mape: 6.3303 - val_root_mean_squared_error: 0.0417
# Epoch 99/150
# 73/73 - 1s - 16ms/step - loss: 7.2814e-04 - mae: 0.0173 - mape: 1721.7610 - root_mean_squared_error: 0.0270 - val_loss: 0.0017 - val_mae: 0.0285 - val_mape: 6.2235 - val_root_mean_squared_error: 0.0412
# Epoch 100/150
# 73/73 - 1s - 15ms/step - loss: 6.7609e-04 - mae: 0.0168 - mape: 5861.8804 - root_mean_squared_error: 0.0260 - val_loss: 0.0016 - val_mae: 0.0270 - val_mape: 6.0514 - val_root_mean_squared_error: 0.0400
# Epoch 101/150
# 73/73 - 1s - 15ms/step - loss: 6.8448e-04 - mae: 0.0168 - mape: 4637.2568 - root_mean_squared_error: 0.0262 - val_loss: 0.0017 - val_mae: 0.0278 - val_mape: 6.2910 - val_root_mean_squared_error: 0.0407
# Epoch 102/150
# 73/73 - 1s - 15ms/step - loss: 7.2992e-04 - mae: 0.0171 - mape: 20049.7012 - root_mean_squared_error: 0.0270 - val_loss: 0.0017 - val_mae: 0.0292 - val_mape: 6.3709 - val_root_mean_squared_error: 0.0418
# Epoch 103/150
# 73/73 - 1s - 15ms/step - loss: 7.3694e-04 - mae: 0.0173 - mape: 15858.2939 - root_mean_squared_error: 0.0271 - val_loss: 0.0017 - val_mae: 0.0292 - val_mape: 6.3818 - val_root_mean_squared_error: 0.0417
# Epoch 104/150
# 73/73 - 1s - 15ms/step - loss: 6.6891e-04 - mae: 0.0170 - mape: 2522.8145 - root_mean_squared_error: 0.0259 - val_loss: 0.0017 - val_mae: 0.0288 - val_mape: 6.5896 - val_root_mean_squared_error: 0.0415
# Epoch 105/150
# 73/73 - 1s - 15ms/step - loss: 6.4459e-04 - mae: 0.0165 - mape: 5025.1982 - root_mean_squared_error: 0.0254 - val_loss: 0.0016 - val_mae: 0.0265 - val_mape: 5.8755 - val_root_mean_squared_error: 0.0394
# Epoch 106/150
# 73/73 - 1s - 16ms/step - loss: 7.1101e-04 - mae: 0.0165 - mape: 4145.0977 - root_mean_squared_error: 0.0267 - val_loss: 0.0018 - val_mae: 0.0296 - val_mape: 6.7833 - val_root_mean_squared_error: 0.0422
# Epoch 107/150
# 73/73 - 1s - 16ms/step - loss: 6.9074e-04 - mae: 0.0167 - mape: 1421.9314 - root_mean_squared_error: 0.0263 - val_loss: 0.0016 - val_mae: 0.0279 - val_mape: 6.0937 - val_root_mean_squared_error: 0.0406
# Epoch 108/150
# 73/73 - 1s - 16ms/step - loss: 7.5745e-04 - mae: 0.0171 - mape: 11098.9678 - root_mean_squared_error: 0.0275 - val_loss: 0.0023 - val_mae: 0.0364 - val_mape: 8.5411 - val_root_mean_squared_error: 0.0483
# Epoch 109/150
# 73/73 - 1s - 15ms/step - loss: 7.5260e-04 - mae: 0.0166 - mape: 457.1107 - root_mean_squared_error: 0.0274 - val_loss: 0.0017 - val_mae: 0.0292 - val_mape: 6.3661 - val_root_mean_squared_error: 0.0417
# Epoch 110/150
# 73/73 - 1s - 15ms/step - loss: 7.4329e-04 - mae: 0.0174 - mape: 342.1070 - root_mean_squared_error: 0.0273 - val_loss: 0.0018 - val_mae: 0.0299 - val_mape: 6.5107 - val_root_mean_squared_error: 0.0423
# Epoch 111/150
# 73/73 - 1s - 15ms/step - loss: 7.3856e-04 - mae: 0.0169 - mape: 5191.9165 - root_mean_squared_error: 0.0272 - val_loss: 0.0015 - val_mae: 0.0264 - val_mape: 5.8872 - val_root_mean_squared_error: 0.0392
# Epoch 112/150
# 73/73 - 1s - 15ms/step - loss: 6.7528e-04 - mae: 0.0167 - mape: 4271.3101 - root_mean_squared_error: 0.0260 - val_loss: 0.0016 - val_mae: 0.0271 - val_mape: 6.0848 - val_root_mean_squared_error: 0.0397
# Epoch 113/150
# 73/73 - 1s - 15ms/step - loss: 7.0361e-04 - mae: 0.0164 - mape: 3139.2068 - root_mean_squared_error: 0.0265 - val_loss: 0.0016 - val_mae: 0.0282 - val_mape: 6.1496 - val_root_mean_squared_error: 0.0406
# Epoch 114/150
# 73/73 - 1s - 15ms/step - loss: 6.5992e-04 - mae: 0.0162 - mape: 4860.0845 - root_mean_squared_error: 0.0257 - val_loss: 0.0016 - val_mae: 0.0275 - val_mape: 6.2225 - val_root_mean_squared_error: 0.0401
# Epoch 115/150
# 73/73 - 1s - 15ms/step - loss: 7.0809e-04 - mae: 0.0165 - mape: 5624.5972 - root_mean_squared_error: 0.0266 - val_loss: 0.0016 - val_mae: 0.0274 - val_mape: 6.1986 - val_root_mean_squared_error: 0.0401
# Epoch 116/150
# 73/73 - 1s - 15ms/step - loss: 6.8164e-04 - mae: 0.0169 - mape: 10029.1260 - root_mean_squared_error: 0.0261 - val_loss: 0.0016 - val_mae: 0.0278 - val_mape: 6.3174 - val_root_mean_squared_error: 0.0403
# Epoch 117/150
# 73/73 - 1s - 16ms/step - loss: 7.1611e-04 - mae: 0.0169 - mape: 2570.9497 - root_mean_squared_error: 0.0268 - val_loss: 0.0016 - val_mae: 0.0275 - val_mape: 6.2344 - val_root_mean_squared_error: 0.0400
# Epoch 118/150
# 73/73 - 1s - 17ms/step - loss: 6.9882e-04 - mae: 0.0165 - mape: 1850.9326 - root_mean_squared_error: 0.0264 - val_loss: 0.0016 - val_mae: 0.0273 - val_mape: 6.1806 - val_root_mean_squared_error: 0.0399
# Epoch 119/150
# 73/73 - 1s - 15ms/step - loss: 6.7877e-04 - mae: 0.0164 - mape: 6950.2231 - root_mean_squared_error: 0.0261 - val_loss: 0.0015 - val_mae: 0.0260 - val_mape: 5.7009 - val_root_mean_squared_error: 0.0385
# Epoch 120/150
# 73/73 - 1s - 15ms/step - loss: 7.0309e-04 - mae: 0.0164 - mape: 3542.9087 - root_mean_squared_error: 0.0265 - val_loss: 0.0015 - val_mae: 0.0259 - val_mape: 5.6723 - val_root_mean_squared_error: 0.0386
# Epoch 121/150
# 73/73 - 1s - 15ms/step - loss: 6.7138e-04 - mae: 0.0165 - mape: 20888.6016 - root_mean_squared_error: 0.0259 - val_loss: 0.0015 - val_mae: 0.0258 - val_mape: 5.6768 - val_root_mean_squared_error: 0.0383
# Epoch 122/150
# 73/73 - 1s - 15ms/step - loss: 7.1606e-04 - mae: 0.0168 - mape: 18703.5957 - root_mean_squared_error: 0.0268 - val_loss: 0.0015 - val_mae: 0.0261 - val_mape: 5.8095 - val_root_mean_squared_error: 0.0384
# Epoch 123/150
# 73/73 - 1s - 15ms/step - loss: 7.2955e-04 - mae: 0.0167 - mape: 6749.3276 - root_mean_squared_error: 0.0270 - val_loss: 0.0015 - val_mae: 0.0256 - val_mape: 5.6138 - val_root_mean_squared_error: 0.0382
# Epoch 124/150
# 73/73 - 1s - 15ms/step - loss: 7.1400e-04 - mae: 0.0164 - mape: 18824.2051 - root_mean_squared_error: 0.0267 - val_loss: 0.0014 - val_mae: 0.0255 - val_mape: 5.6142 - val_root_mean_squared_error: 0.0380
# Epoch 125/150
# 73/73 - 1s - 16ms/step - loss: 6.5772e-04 - mae: 0.0165 - mape: 9460.6709 - root_mean_squared_error: 0.0256 - val_loss: 0.0015 - val_mae: 0.0259 - val_mape: 5.6813 - val_root_mean_squared_error: 0.0383
# Epoch 126/150
# 73/73 - 1s - 16ms/step - loss: 6.2866e-04 - mae: 0.0160 - mape: 6094.1470 - root_mean_squared_error: 0.0251 - val_loss: 0.0014 - val_mae: 0.0254 - val_mape: 5.5922 - val_root_mean_squared_error: 0.0380
# Epoch 127/150
# 73/73 - 1s - 16ms/step - loss: 6.8881e-04 - mae: 0.0164 - mape: 561.6318 - root_mean_squared_error: 0.0262 - val_loss: 0.0017 - val_mae: 0.0286 - val_mape: 6.5285 - val_root_mean_squared_error: 0.0409
# Epoch 128/150
# 73/73 - 1s - 16ms/step - loss: 6.6525e-04 - mae: 0.0161 - mape: 7295.4302 - root_mean_squared_error: 0.0258 - val_loss: 0.0014 - val_mae: 0.0255 - val_mape: 5.5782 - val_root_mean_squared_error: 0.0380
# Epoch 129/150
# 73/73 - 1s - 16ms/step - loss: 6.8307e-04 - mae: 0.0164 - mape: 3132.1438 - root_mean_squared_error: 0.0261 - val_loss: 0.0016 - val_mae: 0.0276 - val_mape: 6.3118 - val_root_mean_squared_error: 0.0398
# Epoch 130/150
# 73/73 - 1s - 16ms/step - loss: 6.6644e-04 - mae: 0.0164 - mape: 9185.6553 - root_mean_squared_error: 0.0258 - val_loss: 0.0014 - val_mae: 0.0256 - val_mape: 5.6061 - val_root_mean_squared_error: 0.0379
# Epoch 131/150
# 73/73 - 1s - 15ms/step - loss: 6.4419e-04 - mae: 0.0159 - mape: 4151.9897 - root_mean_squared_error: 0.0254 - val_loss: 0.0019 - val_mae: 0.0323 - val_mape: 7.5579 - val_root_mean_squared_error: 0.0437
# Epoch 132/150
# 73/73 - 1s - 16ms/step - loss: 6.2990e-04 - mae: 0.0159 - mape: 6171.8491 - root_mean_squared_error: 0.0251 - val_loss: 0.0014 - val_mae: 0.0259 - val_mape: 5.8020 - val_root_mean_squared_error: 0.0380
# Epoch 133/150
# 73/73 - 1s - 15ms/step - loss: 6.7823e-04 - mae: 0.0164 - mape: 8241.3486 - root_mean_squared_error: 0.0260 - val_loss: 0.0017 - val_mae: 0.0298 - val_mape: 6.4773 - val_root_mean_squared_error: 0.0418
# Epoch 134/150
# 73/73 - 1s - 16ms/step - loss: 6.6582e-04 - mae: 0.0158 - mape: 7711.5244 - root_mean_squared_error: 0.0258 - val_loss: 0.0014 - val_mae: 0.0251 - val_mape: 5.5318 - val_root_mean_squared_error: 0.0374
# Epoch 135/150
# 73/73 - 1s - 16ms/step - loss: 6.5703e-04 - mae: 0.0159 - mape: 17261.9395 - root_mean_squared_error: 0.0256 - val_loss: 0.0016 - val_mae: 0.0285 - val_mape: 6.5257 - val_root_mean_squared_error: 0.0406
# Epoch 136/150
# 73/73 - 1s - 16ms/step - loss: 6.6068e-04 - mae: 0.0165 - mape: 14854.6025 - root_mean_squared_error: 0.0257 - val_loss: 0.0015 - val_mae: 0.0261 - val_mape: 5.8532 - val_root_mean_squared_error: 0.0384
# Epoch 137/150
# 73/73 - 1s - 15ms/step - loss: 6.3024e-04 - mae: 0.0161 - mape: 2187.5134 - root_mean_squared_error: 0.0251 - val_loss: 0.0016 - val_mae: 0.0277 - val_mape: 6.0385 - val_root_mean_squared_error: 0.0396
# Epoch 138/150
# 73/73 - 1s - 17ms/step - loss: 7.2498e-04 - mae: 0.0164 - mape: 4326.7998 - root_mean_squared_error: 0.0269 - val_loss: 0.0017 - val_mae: 0.0299 - val_mape: 6.8899 - val_root_mean_squared_error: 0.0417
# Epoch 139/150
# 73/73 - 1s - 17ms/step - loss: 5.9434e-04 - mae: 0.0156 - mape: 9832.5479 - root_mean_squared_error: 0.0244 - val_loss: 0.0014 - val_mae: 0.0254 - val_mape: 5.5484 - val_root_mean_squared_error: 0.0376
# Epoch 140/150
# 73/73 - 1s - 16ms/step - loss: 6.6589e-04 - mae: 0.0161 - mape: 4228.9351 - root_mean_squared_error: 0.0258 - val_loss: 0.0016 - val_mae: 0.0274 - val_mape: 5.9316 - val_root_mean_squared_error: 0.0394
# Epoch 141/150
# 73/73 - 1s - 15ms/step - loss: 6.1513e-04 - mae: 0.0157 - mape: 5641.8271 - root_mean_squared_error: 0.0248 - val_loss: 0.0014 - val_mae: 0.0256 - val_mape: 5.7351 - val_root_mean_squared_error: 0.0377
# Epoch 142/150
# 73/73 - 1s - 16ms/step - loss: 6.7036e-04 - mae: 0.0161 - mape: 3378.1499 - root_mean_squared_error: 0.0259 - val_loss: 0.0014 - val_mae: 0.0248 - val_mape: 5.4179 - val_root_mean_squared_error: 0.0372
# Epoch 143/150
# 73/73 - 1s - 16ms/step - loss: 6.4069e-04 - mae: 0.0164 - mape: 1014.9990 - root_mean_squared_error: 0.0253 - val_loss: 0.0014 - val_mae: 0.0253 - val_mape: 5.6440 - val_root_mean_squared_error: 0.0374
# Epoch 144/150
# 73/73 - 1s - 16ms/step - loss: 7.0213e-04 - mae: 0.0162 - mape: 8508.2861 - root_mean_squared_error: 0.0265 - val_loss: 0.0014 - val_mae: 0.0247 - val_mape: 5.4302 - val_root_mean_squared_error: 0.0369
# Epoch 145/150
# 73/73 - 1s - 16ms/step - loss: 6.6110e-04 - mae: 0.0161 - mape: 10173.3047 - root_mean_squared_error: 0.0257 - val_loss: 0.0014 - val_mae: 0.0251 - val_mape: 5.5601 - val_root_mean_squared_error: 0.0372
# Epoch 146/150
# 73/73 - 1s - 16ms/step - loss: 6.9690e-04 - mae: 0.0165 - mape: 8338.6494 - root_mean_squared_error: 0.0264 - val_loss: 0.0016 - val_mae: 0.0278 - val_mape: 6.3406 - val_root_mean_squared_error: 0.0396
# Epoch 147/150
# 73/73 - 1s - 16ms/step - loss: 6.6330e-04 - mae: 0.0162 - mape: 13068.7852 - root_mean_squared_error: 0.0258 - val_loss: 0.0023 - val_mae: 0.0366 - val_mape: 8.5842 - val_root_mean_squared_error: 0.0478
# Epoch 148/150
# 73/73 - 1s - 16ms/step - loss: 6.3539e-04 - mae: 0.0159 - mape: 17775.6250 - root_mean_squared_error: 0.0252 - val_loss: 0.0014 - val_mae: 0.0252 - val_mape: 5.6120 - val_root_mean_squared_error: 0.0373
# Epoch 149/150
# 73/73 - 1s - 16ms/step - loss: 6.6878e-04 - mae: 0.0158 - mape: 5640.3882 - root_mean_squared_error: 0.0259 - val_loss: 0.0014 - val_mae: 0.0246 - val_mape: 5.4057 - val_root_mean_squared_error: 0.0368
# Epoch 150/150
# 73/73 - 1s - 16ms/step - loss: 6.1319e-04 - mae: 0.0159 - mape: 2851.3582 - root_mean_squared_error: 0.0248 - val_loss: 0.0017 - val_mae: 0.0295 - val_mape: 6.7997 - val_root_mean_squared_error: 0.0407

# %%
####################
### Plot Results ###
####################

# Training MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['loss'][1:], label='MSE')
ax[0, 0].set_title('Training Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Training MAE
ax[0, 1].plot(history.history['mae'][1:], label='MAE', color='black')
ax[0, 1].set_title('Training MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Training RMSE
ax[1, 0].plot(history.history['root_mean_squared_error'][1:], label='RMSE', color='green')
ax[1, 0].set_title('Training RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)

# Training MAPE
ax[1, 1].plot(history.history['mape'][1:], label='MAPE', color='red')
ax[1, 1].set_title('Training MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Validation MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['val_loss'][1:], label='Val MSE')
ax[0, 0].set_title('Validation Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Validation MAE
ax[0, 1].plot(history.history['val_mae'][1:], label='Val MAE')
ax[0, 1].set_title('Validation MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Validation RMSE
ax[1, 0].plot(history.history['val_root_mean_squared_error'][1:], label='Val RMSE')
ax[1, 0].set_title('Validation RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Validation MAPE
ax[1, 1].plot(history.history['val_mape'][1:], label='Val MAPE')
ax[1, 1].set_title('Validation MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Store best training/validation metrics
# Training
train_mse = history.history['loss']
best_epoch = np.argmin(train_mse)
best_train_mse = train_mse[best_epoch]
best_train_rmse = history.history['root_mean_squared_error'][best_epoch]
best_train_mae  = history.history['mae'][best_epoch]
best_train_mape = history.history['mape'][best_epoch]

# Validation: record epoch at which validation loss is the lowest for each seed
val_mse = history.history['val_loss']
best_epoch = np.argmin(val_mse)
best_val_mse = val_mse[best_epoch]
best_val_rmse = history.history['val_root_mean_squared_error'][best_epoch]
best_val_mae  = history.history['val_mae'][best_epoch]
best_val_mape = history.history['val_mape'][best_epoch]

# %%
# -------------------------
# Step 9 — Predict/Testing
# -------------------------
y_predict= model.predict([x_test, test_states[window:]])
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# -----------------------------------
# Step 10 — Test MSE/RMSE/MAE/MAPE/R2
# -----------------------------------

# Compute the loss metrics
test_mse = mean_squared_error(y_test, y_predict)
test_rmse = root_mean_squared_error(y_test, y_predict)
test_mae = mean_absolute_error(y_test, y_predict)
test_mape = mean_absolute_percentage_error(y_test, y_predict)
test_r2_score = r2_score(y_test, y_predict)

print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Mean Absolute Error:", test_mae)
print("Mean Absolute Percentage Error:", test_mape)
print("R2 Score:", test_r2_score)
# Out:
# Mean Squared Error: 0.0001694053415672614
# Root Mean Squared Error: 0.013015580723396916
# Mean Absolute Error: 0.010383478627639721
# Mean Absolute Percentage Error: 0.08290245513289725
# R2 Score: 0.9197124638146077

# %%
#-------------------------------------------------
# Step 11 - Inverse scaling: original price scale
#-------------------------------------------------

y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))
y_predict_orig = scaler.inverse_transform(y_predict)

# %%
#----------------------------------------------
# Step 12 - Plot prediction vs. actuals prices
#----------------------------------------------

# Add window size to test idx
start_index = 1482 + 120
# Test set dates range + convert to datetime
dates = data['Date'].iloc[start_index:start_index + len(y_test_orig)].reset_index(drop=True)
dates = pd.to_datetime(dates)

# Plot the actual vs predicted prices
plt.figure(figsize=(10, 5))
plt.plot(dates, y_test_orig, label='Actual', linewidth=2)
plt.plot(dates, y_predict_orig, label='Predicted', color='red')
plt.title('Actual vs Predicted Litecoin Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#--------------------------
# Step 13 - Export results
#--------------------------

# Export prediction dataset
predictions_df = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.flatten(),
    'Predicted': y_predict_orig.flatten()
})

predictions_df.to_csv('LTC_lstm_hmm_predictions.csv', index=False)

from google.colab import files
files.download('LTC_lstm_hmm_predictions.csv')

# %%
# Store metrics in dataframe along with best training/validation loss (record epoch)
results = {
    "seed": 45,
    "best_epoch": best_epoch + 1,    # best validation epoch
    "train_mse": best_train_mse,
    "train_rmse": best_train_rmse,
    "train_mae": best_train_mae,
    "train_mape": best_train_mape,
    "val_mse": best_val_mse,
    "val_rmse": best_val_rmse,
    "val_mae": best_val_mae,
    "val_mape": best_val_mape,
    "test_mse": test_mse,
    "test_rmse": test_rmse,
    "test_mae": test_mae,
    "test_mape": test_mape,
    "test_r2_score": test_r2_score
}

ltc_results = pd.DataFrame([results])
ltc_results.to_csv('ltc_lstm_hmm_results.csv')

files.download('ltc_lstm_hmm_results.csv')

# %%
# Export results

loss_results = pd.DataFrame(history.history)
loss_results.to_csv('ltc_lstm_hmm_loss_results.csv')

files.download('ltc_lstm_hmm_loss_results.csv')

# %% [markdown]
# # **Regime Classification**

# %%
# ------------------------------------------
# Step 1 — Compute Log returns & Volatility
# ------------------------------------------

original = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.ravel()
})

predicted = pd.DataFrame({
    'Date': dates,
    'Predicted': y_predict_orig.ravel()
})

# Compute returns from actual and predicted prices
returns_orig = original['Actual'].pct_change()
returns_pred = predicted['Predicted'].pct_change()
# Drop NaN values from returns
returns_orig = returns_orig.fillna(0)
returns_pred = returns_pred.fillna(0)

# Compute 10-day rolling volatility
volatility_orig = returns_orig.rolling(window=10).std()
volatility_pred = returns_pred.rolling(window=10).std()
volatility_orig = volatility_orig.fillna(0)
volatility_pred = volatility_pred.fillna(0)

# Update dataframes with returns and volatility
original['Returns'] = returns_orig
predicted['Returns'] = returns_pred
original['Volatility'] = volatility_orig
predicted['Volatility'] = volatility_pred

# %%
# --------------------------------
# Step 2 — Label Volatility L-M-H
# --------------------------------

# Compute quantiles as thresholds for low/med/high volatility
low_threshold = volatility_orig.quantile(0.33)   # lower 33%
high_threshold = volatility_orig.quantile(0.67)  # upper 33%

# Label volatility
def label_volatility(vol):
    if vol <= low_threshold:
        return 'low'
    elif vol >= high_threshold:
        return 'high'
    else:
        return 'medium'

# Apply volatility low/medium/high to original and prediction dataset
original['Volatility_level'] = original['Volatility'].apply(label_volatility)
predicted['Volatility_level'] = predicted['Volatility'].apply(label_volatility)

# %%
# -------------------------------
# Step 3 — Regime Classification
# -------------------------------

# Classify regime based on volatility + average sign of the returns
def classify_regime(pred_labels, vol_value, vol_threshold=(low_threshold, high_threshold), window=3):
    regimes = []
    low_threshold, high_threshold = vol_threshold

    for i in range(len(pred_labels) - window):
        window_preds = pred_labels[i:i+window]
        window_vol = vol_value[i+window]
        sign_pred = np.sign(window_preds.mean())

        if window_vol <= low_threshold:
            regimes.append("Neutral")

        else:
            if sign_pred > 0:
                regimes.append("Bull")
            elif sign_pred < 0:
                regimes.append("Bear")
            else:
                regimes.append("Uncertain")

    return regimes

vol_value = original['Volatility']
regimes = classify_regime(original['Returns'], vol_value)

# %%
####################
######  Plots ######
####################

# Plot price vs. date regime shifts in
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Actual'][3:]);
plt.plot(original['Date'][3:], predicted['Predicted'][3:], color='black', alpha=0.65);

plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4, label='Bull');
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4, label='Bear');
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Neutral' for r in regimes], color='grey', alpha=0.3, label='Neutral');

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);
plt.title('Regime Shift Litecoin Predicted')
plt.legend();
plt.grid(True);
plt.tight_layout();
plt.show();

# %%
# Plot regime shift for log returns vs. date
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Returns'][3:], label='Actual')
plt.plot(original['Date'][3:], predicted['Returns'][3:], color='red', alpha=0.6, label='Predicted')

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);

plt.legend()
plt.title('Regime Shift Litecoin Returns')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift
# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = original['Actual'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Litecoin Actual")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = predicted['Predicted'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Litecoin Prediction")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()
