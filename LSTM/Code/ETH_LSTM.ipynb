# %%
#####################
## Ethereum |(ETH) ##
#####################

# %% [markdown]
# # **Optimized LSTM**

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install pandas

# %%
#######################
###### Libraries ######
#######################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import tensorflow as tf
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
# Set 3 seeds and record the model performance for each : 42, 45, 91
# Best seed
np.random.seed(91)
tf.random.set_seed(91)

# %%
# Load dataset without scaling

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ETH_noscale.csv')
data.drop(columns=['Crypto', 'Open', 'High', 'Low'], inplace=True)
data.head()
# Out:
#          Date   Close
# 0  2018-01-01  757.01
# 1  2018-01-02  864.00
# 2  2018-01-03  938.00
# 3  2018-01-04  942.04
# 4  2018-01-05  958.00

# %%
#################
####  Input  ####
#################

# ----------------------
# Step 1 — Normalization
# ----------------------

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['Close']].values.reshape(-1, 1))
data_scaled = pd.concat([data[['Date']].reset_index(drop=True), pd.DataFrame(scaled_data, columns=['Close'])],axis=1)


# -------------------------
# Step 2 — Train/Test split
# -------------------------

n_samples= len(scaled_data)
train_end = int(0.65 * n_samples)
val_end   = train_end + int(0.10 * n_samples)
input = scaled_data.reshape(-1)

# Train/validation/test slices
train_slice = input[:train_end]
val_slice   = input[train_end:val_end]
test_slice  = input[val_end:]

window = 120

# %%
# -------------------------------
# Step 3 — Create Sliding Windows
# -------------------------------

def sequence(data, window_size):

    data = np.asarray(data)
    data = data.reshape(-1, 1)
    T = data.shape[0]

    x = []
    y = []
    for i in range(window_size, T):
        x.append(data[i-window_size:i])
        y.append(data[i])

    x = np.array(x)
    y = np.array(y)
    return x, y

# Create Windowed sequences
x_train, y_train = sequence(train_slice, window)
x_val,   y_val   = sequence(val_slice,   window)
x_test,  y_test  = sequence(test_slice,  window)

print("x_train shape:", x_train.shape)
print("x_val shape:  ", x_val.shape)
print("x_test shape: ", x_test.shape)
print('y_train shape:', y_train.shape)
print('y_validation shape:', y_val.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (1165, 120, 1)
# x_val shape:   (77, 120, 1)
# x_test shape:  (375, 120, 1)
# y_train shape: (1165, 1)
# y_validation shape: (77, 1)
# y_test shape: (375, 1)

# %%
# ------------------------
# Step 4 — LSTM Input
# ------------------------

act_func = 'tanh'
n_timesteps = x_train.shape[1]
n_features = x_train.shape[2]

# ---------------------------
# Step 5 — LSTM structure
# ---------------------------

lstm = Sequential()
lstm.add(LSTM(64, input_shape=(n_timesteps,n_features), return_sequences=True, activation=act_func))
#lstm.add(Dropout(0.25))
lstm.add(LSTM(16, return_sequences=True, activation=act_func))
lstm.add(LSTM(2, return_sequences=False, activation=act_func))
lstm.add(Dense(1, activation='linear'))

# ----------------------------------
# Step 6 — Compile Model/Regression
# ----------------------------------

# MSE loss
lstm.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', RootMeanSquaredError(), 'mape']);
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# --------------------
# Step 7 — Training
# --------------------

history = lstm.fit(x_train, y_train,
                   epochs=120, batch_size=32,
                   validation_data=(x_val, y_val),
                   verbose=2)
# Out:
# Epoch 1/120
# 37/37 - 12s - 331ms/step - loss: 0.0033 - mae: 0.0319 - mape: 13265.8047 - root_mean_squared_error: 0.0572 - val_loss: 0.0143 - val_mae: 0.1013 - val_mape: 11.6341 - val_root_mean_squared_error: 0.1196
# Epoch 2/120
# 37/37 - 4s - 117ms/step - loss: 0.0011 - mae: 0.0159 - mape: 8269.2930 - root_mean_squared_error: 0.0338 - val_loss: 0.0153 - val_mae: 0.1054 - val_mape: 12.1075 - val_root_mean_squared_error: 0.1236
# Epoch 3/120
# 37/37 - 7s - 192ms/step - loss: 0.0010 - mae: 0.0148 - mape: 68.0593 - root_mean_squared_error: 0.0322 - val_loss: 0.0196 - val_mae: 0.1215 - val_mape: 13.9345 - val_root_mean_squared_error: 0.1399
# Epoch 4/120
# 37/37 - 4s - 119ms/step - loss: 9.5216e-04 - mae: 0.0140 - mape: 2962.4316 - root_mean_squared_error: 0.0309 - val_loss: 0.0248 - val_mae: 0.1400 - val_mape: 16.1199 - val_root_mean_squared_error: 0.1574
# Epoch 5/120
# 37/37 - 4s - 116ms/step - loss: 8.8139e-04 - mae: 0.0135 - mape: 3677.9497 - root_mean_squared_error: 0.0297 - val_loss: 0.0286 - val_mae: 0.1530 - val_mape: 17.6999 - val_root_mean_squared_error: 0.1692
# Epoch 6/120
# 37/37 - 6s - 172ms/step - loss: 8.2169e-04 - mae: 0.0131 - mape: 3540.5947 - root_mean_squared_error: 0.0287 - val_loss: 0.0310 - val_mae: 0.1611 - val_mape: 18.7136 - val_root_mean_squared_error: 0.1761
# Epoch 7/120
# 37/37 - 4s - 121ms/step - loss: 7.6614e-04 - mae: 0.0128 - mape: 3079.6133 - root_mean_squared_error: 0.0277 - val_loss: 0.0329 - val_mae: 0.1673 - val_mape: 19.4946 - val_root_mean_squared_error: 0.1814
# Epoch 8/120
# 37/37 - 5s - 133ms/step - loss: 7.1076e-04 - mae: 0.0124 - mape: 2808.9480 - root_mean_squared_error: 0.0267 - val_loss: 0.0345 - val_mae: 0.1722 - val_mape: 20.1098 - val_root_mean_squared_error: 0.1856
# Epoch 9/120
# 37/37 - 6s - 172ms/step - loss: 6.5530e-04 - mae: 0.0120 - mape: 2798.4355 - root_mean_squared_error: 0.0256 - val_loss: 0.0351 - val_mae: 0.1743 - val_mape: 20.3980 - val_root_mean_squared_error: 0.1873
# Epoch 10/120
# 37/37 - 8s - 220ms/step - loss: 6.0070e-04 - mae: 0.0117 - mape: 2745.7761 - root_mean_squared_error: 0.0245 - val_loss: 0.0348 - val_mae: 0.1742 - val_mape: 20.4231 - val_root_mean_squared_error: 0.1864
# Epoch 11/120
# 37/37 - 7s - 200ms/step - loss: 5.4853e-04 - mae: 0.0117 - mape: 1998.1770 - root_mean_squared_error: 0.0234 - val_loss: 0.0366 - val_mae: 0.1809 - val_mape: 21.3018 - val_root_mean_squared_error: 0.1914
# Epoch 12/120
# 37/37 - 7s - 192ms/step - loss: 5.0696e-04 - mae: 0.0119 - mape: 551.2565 - root_mean_squared_error: 0.0225 - val_loss: 0.0356 - val_mae: 0.1796 - val_mape: 21.2203 - val_root_mean_squared_error: 0.1887
# Epoch 13/120
# 37/37 - 7s - 195ms/step - loss: 5.0344e-04 - mae: 0.0123 - mape: 2169.4465 - root_mean_squared_error: 0.0224 - val_loss: 0.0370 - val_mae: 0.1825 - val_mape: 21.5145 - val_root_mean_squared_error: 0.1924
# Epoch 14/120
# 37/37 - 4s - 119ms/step - loss: 4.7516e-04 - mae: 0.0122 - mape: 4622.4229 - root_mean_squared_error: 0.0218 - val_loss: 0.0392 - val_mae: 0.1886 - val_mape: 22.2809 - val_root_mean_squared_error: 0.1979
# Epoch 15/120
# 37/37 - 4s - 117ms/step - loss: 4.8384e-04 - mae: 0.0125 - mape: 4590.6182 - root_mean_squared_error: 0.0220 - val_loss: 0.0359 - val_mae: 0.1777 - val_mape: 20.8400 - val_root_mean_squared_error: 0.1894
# Epoch 16/120
# 37/37 - 7s - 199ms/step - loss: 4.5889e-04 - mae: 0.0120 - mape: 5042.2227 - root_mean_squared_error: 0.0214 - val_loss: 0.0395 - val_mae: 0.1876 - val_mape: 22.0539 - val_root_mean_squared_error: 0.1988
# Epoch 17/120
# 37/37 - 4s - 117ms/step - loss: 4.2634e-04 - mae: 0.0112 - mape: 3769.5330 - root_mean_squared_error: 0.0206 - val_loss: 0.0427 - val_mae: 0.1937 - val_mape: 22.6850 - val_root_mean_squared_error: 0.2066
# Epoch 18/120
# 37/37 - 6s - 156ms/step - loss: 3.9980e-04 - mae: 0.0106 - mape: 3236.2556 - root_mean_squared_error: 0.0200 - val_loss: 0.0442 - val_mae: 0.1966 - val_mape: 22.9981 - val_root_mean_squared_error: 0.2103
# Epoch 19/120
# 37/37 - 6s - 156ms/step - loss: 3.8568e-04 - mae: 0.0104 - mape: 3307.8882 - root_mean_squared_error: 0.0196 - val_loss: 0.0445 - val_mae: 0.1968 - val_mape: 23.0041 - val_root_mean_squared_error: 0.2108
# Epoch 20/120
# 37/37 - 4s - 120ms/step - loss: 3.7608e-04 - mae: 0.0104 - mape: 3198.9656 - root_mean_squared_error: 0.0194 - val_loss: 0.0447 - val_mae: 0.1969 - val_mape: 22.9993 - val_root_mean_squared_error: 0.2114
# Epoch 21/120
# 37/37 - 6s - 168ms/step - loss: 3.7042e-04 - mae: 0.0104 - mape: 3350.7163 - root_mean_squared_error: 0.0192 - val_loss: 0.0434 - val_mae: 0.1933 - val_mape: 22.5386 - val_root_mean_squared_error: 0.2084
# Epoch 22/120
# 37/37 - 9s - 242ms/step - loss: 3.6940e-04 - mae: 0.0106 - mape: 3682.9631 - root_mean_squared_error: 0.0192 - val_loss: 0.0453 - val_mae: 0.1976 - val_mape: 23.0540 - val_root_mean_squared_error: 0.2128
# Epoch 23/120
# 37/37 - 6s - 162ms/step - loss: 3.5671e-04 - mae: 0.0104 - mape: 3391.6423 - root_mean_squared_error: 0.0189 - val_loss: 0.0493 - val_mae: 0.2071 - val_mape: 24.1994 - val_root_mean_squared_error: 0.2221
# Epoch 24/120
# 37/37 - 9s - 232ms/step - loss: 3.4443e-04 - mae: 0.0102 - mape: 3335.7690 - root_mean_squared_error: 0.0186 - val_loss: 0.0542 - val_mae: 0.2183 - val_mape: 25.5580 - val_root_mean_squared_error: 0.2328
# Epoch 25/120
# 37/37 - 7s - 194ms/step - loss: 3.3644e-04 - mae: 0.0100 - mape: 3248.2776 - root_mean_squared_error: 0.0183 - val_loss: 0.0649 - val_mae: 0.2412 - val_mape: 28.3416 - val_root_mean_squared_error: 0.2548
# Epoch 26/120
# 37/37 - 4s - 118ms/step - loss: 3.1859e-04 - mae: 0.0096 - mape: 1693.7797 - root_mean_squared_error: 0.0178 - val_loss: 0.0603 - val_mae: 0.2317 - val_mape: 27.1976 - val_root_mean_squared_error: 0.2456
# Epoch 27/120
# 37/37 - 5s - 135ms/step - loss: 3.2276e-04 - mae: 0.0097 - mape: 2699.7659 - root_mean_squared_error: 0.0180 - val_loss: 0.0705 - val_mae: 0.2525 - val_mape: 29.7340 - val_root_mean_squared_error: 0.2655
# Epoch 28/120
# 37/37 - 6s - 173ms/step - loss: 3.2596e-04 - mae: 0.0094 - mape: 184.9972 - root_mean_squared_error: 0.0181 - val_loss: 0.0735 - val_mae: 0.2583 - val_mape: 30.4383 - val_root_mean_squared_error: 0.2711
# Epoch 29/120
# 37/37 - 4s - 117ms/step - loss: 3.0628e-04 - mae: 0.0095 - mape: 1658.2394 - root_mean_squared_error: 0.0175 - val_loss: 0.0644 - val_mae: 0.2403 - val_mape: 28.2467 - val_root_mean_squared_error: 0.2537
# Epoch 30/120
# 37/37 - 4s - 117ms/step - loss: 3.0787e-04 - mae: 0.0093 - mape: 937.6100 - root_mean_squared_error: 0.0175 - val_loss: 0.0635 - val_mae: 0.2386 - val_mape: 28.0410 - val_root_mean_squared_error: 0.2519
# Epoch 31/120
# 37/37 - 6s - 172ms/step - loss: 3.0078e-04 - mae: 0.0094 - mape: 1512.4188 - root_mean_squared_error: 0.0173 - val_loss: 0.0601 - val_mae: 0.2320 - val_mape: 27.2668 - val_root_mean_squared_error: 0.2451
# Epoch 32/120
# 37/37 - 8s - 220ms/step - loss: 2.9824e-04 - mae: 0.0094 - mape: 1679.2463 - root_mean_squared_error: 0.0173 - val_loss: 0.0620 - val_mae: 0.2362 - val_mape: 27.7969 - val_root_mean_squared_error: 0.2490
# Epoch 33/120
# 37/37 - 6s - 174ms/step - loss: 2.9705e-04 - mae: 0.0094 - mape: 1249.2286 - root_mean_squared_error: 0.0172 - val_loss: 0.0598 - val_mae: 0.2317 - val_mape: 27.2434 - val_root_mean_squared_error: 0.2445
# Epoch 34/120
# 37/37 - 4s - 115ms/step - loss: 2.9102e-04 - mae: 0.0092 - mape: 672.2643 - root_mean_squared_error: 0.0171 - val_loss: 0.0576 - val_mae: 0.2275 - val_mape: 26.7637 - val_root_mean_squared_error: 0.2401
# Epoch 35/120
# 37/37 - 4s - 116ms/step - loss: 2.8890e-04 - mae: 0.0092 - mape: 782.9255 - root_mean_squared_error: 0.0170 - val_loss: 0.0526 - val_mae: 0.2168 - val_mape: 25.4832 - val_root_mean_squared_error: 0.2294
# Epoch 36/120
# 37/37 - 7s - 185ms/step - loss: 2.8341e-04 - mae: 0.0091 - mape: 607.7153 - root_mean_squared_error: 0.0168 - val_loss: 0.0488 - val_mae: 0.2089 - val_mape: 24.5617 - val_root_mean_squared_error: 0.2209
# Epoch 37/120
# 37/37 - 9s - 235ms/step - loss: 2.8209e-04 - mae: 0.0092 - mape: 1179.0094 - root_mean_squared_error: 0.0168 - val_loss: 0.0419 - val_mae: 0.1926 - val_mape: 22.6113 - val_root_mean_squared_error: 0.2047
# Epoch 38/120
# 37/37 - 6s - 165ms/step - loss: 2.8881e-04 - mae: 0.0093 - mape: 1774.6884 - root_mean_squared_error: 0.0170 - val_loss: 0.0380 - val_mae: 0.1830 - val_mape: 21.4734 - val_root_mean_squared_error: 0.1951
# Epoch 39/120
# 37/37 - 9s - 235ms/step - loss: 3.0209e-04 - mae: 0.0097 - mape: 3135.4922 - root_mean_squared_error: 0.0174 - val_loss: 0.0377 - val_mae: 0.1818 - val_mape: 21.3053 - val_root_mean_squared_error: 0.1941
# Epoch 40/120
# 37/37 - 6s - 170ms/step - loss: 3.2076e-04 - mae: 0.0100 - mape: 3908.0137 - root_mean_squared_error: 0.0179 - val_loss: 0.0434 - val_mae: 0.1954 - val_mape: 22.8926 - val_root_mean_squared_error: 0.2083
# Epoch 41/120
# 37/37 - 9s - 257ms/step - loss: 2.9044e-04 - mae: 0.0096 - mape: 4428.4839 - root_mean_squared_error: 0.0170 - val_loss: 0.0436 - val_mae: 0.1962 - val_mape: 23.0173 - val_root_mean_squared_error: 0.2088
# Epoch 42/120
# 37/37 - 6s - 154ms/step - loss: 2.7396e-04 - mae: 0.0092 - mape: 3667.6172 - root_mean_squared_error: 0.0166 - val_loss: 0.0486 - val_mae: 0.2081 - val_mape: 24.4557 - val_root_mean_squared_error: 0.2204
# Epoch 43/120
# 37/37 - 4s - 116ms/step - loss: 2.6867e-04 - mae: 0.0092 - mape: 3086.4216 - root_mean_squared_error: 0.0164 - val_loss: 0.0466 - val_mae: 0.2036 - val_mape: 23.9083 - val_root_mean_squared_error: 0.2159
# Epoch 44/120
# 37/37 - 5s - 135ms/step - loss: 2.6554e-04 - mae: 0.0091 - mape: 2892.7332 - root_mean_squared_error: 0.0163 - val_loss: 0.0463 - val_mae: 0.2029 - val_mape: 23.8244 - val_root_mean_squared_error: 0.2151
# Epoch 45/120
# 37/37 - 6s - 152ms/step - loss: 2.6596e-04 - mae: 0.0091 - mape: 2789.2751 - root_mean_squared_error: 0.0163 - val_loss: 0.0450 - val_mae: 0.1999 - val_mape: 23.4735 - val_root_mean_squared_error: 0.2121
# Epoch 46/120
# 37/37 - 10s - 265ms/step - loss: 2.6239e-04 - mae: 0.0090 - mape: 2711.2729 - root_mean_squared_error: 0.0162 - val_loss: 0.0434 - val_mae: 0.1960 - val_mape: 23.0139 - val_root_mean_squared_error: 0.2083
# Epoch 47/120
# 37/37 - 9s - 252ms/step - loss: 2.5896e-04 - mae: 0.0089 - mape: 2669.8477 - root_mean_squared_error: 0.0161 - val_loss: 0.0413 - val_mae: 0.1910 - val_mape: 22.4192 - val_root_mean_squared_error: 0.2032
# Epoch 48/120
# 37/37 - 6s - 162ms/step - loss: 2.5682e-04 - mae: 0.0089 - mape: 2694.5674 - root_mean_squared_error: 0.0160 - val_loss: 0.0394 - val_mae: 0.1865 - val_mape: 21.8873 - val_root_mean_squared_error: 0.1986
# Epoch 49/120
# 37/37 - 5s - 129ms/step - loss: 2.5550e-04 - mae: 0.0089 - mape: 2824.8154 - root_mean_squared_error: 0.0160 - val_loss: 0.0377 - val_mae: 0.1822 - val_mape: 21.3859 - val_root_mean_squared_error: 0.1943
# Epoch 50/120
# 37/37 - 5s - 127ms/step - loss: 2.5512e-04 - mae: 0.0089 - mape: 3076.4258 - root_mean_squared_error: 0.0160 - val_loss: 0.0375 - val_mae: 0.1811 - val_mape: 21.2601 - val_root_mean_squared_error: 0.1936
# Epoch 51/120
# 37/37 - 6s - 173ms/step - loss: 2.6091e-04 - mae: 0.0091 - mape: 3475.5825 - root_mean_squared_error: 0.0162 - val_loss: 0.0387 - val_mae: 0.1824 - val_mape: 21.3229 - val_root_mean_squared_error: 0.1966
# Epoch 52/120
# 37/37 - 8s - 221ms/step - loss: 2.6734e-04 - mae: 0.0094 - mape: 3962.5879 - root_mean_squared_error: 0.0164 - val_loss: 0.0468 - val_mae: 0.2010 - val_mape: 23.5846 - val_root_mean_squared_error: 0.2162
# Epoch 53/120
# 37/37 - 6s - 166ms/step - loss: 2.6576e-04 - mae: 0.0094 - mape: 3562.0852 - root_mean_squared_error: 0.0163 - val_loss: 0.0443 - val_mae: 0.1957 - val_mape: 22.8777 - val_root_mean_squared_error: 0.2106
# Epoch 54/120
# 37/37 - 8s - 227ms/step - loss: 2.7050e-04 - mae: 0.0095 - mape: 3216.0815 - root_mean_squared_error: 0.0164 - val_loss: 0.0517 - val_mae: 0.2136 - val_mape: 25.0415 - val_root_mean_squared_error: 0.2273
# Epoch 55/120
# 37/37 - 7s - 194ms/step - loss: 2.5233e-04 - mae: 0.0089 - mape: 3291.0437 - root_mean_squared_error: 0.0159 - val_loss: 0.0533 - val_mae: 0.2142 - val_mape: 25.0757 - val_root_mean_squared_error: 0.2308
# Epoch 56/120
# 37/37 - 4s - 116ms/step - loss: 2.6571e-04 - mae: 0.0094 - mape: 3496.3621 - root_mean_squared_error: 0.0163 - val_loss: 0.0478 - val_mae: 0.2025 - val_mape: 23.6334 - val_root_mean_squared_error: 0.2187
# Epoch 57/120
# 37/37 - 4s - 116ms/step - loss: 2.7191e-04 - mae: 0.0094 - mape: 3179.4839 - root_mean_squared_error: 0.0165 - val_loss: 0.0561 - val_mae: 0.2225 - val_mape: 26.0773 - val_root_mean_squared_error: 0.2368
# Epoch 58/120
# 37/37 - 6s - 173ms/step - loss: 2.4030e-04 - mae: 0.0087 - mape: 3243.1519 - root_mean_squared_error: 0.0155 - val_loss: 0.0573 - val_mae: 0.2249 - val_mape: 26.4196 - val_root_mean_squared_error: 0.2394
# Epoch 59/120
# 37/37 - 4s - 117ms/step - loss: 3.0837e-04 - mae: 0.0096 - mape: 3635.6653 - root_mean_squared_error: 0.0176 - val_loss: 0.0352 - val_mae: 0.1678 - val_mape: 19.5182 - val_root_mean_squared_error: 0.1875
# Epoch 60/120
# 37/37 - 4s - 118ms/step - loss: 2.6719e-04 - mae: 0.0093 - mape: 3660.2939 - root_mean_squared_error: 0.0163 - val_loss: 0.0439 - val_mae: 0.1939 - val_mape: 22.6039 - val_root_mean_squared_error: 0.2096
# Epoch 61/120
# 37/37 - 6s - 173ms/step - loss: 2.4018e-04 - mae: 0.0085 - mape: 4150.9766 - root_mean_squared_error: 0.0155 - val_loss: 0.0485 - val_mae: 0.2036 - val_mape: 23.8011 - val_root_mean_squared_error: 0.2201
# Epoch 62/120
# 37/37 - 4s - 116ms/step - loss: 2.4384e-04 - mae: 0.0087 - mape: 3392.0686 - root_mean_squared_error: 0.0156 - val_loss: 0.0569 - val_mae: 0.2233 - val_mape: 26.1166 - val_root_mean_squared_error: 0.2386
# Epoch 63/120
# 37/37 - 4s - 117ms/step - loss: 2.2476e-04 - mae: 0.0081 - mape: 3013.8699 - root_mean_squared_error: 0.0150 - val_loss: 0.0532 - val_mae: 0.2140 - val_mape: 25.0326 - val_root_mean_squared_error: 0.2306
# Epoch 64/120
# 37/37 - 6s - 173ms/step - loss: 2.6336e-04 - mae: 0.0092 - mape: 3477.3569 - root_mean_squared_error: 0.0162 - val_loss: 0.0569 - val_mae: 0.2230 - val_mape: 26.0705 - val_root_mean_squared_error: 0.2385
# Epoch 65/120
# 37/37 - 8s - 220ms/step - loss: 2.3517e-04 - mae: 0.0082 - mape: 2827.6870 - root_mean_squared_error: 0.0153 - val_loss: 0.0570 - val_mae: 0.2206 - val_mape: 25.7255 - val_root_mean_squared_error: 0.2388
# Epoch 66/120
# 37/37 - 7s - 194ms/step - loss: 2.3952e-04 - mae: 0.0085 - mape: 2512.6406 - root_mean_squared_error: 0.0155 - val_loss: 0.0702 - val_mae: 0.2474 - val_mape: 28.9292 - val_root_mean_squared_error: 0.2649
# Epoch 67/120
# 37/37 - 8s - 219ms/step - loss: 2.2913e-04 - mae: 0.0084 - mape: 2106.5173 - root_mean_squared_error: 0.0151 - val_loss: 0.0696 - val_mae: 0.2472 - val_mape: 29.0731 - val_root_mean_squared_error: 0.2639
# Epoch 68/120
# 37/37 - 6s - 173ms/step - loss: 2.5558e-04 - mae: 0.0092 - mape: 3188.4458 - root_mean_squared_error: 0.0160 - val_loss: 0.0654 - val_mae: 0.2387 - val_mape: 27.8985 - val_root_mean_squared_error: 0.2557
# Epoch 69/120
# 37/37 - 4s - 116ms/step - loss: 2.2319e-04 - mae: 0.0080 - mape: 2783.0930 - root_mean_squared_error: 0.0149 - val_loss: 0.0640 - val_mae: 0.2344 - val_mape: 27.3550 - val_root_mean_squared_error: 0.2530
# Epoch 70/120
# 37/37 - 5s - 143ms/step - loss: 2.3599e-04 - mae: 0.0086 - mape: 2083.8713 - root_mean_squared_error: 0.0154 - val_loss: 0.0771 - val_mae: 0.2600 - val_mape: 30.4288 - val_root_mean_squared_error: 0.2776
# Epoch 71/120
# 37/37 - 6s - 174ms/step - loss: 2.2756e-04 - mae: 0.0084 - mape: 1753.3799 - root_mean_squared_error: 0.0151 - val_loss: 0.0776 - val_mae: 0.2622 - val_mape: 30.8571 - val_root_mean_squared_error: 0.2786
# Epoch 72/120
# 37/37 - 10s - 267ms/step - loss: 2.3397e-04 - mae: 0.0087 - mape: 2821.6917 - root_mean_squared_error: 0.0153 - val_loss: 0.0753 - val_mae: 0.2570 - val_mape: 30.0676 - val_root_mean_squared_error: 0.2745
# Epoch 73/120
# 37/37 - 9s - 247ms/step - loss: 2.1255e-04 - mae: 0.0079 - mape: 2376.3076 - root_mean_squared_error: 0.0146 - val_loss: 0.0707 - val_mae: 0.2477 - val_mape: 28.9613 - val_root_mean_squared_error: 0.2658
# Epoch 74/120
# 37/37 - 6s - 154ms/step - loss: 2.3229e-04 - mae: 0.0085 - mape: 2174.2922 - root_mean_squared_error: 0.0152 - val_loss: 0.0826 - val_mae: 0.2701 - val_mape: 31.6681 - val_root_mean_squared_error: 0.2873
# Epoch 75/120
# 37/37 - 5s - 134ms/step - loss: 2.1687e-04 - mae: 0.0081 - mape: 2008.3646 - root_mean_squared_error: 0.0147 - val_loss: 0.0763 - val_mae: 0.2591 - val_mape: 30.4246 - val_root_mean_squared_error: 0.2763
# Epoch 76/120
# 37/37 - 4s - 117ms/step - loss: 2.3306e-04 - mae: 0.0087 - mape: 2598.1409 - root_mean_squared_error: 0.0153 - val_loss: 0.0818 - val_mae: 0.2689 - val_mape: 31.5222 - val_root_mean_squared_error: 0.2860
# Epoch 77/120
# 37/37 - 6s - 158ms/step - loss: 2.0940e-04 - mae: 0.0078 - mape: 2199.4192 - root_mean_squared_error: 0.0145 - val_loss: 0.0765 - val_mae: 0.2584 - val_mape: 30.2500 - val_root_mean_squared_error: 0.2766
# Epoch 78/120
# 37/37 - 9s - 236ms/step - loss: 2.2886e-04 - mae: 0.0085 - mape: 1868.9213 - root_mean_squared_error: 0.0151 - val_loss: 0.0882 - val_mae: 0.2802 - val_mape: 32.9017 - val_root_mean_squared_error: 0.2970
# Epoch 79/120
# 37/37 - 7s - 192ms/step - loss: 2.1699e-04 - mae: 0.0082 - mape: 1738.9989 - root_mean_squared_error: 0.0147 - val_loss: 0.0842 - val_mae: 0.2735 - val_mape: 32.1724 - val_root_mean_squared_error: 0.2902
# Epoch 80/120
# 37/37 - 4s - 115ms/step - loss: 2.2408e-04 - mae: 0.0084 - mape: 2069.0569 - root_mean_squared_error: 0.0150 - val_loss: 0.0880 - val_mae: 0.2799 - val_mape: 32.8651 - val_root_mean_squared_error: 0.2967
# Epoch 81/120
# 37/37 - 4s - 115ms/step - loss: 2.0979e-04 - mae: 0.0080 - mape: 1783.0629 - root_mean_squared_error: 0.0145 - val_loss: 0.0840 - val_mae: 0.2727 - val_mape: 32.0425 - val_root_mean_squared_error: 0.2898
# Epoch 82/120
# 37/37 - 7s - 194ms/step - loss: 2.2328e-04 - mae: 0.0084 - mape: 1851.7815 - root_mean_squared_error: 0.0149 - val_loss: 0.0912 - val_mae: 0.2857 - val_mape: 33.5932 - val_root_mean_squared_error: 0.3019
# Epoch 83/120
# 37/37 - 4s - 117ms/step - loss: 2.0930e-04 - mae: 0.0081 - mape: 1683.6244 - root_mean_squared_error: 0.0145 - val_loss: 0.0867 - val_mae: 0.2776 - val_mape: 32.6482 - val_root_mean_squared_error: 0.2944
# Epoch 84/120
# 37/37 - 4s - 118ms/step - loss: 2.2033e-04 - mae: 0.0083 - mape: 1703.6132 - root_mean_squared_error: 0.0148 - val_loss: 0.0934 - val_mae: 0.2897 - val_mape: 34.0974 - val_root_mean_squared_error: 0.3056
# Epoch 85/120
# 37/37 - 6s - 172ms/step - loss: 2.0778e-04 - mae: 0.0080 - mape: 1593.6580 - root_mean_squared_error: 0.0144 - val_loss: 0.0890 - val_mae: 0.2817 - val_mape: 33.1485 - val_root_mean_squared_error: 0.2983
# Epoch 86/120
# 37/37 - 4s - 117ms/step - loss: 2.1688e-04 - mae: 0.0082 - mape: 1560.7397 - root_mean_squared_error: 0.0147 - val_loss: 0.0952 - val_mae: 0.2929 - val_mape: 34.4965 - val_root_mean_squared_error: 0.3086
# Epoch 87/120
# 37/37 - 4s - 117ms/step - loss: 2.0606e-04 - mae: 0.0080 - mape: 1525.8824 - root_mean_squared_error: 0.0144 - val_loss: 0.0909 - val_mae: 0.2852 - val_mape: 33.5626 - val_root_mean_squared_error: 0.3016
# Epoch 88/120
# 37/37 - 7s - 181ms/step - loss: 2.1345e-04 - mae: 0.0082 - mape: 1441.7056 - root_mean_squared_error: 0.0146 - val_loss: 0.0968 - val_mae: 0.2955 - val_mape: 34.8219 - val_root_mean_squared_error: 0.3111
# Epoch 89/120
# 37/37 - 4s - 117ms/step - loss: 2.0421e-04 - mae: 0.0080 - mape: 1487.3846 - root_mean_squared_error: 0.0143 - val_loss: 0.0928 - val_mae: 0.2883 - val_mape: 33.9418 - val_root_mean_squared_error: 0.3047
# Epoch 90/120
# 37/37 - 6s - 167ms/step - loss: 2.1023e-04 - mae: 0.0081 - mape: 1356.6110 - root_mean_squared_error: 0.0145 - val_loss: 0.0980 - val_mae: 0.2977 - val_mape: 35.0998 - val_root_mean_squared_error: 0.3131
# Epoch 91/120
# 37/37 - 5s - 142ms/step - loss: 2.0234e-04 - mae: 0.0080 - mape: 1475.2964 - root_mean_squared_error: 0.0142 - val_loss: 0.0947 - val_mae: 0.2915 - val_mape: 34.3231 - val_root_mean_squared_error: 0.3078
# Epoch 92/120
# 37/37 - 4s - 115ms/step - loss: 2.0725e-04 - mae: 0.0081 - mape: 1317.8347 - root_mean_squared_error: 0.0144 - val_loss: 0.0991 - val_mae: 0.2995 - val_mape: 35.3329 - val_root_mean_squared_error: 0.3148
# Epoch 93/120
# 37/37 - 5s - 144ms/step - loss: 2.0065e-04 - mae: 0.0079 - mape: 1479.2894 - root_mean_squared_error: 0.0142 - val_loss: 0.0968 - val_mae: 0.2949 - val_mape: 34.7353 - val_root_mean_squared_error: 0.3111
# Epoch 94/120
# 37/37 - 9s - 248ms/step - loss: 2.0435e-04 - mae: 0.0080 - mape: 1336.8196 - root_mean_squared_error: 0.0143 - val_loss: 0.0999 - val_mae: 0.3009 - val_mape: 35.5099 - val_root_mean_squared_error: 0.3160
# Epoch 95/120
# 37/37 - 6s - 158ms/step - loss: 1.9935e-04 - mae: 0.0079 - mape: 1488.3580 - root_mean_squared_error: 0.0141 - val_loss: 0.0989 - val_mae: 0.2986 - val_mape: 35.1870 - val_root_mean_squared_error: 0.3145
# Epoch 96/120
# 37/37 - 5s - 130ms/step - loss: 2.0136e-04 - mae: 0.0079 - mape: 1406.7324 - root_mean_squared_error: 0.0142 - val_loss: 0.1005 - val_mae: 0.3020 - val_mape: 35.6482 - val_root_mean_squared_error: 0.3171
# Epoch 97/120
# 37/37 - 4s - 115ms/step - loss: 1.9840e-04 - mae: 0.0079 - mape: 1502.3125 - root_mean_squared_error: 0.0141 - val_loss: 0.1008 - val_mae: 0.3020 - val_mape: 35.6310 - val_root_mean_squared_error: 0.3175
# Epoch 98/120
# 37/37 - 6s - 160ms/step - loss: 1.9853e-04 - mae: 0.0079 - mape: 1489.4608 - root_mean_squared_error: 0.0141 - val_loss: 0.1015 - val_mae: 0.3034 - val_mape: 35.8270 - val_root_mean_squared_error: 0.3185
# Epoch 99/120
# 37/37 - 5s - 128ms/step - loss: 1.9728e-04 - mae: 0.0078 - mape: 1531.6765 - root_mean_squared_error: 0.0140 - val_loss: 0.1023 - val_mae: 0.3048 - val_mape: 35.9954 - val_root_mean_squared_error: 0.3198
# Epoch 100/120
# 37/37 - 4s - 119ms/step - loss: 1.9628e-04 - mae: 0.0078 - mape: 1551.2711 - root_mean_squared_error: 0.0140 - val_loss: 0.1027 - val_mae: 0.3057 - val_mape: 36.1080 - val_root_mean_squared_error: 0.3205
# Epoch 101/120
# 37/37 - 6s - 168ms/step - loss: 1.9557e-04 - mae: 0.0078 - mape: 1570.9104 - root_mean_squared_error: 0.0140 - val_loss: 0.1034 - val_mae: 0.3070 - val_mape: 36.2861 - val_root_mean_squared_error: 0.3216
# Epoch 102/120
# 37/37 - 8s - 229ms/step - loss: 1.9446e-04 - mae: 0.0078 - mape: 1588.6721 - root_mean_squared_error: 0.0139 - val_loss: 0.1039 - val_mae: 0.3080 - val_mape: 36.4238 - val_root_mean_squared_error: 0.3224
# Epoch 103/120
# 37/37 - 7s - 189ms/step - loss: 1.9359e-04 - mae: 0.0077 - mape: 1597.8772 - root_mean_squared_error: 0.0139 - val_loss: 0.1044 - val_mae: 0.3090 - val_mape: 36.5621 - val_root_mean_squared_error: 0.3231
# Epoch 104/120
# 37/37 - 4s - 116ms/step - loss: 1.9264e-04 - mae: 0.0077 - mape: 1602.3944 - root_mean_squared_error: 0.0139 - val_loss: 0.1047 - val_mae: 0.3099 - val_mape: 36.6907 - val_root_mean_squared_error: 0.3236
# Epoch 105/120
# 37/37 - 4s - 116ms/step - loss: 1.9170e-04 - mae: 0.0077 - mape: 1595.9342 - root_mean_squared_error: 0.0138 - val_loss: 0.1049 - val_mae: 0.3104 - val_mape: 36.7842 - val_root_mean_squared_error: 0.3238
# Epoch 106/120
# 37/37 - 7s - 194ms/step - loss: 1.9085e-04 - mae: 0.0077 - mape: 1578.3408 - root_mean_squared_error: 0.0138 - val_loss: 0.1046 - val_mae: 0.3105 - val_mape: 36.8200 - val_root_mean_squared_error: 0.3235
# Epoch 107/120
# 37/37 - 4s - 116ms/step - loss: 1.9005e-04 - mae: 0.0076 - mape: 1545.7168 - root_mean_squared_error: 0.0138 - val_loss: 0.1038 - val_mae: 0.3096 - val_mape: 36.7457 - val_root_mean_squared_error: 0.3222
# Epoch 108/120
# 37/37 - 4s - 116ms/step - loss: 1.8936e-04 - mae: 0.0076 - mape: 1499.9185 - root_mean_squared_error: 0.0138 - val_loss: 0.1023 - val_mae: 0.3074 - val_mape: 36.5011 - val_root_mean_squared_error: 0.3198
# Epoch 109/120
# 37/37 - 7s - 184ms/step - loss: 1.8866e-04 - mae: 0.0076 - mape: 1454.4225 - root_mean_squared_error: 0.0137 - val_loss: 0.1001 - val_mae: 0.3040 - val_mape: 36.1060 - val_root_mean_squared_error: 0.3164
# Epoch 110/120
# 37/37 - 4s - 116ms/step - loss: 1.8765e-04 - mae: 0.0075 - mape: 1442.7828 - root_mean_squared_error: 0.0137 - val_loss: 0.0983 - val_mae: 0.3011 - val_mape: 35.7542 - val_root_mean_squared_error: 0.3135
# Epoch 111/120
# 37/37 - 5s - 129ms/step - loss: 1.8645e-04 - mae: 0.0075 - mape: 1495.7802 - root_mean_squared_error: 0.0137 - val_loss: 0.0977 - val_mae: 0.3002 - val_mape: 35.6403 - val_root_mean_squared_error: 0.3125
# Epoch 112/120
# 37/37 - 6s - 160ms/step - loss: 1.8600e-04 - mae: 0.0075 - mape: 1580.3462 - root_mean_squared_error: 0.0136 - val_loss: 0.0979 - val_mae: 0.3006 - val_mape: 35.6991 - val_root_mean_squared_error: 0.3129
# Epoch 113/120
# 37/37 - 9s - 250ms/step - loss: 1.8609e-04 - mae: 0.0075 - mape: 1622.0829 - root_mean_squared_error: 0.0136 - val_loss: 0.0981 - val_mae: 0.3011 - val_mape: 35.7580 - val_root_mean_squared_error: 0.3132
# Epoch 114/120
# 37/37 - 6s - 158ms/step - loss: 1.8530e-04 - mae: 0.0074 - mape: 1610.3408 - root_mean_squared_error: 0.0136 - val_loss: 0.0981 - val_mae: 0.3012 - val_mape: 35.7832 - val_root_mean_squared_error: 0.3132
# Epoch 115/120
# 37/37 - 10s - 270ms/step - loss: 1.8340e-04 - mae: 0.0074 - mape: 1600.9241 - root_mean_squared_error: 0.0135 - val_loss: 0.0982 - val_mae: 0.3016 - val_mape: 35.8376 - val_root_mean_squared_error: 0.3134
# Epoch 116/120
# 37/37 - 5s - 144ms/step - loss: 1.8156e-04 - mae: 0.0073 - mape: 1627.7245 - root_mean_squared_error: 0.0135 - val_loss: 0.0986 - val_mae: 0.3024 - val_mape: 35.9444 - val_root_mean_squared_error: 0.3140
# Epoch 117/120
# 37/37 - 4s - 116ms/step - loss: 1.8029e-04 - mae: 0.0073 - mape: 1672.5861 - root_mean_squared_error: 0.0134 - val_loss: 0.0991 - val_mae: 0.3034 - val_mape: 36.0683 - val_root_mean_squared_error: 0.3147
# Epoch 118/120
# 37/37 - 6s - 149ms/step - loss: 1.7916e-04 - mae: 0.0073 - mape: 1712.3346 - root_mean_squared_error: 0.0134 - val_loss: 0.0994 - val_mae: 0.3041 - val_mape: 36.1700 - val_root_mean_squared_error: 0.3153
# Epoch 119/120
# 37/37 - 5s - 141ms/step - loss: 1.7791e-04 - mae: 0.0073 - mape: 1741.2816 - root_mean_squared_error: 0.0133 - val_loss: 0.0995 - val_mae: 0.3044 - val_mape: 36.2243 - val_root_mean_squared_error: 0.3154
# Epoch 120/120
# 37/37 - 4s - 115ms/step - loss: 1.7678e-04 - mae: 0.0072 - mape: 1760.3755 - root_mean_squared_error: 0.0133 - val_loss: 0.0992 - val_mae: 0.3041 - val_mape: 36.1976 - val_root_mean_squared_error: 0.3150

# %%
####################
### Plot Results ###
####################

# Training MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['loss'], label='MSE')
ax[0, 0].set_title('Training Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0, 0].grid(True)

# Training MAE
ax[0, 1].plot(history.history['mae'], label='MAE', color='black')
ax[0, 1].set_title('Training MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0, 1].grid(True)

# Training RMSe
ax[1, 0].plot(history.history['root_mean_squared_error'], label='RMSE', color='green')
ax[1, 0].set_title('Training RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1, 0].grid(True)

# Training MAPE
ax[1, 1].plot(history.history['mape'], label='MAPE', color='red')
ax[1, 1].set_title('Training MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Validation MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['val_loss'][1:], label='Val MSE')
ax[0, 0].set_title('Validation Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Validation MAE
ax[0, 1].plot(history.history['val_mae'][1:], label='Val MAE')
ax[0, 1].set_title('Validation MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Validation RMSE
ax[1, 0].plot(history.history['val_root_mean_squared_error'][1:], label='Val RMSE')
ax[1, 0].set_title('Validation RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Validation MAPE
ax[1, 1].plot(history.history['val_mape'][1:], label='Val MAPE')
ax[1, 1].set_title('Validation MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Store best training/validation metrics
# Training
train_mse = history.history['loss']
best_epoch = np.argmin(train_mse)
best_train_mse = train_mse[best_epoch]
best_train_rmse = history.history['root_mean_squared_error'][best_epoch]
best_train_mae  = history.history['mae'][best_epoch]
best_train_mape = history.history['mape'][best_epoch]

# Validation: record epoch at which validation loss is the lowest for each seed
val_mse = history.history['val_loss']
best_epoch = np.argmin(val_mse)
best_val_mse = val_mse[best_epoch]
best_val_rmse = history.history['val_root_mean_squared_error'][best_epoch]
best_val_mae  = history.history['val_mae'][best_epoch]
best_val_mape = history.history['val_mape'][best_epoch]

# %%
# -------------------------
# Step 8 — Predict/Testing
# -------------------------

y_predict= lstm.predict(x_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step

# %%
# -----------------------------------
# Step 9 — Test MSE/RMSE/MAE/MAPE/R2
# -----------------------------------

# Compute the loss metrics
test_mse = mean_squared_error(y_test, y_predict)
test_rmse = root_mean_squared_error(y_test, y_predict)
test_mae = mean_absolute_error(y_test, y_predict)
test_mape = mean_absolute_percentage_error(y_test, y_predict)
test_r2_score = r2_score(y_test, y_predict)

print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Mean Absolute Error:", test_mae)
print("Mean Absolute Percentage Error:", test_mape)
print("R2 Score:", test_r2_score)
# Out:
# Mean Squared Error: 0.000454571292821664
# Root Mean Squared Error: 0.021320677588239637
# Mean Absolute Error: 0.014840065242022528
# Mean Absolute Percentage Error: 0.050479278930851613
# R2 Score: 0.8560309806913031

# %%
#-------------------------------------------------
# Step 10 - Inverse scaling: original price scale
#-------------------------------------------------

y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))
y_predict_orig = scaler.inverse_transform(y_predict)

# %%
#----------------------------------------------
# Step 11 - Plot prediction vs. actuals prices
#----------------------------------------------

# Add window size to test idx
start_index = 1482 + 120
# Test set dates range + convert to datetime
dates = data['Date'].iloc[start_index:start_index + len(y_test_orig)].reset_index(drop=True)
dates = pd.to_datetime(dates)

# Plot the actual vs predicted prices
plt.figure(figsize=(12, 5))
plt.plot(dates, y_test_orig, label='Actual', linewidth=2)
plt.plot(dates, y_predict_orig, label='Predicted', color='red')
plt.title('Actual vs Predicted Ethereum Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#--------------------------
# Step 12 - Export results
#--------------------------

# Export prediction dataset
predictions_df = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.flatten(),
    'Predicted': y_predict_orig.flatten()
})

predictions_df.to_csv('ETH_lstm_predictions.csv', index=False)

from google.colab import files
files.download('ETH_lstm_predictions.csv')

# %%
# Store metrics in dataframe along with best training/validation loss (record epoch)
results = {
    "seed": 91,
    "best_epoch": best_epoch + 1,    # best validation epoch
    "train_mse": best_train_mse,
    "train_rmse": best_train_rmse,
    "train_mae": best_train_mae,
    "train_mape": best_train_mape,
    "val_mse": best_val_mse,
    "val_rmse": best_val_rmse,
    "val_mae": best_val_mae,
    "val_mape": best_val_mape,
    "test_mse": test_mse,
    "test_rmse": test_rmse,
    "test_mae": test_mae,
    "test_mape": test_mape,
    "test_r2_score": test_r2_score
}

eth_results = pd.DataFrame([results])
eth_results.to_csv('eth_lstm_results.csv')

files.download('eth_lstm_results.csv')

# %%
# Export loss results
loss_results = pd.DataFrame(history.history)
loss_results.to_csv('loss_eth_results.csv')

files.download('loss_eth_results.csv')

# %% [markdown]
# # **Regime Classification**

# %%
# ------------------------------------------
# Step 1 — Compute Log returns & Volatility
# ------------------------------------------

original = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.ravel()
})

predicted = pd.DataFrame({
    'Date': dates,
    'Predicted': y_predict_orig.ravel()
})

# Compute returns from actual and predicted prices
returns_orig = original['Actual'].pct_change()
returns_pred = predicted['Predicted'].pct_change()
# Drop NaN values from returns
returns_orig = returns_orig.fillna(0)
returns_pred = returns_pred.fillna(0)

# Compute 10-day rolling volatility
volatility_orig = returns_orig.rolling(window=10).std()
volatility_pred = returns_pred.rolling(window=10).std()
volatility_orig = volatility_orig.fillna(0)
volatility_pred = volatility_pred.fillna(0)

# Update dataframes with returns and volatility
original['Returns'] = returns_orig
predicted['Returns'] = returns_pred
original['Volatility'] = volatility_orig
predicted['Volatility'] = volatility_pred

# %%
# --------------------------------
# Step 2 — Label Volatility L-M-H
# --------------------------------

# Compute quantiles as thresholds for low/med/high volatility
low_threshold = volatility_orig.quantile(0.33)   # lower 33%
high_threshold = volatility_orig.quantile(0.67)  # upper 33%

# Label volatility
def label_volatility(vol):
    if vol <= low_threshold:
        return 'low'
    elif vol >= high_threshold:
        return 'high'
    else:
        return 'medium'

# Apply volatility low/medium/high to original and prediction dataset
original['Volatility_level'] = original['Volatility'].apply(label_volatility)
predicted['Volatility_level'] = predicted['Volatility'].apply(label_volatility)

# %%
# -------------------------------
# Step 3 — Regime Classification
# -------------------------------

# Classify regime based on volatility + average sign of the returns
def classify_regime(pred_labels, vol_value, vol_threshold=(low_threshold, high_threshold), window=3):
    regimes = []
    low_threshold, high_threshold = vol_threshold

    for i in range(len(pred_labels) - window):
        window_preds = pred_labels[i:i+window]
        window_vol = vol_value[i+window]
        sign_pred = np.sign(window_preds.mean())

        if window_vol <= low_threshold:
            regimes.append("Neutral")

        else:
            if sign_pred > 0:
                regimes.append("Bull")
            elif sign_pred < 0:
                regimes.append("Bear")
            else:
                regimes.append("Uncertain")

    return regimes

vol_value = original['Volatility']
regimes = classify_regime(original['Returns'], vol_value)

# %%
####################
######  Plots ######
####################

# Plot price vs. date regime shifts in
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Actual'][3:])
plt.plot(original['Date'][3:], predicted['Predicted'][3:], color='black', alpha=0.65)

plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Neutral' for r in regimes], color='grey', alpha=0.3);

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3228268198.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot regime shift for log returns vs. date
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Returns'][3:])
plt.plot(original['Date'][3:], predicted['Returns'][3:], color='red', alpha=0.6)

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4137138025.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot price vs. date regime shift
# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = original['Actual'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Ethereum Actual")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = predicted['Predicted'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Ethereum Prediction")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()
