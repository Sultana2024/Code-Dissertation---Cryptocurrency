# %%
#####################
###   XRP (XRP)   ###
#####################

# %% [markdown]
# # **Optimized LSTM**

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install pandas

# %%
#######################
###### Libraries ######
#######################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import tensorflow as tf
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
# Set 3 seeds and record the model performance for each : 42, 45, 91
# Best seed
np.random.seed(91)
tf.random.set_seed(91)

# %%
# Load dataset without scaling

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/XRP_noscale.csv')
data.drop(columns=['Crypto', 'Open', 'High', 'Low'], inplace=True)
data.head()
# Out:
#          Date  Close
# 0  2018-01-01   2.10
# 1  2018-01-02   2.21
# 2  2018-01-03   2.78
# 3  2018-01-04   2.60
# 4  2018-01-05   2.65

# %%
#################
####  Input  ####
#################

# ----------------------
# Step 1 — Normalization
# ----------------------

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['Close']].values.reshape(-1, 1))
data_scaled = pd.concat([data[['Date']].reset_index(drop=True), pd.DataFrame(scaled_data, columns=['Close'])],axis=1)


# -------------------------
# Step 2 — Train/Test split
# -------------------------

n_samples= len(scaled_data)
train_end = int(0.65 * n_samples)
val_end   = train_end + int(0.10 * n_samples)
input = scaled_data.reshape(-1)

# Train/validation/test slices
train_slice = input[:train_end]
val_slice   = input[train_end:val_end]
test_slice  = input[val_end:]

window = 120

# %%
# -------------------------------
# Step 3 — Create Sliding Windows
# -------------------------------

def sequence(data, window_size):

    data = np.asarray(data)
    data = data.reshape(-1, 1)
    T = data.shape[0]

    x = []
    y = []
    for i in range(window_size, T):
        x.append(data[i-window_size:i])
        y.append(data[i])

    x = np.array(x)
    y = np.array(y)
    return x, y

# Create Windowed sequences
x_train, y_train = sequence(train_slice, window)
x_val,   y_val   = sequence(val_slice,   window)
x_test,  y_test  = sequence(test_slice,  window)

print("x_train shape:", x_train.shape)
print("x_val shape:  ", x_val.shape)
print("x_test shape: ", x_test.shape)
print('y_train shape:', y_train.shape)
print('y_validation shape:', y_val.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (1165, 120, 1)
# x_val shape:   (77, 120, 1)
# x_test shape:  (375, 120, 1)
# y_train shape: (1165, 1)
# y_validation shape: (77, 1)
# y_test shape: (375, 1)

# %%
# ------------------------
# Step 4 — LSTM Input
# ------------------------

act_func = 'tanh'
n_timesteps = x_train.shape[1]
n_features = x_train.shape[2]

# ---------------------------
# Step 5 — LSTM structure
# ---------------------------

lstm = Sequential()
lstm.add(LSTM(64, input_shape=(n_timesteps,n_features), return_sequences=True, activation=act_func))
#lstm.add(Dropout(0.25))
lstm.add(LSTM(16, return_sequences=True, activation=act_func))
lstm.add(LSTM(2, return_sequences=False, activation=act_func))
lstm.add(Dense(1, activation='linear'))

# ----------------------------------
# Step 6 — Compile Model/Regression
# ----------------------------------

# MSE loss
lstm.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', RootMeanSquaredError(), 'mape']);
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# --------------------
# Step 7 — Training
# --------------------

history = lstm.fit(x_train, y_train,
                   epochs=120, batch_size=32,
                   validation_data=(x_val, y_val),
                   verbose=2)
# Out:
# Epoch 1/120
# 37/37 - 10s - 284ms/step - loss: 0.0032 - mae: 0.0334 - mape: 17564.3750 - root_mean_squared_error: 0.0567 - val_loss: 0.0015 - val_mae: 0.0340 - val_mape: 12.0931 - val_root_mean_squared_error: 0.0382
# Epoch 2/120
# 37/37 - 5s - 148ms/step - loss: 0.0017 - mae: 0.0209 - mape: 21253.8652 - root_mean_squared_error: 0.0409 - val_loss: 0.0011 - val_mae: 0.0273 - val_mape: 9.4573 - val_root_mean_squared_error: 0.0326
# Epoch 3/120
# 37/37 - 4s - 109ms/step - loss: 0.0014 - mae: 0.0189 - mape: 21696.8281 - root_mean_squared_error: 0.0373 - val_loss: 0.0011 - val_mae: 0.0238 - val_mape: 7.8261 - val_root_mean_squared_error: 0.0325
# Epoch 4/120
# 37/37 - 5s - 139ms/step - loss: 0.0013 - mae: 0.0185 - mape: 23253.3750 - root_mean_squared_error: 0.0356 - val_loss: 8.8281e-04 - val_mae: 0.0227 - val_mape: 7.5815 - val_root_mean_squared_error: 0.0297
# Epoch 5/120
# 37/37 - 7s - 179ms/step - loss: 0.0012 - mae: 0.0178 - mape: 22511.6016 - root_mean_squared_error: 0.0344 - val_loss: 8.0504e-04 - val_mae: 0.0221 - val_mape: 7.4136 - val_root_mean_squared_error: 0.0284
# Epoch 6/120
# 37/37 - 4s - 104ms/step - loss: 0.0011 - mae: 0.0173 - mape: 22797.0547 - root_mean_squared_error: 0.0333 - val_loss: 7.3030e-04 - val_mae: 0.0212 - val_mape: 7.1704 - val_root_mean_squared_error: 0.0270
# Epoch 7/120
# 37/37 - 4s - 105ms/step - loss: 0.0010 - mae: 0.0170 - mape: 23065.3398 - root_mean_squared_error: 0.0324 - val_loss: 6.6868e-04 - val_mae: 0.0202 - val_mape: 6.8993 - val_root_mean_squared_error: 0.0259
# Epoch 8/120
# 37/37 - 6s - 171ms/step - loss: 9.8883e-04 - mae: 0.0167 - mape: 23520.2617 - root_mean_squared_error: 0.0314 - val_loss: 6.1843e-04 - val_mae: 0.0192 - val_mape: 6.5936 - val_root_mean_squared_error: 0.0249
# Epoch 9/120
# 37/37 - 4s - 102ms/step - loss: 9.3338e-04 - mae: 0.0164 - mape: 23847.9238 - root_mean_squared_error: 0.0306 - val_loss: 5.7672e-04 - val_mae: 0.0182 - val_mape: 6.2849 - val_root_mean_squared_error: 0.0240
# Epoch 10/120
# 37/37 - 6s - 161ms/step - loss: 8.7673e-04 - mae: 0.0160 - mape: 23828.6113 - root_mean_squared_error: 0.0296 - val_loss: 5.4338e-04 - val_mae: 0.0172 - val_mape: 6.0123 - val_root_mean_squared_error: 0.0233
# Epoch 11/120
# 37/37 - 5s - 127ms/step - loss: 8.1354e-04 - mae: 0.0154 - mape: 23202.2891 - root_mean_squared_error: 0.0285 - val_loss: 5.2350e-04 - val_mae: 0.0164 - val_mape: 5.8063 - val_root_mean_squared_error: 0.0229
# Epoch 12/120
# 37/37 - 4s - 114ms/step - loss: 7.3719e-04 - mae: 0.0146 - mape: 21687.0781 - root_mean_squared_error: 0.0272 - val_loss: 5.3405e-04 - val_mae: 0.0165 - val_mape: 5.8879 - val_root_mean_squared_error: 0.0231
# Epoch 13/120
# 37/37 - 6s - 170ms/step - loss: 6.4699e-04 - mae: 0.0136 - mape: 19176.8496 - root_mean_squared_error: 0.0254 - val_loss: 6.1494e-04 - val_mae: 0.0183 - val_mape: 6.6289 - val_root_mean_squared_error: 0.0248
# Epoch 14/120
# 37/37 - 4s - 113ms/step - loss: 5.8998e-04 - mae: 0.0134 - mape: 18057.0273 - root_mean_squared_error: 0.0243 - val_loss: 6.8580e-04 - val_mae: 0.0200 - val_mape: 7.2230 - val_root_mean_squared_error: 0.0262
# Epoch 15/120
# 37/37 - 4s - 120ms/step - loss: 5.6736e-04 - mae: 0.0133 - mape: 17797.7051 - root_mean_squared_error: 0.0238 - val_loss: 6.2869e-04 - val_mae: 0.0190 - val_mape: 6.8890 - val_root_mean_squared_error: 0.0251
# Epoch 16/120
# 37/37 - 7s - 177ms/step - loss: 5.4979e-04 - mae: 0.0129 - mape: 16982.8301 - root_mean_squared_error: 0.0234 - val_loss: 5.9380e-04 - val_mae: 0.0184 - val_mape: 6.6768 - val_root_mean_squared_error: 0.0244
# Epoch 17/120
# 37/37 - 4s - 105ms/step - loss: 5.3817e-04 - mae: 0.0127 - mape: 16649.4102 - root_mean_squared_error: 0.0232 - val_loss: 5.9538e-04 - val_mae: 0.0185 - val_mape: 6.7322 - val_root_mean_squared_error: 0.0244
# Epoch 18/120
# 37/37 - 4s - 105ms/step - loss: 5.2938e-04 - mae: 0.0126 - mape: 16472.9219 - root_mean_squared_error: 0.0230 - val_loss: 5.9722e-04 - val_mae: 0.0187 - val_mape: 6.7908 - val_root_mean_squared_error: 0.0244
# Epoch 19/120
# 37/37 - 7s - 183ms/step - loss: 5.2165e-04 - mae: 0.0125 - mape: 16314.4414 - root_mean_squared_error: 0.0228 - val_loss: 5.9733e-04 - val_mae: 0.0188 - val_mape: 6.8337 - val_root_mean_squared_error: 0.0244
# Epoch 20/120
# 37/37 - 9s - 231ms/step - loss: 5.1444e-04 - mae: 0.0124 - mape: 16163.7490 - root_mean_squared_error: 0.0227 - val_loss: 5.9603e-04 - val_mae: 0.0189 - val_mape: 6.8622 - val_root_mean_squared_error: 0.0244
# Epoch 21/120
# 37/37 - 6s - 149ms/step - loss: 5.0761e-04 - mae: 0.0123 - mape: 16022.9443 - root_mean_squared_error: 0.0225 - val_loss: 5.9355e-04 - val_mae: 0.0189 - val_mape: 6.8784 - val_root_mean_squared_error: 0.0244
# Epoch 22/120
# 37/37 - 4s - 106ms/step - loss: 5.0106e-04 - mae: 0.0123 - mape: 15892.9854 - root_mean_squared_error: 0.0224 - val_loss: 5.9005e-04 - val_mae: 0.0189 - val_mape: 6.8832 - val_root_mean_squared_error: 0.0243
# Epoch 23/120
# 37/37 - 5s - 136ms/step - loss: 4.9474e-04 - mae: 0.0122 - mape: 15775.3545 - root_mean_squared_error: 0.0222 - val_loss: 5.8563e-04 - val_mae: 0.0189 - val_mape: 6.8809 - val_root_mean_squared_error: 0.0242
# Epoch 24/120
# 37/37 - 6s - 161ms/step - loss: 4.8863e-04 - mae: 0.0121 - mape: 15671.0781 - root_mean_squared_error: 0.0221 - val_loss: 5.8038e-04 - val_mae: 0.0189 - val_mape: 6.8727 - val_root_mean_squared_error: 0.0241
# Epoch 25/120
# 37/37 - 4s - 105ms/step - loss: 4.8267e-04 - mae: 0.0121 - mape: 15581.2139 - root_mean_squared_error: 0.0220 - val_loss: 5.7440e-04 - val_mae: 0.0188 - val_mape: 6.8558 - val_root_mean_squared_error: 0.0240
# Epoch 26/120
# 37/37 - 4s - 111ms/step - loss: 4.7685e-04 - mae: 0.0120 - mape: 15507.2939 - root_mean_squared_error: 0.0218 - val_loss: 5.6781e-04 - val_mae: 0.0188 - val_mape: 6.8299 - val_root_mean_squared_error: 0.0238
# Epoch 27/120
# 37/37 - 6s - 151ms/step - loss: 4.7115e-04 - mae: 0.0119 - mape: 15451.7285 - root_mean_squared_error: 0.0217 - val_loss: 5.6079e-04 - val_mae: 0.0187 - val_mape: 6.7988 - val_root_mean_squared_error: 0.0237
# Epoch 28/120
# 37/37 - 4s - 116ms/step - loss: 4.6556e-04 - mae: 0.0119 - mape: 15417.9141 - root_mean_squared_error: 0.0216 - val_loss: 5.5350e-04 - val_mae: 0.0186 - val_mape: 6.7652 - val_root_mean_squared_error: 0.0235
# Epoch 29/120
# 37/37 - 5s - 125ms/step - loss: 4.6005e-04 - mae: 0.0118 - mape: 15410.4844 - root_mean_squared_error: 0.0214 - val_loss: 5.4614e-04 - val_mae: 0.0185 - val_mape: 6.7283 - val_root_mean_squared_error: 0.0234
# Epoch 30/120
# 37/37 - 5s - 134ms/step - loss: 4.5462e-04 - mae: 0.0117 - mape: 15435.3252 - root_mean_squared_error: 0.0213 - val_loss: 5.3896e-04 - val_mae: 0.0184 - val_mape: 6.6879 - val_root_mean_squared_error: 0.0232
# Epoch 31/120
# 37/37 - 4s - 121ms/step - loss: 4.4923e-04 - mae: 0.0117 - mape: 15498.9756 - root_mean_squared_error: 0.0212 - val_loss: 5.3233e-04 - val_mae: 0.0183 - val_mape: 6.6463 - val_root_mean_squared_error: 0.0231
# Epoch 32/120
# 37/37 - 5s - 125ms/step - loss: 4.4385e-04 - mae: 0.0116 - mape: 15606.9990 - root_mean_squared_error: 0.0211 - val_loss: 5.2686e-04 - val_mae: 0.0182 - val_mape: 6.6077 - val_root_mean_squared_error: 0.0230
# Epoch 33/120
# 37/37 - 5s - 131ms/step - loss: 4.3838e-04 - mae: 0.0116 - mape: 15761.0830 - root_mean_squared_error: 0.0209 - val_loss: 5.2376e-04 - val_mae: 0.0181 - val_mape: 6.5804 - val_root_mean_squared_error: 0.0229
# Epoch 34/120
# 37/37 - 4s - 105ms/step - loss: 4.3265e-04 - mae: 0.0115 - mape: 15957.8125 - root_mean_squared_error: 0.0208 - val_loss: 5.2527e-04 - val_mae: 0.0181 - val_mape: 6.5784 - val_root_mean_squared_error: 0.0229
# Epoch 35/120
# 37/37 - 4s - 121ms/step - loss: 4.2637e-04 - mae: 0.0115 - mape: 16193.7822 - root_mean_squared_error: 0.0206 - val_loss: 5.3509e-04 - val_mae: 0.0182 - val_mape: 6.6299 - val_root_mean_squared_error: 0.0231
# Epoch 36/120
# 37/37 - 5s - 129ms/step - loss: 4.1922e-04 - mae: 0.0115 - mape: 16474.8730 - root_mean_squared_error: 0.0205 - val_loss: 5.5513e-04 - val_mae: 0.0184 - val_mape: 6.7189 - val_root_mean_squared_error: 0.0236
# Epoch 37/120
# 37/37 - 4s - 102ms/step - loss: 4.1147e-04 - mae: 0.0114 - mape: 16755.8379 - root_mean_squared_error: 0.0203 - val_loss: 5.6388e-04 - val_mae: 0.0184 - val_mape: 6.7117 - val_root_mean_squared_error: 0.0237
# Epoch 38/120
# 37/37 - 6s - 166ms/step - loss: 4.0505e-04 - mae: 0.0113 - mape: 16567.3516 - root_mean_squared_error: 0.0201 - val_loss: 5.3292e-04 - val_mae: 0.0179 - val_mape: 6.5477 - val_root_mean_squared_error: 0.0231
# Epoch 39/120
# 37/37 - 5s - 122ms/step - loss: 4.0018e-04 - mae: 0.0112 - mape: 16054.1113 - root_mean_squared_error: 0.0200 - val_loss: 4.9252e-04 - val_mae: 0.0173 - val_mape: 6.2807 - val_root_mean_squared_error: 0.0222
# Epoch 40/120
# 37/37 - 4s - 121ms/step - loss: 3.9242e-04 - mae: 0.0112 - mape: 15922.4189 - root_mean_squared_error: 0.0198 - val_loss: 4.9881e-04 - val_mae: 0.0173 - val_mape: 6.3051 - val_root_mean_squared_error: 0.0223
# Epoch 41/120
# 37/37 - 5s - 129ms/step - loss: 3.9055e-04 - mae: 0.0112 - mape: 15970.3174 - root_mean_squared_error: 0.0198 - val_loss: 4.8142e-04 - val_mae: 0.0170 - val_mape: 6.1946 - val_root_mean_squared_error: 0.0219
# Epoch 42/120
# 37/37 - 5s - 127ms/step - loss: 3.8470e-04 - mae: 0.0111 - mape: 15767.9756 - root_mean_squared_error: 0.0196 - val_loss: 4.6803e-04 - val_mae: 0.0169 - val_mape: 6.1179 - val_root_mean_squared_error: 0.0216
# Epoch 43/120
# 37/37 - 4s - 103ms/step - loss: 3.8024e-04 - mae: 0.0111 - mape: 15742.4580 - root_mean_squared_error: 0.0195 - val_loss: 4.5793e-04 - val_mae: 0.0168 - val_mape: 6.0664 - val_root_mean_squared_error: 0.0214
# Epoch 44/120
# 37/37 - 7s - 177ms/step - loss: 3.7611e-04 - mae: 0.0111 - mape: 15767.5469 - root_mean_squared_error: 0.0194 - val_loss: 4.4905e-04 - val_mae: 0.0166 - val_mape: 6.0140 - val_root_mean_squared_error: 0.0212
# Epoch 45/120
# 37/37 - 4s - 109ms/step - loss: 3.7233e-04 - mae: 0.0110 - mape: 15808.2988 - root_mean_squared_error: 0.0193 - val_loss: 4.4124e-04 - val_mae: 0.0165 - val_mape: 5.9603 - val_root_mean_squared_error: 0.0210
# Epoch 46/120
# 37/37 - 5s - 135ms/step - loss: 3.6882e-04 - mae: 0.0110 - mape: 15841.3232 - root_mean_squared_error: 0.0192 - val_loss: 4.3348e-04 - val_mae: 0.0164 - val_mape: 5.9037 - val_root_mean_squared_error: 0.0208
# Epoch 47/120
# 37/37 - 5s - 146ms/step - loss: 3.6533e-04 - mae: 0.0110 - mape: 15841.4561 - root_mean_squared_error: 0.0191 - val_loss: 4.2542e-04 - val_mae: 0.0162 - val_mape: 5.8442 - val_root_mean_squared_error: 0.0206
# Epoch 48/120
# 37/37 - 4s - 103ms/step - loss: 3.6170e-04 - mae: 0.0109 - mape: 15797.8760 - root_mean_squared_error: 0.0190 - val_loss: 4.1699e-04 - val_mae: 0.0161 - val_mape: 5.7809 - val_root_mean_squared_error: 0.0204
# Epoch 49/120
# 37/37 - 5s - 137ms/step - loss: 3.5794e-04 - mae: 0.0109 - mape: 15714.9531 - root_mean_squared_error: 0.0189 - val_loss: 4.0857e-04 - val_mae: 0.0160 - val_mape: 5.7182 - val_root_mean_squared_error: 0.0202
# Epoch 50/120
# 37/37 - 5s - 145ms/step - loss: 3.5413e-04 - mae: 0.0108 - mape: 15615.3525 - root_mean_squared_error: 0.0188 - val_loss: 4.0092e-04 - val_mae: 0.0159 - val_mape: 5.6579 - val_root_mean_squared_error: 0.0200
# Epoch 51/120
# 37/37 - 4s - 103ms/step - loss: 3.5042e-04 - mae: 0.0108 - mape: 15532.2041 - root_mean_squared_error: 0.0187 - val_loss: 3.9451e-04 - val_mae: 0.0157 - val_mape: 5.6034 - val_root_mean_squared_error: 0.0199
# Epoch 52/120
# 37/37 - 4s - 103ms/step - loss: 3.4686e-04 - mae: 0.0107 - mape: 15479.7422 - root_mean_squared_error: 0.0186 - val_loss: 3.8933e-04 - val_mae: 0.0156 - val_mape: 5.5571 - val_root_mean_squared_error: 0.0197
# Epoch 53/120
# 37/37 - 5s - 139ms/step - loss: 3.4334e-04 - mae: 0.0107 - mape: 15447.5693 - root_mean_squared_error: 0.0185 - val_loss: 3.8542e-04 - val_mae: 0.0156 - val_mape: 5.5195 - val_root_mean_squared_error: 0.0196
# Epoch 54/120
# 37/37 - 9s - 240ms/step - loss: 3.3977e-04 - mae: 0.0106 - mape: 15426.8340 - root_mean_squared_error: 0.0184 - val_loss: 3.8290e-04 - val_mae: 0.0156 - val_mape: 5.4966 - val_root_mean_squared_error: 0.0196
# Epoch 55/120
# 37/37 - 5s - 144ms/step - loss: 3.3633e-04 - mae: 0.0106 - mape: 15425.6855 - root_mean_squared_error: 0.0183 - val_loss: 3.8233e-04 - val_mae: 0.0156 - val_mape: 5.4890 - val_root_mean_squared_error: 0.0196
# Epoch 56/120
# 37/37 - 4s - 102ms/step - loss: 3.3339e-04 - mae: 0.0106 - mape: 15454.3057 - root_mean_squared_error: 0.0183 - val_loss: 3.8753e-04 - val_mae: 0.0157 - val_mape: 5.4901 - val_root_mean_squared_error: 0.0197
# Epoch 57/120
# 37/37 - 4s - 101ms/step - loss: 3.3095e-04 - mae: 0.0106 - mape: 15498.5938 - root_mean_squared_error: 0.0182 - val_loss: 4.0447e-04 - val_mae: 0.0161 - val_mape: 5.5564 - val_root_mean_squared_error: 0.0201
# Epoch 58/120
# 37/37 - 7s - 183ms/step - loss: 3.2826e-04 - mae: 0.0106 - mape: 15532.8965 - root_mean_squared_error: 0.0181 - val_loss: 4.2470e-04 - val_mae: 0.0165 - val_mape: 5.6505 - val_root_mean_squared_error: 0.0206
# Epoch 59/120
# 37/37 - 4s - 102ms/step - loss: 3.2535e-04 - mae: 0.0106 - mape: 15555.8545 - root_mean_squared_error: 0.0180 - val_loss: 4.4952e-04 - val_mae: 0.0170 - val_mape: 5.7729 - val_root_mean_squared_error: 0.0212
# Epoch 60/120
# 37/37 - 4s - 102ms/step - loss: 3.2292e-04 - mae: 0.0106 - mape: 15596.1748 - root_mean_squared_error: 0.0180 - val_loss: 4.7074e-04 - val_mae: 0.0174 - val_mape: 5.8828 - val_root_mean_squared_error: 0.0217
# Epoch 61/120
# 37/37 - 7s - 184ms/step - loss: 3.1839e-04 - mae: 0.0106 - mape: 15549.0459 - root_mean_squared_error: 0.0178 - val_loss: 5.0327e-04 - val_mae: 0.0180 - val_mape: 6.0502 - val_root_mean_squared_error: 0.0224
# Epoch 62/120
# 37/37 - 9s - 231ms/step - loss: 3.2110e-04 - mae: 0.0107 - mape: 15812.2178 - root_mean_squared_error: 0.0179 - val_loss: 4.9498e-04 - val_mae: 0.0179 - val_mape: 6.0606 - val_root_mean_squared_error: 0.0222
# Epoch 63/120
# 37/37 - 6s - 167ms/step - loss: 3.0635e-04 - mae: 0.0104 - mape: 15109.9072 - root_mean_squared_error: 0.0175 - val_loss: 4.7947e-04 - val_mae: 0.0175 - val_mape: 5.8952 - val_root_mean_squared_error: 0.0219
# Epoch 64/120
# 37/37 - 4s - 103ms/step - loss: 3.3284e-04 - mae: 0.0108 - mape: 16532.2812 - root_mean_squared_error: 0.0182 - val_loss: 4.2370e-04 - val_mae: 0.0167 - val_mape: 5.7389 - val_root_mean_squared_error: 0.0206
# Epoch 65/120
# 37/37 - 4s - 102ms/step - loss: 2.9048e-04 - mae: 0.0098 - mape: 13825.2480 - root_mean_squared_error: 0.0170 - val_loss: 4.2901e-04 - val_mae: 0.0166 - val_mape: 5.6365 - val_root_mean_squared_error: 0.0207
# Epoch 66/120
# 37/37 - 5s - 146ms/step - loss: 3.1350e-04 - mae: 0.0101 - mape: 14476.1699 - root_mean_squared_error: 0.0177 - val_loss: 3.8216e-04 - val_mae: 0.0148 - val_mape: 5.3453 - val_root_mean_squared_error: 0.0195
# Epoch 67/120
# 37/37 - 4s - 104ms/step - loss: 3.1251e-04 - mae: 0.0099 - mape: 13806.8232 - root_mean_squared_error: 0.0177 - val_loss: 3.2045e-04 - val_mae: 0.0137 - val_mape: 4.8148 - val_root_mean_squared_error: 0.0179
# Epoch 68/120
# 37/37 - 5s - 137ms/step - loss: 3.0430e-04 - mae: 0.0100 - mape: 14023.5635 - root_mean_squared_error: 0.0174 - val_loss: 3.8662e-04 - val_mae: 0.0160 - val_mape: 5.5021 - val_root_mean_squared_error: 0.0197
# Epoch 69/120
# 37/37 - 6s - 156ms/step - loss: 2.9068e-04 - mae: 0.0098 - mape: 12976.6787 - root_mean_squared_error: 0.0170 - val_loss: 3.2162e-04 - val_mae: 0.0140 - val_mape: 4.8643 - val_root_mean_squared_error: 0.0179
# Epoch 70/120
# 37/37 - 4s - 102ms/step - loss: 2.9816e-04 - mae: 0.0098 - mape: 13147.8711 - root_mean_squared_error: 0.0173 - val_loss: 3.1768e-04 - val_mae: 0.0139 - val_mape: 4.8606 - val_root_mean_squared_error: 0.0178
# Epoch 71/120
# 37/37 - 4s - 113ms/step - loss: 2.9161e-04 - mae: 0.0098 - mape: 12656.6777 - root_mean_squared_error: 0.0171 - val_loss: 3.1749e-04 - val_mae: 0.0139 - val_mape: 4.8271 - val_root_mean_squared_error: 0.0178
# Epoch 72/120
# 37/37 - 5s - 145ms/step - loss: 2.9773e-04 - mae: 0.0098 - mape: 13798.8877 - root_mean_squared_error: 0.0173 - val_loss: 3.4033e-04 - val_mae: 0.0148 - val_mape: 5.1227 - val_root_mean_squared_error: 0.0184
# Epoch 73/120
# 37/37 - 4s - 102ms/step - loss: 2.7292e-04 - mae: 0.0094 - mape: 11787.7549 - root_mean_squared_error: 0.0165 - val_loss: 3.5687e-04 - val_mae: 0.0152 - val_mape: 5.2139 - val_root_mean_squared_error: 0.0189
# Epoch 74/120
# 37/37 - 4s - 112ms/step - loss: 2.8927e-04 - mae: 0.0097 - mape: 12011.1641 - root_mean_squared_error: 0.0170 - val_loss: 3.2025e-04 - val_mae: 0.0141 - val_mape: 4.8839 - val_root_mean_squared_error: 0.0179
# Epoch 75/120
# 37/37 - 5s - 144ms/step - loss: 2.7824e-04 - mae: 0.0095 - mape: 12491.9463 - root_mean_squared_error: 0.0167 - val_loss: 3.6603e-04 - val_mae: 0.0156 - val_mape: 5.3510 - val_root_mean_squared_error: 0.0191
# Epoch 76/120
# 37/37 - 5s - 125ms/step - loss: 2.7279e-04 - mae: 0.0094 - mape: 11399.4648 - root_mean_squared_error: 0.0165 - val_loss: 3.7399e-04 - val_mae: 0.0158 - val_mape: 5.4002 - val_root_mean_squared_error: 0.0193
# Epoch 77/120
# 37/37 - 5s - 129ms/step - loss: 2.7076e-04 - mae: 0.0093 - mape: 10660.3184 - root_mean_squared_error: 0.0165 - val_loss: 3.6502e-04 - val_mae: 0.0156 - val_mape: 5.3414 - val_root_mean_squared_error: 0.0191
# Epoch 78/120
# 37/37 - 4s - 120ms/step - loss: 2.7116e-04 - mae: 0.0094 - mape: 10869.8438 - root_mean_squared_error: 0.0165 - val_loss: 3.6112e-04 - val_mae: 0.0155 - val_mape: 5.3379 - val_root_mean_squared_error: 0.0190
# Epoch 79/120
# 37/37 - 5s - 122ms/step - loss: 2.7111e-04 - mae: 0.0093 - mape: 10990.0547 - root_mean_squared_error: 0.0165 - val_loss: 3.4991e-04 - val_mae: 0.0152 - val_mape: 5.2764 - val_root_mean_squared_error: 0.0187
# Epoch 80/120
# 37/37 - 5s - 128ms/step - loss: 2.7980e-04 - mae: 0.0095 - mape: 11917.4150 - root_mean_squared_error: 0.0167 - val_loss: 3.3497e-04 - val_mae: 0.0148 - val_mape: 5.1600 - val_root_mean_squared_error: 0.0183
# Epoch 81/120
# 37/37 - 4s - 119ms/step - loss: 2.7413e-04 - mae: 0.0094 - mape: 11676.0107 - root_mean_squared_error: 0.0166 - val_loss: 3.6956e-04 - val_mae: 0.0157 - val_mape: 5.4385 - val_root_mean_squared_error: 0.0192
# Epoch 82/120
# 37/37 - 4s - 101ms/step - loss: 2.7378e-04 - mae: 0.0095 - mape: 11599.0342 - root_mean_squared_error: 0.0165 - val_loss: 3.7503e-04 - val_mae: 0.0158 - val_mape: 5.4910 - val_root_mean_squared_error: 0.0194
# Epoch 83/120
# 37/37 - 6s - 175ms/step - loss: 2.6639e-04 - mae: 0.0093 - mape: 10676.6631 - root_mean_squared_error: 0.0163 - val_loss: 3.8513e-04 - val_mae: 0.0161 - val_mape: 5.5820 - val_root_mean_squared_error: 0.0196
# Epoch 84/120
# 37/37 - 4s - 113ms/step - loss: 2.7084e-04 - mae: 0.0094 - mape: 11209.0527 - root_mean_squared_error: 0.0165 - val_loss: 3.7501e-04 - val_mae: 0.0158 - val_mape: 5.5155 - val_root_mean_squared_error: 0.0194
# Epoch 85/120
# 37/37 - 4s - 103ms/step - loss: 2.6247e-04 - mae: 0.0092 - mape: 10139.1670 - root_mean_squared_error: 0.0162 - val_loss: 3.8687e-04 - val_mae: 0.0161 - val_mape: 5.5997 - val_root_mean_squared_error: 0.0197
# Epoch 86/120
# 37/37 - 7s - 179ms/step - loss: 2.7202e-04 - mae: 0.0095 - mape: 11497.8516 - root_mean_squared_error: 0.0165 - val_loss: 3.6631e-04 - val_mae: 0.0156 - val_mape: 5.4516 - val_root_mean_squared_error: 0.0191
# Epoch 87/120
# 37/37 - 4s - 105ms/step - loss: 2.5669e-04 - mae: 0.0090 - mape: 9597.5771 - root_mean_squared_error: 0.0160 - val_loss: 4.0604e-04 - val_mae: 0.0164 - val_mape: 5.7183 - val_root_mean_squared_error: 0.0202
# Epoch 88/120
# 37/37 - 4s - 102ms/step - loss: 2.7639e-04 - mae: 0.0097 - mape: 12032.3633 - root_mean_squared_error: 0.0166 - val_loss: 3.5087e-04 - val_mae: 0.0152 - val_mape: 5.3132 - val_root_mean_squared_error: 0.0187
# Epoch 89/120
# 37/37 - 5s - 126ms/step - loss: 2.5146e-04 - mae: 0.0089 - mape: 9329.9678 - root_mean_squared_error: 0.0159 - val_loss: 4.1629e-04 - val_mae: 0.0166 - val_mape: 5.7887 - val_root_mean_squared_error: 0.0204
# Epoch 90/120
# 37/37 - 4s - 121ms/step - loss: 2.7418e-04 - mae: 0.0096 - mape: 11648.6875 - root_mean_squared_error: 0.0166 - val_loss: 3.2587e-04 - val_mae: 0.0145 - val_mape: 5.0878 - val_root_mean_squared_error: 0.0181
# Epoch 91/120
# 37/37 - 4s - 102ms/step - loss: 2.4960e-04 - mae: 0.0089 - mape: 9399.4941 - root_mean_squared_error: 0.0158 - val_loss: 3.8999e-04 - val_mae: 0.0161 - val_mape: 5.6136 - val_root_mean_squared_error: 0.0197
# Epoch 92/120
# 37/37 - 4s - 114ms/step - loss: 2.6444e-04 - mae: 0.0094 - mape: 11013.5352 - root_mean_squared_error: 0.0163 - val_loss: 3.2326e-04 - val_mae: 0.0145 - val_mape: 5.0835 - val_root_mean_squared_error: 0.0180
# Epoch 93/120
# 37/37 - 5s - 135ms/step - loss: 2.4876e-04 - mae: 0.0089 - mape: 9372.6416 - root_mean_squared_error: 0.0158 - val_loss: 3.7317e-04 - val_mae: 0.0157 - val_mape: 5.5054 - val_root_mean_squared_error: 0.0193
# Epoch 94/120
# 37/37 - 4s - 108ms/step - loss: 2.6065e-04 - mae: 0.0093 - mape: 10829.9229 - root_mean_squared_error: 0.0161 - val_loss: 3.1884e-04 - val_mae: 0.0144 - val_mape: 5.0451 - val_root_mean_squared_error: 0.0179
# Epoch 95/120
# 37/37 - 4s - 105ms/step - loss: 2.4600e-04 - mae: 0.0089 - mape: 9150.8926 - root_mean_squared_error: 0.0157 - val_loss: 3.6899e-04 - val_mae: 0.0156 - val_mape: 5.4690 - val_root_mean_squared_error: 0.0192
# Epoch 96/120
# 37/37 - 6s - 160ms/step - loss: 2.6012e-04 - mae: 0.0093 - mape: 10899.5146 - root_mean_squared_error: 0.0161 - val_loss: 3.0855e-04 - val_mae: 0.0140 - val_mape: 4.9328 - val_root_mean_squared_error: 0.0176
# Epoch 97/120
# 37/37 - 4s - 105ms/step - loss: 2.4277e-04 - mae: 0.0088 - mape: 9000.1445 - root_mean_squared_error: 0.0156 - val_loss: 3.5709e-04 - val_mae: 0.0153 - val_mape: 5.3686 - val_root_mean_squared_error: 0.0189
# Epoch 98/120
# 37/37 - 6s - 173ms/step - loss: 2.5788e-04 - mae: 0.0093 - mape: 10818.1611 - root_mean_squared_error: 0.0161 - val_loss: 2.9333e-04 - val_mae: 0.0135 - val_mape: 4.7453 - val_root_mean_squared_error: 0.0171
# Epoch 99/120
# 37/37 - 4s - 113ms/step - loss: 2.4018e-04 - mae: 0.0088 - mape: 9049.3018 - root_mean_squared_error: 0.0155 - val_loss: 3.3130e-04 - val_mae: 0.0147 - val_mape: 5.1546 - val_root_mean_squared_error: 0.0182
# Epoch 100/120
# 37/37 - 4s - 104ms/step - loss: 2.5173e-04 - mae: 0.0091 - mape: 10357.5332 - root_mean_squared_error: 0.0159 - val_loss: 2.8739e-04 - val_mae: 0.0133 - val_mape: 4.6656 - val_root_mean_squared_error: 0.0170
# Epoch 101/120
# 37/37 - 4s - 119ms/step - loss: 2.3838e-04 - mae: 0.0087 - mape: 9070.5244 - root_mean_squared_error: 0.0154 - val_loss: 3.1208e-04 - val_mae: 0.0142 - val_mape: 4.9692 - val_root_mean_squared_error: 0.0177
# Epoch 102/120
# 37/37 - 5s - 130ms/step - loss: 2.4721e-04 - mae: 0.0090 - mape: 10026.5137 - root_mean_squared_error: 0.0157 - val_loss: 2.8368e-04 - val_mae: 0.0131 - val_mape: 4.6113 - val_root_mean_squared_error: 0.0168
# Epoch 103/120
# 37/37 - 4s - 102ms/step - loss: 2.3651e-04 - mae: 0.0087 - mape: 9032.7314 - root_mean_squared_error: 0.0154 - val_loss: 2.9943e-04 - val_mae: 0.0138 - val_mape: 4.8302 - val_root_mean_squared_error: 0.0173
# Epoch 104/120
# 37/37 - 4s - 103ms/step - loss: 2.4412e-04 - mae: 0.0090 - mape: 9863.3584 - root_mean_squared_error: 0.0156 - val_loss: 2.8041e-04 - val_mae: 0.0129 - val_mape: 4.5417 - val_root_mean_squared_error: 0.0167
# Epoch 105/120
# 37/37 - 6s - 160ms/step - loss: 2.3423e-04 - mae: 0.0087 - mape: 8946.6201 - root_mean_squared_error: 0.0153 - val_loss: 2.9022e-04 - val_mae: 0.0134 - val_mape: 4.7081 - val_root_mean_squared_error: 0.0170
# Epoch 106/120
# 37/37 - 4s - 104ms/step - loss: 2.4132e-04 - mae: 0.0089 - mape: 9664.8467 - root_mean_squared_error: 0.0155 - val_loss: 2.7921e-04 - val_mae: 0.0128 - val_mape: 4.5001 - val_root_mean_squared_error: 0.0167
# Epoch 107/120
# 37/37 - 6s - 175ms/step - loss: 2.3200e-04 - mae: 0.0086 - mape: 8855.7656 - root_mean_squared_error: 0.0152 - val_loss: 2.8258e-04 - val_mae: 0.0131 - val_mape: 4.6044 - val_root_mean_squared_error: 0.0168
# Epoch 108/120
# 37/37 - 4s - 113ms/step - loss: 2.3798e-04 - mae: 0.0088 - mape: 9398.7373 - root_mean_squared_error: 0.0154 - val_loss: 2.7913e-04 - val_mae: 0.0128 - val_mape: 4.4915 - val_root_mean_squared_error: 0.0167
# Epoch 109/120
# 37/37 - 4s - 104ms/step - loss: 2.3014e-04 - mae: 0.0086 - mape: 8787.2305 - root_mean_squared_error: 0.0152 - val_loss: 2.7643e-04 - val_mae: 0.0129 - val_mape: 4.5247 - val_root_mean_squared_error: 0.0166
# Epoch 110/120
# 37/37 - 5s - 126ms/step - loss: 2.3394e-04 - mae: 0.0088 - mape: 9103.3906 - root_mean_squared_error: 0.0153 - val_loss: 2.7915e-04 - val_mae: 0.0128 - val_mape: 4.4848 - val_root_mean_squared_error: 0.0167
# Epoch 111/120
# 37/37 - 5s - 127ms/step - loss: 2.2854e-04 - mae: 0.0086 - mape: 8721.1631 - root_mean_squared_error: 0.0151 - val_loss: 2.7365e-04 - val_mae: 0.0127 - val_mape: 4.4644 - val_root_mean_squared_error: 0.0165
# Epoch 112/120
# 37/37 - 5s - 126ms/step - loss: 2.2982e-04 - mae: 0.0087 - mape: 8823.4922 - root_mean_squared_error: 0.0152 - val_loss: 2.7968e-04 - val_mae: 0.0128 - val_mape: 4.4797 - val_root_mean_squared_error: 0.0167
# Epoch 113/120
# 37/37 - 7s - 185ms/step - loss: 2.2682e-04 - mae: 0.0086 - mape: 8614.1465 - root_mean_squared_error: 0.0151 - val_loss: 2.7555e-04 - val_mae: 0.0127 - val_mape: 4.4521 - val_root_mean_squared_error: 0.0166
# Epoch 114/120
# 37/37 - 9s - 231ms/step - loss: 2.2632e-04 - mae: 0.0086 - mape: 8589.6162 - root_mean_squared_error: 0.0150 - val_loss: 2.8190e-04 - val_mae: 0.0128 - val_mape: 4.4842 - val_root_mean_squared_error: 0.0168
# Epoch 115/120
# 37/37 - 6s - 174ms/step - loss: 2.2462e-04 - mae: 0.0086 - mape: 8445.0371 - root_mean_squared_error: 0.0150 - val_loss: 2.8136e-04 - val_mae: 0.0127 - val_mape: 4.4737 - val_root_mean_squared_error: 0.0168
# Epoch 116/120
# 37/37 - 4s - 106ms/step - loss: 2.2354e-04 - mae: 0.0085 - mape: 8379.0898 - root_mean_squared_error: 0.0150 - val_loss: 2.8662e-04 - val_mae: 0.0128 - val_mape: 4.4964 - val_root_mean_squared_error: 0.0169
# Epoch 117/120
# 37/37 - 4s - 104ms/step - loss: 2.2219e-04 - mae: 0.0085 - mape: 8252.6240 - root_mean_squared_error: 0.0149 - val_loss: 2.9069e-04 - val_mae: 0.0128 - val_mape: 4.5107 - val_root_mean_squared_error: 0.0170
# Epoch 118/120
# 37/37 - 7s - 192ms/step - loss: 2.2107e-04 - mae: 0.0085 - mape: 8159.1450 - root_mean_squared_error: 0.0149 - val_loss: 2.9430e-04 - val_mae: 0.0129 - val_mape: 4.5276 - val_root_mean_squared_error: 0.0172
# Epoch 119/120
# 37/37 - 4s - 109ms/step - loss: 2.1982e-04 - mae: 0.0085 - mape: 8055.5889 - root_mean_squared_error: 0.0148 - val_loss: 3.0252e-04 - val_mae: 0.0130 - val_mape: 4.5773 - val_root_mean_squared_error: 0.0174
# Epoch 120/120
# 37/37 - 5s - 132ms/step - loss: 2.1870e-04 - mae: 0.0084 - mape: 7932.8926 - root_mean_squared_error: 0.0148 - val_loss: 3.0618e-04 - val_mae: 0.0131 - val_mape: 4.6014 - val_root_mean_squared_error: 0.0175

# %%
####################
### Plot Results ###
####################

# Training MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['loss'], label='MSE')
ax[0, 0].set_title('Training Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0, 0].grid(True)

# Training MAE
ax[0, 1].plot(history.history['mae'], label='MAE', color='black')
ax[0, 1].set_title('Training MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0, 1].grid(True)

# Training RMSe
ax[1, 0].plot(history.history['root_mean_squared_error'], label='RMSE', color='green')
ax[1, 0].set_title('Training RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1, 0].grid(True)

# Training MAPE
ax[1, 1].plot(history.history['mape'], label='MAPE', color='red')
ax[1, 1].set_title('Training MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Validation MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['val_loss'][1:], label='Val MSE')
ax[0, 0].set_title('Validation Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Validation MAE
ax[0, 1].plot(history.history['val_mae'][1:], label='Val MAE')
ax[0, 1].set_title('Validation MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Validation RMSE
ax[1, 0].plot(history.history['val_root_mean_squared_error'][1:], label='Val RMSE')
ax[1, 0].set_title('Validation RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Validation MAPE
ax[1, 1].plot(history.history['val_mape'][1:], label='Val MAPE')
ax[1, 1].set_title('Validation MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Store best training/validation metrics
# Training
train_mse = history.history['loss']
best_epoch = np.argmin(train_mse)
best_train_mse = train_mse[best_epoch]
best_train_rmse = history.history['root_mean_squared_error'][best_epoch]
best_train_mae  = history.history['mae'][best_epoch]
best_train_mape = history.history['mape'][best_epoch]

# Validation: record epoch at which validation loss is the lowest for each seed
val_mse = history.history['val_loss']
best_epoch = np.argmin(val_mse)
best_val_mse = val_mse[best_epoch]
best_val_rmse = history.history['val_root_mean_squared_error'][best_epoch]
best_val_mae  = history.history['val_mae'][best_epoch]
best_val_mape = history.history['val_mape'][best_epoch]

# %%
# -------------------------
# Step 8 — Predict/Testing
# -------------------------

y_predict= lstm.predict(x_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step

# %%
# -----------------------------------
# Step 9 — Test MSE/RMSE/MAE/MAPE/R2
# -----------------------------------

# Compute the loss metrics
test_mse = mean_squared_error(y_test, y_predict)
test_rmse = root_mean_squared_error(y_test, y_predict)
test_mae = mean_absolute_error(y_test, y_predict)
test_mape = mean_absolute_percentage_error(y_test, y_predict)
test_r2_score = r2_score(y_test, y_predict)

print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Mean Absolute Error:", test_mae)
print("Mean Absolute Percentage Error:", test_mape)
print("R2 Score:", test_r2_score)
# Out:
# Mean Squared Error: 5.096396176774558e-05
# Root Mean Squared Error: 0.0071389048017007194
# Mean Absolute Error: 0.00480079828548913
# Mean Absolute Percentage Error: 0.04957545673567845
# R2 Score: 0.8920825186116512

# %%
#-------------------------------------------------
# Step 10 - Inverse scaling: original price scale
#-------------------------------------------------

y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))
y_predict_orig = scaler.inverse_transform(y_predict)

# %%
#----------------------------------------------
# Step 11 - Plot prediction vs. actuals prices
#----------------------------------------------

# Add window size to test idx
start_index = 1482 + 120
# Test set dates range + convert to datetime
dates = data['Date'].iloc[start_index:start_index + len(y_test_orig)].reset_index(drop=True)
dates = pd.to_datetime(dates)

# Plot the actual vs predicted prices
plt.figure(figsize=(12, 5))
plt.plot(dates, y_test_orig, label='Actual', linewidth=2)
plt.plot(dates, y_predict_orig, label='Predicted', color='red')
plt.title('Actual vs Predicted XRP Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#--------------------------
# Step 12 - Export results
#--------------------------

# Export prediction dataset
predictions_df = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.flatten(),
    'Predicted': y_predict_orig.flatten()
})

predictions_df.to_csv('XRP_lstm_predictions.csv', index=False)

from google.colab import files
files.download('XRP_lstm_predictions.csv')

# %%
# Store metrics in dataframe along with best training/validation loss (record epoch)
results = {
    "seed": 91,
    "best_epoch": best_epoch + 1,    # best validation epoch
    "train_mse": best_train_mse,
    "train_rmse": best_train_rmse,
    "train_mae": best_train_mae,
    "train_mape": best_train_mape,
    "val_mse": best_val_mse,
    "val_rmse": best_val_rmse,
    "val_mae": best_val_mae,
    "val_mape": best_val_mape,
    "test_mse": test_mse,
    "test_rmse": test_rmse,
    "test_mae": test_mae,
    "test_mape": test_mape,
    "test_r2_score": test_r2_score
}

xrp_results = pd.DataFrame([results])
xrp_results.to_csv('xrp_lstm_results.csv')

files.download('xrp_lstm_results.csv')

# %%
# Export loss results
loss_results = pd.DataFrame(history.history)
loss_results.to_csv('loss_xrp_results.csv')

files.download('loss_xrp_results.csv')

# %% [markdown]
# # **Regime Classification**

# %%
# ------------------------------------------
# Step 1 — Compute Log returns & Volatility
# ------------------------------------------

original = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.ravel()
})

predicted = pd.DataFrame({
    'Date': dates,
    'Predicted': y_predict_orig.ravel()
})

# Compute returns from actual and predicted prices
returns_orig = original['Actual'].pct_change()
returns_pred = predicted['Predicted'].pct_change()
# Drop NaN values from returns
returns_orig = returns_orig.fillna(0)
returns_pred = returns_pred.fillna(0)

# Compute 10-day rolling volatility
volatility_orig = returns_orig.rolling(window=10).std()
volatility_pred = returns_pred.rolling(window=10).std()
volatility_orig = volatility_orig.fillna(0)
volatility_pred = volatility_pred.fillna(0)

# Update dataframes with returns and volatility
original['Returns'] = returns_orig
predicted['Returns'] = returns_pred
original['Volatility'] = volatility_orig
predicted['Volatility'] = volatility_pred

# %%
# --------------------------------
# Step 2 — Label Volatility L-M-H
# --------------------------------

# Compute quantiles as thresholds for low/med/high volatility
low_threshold = volatility_orig.quantile(0.33)   # lower 33%
high_threshold = volatility_orig.quantile(0.67)  # upper 33%

# Label volatility
def label_volatility(vol):
    if vol <= low_threshold:
        return 'low'
    elif vol >= high_threshold:
        return 'high'
    else:
        return 'medium'

# Apply volatility low/medium/high to original and prediction dataset
original['Volatility_level'] = original['Volatility'].apply(label_volatility)
predicted['Volatility_level'] = predicted['Volatility'].apply(label_volatility)

# %%
# -------------------------------
# Step 3 — Regime Classification
# -------------------------------

# Classify regime based on volatility + average sign of the returns
def classify_regime(pred_labels, vol_value, vol_threshold=(low_threshold, high_threshold), window=3):
    regimes = []
    low_threshold, high_threshold = vol_threshold

    for i in range(len(pred_labels) - window):
        window_preds = pred_labels[i:i+window]
        window_vol = vol_value[i+window]
        sign_pred = np.sign(window_preds.mean())

        if window_vol <= low_threshold:
            regimes.append("Neutral")

        else:
            if sign_pred > 0:
                regimes.append("Bull")
            elif sign_pred < 0:
                regimes.append("Bear")
            else:
                regimes.append("Uncertain")

    return regimes

vol_value = original['Volatility']
regimes = classify_regime(original['Returns'], vol_value)

# %%
####################
######  Plots ######
####################

# Plot price vs. date regime shifts in
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Actual'][3:])
plt.plot(original['Date'][3:], predicted['Predicted'][3:], color='black', alpha=0.65)

plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Neutral' for r in regimes], color='grey', alpha=0.3);

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3228268198.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot regime shift for log returns vs. date
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Returns'][3:])
plt.plot(original['Date'][3:], predicted['Returns'][3:], color='red', alpha=0.6)

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4137138025.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot price vs. date regime shift
# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = original['Actual'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift XRP Actual")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = predicted['Predicted'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift XRP Prediction")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()
