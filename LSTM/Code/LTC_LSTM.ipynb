# %%
#####################
## Litecoin (LTC)  ##
#####################

# %% [markdown]
# # **Optimized LSTM**

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install pandas

# %%
#######################
###### Libraries ######
#######################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import tensorflow as tf
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
# Set 3 seeds and record the model performance for each : 42, 45, 91
# Best seed
np.random.seed(91)
tf.random.set_seed(91)

# %%
# Load dataset without scaling

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LTC_noscale.csv')
data.drop(columns=['Crypto', 'Open', 'High', 'Low'], inplace=True)
data.head()
# Out:
#          Date   Close
# 0  2018-01-01  225.63
# 1  2018-01-02  254.60
# 2  2018-01-03  243.00
# 3  2018-01-04  240.00
# 4  2018-01-05  240.45

# %%
#################
####  Input  ####
#################

# ----------------------
# Step 1 — Normalization
# ----------------------

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['Close']].values.reshape(-1, 1))
data_scaled = pd.concat([data[['Date']].reset_index(drop=True), pd.DataFrame(scaled_data, columns=['Close'])],axis=1)


# -------------------------
# Step 2 — Train/Test split
# -------------------------

n_samples= len(scaled_data)
train_end = int(0.65 * n_samples)
val_end   = train_end + int(0.10 * n_samples)
input = scaled_data.reshape(-1)

# Train/validation/test slices
train_slice = input[:train_end]
val_slice   = input[train_end:val_end]
test_slice  = input[val_end:]

window = 120

# %%
# -------------------------------
# Step 3 — Create Sliding Windows
# -------------------------------

def sequence(data, window_size):
    data = np.asarray(data)
    data = data.reshape(-1, 1)
    T = data.shape[0]

    x = []
    y = []
    for i in range(window_size, T):
        x.append(data[i-window_size:i])
        y.append(data[i])

    x = np.array(x)
    y = np.array(y)
    return x, y

# Create Windowed sequences
x_train, y_train = sequence(train_slice, window)
x_val,   y_val   = sequence(val_slice,   window)
x_test,  y_test  = sequence(test_slice,  window)

print("x_train shape:", x_train.shape)
print("x_val shape:  ", x_val.shape)
print("x_test shape: ", x_test.shape)
print('y_train shape:', y_train.shape)
print('y_validation shape:', y_val.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (1165, 120, 1)
# x_val shape:   (77, 120, 1)
# x_test shape:  (375, 120, 1)
# y_train shape: (1165, 1)
# y_validation shape: (77, 1)
# y_test shape: (375, 1)

# %%
# ------------------------
# Step 4 — LSTM Input
# ------------------------

act_func = 'tanh'
n_timesteps = x_train.shape[1]
n_features = x_train.shape[2]

# ---------------------------
# Step 5 — LSTM structure
# ---------------------------

lstm = Sequential()
lstm.add(LSTM(64, input_shape=(n_timesteps,n_features), return_sequences=True, activation=act_func))
#lstm.add(Dropout(0.25))
lstm.add(LSTM(16, return_sequences=True, activation=act_func))
lstm.add(LSTM(2, return_sequences=False, activation=act_func))
lstm.add(Dense(1, activation='linear'))

# ----------------------------------
# Step 6 — Compile Model/Regression
# ----------------------------------

# MSE loss
lstm.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', RootMeanSquaredError(), 'mape']);
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# --------------------
# Step 7 — Training
# --------------------

history = lstm.fit(x_train, y_train,
                   epochs=120, batch_size=32,
                   validation_data=(x_val, y_val),
                   verbose=2)
# Out:
# Epoch 1/120
# 37/37 - 13s - 343ms/step - loss: 0.0119 - mae: 0.0675 - mape: 21021.3105 - root_mean_squared_error: 0.1092 - val_loss: 0.0081 - val_mae: 0.0682 - val_mape: 15.6653 - val_root_mean_squared_error: 0.0901
# Epoch 2/120
# 37/37 - 4s - 116ms/step - loss: 0.0032 - mae: 0.0330 - mape: 31510.7461 - root_mean_squared_error: 0.0568 - val_loss: 0.0072 - val_mae: 0.0665 - val_mape: 15.1246 - val_root_mean_squared_error: 0.0850
# Epoch 3/120
# 37/37 - 6s - 172ms/step - loss: 0.0030 - mae: 0.0318 - mape: 26018.9648 - root_mean_squared_error: 0.0550 - val_loss: 0.0067 - val_mae: 0.0656 - val_mape: 14.9973 - val_root_mean_squared_error: 0.0821
# Epoch 4/120
# 37/37 - 5s - 139ms/step - loss: 0.0028 - mae: 0.0302 - mape: 23887.4062 - root_mean_squared_error: 0.0527 - val_loss: 0.0061 - val_mae: 0.0628 - val_mape: 14.3061 - val_root_mean_squared_error: 0.0783
# Epoch 5/120
# 37/37 - 4s - 117ms/step - loss: 0.0026 - mae: 0.0290 - mape: 21336.1406 - root_mean_squared_error: 0.0508 - val_loss: 0.0056 - val_mae: 0.0602 - val_mape: 13.6780 - val_root_mean_squared_error: 0.0749
# Epoch 6/120
# 37/37 - 6s - 152ms/step - loss: 0.0024 - mae: 0.0279 - mape: 18729.7402 - root_mean_squared_error: 0.0489 - val_loss: 0.0052 - val_mae: 0.0577 - val_mape: 13.1058 - val_root_mean_squared_error: 0.0719
# Epoch 7/120
# 37/37 - 5s - 138ms/step - loss: 0.0022 - mae: 0.0268 - mape: 16030.3555 - root_mean_squared_error: 0.0469 - val_loss: 0.0048 - val_mae: 0.0557 - val_mape: 12.6685 - val_root_mean_squared_error: 0.0694
# Epoch 8/120
# 37/37 - 4s - 116ms/step - loss: 0.0020 - mae: 0.0257 - mape: 13477.5244 - root_mean_squared_error: 0.0447 - val_loss: 0.0047 - val_mae: 0.0555 - val_mape: 12.7470 - val_root_mean_squared_error: 0.0687
# Epoch 9/120
# 37/37 - 6s - 157ms/step - loss: 0.0018 - mae: 0.0248 - mape: 11528.7949 - root_mean_squared_error: 0.0421 - val_loss: 0.0051 - val_mae: 0.0581 - val_mape: 13.6474 - val_root_mean_squared_error: 0.0714
# Epoch 10/120
# 37/37 - 5s - 134ms/step - loss: 0.0015 - mae: 0.0241 - mape: 10362.4209 - root_mean_squared_error: 0.0393 - val_loss: 0.0058 - val_mae: 0.0616 - val_mape: 14.8697 - val_root_mean_squared_error: 0.0761
# Epoch 11/120
# 37/37 - 4s - 116ms/step - loss: 0.0014 - mae: 0.0238 - mape: 8265.0996 - root_mean_squared_error: 0.0376 - val_loss: 0.0038 - val_mae: 0.0422 - val_mape: 9.5772 - val_root_mean_squared_error: 0.0620
# Epoch 12/120
# 37/37 - 8s - 228ms/step - loss: 0.0014 - mae: 0.0232 - mape: 5870.2168 - root_mean_squared_error: 0.0369 - val_loss: 0.0035 - val_mae: 0.0408 - val_mape: 9.1193 - val_root_mean_squared_error: 0.0591
# Epoch 13/120
# 37/37 - 4s - 116ms/step - loss: 0.0012 - mae: 0.0220 - mape: 7313.1938 - root_mean_squared_error: 0.0351 - val_loss: 0.0037 - val_mae: 0.0411 - val_mape: 9.3455 - val_root_mean_squared_error: 0.0609
# Epoch 14/120
# 37/37 - 4s - 116ms/step - loss: 0.0012 - mae: 0.0211 - mape: 8597.2998 - root_mean_squared_error: 0.0340 - val_loss: 0.0037 - val_mae: 0.0410 - val_mape: 9.3455 - val_root_mean_squared_error: 0.0606
# Epoch 15/120
# 37/37 - 6s - 173ms/step - loss: 0.0011 - mae: 0.0209 - mape: 8953.4570 - root_mean_squared_error: 0.0335 - val_loss: 0.0036 - val_mae: 0.0408 - val_mape: 9.2876 - val_root_mean_squared_error: 0.0600
# Epoch 16/120
# 37/37 - 4s - 116ms/step - loss: 0.0011 - mae: 0.0206 - mape: 8940.3613 - root_mean_squared_error: 0.0330 - val_loss: 0.0035 - val_mae: 0.0405 - val_mape: 9.2171 - val_root_mean_squared_error: 0.0594
# Epoch 17/120
# 37/37 - 4s - 117ms/step - loss: 0.0010 - mae: 0.0204 - mape: 8957.5645 - root_mean_squared_error: 0.0324 - val_loss: 0.0035 - val_mae: 0.0406 - val_mape: 9.2549 - val_root_mean_squared_error: 0.0593
# Epoch 18/120
# 37/37 - 7s - 184ms/step - loss: 0.0010 - mae: 0.0201 - mape: 8951.1758 - root_mean_squared_error: 0.0318 - val_loss: 0.0036 - val_mae: 0.0411 - val_mape: 9.3698 - val_root_mean_squared_error: 0.0597
# Epoch 19/120
# 37/37 - 4s - 116ms/step - loss: 9.7798e-04 - mae: 0.0198 - mape: 8686.1973 - root_mean_squared_error: 0.0313 - val_loss: 0.0036 - val_mae: 0.0417 - val_mape: 9.5326 - val_root_mean_squared_error: 0.0603
# Epoch 20/120
# 37/37 - 6s - 164ms/step - loss: 9.4317e-04 - mae: 0.0195 - mape: 8148.4805 - root_mean_squared_error: 0.0307 - val_loss: 0.0037 - val_mae: 0.0423 - val_mape: 9.6833 - val_root_mean_squared_error: 0.0608
# Epoch 21/120
# 37/37 - 9s - 251ms/step - loss: 9.1139e-04 - mae: 0.0192 - mape: 7713.5752 - root_mean_squared_error: 0.0302 - val_loss: 0.0036 - val_mae: 0.0424 - val_mape: 9.7217 - val_root_mean_squared_error: 0.0603
# Epoch 22/120
# 37/37 - 6s - 161ms/step - loss: 8.9493e-04 - mae: 0.0191 - mape: 8123.1899 - root_mean_squared_error: 0.0299 - val_loss: 0.0033 - val_mae: 0.0412 - val_mape: 9.4083 - val_root_mean_squared_error: 0.0577
# Epoch 23/120
# 37/37 - 5s - 130ms/step - loss: 8.5997e-04 - mae: 0.0188 - mape: 7694.2651 - root_mean_squared_error: 0.0293 - val_loss: 0.0034 - val_mae: 0.0415 - val_mape: 9.4863 - val_root_mean_squared_error: 0.0581
# Epoch 24/120
# 37/37 - 4s - 118ms/step - loss: 8.4406e-04 - mae: 0.0185 - mape: 7620.6851 - root_mean_squared_error: 0.0291 - val_loss: 0.0032 - val_mae: 0.0403 - val_mape: 9.2020 - val_root_mean_squared_error: 0.0568
# Epoch 25/120
# 37/37 - 7s - 195ms/step - loss: 8.1029e-04 - mae: 0.0183 - mape: 7200.3364 - root_mean_squared_error: 0.0285 - val_loss: 0.0034 - val_mae: 0.0413 - val_mape: 9.4700 - val_root_mean_squared_error: 0.0585
# Epoch 26/120
# 37/37 - 8s - 220ms/step - loss: 8.0177e-04 - mae: 0.0180 - mape: 7019.6592 - root_mean_squared_error: 0.0283 - val_loss: 0.0032 - val_mae: 0.0397 - val_mape: 9.0868 - val_root_mean_squared_error: 0.0564
# Epoch 27/120
# 37/37 - 7s - 176ms/step - loss: 7.7966e-04 - mae: 0.0180 - mape: 6865.8682 - root_mean_squared_error: 0.0279 - val_loss: 0.0035 - val_mae: 0.0414 - val_mape: 9.5190 - val_root_mean_squared_error: 0.0588
# Epoch 28/120
# 37/37 - 4s - 117ms/step - loss: 7.7247e-04 - mae: 0.0177 - mape: 6644.6055 - root_mean_squared_error: 0.0278 - val_loss: 0.0032 - val_mae: 0.0394 - val_mape: 9.0335 - val_root_mean_squared_error: 0.0562
# Epoch 29/120
# 37/37 - 4s - 116ms/step - loss: 7.5880e-04 - mae: 0.0177 - mape: 6589.7749 - root_mean_squared_error: 0.0275 - val_loss: 0.0035 - val_mae: 0.0412 - val_mape: 9.4617 - val_root_mean_squared_error: 0.0588
# Epoch 30/120
# 37/37 - 6s - 174ms/step - loss: 7.5347e-04 - mae: 0.0175 - mape: 6354.1177 - root_mean_squared_error: 0.0274 - val_loss: 0.0032 - val_mae: 0.0394 - val_mape: 9.0369 - val_root_mean_squared_error: 0.0563
# Epoch 31/120
# 37/37 - 4s - 116ms/step - loss: 7.4518e-04 - mae: 0.0175 - mape: 6318.5498 - root_mean_squared_error: 0.0273 - val_loss: 0.0034 - val_mae: 0.0406 - val_mape: 9.3239 - val_root_mean_squared_error: 0.0582
# Epoch 32/120
# 37/37 - 4s - 118ms/step - loss: 7.4290e-04 - mae: 0.0174 - mape: 6102.2300 - root_mean_squared_error: 0.0273 - val_loss: 0.0032 - val_mae: 0.0393 - val_mape: 9.0101 - val_root_mean_squared_error: 0.0562
# Epoch 33/120
# 37/37 - 7s - 195ms/step - loss: 7.3641e-04 - mae: 0.0175 - mape: 6062.2856 - root_mean_squared_error: 0.0271 - val_loss: 0.0033 - val_mae: 0.0398 - val_mape: 9.1443 - val_root_mean_squared_error: 0.0570
# Epoch 34/120
# 37/37 - 4s - 117ms/step - loss: 7.3319e-04 - mae: 0.0174 - mape: 5913.5249 - root_mean_squared_error: 0.0271 - val_loss: 0.0031 - val_mae: 0.0389 - val_mape: 8.9354 - val_root_mean_squared_error: 0.0558
# Epoch 35/120
# 37/37 - 4s - 116ms/step - loss: 7.2512e-04 - mae: 0.0173 - mape: 5842.3960 - root_mean_squared_error: 0.0269 - val_loss: 0.0031 - val_mae: 0.0390 - val_mape: 8.9592 - val_root_mean_squared_error: 0.0558
# Epoch 36/120
# 37/37 - 6s - 174ms/step - loss: 7.1862e-04 - mae: 0.0173 - mape: 5708.6226 - root_mean_squared_error: 0.0268 - val_loss: 0.0030 - val_mae: 0.0385 - val_mape: 8.8399 - val_root_mean_squared_error: 0.0551
# Epoch 37/120
# 37/37 - 4s - 118ms/step - loss: 7.1013e-04 - mae: 0.0172 - mape: 5598.9141 - root_mean_squared_error: 0.0266 - val_loss: 0.0030 - val_mae: 0.0383 - val_mape: 8.7984 - val_root_mean_squared_error: 0.0549
# Epoch 38/120
# 37/37 - 5s - 123ms/step - loss: 7.0247e-04 - mae: 0.0171 - mape: 5466.8296 - root_mean_squared_error: 0.0265 - val_loss: 0.0030 - val_mae: 0.0380 - val_mape: 8.7157 - val_root_mean_squared_error: 0.0544
# Epoch 39/120
# 37/37 - 6s - 173ms/step - loss: 6.9451e-04 - mae: 0.0170 - mape: 5347.6011 - root_mean_squared_error: 0.0264 - val_loss: 0.0029 - val_mae: 0.0377 - val_mape: 8.6513 - val_root_mean_squared_error: 0.0540
# Epoch 40/120
# 37/37 - 4s - 117ms/step - loss: 6.8695e-04 - mae: 0.0169 - mape: 5221.5371 - root_mean_squared_error: 0.0262 - val_loss: 0.0029 - val_mae: 0.0374 - val_mape: 8.5771 - val_root_mean_squared_error: 0.0536
# Epoch 41/120
# 37/37 - 5s - 139ms/step - loss: 6.7947e-04 - mae: 0.0168 - mape: 5101.3135 - root_mean_squared_error: 0.0261 - val_loss: 0.0028 - val_mae: 0.0371 - val_mape: 8.5120 - val_root_mean_squared_error: 0.0532
# Epoch 42/120
# 37/37 - 6s - 152ms/step - loss: 6.7219e-04 - mae: 0.0167 - mape: 4980.3037 - root_mean_squared_error: 0.0259 - val_loss: 0.0028 - val_mae: 0.0368 - val_mape: 8.4412 - val_root_mean_squared_error: 0.0527
# Epoch 43/120
# 37/37 - 4s - 116ms/step - loss: 6.6507e-04 - mae: 0.0166 - mape: 4864.7583 - root_mean_squared_error: 0.0258 - val_loss: 0.0027 - val_mae: 0.0366 - val_mape: 8.3670 - val_root_mean_squared_error: 0.0523
# Epoch 44/120
# 37/37 - 5s - 141ms/step - loss: 6.5825e-04 - mae: 0.0166 - mape: 4753.6821 - root_mean_squared_error: 0.0257 - val_loss: 0.0027 - val_mae: 0.0363 - val_mape: 8.2928 - val_root_mean_squared_error: 0.0518
# Epoch 45/120
# 37/37 - 5s - 148ms/step - loss: 6.5192e-04 - mae: 0.0165 - mape: 4646.5762 - root_mean_squared_error: 0.0255 - val_loss: 0.0026 - val_mae: 0.0359 - val_mape: 8.2172 - val_root_mean_squared_error: 0.0514
# Epoch 46/120
# 37/37 - 10s - 283ms/step - loss: 6.4617e-04 - mae: 0.0164 - mape: 4536.8325 - root_mean_squared_error: 0.0254 - val_loss: 0.0026 - val_mae: 0.0357 - val_mape: 8.1447 - val_root_mean_squared_error: 0.0509
# Epoch 47/120
# 37/37 - 5s - 134ms/step - loss: 6.4079e-04 - mae: 0.0164 - mape: 4414.8862 - root_mean_squared_error: 0.0253 - val_loss: 0.0026 - val_mae: 0.0354 - val_mape: 8.0778 - val_root_mean_squared_error: 0.0505
# Epoch 48/120
# 37/37 - 4s - 117ms/step - loss: 6.3530e-04 - mae: 0.0163 - mape: 4267.6084 - root_mean_squared_error: 0.0252 - val_loss: 0.0025 - val_mae: 0.0351 - val_mape: 8.0161 - val_root_mean_squared_error: 0.0502
# Epoch 49/120
# 37/37 - 7s - 196ms/step - loss: 6.2940e-04 - mae: 0.0162 - mape: 4103.7373 - root_mean_squared_error: 0.0251 - val_loss: 0.0025 - val_mae: 0.0349 - val_mape: 7.9591 - val_root_mean_squared_error: 0.0498
# Epoch 50/120
# 37/37 - 4s - 119ms/step - loss: 6.2319e-04 - mae: 0.0161 - mape: 3951.6777 - root_mean_squared_error: 0.0250 - val_loss: 0.0025 - val_mae: 0.0347 - val_mape: 7.9097 - val_root_mean_squared_error: 0.0495
# Epoch 51/120
# 37/37 - 5s - 137ms/step - loss: 6.1697e-04 - mae: 0.0161 - mape: 3813.2039 - root_mean_squared_error: 0.0248 - val_loss: 0.0024 - val_mae: 0.0345 - val_mape: 7.8623 - val_root_mean_squared_error: 0.0493
# Epoch 52/120
# 37/37 - 6s - 174ms/step - loss: 6.1084e-04 - mae: 0.0160 - mape: 3672.1755 - root_mean_squared_error: 0.0247 - val_loss: 0.0024 - val_mae: 0.0343 - val_mape: 7.8132 - val_root_mean_squared_error: 0.0490
# Epoch 53/120
# 37/37 - 8s - 220ms/step - loss: 6.0481e-04 - mae: 0.0159 - mape: 3523.5381 - root_mean_squared_error: 0.0246 - val_loss: 0.0024 - val_mae: 0.0341 - val_mape: 7.7620 - val_root_mean_squared_error: 0.0487
# Epoch 54/120
# 37/37 - 7s - 191ms/step - loss: 5.9886e-04 - mae: 0.0158 - mape: 3375.2793 - root_mean_squared_error: 0.0245 - val_loss: 0.0024 - val_mae: 0.0339 - val_mape: 7.7102 - val_root_mean_squared_error: 0.0485
# Epoch 55/120
# 37/37 - 4s - 119ms/step - loss: 5.9303e-04 - mae: 0.0157 - mape: 3227.8340 - root_mean_squared_error: 0.0244 - val_loss: 0.0023 - val_mae: 0.0337 - val_mape: 7.6573 - val_root_mean_squared_error: 0.0482
# Epoch 56/120
# 37/37 - 5s - 125ms/step - loss: 5.8730e-04 - mae: 0.0157 - mape: 3077.5913 - root_mean_squared_error: 0.0242 - val_loss: 0.0023 - val_mae: 0.0335 - val_mape: 7.6027 - val_root_mean_squared_error: 0.0480
# Epoch 57/120
# 37/37 - 6s - 166ms/step - loss: 5.8164e-04 - mae: 0.0156 - mape: 2924.4229 - root_mean_squared_error: 0.0241 - val_loss: 0.0023 - val_mae: 0.0333 - val_mape: 7.5479 - val_root_mean_squared_error: 0.0477
# Epoch 58/120
# 37/37 - 4s - 119ms/step - loss: 5.7605e-04 - mae: 0.0155 - mape: 2770.7732 - root_mean_squared_error: 0.0240 - val_loss: 0.0023 - val_mae: 0.0331 - val_mape: 7.4962 - val_root_mean_squared_error: 0.0475
# Epoch 59/120
# 37/37 - 6s - 165ms/step - loss: 5.7052e-04 - mae: 0.0154 - mape: 2616.6611 - root_mean_squared_error: 0.0239 - val_loss: 0.0022 - val_mae: 0.0329 - val_mape: 7.4472 - val_root_mean_squared_error: 0.0472
# Epoch 60/120
# 37/37 - 5s - 145ms/step - loss: 5.6504e-04 - mae: 0.0154 - mape: 2461.3003 - root_mean_squared_error: 0.0238 - val_loss: 0.0022 - val_mae: 0.0327 - val_mape: 7.4013 - val_root_mean_squared_error: 0.0470
# Epoch 61/120
# 37/37 - 11s - 297ms/step - loss: 5.5961e-04 - mae: 0.0153 - mape: 2305.0498 - root_mean_squared_error: 0.0237 - val_loss: 0.0022 - val_mae: 0.0325 - val_mape: 7.3539 - val_root_mean_squared_error: 0.0467
# Epoch 62/120
# 37/37 - 9s - 230ms/step - loss: 5.5422e-04 - mae: 0.0152 - mape: 2148.4014 - root_mean_squared_error: 0.0235 - val_loss: 0.0022 - val_mae: 0.0324 - val_mape: 7.3053 - val_root_mean_squared_error: 0.0464
# Epoch 63/120
# 37/37 - 6s - 167ms/step - loss: 5.4887e-04 - mae: 0.0151 - mape: 1991.5391 - root_mean_squared_error: 0.0234 - val_loss: 0.0021 - val_mae: 0.0322 - val_mape: 7.2571 - val_root_mean_squared_error: 0.0462
# Epoch 64/120
# 37/37 - 5s - 124ms/step - loss: 5.4357e-04 - mae: 0.0151 - mape: 1834.5178 - root_mean_squared_error: 0.0233 - val_loss: 0.0021 - val_mae: 0.0320 - val_mape: 7.2096 - val_root_mean_squared_error: 0.0459
# Epoch 65/120
# 37/37 - 5s - 131ms/step - loss: 5.3831e-04 - mae: 0.0150 - mape: 1677.7247 - root_mean_squared_error: 0.0232 - val_loss: 0.0021 - val_mae: 0.0318 - val_mape: 7.1631 - val_root_mean_squared_error: 0.0457
# Epoch 66/120
# 37/37 - 6s - 173ms/step - loss: 5.3310e-04 - mae: 0.0149 - mape: 1521.7275 - root_mean_squared_error: 0.0231 - val_loss: 0.0021 - val_mae: 0.0316 - val_mape: 7.1156 - val_root_mean_squared_error: 0.0454
# Epoch 67/120
# 37/37 - 4s - 117ms/step - loss: 5.2795e-04 - mae: 0.0148 - mape: 1367.1588 - root_mean_squared_error: 0.0230 - val_loss: 0.0020 - val_mae: 0.0314 - val_mape: 7.0678 - val_root_mean_squared_error: 0.0452
# Epoch 68/120
# 37/37 - 5s - 138ms/step - loss: 5.2287e-04 - mae: 0.0147 - mape: 1214.9231 - root_mean_squared_error: 0.0229 - val_loss: 0.0020 - val_mae: 0.0312 - val_mape: 7.0232 - val_root_mean_squared_error: 0.0449
# Epoch 69/120
# 37/37 - 7s - 181ms/step - loss: 5.1786e-04 - mae: 0.0147 - mape: 1065.8623 - root_mean_squared_error: 0.0228 - val_loss: 0.0020 - val_mae: 0.0311 - val_mape: 6.9827 - val_root_mean_squared_error: 0.0447
# Epoch 70/120
# 37/37 - 9s - 252ms/step - loss: 5.1294e-04 - mae: 0.0146 - mape: 921.2543 - root_mean_squared_error: 0.0226 - val_loss: 0.0020 - val_mae: 0.0309 - val_mape: 6.9411 - val_root_mean_squared_error: 0.0444
# Epoch 71/120
# 37/37 - 6s - 158ms/step - loss: 5.0811e-04 - mae: 0.0145 - mape: 782.5463 - root_mean_squared_error: 0.0225 - val_loss: 0.0019 - val_mae: 0.0307 - val_mape: 6.8998 - val_root_mean_squared_error: 0.0441
# Epoch 72/120
# 37/37 - 4s - 117ms/step - loss: 5.0339e-04 - mae: 0.0144 - mape: 651.3701 - root_mean_squared_error: 0.0224 - val_loss: 0.0019 - val_mae: 0.0305 - val_mape: 6.8590 - val_root_mean_squared_error: 0.0439
# Epoch 73/120
# 37/37 - 5s - 141ms/step - loss: 4.9878e-04 - mae: 0.0143 - mape: 529.6343 - root_mean_squared_error: 0.0223 - val_loss: 0.0019 - val_mae: 0.0303 - val_mape: 6.8172 - val_root_mean_squared_error: 0.0436
# Epoch 74/120
# 37/37 - 6s - 150ms/step - loss: 4.9431e-04 - mae: 0.0143 - mape: 419.9591 - root_mean_squared_error: 0.0222 - val_loss: 0.0019 - val_mae: 0.0302 - val_mape: 6.7761 - val_root_mean_squared_error: 0.0434
# Epoch 75/120
# 37/37 - 10s - 276ms/step - loss: 4.8997e-04 - mae: 0.0142 - mape: 325.7269 - root_mean_squared_error: 0.0221 - val_loss: 0.0019 - val_mae: 0.0300 - val_mape: 6.7350 - val_root_mean_squared_error: 0.0431
# Epoch 76/120
# 37/37 - 5s - 138ms/step - loss: 4.8580e-04 - mae: 0.0141 - mape: 251.9990 - root_mean_squared_error: 0.0220 - val_loss: 0.0018 - val_mae: 0.0298 - val_mape: 6.6924 - val_root_mean_squared_error: 0.0429
# Epoch 77/120
# 37/37 - 4s - 118ms/step - loss: 4.8182e-04 - mae: 0.0140 - mape: 206.8539 - root_mean_squared_error: 0.0220 - val_loss: 0.0018 - val_mae: 0.0296 - val_mape: 6.6468 - val_root_mean_squared_error: 0.0426
# Epoch 78/120
# 37/37 - 7s - 193ms/step - loss: 4.7808e-04 - mae: 0.0139 - mape: 201.6974 - root_mean_squared_error: 0.0219 - val_loss: 0.0018 - val_mae: 0.0293 - val_mape: 6.5978 - val_root_mean_squared_error: 0.0423
# Epoch 79/120
# 37/37 - 8s - 222ms/step - loss: 4.7459e-04 - mae: 0.0138 - mape: 240.4994 - root_mean_squared_error: 0.0218 - val_loss: 0.0018 - val_mae: 0.0291 - val_mape: 6.5526 - val_root_mean_squared_error: 0.0421
# Epoch 80/120
# 37/37 - 7s - 194ms/step - loss: 4.7124e-04 - mae: 0.0137 - mape: 273.3275 - root_mean_squared_error: 0.0217 - val_loss: 0.0017 - val_mae: 0.0289 - val_mape: 6.5186 - val_root_mean_squared_error: 0.0418
# Epoch 81/120
# 37/37 - 4s - 117ms/step - loss: 4.6796e-04 - mae: 0.0137 - mape: 227.5561 - root_mean_squared_error: 0.0216 - val_loss: 0.0017 - val_mae: 0.0287 - val_mape: 6.4732 - val_root_mean_squared_error: 0.0415
# Epoch 82/120
# 37/37 - 4s - 116ms/step - loss: 4.6480e-04 - mae: 0.0136 - mape: 181.1420 - root_mean_squared_error: 0.0216 - val_loss: 0.0017 - val_mae: 0.0285 - val_mape: 6.4231 - val_root_mean_squared_error: 0.0412
# Epoch 83/120
# 37/37 - 7s - 194ms/step - loss: 4.6190e-04 - mae: 0.0135 - mape: 169.0291 - root_mean_squared_error: 0.0215 - val_loss: 0.0017 - val_mae: 0.0283 - val_mape: 6.3734 - val_root_mean_squared_error: 0.0409
# Epoch 84/120
# 37/37 - 4s - 117ms/step - loss: 4.5907e-04 - mae: 0.0135 - mape: 159.9066 - root_mean_squared_error: 0.0214 - val_loss: 0.0017 - val_mae: 0.0281 - val_mape: 6.3291 - val_root_mean_squared_error: 0.0407
# Epoch 85/120
# 37/37 - 4s - 117ms/step - loss: 4.5648e-04 - mae: 0.0134 - mape: 157.2496 - root_mean_squared_error: 0.0214 - val_loss: 0.0016 - val_mae: 0.0279 - val_mape: 6.2847 - val_root_mean_squared_error: 0.0404
# Epoch 86/120
# 37/37 - 7s - 177ms/step - loss: 4.5399e-04 - mae: 0.0134 - mape: 156.4541 - root_mean_squared_error: 0.0213 - val_loss: 0.0016 - val_mae: 0.0277 - val_mape: 6.2443 - val_root_mean_squared_error: 0.0402
# Epoch 87/120
# 37/37 - 10s - 258ms/step - loss: 4.5169e-04 - mae: 0.0133 - mape: 163.0272 - root_mean_squared_error: 0.0213 - val_loss: 0.0016 - val_mae: 0.0275 - val_mape: 6.2036 - val_root_mean_squared_error: 0.0400
# Epoch 88/120
# 37/37 - 9s - 255ms/step - loss: 4.4942e-04 - mae: 0.0133 - mape: 173.2936 - root_mean_squared_error: 0.0212 - val_loss: 0.0016 - val_mae: 0.0273 - val_mape: 6.1668 - val_root_mean_squared_error: 0.0398
# Epoch 89/120
# 37/37 - 6s - 160ms/step - loss: 4.4731e-04 - mae: 0.0133 - mape: 191.4779 - root_mean_squared_error: 0.0211 - val_loss: 0.0016 - val_mae: 0.0271 - val_mape: 6.1290 - val_root_mean_squared_error: 0.0396
# Epoch 90/120
# 37/37 - 5s - 130ms/step - loss: 4.4518e-04 - mae: 0.0132 - mape: 215.2488 - root_mean_squared_error: 0.0211 - val_loss: 0.0016 - val_mae: 0.0270 - val_mape: 6.0957 - val_root_mean_squared_error: 0.0394
# Epoch 91/120
# 37/37 - 5s - 125ms/step - loss: 4.4317e-04 - mae: 0.0132 - mape: 246.6825 - root_mean_squared_error: 0.0211 - val_loss: 0.0015 - val_mae: 0.0268 - val_mape: 6.0626 - val_root_mean_squared_error: 0.0392
# Epoch 92/120
# 37/37 - 6s - 165ms/step - loss: 4.4107e-04 - mae: 0.0131 - mape: 284.7548 - root_mean_squared_error: 0.0210 - val_loss: 0.0015 - val_mae: 0.0267 - val_mape: 6.0356 - val_root_mean_squared_error: 0.0391
# Epoch 93/120
# 37/37 - 5s - 123ms/step - loss: 4.3910e-04 - mae: 0.0131 - mape: 328.2797 - root_mean_squared_error: 0.0210 - val_loss: 0.0015 - val_mae: 0.0266 - val_mape: 6.0045 - val_root_mean_squared_error: 0.0390
# Epoch 94/120
# 37/37 - 4s - 118ms/step - loss: 4.3698e-04 - mae: 0.0130 - mape: 378.5374 - root_mean_squared_error: 0.0209 - val_loss: 0.0015 - val_mae: 0.0265 - val_mape: 5.9812 - val_root_mean_squared_error: 0.0389
# Epoch 95/120
# 37/37 - 6s - 173ms/step - loss: 4.3502e-04 - mae: 0.0130 - mape: 430.1923 - root_mean_squared_error: 0.0209 - val_loss: 0.0015 - val_mae: 0.0263 - val_mape: 5.9509 - val_root_mean_squared_error: 0.0388
# Epoch 96/120
# 37/37 - 4s - 118ms/step - loss: 4.3283e-04 - mae: 0.0129 - mape: 488.4556 - root_mean_squared_error: 0.0208 - val_loss: 0.0015 - val_mae: 0.0262 - val_mape: 5.9321 - val_root_mean_squared_error: 0.0387
# Epoch 97/120
# 37/37 - 5s - 138ms/step - loss: 4.3090e-04 - mae: 0.0129 - mape: 542.3548 - root_mean_squared_error: 0.0208 - val_loss: 0.0015 - val_mae: 0.0261 - val_mape: 5.9032 - val_root_mean_squared_error: 0.0386
# Epoch 98/120
# 37/37 - 7s - 192ms/step - loss: 4.2863e-04 - mae: 0.0128 - mape: 604.2324 - root_mean_squared_error: 0.0207 - val_loss: 0.0015 - val_mae: 0.0261 - val_mape: 5.8975 - val_root_mean_squared_error: 0.0385
# Epoch 99/120
# 37/37 - 8s - 224ms/step - loss: 4.2677e-04 - mae: 0.0128 - mape: 654.3804 - root_mean_squared_error: 0.0207 - val_loss: 0.0015 - val_mae: 0.0260 - val_mape: 5.8696 - val_root_mean_squared_error: 0.0384
# Epoch 100/120
# 37/37 - 6s - 173ms/step - loss: 4.2443e-04 - mae: 0.0127 - mape: 716.7515 - root_mean_squared_error: 0.0206 - val_loss: 0.0015 - val_mae: 0.0260 - val_mape: 5.8713 - val_root_mean_squared_error: 0.0384
# Epoch 101/120
# 37/37 - 8s - 221ms/step - loss: 4.2272e-04 - mae: 0.0127 - mape: 758.5089 - root_mean_squared_error: 0.0206 - val_loss: 0.0015 - val_mae: 0.0259 - val_mape: 5.8413 - val_root_mean_squared_error: 0.0383
# Epoch 102/120
# 37/37 - 6s - 174ms/step - loss: 4.2026e-04 - mae: 0.0126 - mape: 820.1212 - root_mean_squared_error: 0.0205 - val_loss: 0.0015 - val_mae: 0.0259 - val_mape: 5.8525 - val_root_mean_squared_error: 0.0383
# Epoch 103/120
# 37/37 - 4s - 116ms/step - loss: 4.1879e-04 - mae: 0.0126 - mape: 850.3284 - root_mean_squared_error: 0.0205 - val_loss: 0.0015 - val_mae: 0.0257 - val_mape: 5.8132 - val_root_mean_squared_error: 0.0381
# Epoch 104/120
# 37/37 - 6s - 158ms/step - loss: 4.1616e-04 - mae: 0.0125 - mape: 911.6301 - root_mean_squared_error: 0.0204 - val_loss: 0.0015 - val_mae: 0.0259 - val_mape: 5.8380 - val_root_mean_squared_error: 0.0382
# Epoch 105/120
# 37/37 - 6s - 156ms/step - loss: 4.1504e-04 - mae: 0.0125 - mape: 928.5380 - root_mean_squared_error: 0.0204 - val_loss: 0.0014 - val_mae: 0.0256 - val_mape: 5.7843 - val_root_mean_squared_error: 0.0380
# Epoch 106/120
# 37/37 - 4s - 116ms/step - loss: 4.1216e-04 - mae: 0.0125 - mape: 990.3569 - root_mean_squared_error: 0.0203 - val_loss: 0.0015 - val_mae: 0.0258 - val_mape: 5.8286 - val_root_mean_squared_error: 0.0381
# Epoch 107/120
# 37/37 - 5s - 135ms/step - loss: 4.1154e-04 - mae: 0.0124 - mape: 994.0604 - root_mean_squared_error: 0.0203 - val_loss: 0.0014 - val_mae: 0.0255 - val_mape: 5.7548 - val_root_mean_squared_error: 0.0378
# Epoch 108/120
# 37/37 - 6s - 154ms/step - loss: 4.0826e-04 - mae: 0.0124 - mape: 1056.1467 - root_mean_squared_error: 0.0202 - val_loss: 0.0015 - val_mae: 0.0258 - val_mape: 5.8272 - val_root_mean_squared_error: 0.0381
# Epoch 109/120
# 37/37 - 4s - 116ms/step - loss: 4.0830e-04 - mae: 0.0123 - mape: 1049.6973 - root_mean_squared_error: 0.0202 - val_loss: 0.0014 - val_mae: 0.0254 - val_mape: 5.7228 - val_root_mean_squared_error: 0.0377
# Epoch 110/120
# 37/37 - 6s - 175ms/step - loss: 4.0448e-04 - mae: 0.0123 - mape: 1108.4292 - root_mean_squared_error: 0.0201 - val_loss: 0.0014 - val_mae: 0.0258 - val_mape: 5.8311 - val_root_mean_squared_error: 0.0381
# Epoch 111/120
# 37/37 - 9s - 240ms/step - loss: 4.0533e-04 - mae: 0.0123 - mape: 1099.8029 - root_mean_squared_error: 0.0201 - val_loss: 0.0014 - val_mae: 0.0252 - val_mape: 5.6898 - val_root_mean_squared_error: 0.0375
# Epoch 112/120
# 37/37 - 7s - 194ms/step - loss: 4.0089e-04 - mae: 0.0122 - mape: 1146.5129 - root_mean_squared_error: 0.0200 - val_loss: 0.0014 - val_mae: 0.0259 - val_mape: 5.8343 - val_root_mean_squared_error: 0.0380
# Epoch 113/120
# 37/37 - 8s - 220ms/step - loss: 4.0247e-04 - mae: 0.0122 - mape: 1147.9839 - root_mean_squared_error: 0.0201 - val_loss: 0.0014 - val_mae: 0.0251 - val_mape: 5.6616 - val_root_mean_squared_error: 0.0374
# Epoch 114/120
# 37/37 - 7s - 176ms/step - loss: 3.9748e-04 - mae: 0.0121 - mape: 1170.7975 - root_mean_squared_error: 0.0199 - val_loss: 0.0014 - val_mae: 0.0259 - val_mape: 5.8331 - val_root_mean_squared_error: 0.0380
# Epoch 115/120
# 37/37 - 4s - 117ms/step - loss: 3.9951e-04 - mae: 0.0121 - mape: 1193.4230 - root_mean_squared_error: 0.0200 - val_loss: 0.0014 - val_mae: 0.0251 - val_mape: 5.6452 - val_root_mean_squared_error: 0.0373
# Epoch 116/120
# 37/37 - 5s - 138ms/step - loss: 3.9425e-04 - mae: 0.0121 - mape: 1183.9298 - root_mean_squared_error: 0.0199 - val_loss: 0.0014 - val_mae: 0.0258 - val_mape: 5.8268 - val_root_mean_squared_error: 0.0380
# Epoch 117/120
# 37/37 - 7s - 188ms/step - loss: 3.9637e-04 - mae: 0.0120 - mape: 1232.0326 - root_mean_squared_error: 0.0199 - val_loss: 0.0014 - val_mae: 0.0251 - val_mape: 5.6461 - val_root_mean_squared_error: 0.0372
# Epoch 118/120
# 37/37 - 8s - 228ms/step - loss: 3.9117e-04 - mae: 0.0120 - mape: 1188.2642 - root_mean_squared_error: 0.0198 - val_loss: 0.0014 - val_mae: 0.0258 - val_mape: 5.8198 - val_root_mean_squared_error: 0.0379
# Epoch 119/120
# 37/37 - 6s - 175ms/step - loss: 3.9319e-04 - mae: 0.0120 - mape: 1260.6104 - root_mean_squared_error: 0.0198 - val_loss: 0.0014 - val_mae: 0.0251 - val_mape: 5.6569 - val_root_mean_squared_error: 0.0372
# Epoch 120/120
# 37/37 - 4s - 116ms/step - loss: 3.8825e-04 - mae: 0.0119 - mape: 1185.0750 - root_mean_squared_error: 0.0197 - val_loss: 0.0014 - val_mae: 0.0258 - val_mape: 5.8145 - val_root_mean_squared_error: 0.0378

# %%
####################
### Plot Results ###
####################

# Training MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['loss'], label='MSE')
ax[0, 0].set_title('Training Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0, 0].grid(True)

# Training MAE
ax[0, 1].plot(history.history['mae'], label='MAE', color='black')
ax[0, 1].set_title('Training MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0, 1].grid(True)

# Training RMSe
ax[1, 0].plot(history.history['root_mean_squared_error'], label='RMSE', color='green')
ax[1, 0].set_title('Training RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1, 0].grid(True)

# Training MAPE
ax[1, 1].plot(history.history['mape'], label='MAPE', color='red')
ax[1, 1].set_title('Training MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Validation MSE
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(history.history['val_loss'][1:], label='Val MSE')
ax[0, 0].set_title('Validation Loss')
ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Loss')
ax[0, 0].legend()
ax[0,0].grid(True)

# Validation MAE
ax[0, 1].plot(history.history['val_mae'][1:], label='Val MAE')
ax[0, 1].set_title('Validation MAE')
ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('MAE')
ax[0, 1].legend()
ax[0,1].grid(True)

# Validation RMSE
ax[1, 0].plot(history.history['val_root_mean_squared_error'][1:], label='Val RMSE')
ax[1, 0].set_title('Validation RMSE')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('RMSE')
ax[1, 0].legend()
ax[1,0].grid(True)


# Validation MAPE
ax[1, 1].plot(history.history['val_mape'][1:], label='Val MAPE')
ax[1, 1].set_title('Validation MAPE')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('MAPE')
ax[1, 1].legend()
ax[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Store best training/validation metrics
# Training
train_mse = history.history['loss']
best_epoch = np.argmin(train_mse)
best_train_mse = train_mse[best_epoch]
best_train_rmse = history.history['root_mean_squared_error'][best_epoch]
best_train_mae  = history.history['mae'][best_epoch]
best_train_mape = history.history['mape'][best_epoch]

# Validation: record epoch at which validation loss is the lowest for each seed
val_mse = history.history['val_loss']
best_epoch = np.argmin(val_mse)
best_val_mse = val_mse[best_epoch]
best_val_rmse = history.history['val_root_mean_squared_error'][best_epoch]
best_val_mae  = history.history['val_mae'][best_epoch]
best_val_mape = history.history['val_mape'][best_epoch]

# %%
# -------------------------
# Step 8 — Predict/Testing
# -------------------------

y_predict= lstm.predict(x_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step

# %%
# -----------------------------------
# Step 9 — Test MSE/RMSE/MAE/MAPE/R2
# -----------------------------------

# Compute the loss metrics
test_mse = mean_squared_error(y_test, y_predict)
test_rmse = root_mean_squared_error(y_test, y_predict)
test_mae = mean_absolute_error(y_test, y_predict)
test_mape = mean_absolute_percentage_error(y_test, y_predict)
test_r2_score = r2_score(y_test, y_predict)

print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Mean Absolute Error:", test_mae)
print("Mean Absolute Percentage Error:", test_mape)
print("R2 Score:", test_r2_score)
# Out:
# Mean Squared Error: 9.833012386856379e-05
# Root Mean Squared Error: 0.009916154691641503
# Mean Absolute Error: 0.007384847140831289
# Mean Absolute Percentage Error: 0.05726127404679151
# R2 Score: 0.9533976714950462

# %%
#-------------------------------------------------
# Step 10 - Inverse scaling: original price scale
#-------------------------------------------------

y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))
y_predict_orig = scaler.inverse_transform(y_predict)

# %%
#----------------------------------------------
# Step 11 - Plot prediction vs. actuals prices
#----------------------------------------------

# Add window size to test idx
start_index = 1482 + 120
# Test set dates range + convert to datetime
dates = data['Date'].iloc[start_index:start_index + len(y_test_orig)].reset_index(drop=True)
dates = pd.to_datetime(dates)

# Plot the actual vs predicted prices
plt.figure(figsize=(12, 5))
plt.plot(dates, y_test_orig, label='Actual', linewidth=2)
plt.plot(dates, y_predict_orig, label='Predicted', color='red')
plt.title('Actual vs Predicted Litecoin Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#--------------------------
# Step 12 - Export results
#--------------------------

# Export prediction dataset
predictions_df = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.flatten(),
    'Predicted': y_predict_orig.flatten()
})

predictions_df.to_csv('LTC_lstm_predictions.csv', index=False)

from google.colab import files
files.download('LTC_lstm_predictions.csv')

# %%
# Store metrics in dataframe along with best training/validation loss (record epoch)
results = {
    "seed": 91,
    "best_epoch": best_epoch + 1,    # best validation epoch
    "train_mse": best_train_mse,
    "train_rmse": best_train_rmse,
    "train_mae": best_train_mae,
    "train_mape": best_train_mape,
    "val_mse": best_val_mse,
    "val_rmse": best_val_rmse,
    "val_mae": best_val_mae,
    "val_mape": best_val_mape,
    "test_mse": test_mse,
    "test_rmse": test_rmse,
    "test_mae": test_mae,
    "test_mape": test_mape,
    "test_r2_score": test_r2_score
}

ltc_results = pd.DataFrame([results])
ltc_results.to_csv('ltc_lstm_results.csv')

files.download('ltc_lstm_results.csv')

# %%
# Export loss results
loss_results = pd.DataFrame(history.history)
loss_results.to_csv('loss_ltc_results.csv')

files.download('loss_ltc_results.csv')

# %% [markdown]
# # **Regime Classification**

# %%
# ------------------------------------------
# Step 1 — Compute Log returns & Volatility
# ------------------------------------------

original = pd.DataFrame({
    'Date': dates,
    'Actual': y_test_orig.ravel()
})

predicted = pd.DataFrame({
    'Date': dates,
    'Predicted': y_predict_orig.ravel()
})

# Compute returns from actual and predicted prices
returns_orig = original['Actual'].pct_change()
returns_pred = predicted['Predicted'].pct_change()
# Drop NaN values from returns
returns_orig = returns_orig.fillna(0)
returns_pred = returns_pred.fillna(0)

# Compute 10-day rolling volatility
volatility_orig = returns_orig.rolling(window=10).std()
volatility_pred = returns_pred.rolling(window=10).std()
volatility_orig = volatility_orig.fillna(0)
volatility_pred = volatility_pred.fillna(0)

# Update dataframes with returns and volatility
original['Returns'] = returns_orig
predicted['Returns'] = returns_pred
original['Volatility'] = volatility_orig
predicted['Volatility'] = volatility_pred

# %%
# --------------------------------
# Step 2 — Label Volatility L-M-H
# --------------------------------

# Compute quantiles as thresholds for low/med/high volatility
low_threshold = volatility_orig.quantile(0.33)   # lower 33%
high_threshold = volatility_orig.quantile(0.67)  # upper 33%

# Label volatility
def label_volatility(vol):
    if vol <= low_threshold:
        return 'low'
    elif vol >= high_threshold:
        return 'high'
    else:
        return 'medium'

# Apply volatility low/medium/high to original and prediction dataset
original['Volatility_level'] = original['Volatility'].apply(label_volatility)
predicted['Volatility_level'] = predicted['Volatility'].apply(label_volatility)

# %%
# -------------------------------
# Step 3 — Regime Classification
# -------------------------------

# Classify regime based on volatility + average sign of the returns
def classify_regime(pred_labels, vol_value, vol_threshold=(low_threshold, high_threshold), window=3):
    regimes = []
    low_threshold, high_threshold = vol_threshold

    for i in range(len(pred_labels) - window):
        window_preds = pred_labels[i:i+window]
        window_vol = vol_value[i+window]
        sign_pred = np.sign(window_preds.mean())

        if window_vol <= low_threshold:
            regimes.append("Neutral")

        else:
            if sign_pred > 0:
                regimes.append("Bull")
            elif sign_pred < 0:
                regimes.append("Bear")
            else:
                regimes.append("Uncertain")

    return regimes

vol_value = original['Volatility']
regimes = classify_regime(original['Returns'], vol_value)

# %%
####################
######  Plots ######
####################

# Plot price vs. date regime shifts in
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Actual'][3:])
plt.plot(original['Date'][3:], predicted['Predicted'][3:], color='black', alpha=0.65)

plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bull' for r in regimes], color='green', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Bear' for r in regimes], color='red', alpha=0.4);
plt.fill_between(original['Date'][3:], predicted['Predicted'][3:], where=[r == 'Neutral' for r in regimes], color='grey', alpha=0.3);

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3228268198.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot regime shift for log returns vs. date
plt.figure(figsize=(12, 5))
plt.plot(original['Date'][3:], original['Returns'][3:])
plt.plot(original['Date'][3:], predicted['Returns'][3:], color='red', alpha=0.6)

N = len(original['Date'][3:]) // 5
xticks = original['Date'][3::N]
plt.xticks(xticks);

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4137138025.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot price vs. date regime shift
# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = original['Actual'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Litecoin Actual")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot price vs. date regime shift

# Select dates, prices values and convert to matplotlib format
# Plot each segment
dates = pd.to_datetime(original['Date'][3:])
prices = predicted['Predicted'][3:].values
x = mdates.date2num(dates)
points = np.array([x, prices]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Map each regime to color & add legend to plot
color_map = {'Bull': 'green', 'Bear': 'red', 'Neutral': 'black', 'Uncertain':'blue'}
colors = [color_map.get(r, 'black') for r in regimes[:len(segments)]]
legend = [
    Line2D([0], [0], color='green', lw=2, label='Bull'),
    Line2D([0], [0], color='red', lw=2, label='Bear'),
    Line2D([0], [0], color='black', lw=2, label='Neutral'),
    Line2D([0], [0], color='blue', lw=2, label='Uncertain')
]


# Plot Lineplot with date range from above/legend
fig, ax = plt.subplots(figsize=(12, 5))
lc = LineCollection(segments, colors=colors, linewidth=2)
ax.add_collection(lc)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(prices.min(), prices.max())
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=0)

ax.legend(handles=legend)
ax.set_title("Regime Shift Litecoin Prediction")
ax.set_xlabel("Date")
ax.set_ylabel("Price")

plt.grid(True)
plt.tight_layout()
plt.show()
